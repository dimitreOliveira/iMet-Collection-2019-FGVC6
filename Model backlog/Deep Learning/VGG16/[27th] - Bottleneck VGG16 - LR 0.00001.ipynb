# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.00001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 21s - loss: 0.0930 - acc: 0.9603 - categorical_accuracy: 0.0167 - f2_score: 0.0506 - f2_score_1: 0.0479 - f2_score_2: 0.0447 - f2_score_3: 0.0412 - f2_score_4: 0.0392 - f2_score_5: 0.0378 - f2_score_6: 0.0314 - f2_score_7: 0.0259 - val_loss: 0.0165 - val_acc: 0.9971 - val_categorical_accuracy: 0.0134 - val_f2_score: 0.0513 - val_f2_score_1: 0.0247 - val_f2_score_2: 0.0045 - val_f2_score_3: 2.0553e-04 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 2/200
#  - 18s - loss: 0.0195 - acc: 0.9967 - categorical_accuracy: 0.0431 - f2_score: 0.1130 - f2_score_1: 0.0974 - f2_score_2: 0.0830 - f2_score_3: 0.0705 - f2_score_4: 0.0636 - f2_score_5: 0.0595 - f2_score_6: 0.0419 - f2_score_7: 0.0290 - val_loss: 0.0147 - val_acc: 0.9971 - val_categorical_accuracy: 0.0680 - val_f2_score: 0.1146 - val_f2_score_1: 0.0696 - val_f2_score_2: 0.0442 - val_f2_score_3: 0.0264 - val_f2_score_4: 0.0181 - val_f2_score_5: 0.0132 - val_f2_score_6: 0.0015 - val_f2_score_7: 1.0903e-05
# Epoch 3/200
#  - 18s - loss: 0.0169 - acc: 0.9969 - categorical_accuracy: 0.0642 - f2_score: 0.1561 - f2_score_1: 0.1315 - f2_score_2: 0.1091 - f2_score_3: 0.0900 - f2_score_4: 0.0805 - f2_score_5: 0.0744 - f2_score_6: 0.0504 - f2_score_7: 0.0334 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0989 - val_f2_score: 0.1769 - val_f2_score_1: 0.1210 - val_f2_score_2: 0.0822 - val_f2_score_3: 0.0574 - val_f2_score_4: 0.0452 - val_f2_score_5: 0.0384 - val_f2_score_6: 0.0149 - val_f2_score_7: 0.0038
# Epoch 4/200
#  - 18s - loss: 0.0157 - acc: 0.9970 - categorical_accuracy: 0.0807 - f2_score: 0.1908 - f2_score_1: 0.1611 - f2_score_2: 0.1337 - f2_score_3: 0.1101 - f2_score_4: 0.0983 - f2_score_5: 0.0911 - f2_score_6: 0.0607 - f2_score_7: 0.0399 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.1166 - val_f2_score: 0.2122 - val_f2_score_1: 0.1498 - val_f2_score_2: 0.1075 - val_f2_score_3: 0.0787 - val_f2_score_4: 0.0650 - val_f2_score_5: 0.0575 - val_f2_score_6: 0.0279 - val_f2_score_7: 0.0118
# Epoch 5/200
#  - 18s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0953 - f2_score: 0.2179 - f2_score_1: 0.1840 - f2_score_2: 0.1536 - f2_score_3: 0.1267 - f2_score_4: 0.1131 - f2_score_5: 0.1050 - f2_score_6: 0.0707 - f2_score_7: 0.0468 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1251 - val_f2_score: 0.2539 - val_f2_score_1: 0.1902 - val_f2_score_2: 0.1441 - val_f2_score_3: 0.1093 - val_f2_score_4: 0.0935 - val_f2_score_5: 0.0844 - val_f2_score_6: 0.0494 - val_f2_score_7: 0.0273
# Epoch 6/200
#  - 18s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.1058 - f2_score: 0.2401 - f2_score_1: 0.2046 - f2_score_2: 0.1713 - f2_score_3: 0.1426 - f2_score_4: 0.1273 - f2_score_5: 0.1183 - f2_score_6: 0.0803 - f2_score_7: 0.0534 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1258 - val_f2_score: 0.2727 - val_f2_score_1: 0.2127 - val_f2_score_2: 0.1642 - val_f2_score_3: 0.1285 - val_f2_score_4: 0.1114 - val_f2_score_5: 0.1015 - val_f2_score_6: 0.0628 - val_f2_score_7: 0.0371
# Epoch 7/200
#  - 18s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1164 - f2_score: 0.2584 - f2_score_1: 0.2218 - f2_score_2: 0.1871 - f2_score_3: 0.1567 - f2_score_4: 0.1405 - f2_score_5: 0.1306 - f2_score_6: 0.0902 - f2_score_7: 0.0610 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1375 - val_f2_score: 0.2977 - val_f2_score_1: 0.2431 - val_f2_score_2: 0.1936 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.1360 - val_f2_score_5: 0.1248 - val_f2_score_6: 0.0810 - val_f2_score_7: 0.0519
# Epoch 8/200
#  - 18s - loss: 0.0135 - acc: 0.9971 - categorical_accuracy: 0.1248 - f2_score: 0.2734 - f2_score_1: 0.2366 - f2_score_2: 0.2004 - f2_score_3: 0.1689 - f2_score_4: 0.1523 - f2_score_5: 0.1419 - f2_score_6: 0.0999 - f2_score_7: 0.0689 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1453 - val_f2_score: 0.3081 - val_f2_score_1: 0.2539 - val_f2_score_2: 0.2054 - val_f2_score_3: 0.1654 - val_f2_score_4: 0.1454 - val_f2_score_5: 0.1344 - val_f2_score_6: 0.0906 - val_f2_score_7: 0.0604
# Epoch 9/200
#  - 18s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1301 - f2_score: 0.2864 - f2_score_1: 0.2500 - f2_score_2: 0.2134 - f2_score_3: 0.1804 - f2_score_4: 0.1630 - f2_score_5: 0.1529 - f2_score_6: 0.1082 - f2_score_7: 0.0755 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1464 - val_f2_score: 0.3222 - val_f2_score_1: 0.2714 - val_f2_score_2: 0.2231 - val_f2_score_3: 0.1838 - val_f2_score_4: 0.1623 - val_f2_score_5: 0.1498 - val_f2_score_6: 0.1027 - val_f2_score_7: 0.0709
# Epoch 10/200
#  - 18s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1374 - f2_score: 0.2986 - f2_score_1: 0.2624 - f2_score_2: 0.2250 - f2_score_3: 0.1913 - f2_score_4: 0.1733 - f2_score_5: 0.1620 - f2_score_6: 0.1154 - f2_score_7: 0.0808 - val_loss: 0.0119 - val_acc: 0.9973 - val_categorical_accuracy: 0.1558 - val_f2_score: 0.3338 - val_f2_score_1: 0.2890 - val_f2_score_2: 0.2438 - val_f2_score_3: 0.2028 - val_f2_score_4: 0.1812 - val_f2_score_5: 0.1681 - val_f2_score_6: 0.1158 - val_f2_score_7: 0.0805
# Epoch 11/200
#  - 18s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1435 - f2_score: 0.3075 - f2_score_1: 0.2724 - f2_score_2: 0.2352 - f2_score_3: 0.2007 - f2_score_4: 0.1824 - f2_score_5: 0.1709 - f2_score_6: 0.1228 - f2_score_7: 0.0870 - val_loss: 0.0118 - val_acc: 0.9973 - val_categorical_accuracy: 0.1551 - val_f2_score: 0.3433 - val_f2_score_1: 0.2998 - val_f2_score_2: 0.2548 - val_f2_score_3: 0.2140 - val_f2_score_4: 0.1922 - val_f2_score_5: 0.1787 - val_f2_score_6: 0.1248 - val_f2_score_7: 0.0882
# Epoch 12/200
#  - 18s - loss: 0.0125 - acc: 0.9972 - categorical_accuracy: 0.1482 - f2_score: 0.3163 - f2_score_1: 0.2804 - f2_score_2: 0.2431 - f2_score_3: 0.2088 - f2_score_4: 0.1908 - f2_score_5: 0.1793 - f2_score_6: 0.1306 - f2_score_7: 0.0933 - val_loss: 0.0117 - val_acc: 0.9973 - val_categorical_accuracy: 0.1557 - val_f2_score: 0.3504 - val_f2_score_1: 0.3084 - val_f2_score_2: 0.2648 - val_f2_score_3: 0.2244 - val_f2_score_4: 0.2021 - val_f2_score_5: 0.1893 - val_f2_score_6: 0.1350 - val_f2_score_7: 0.0972
# Epoch 13/200
#  - 18s - loss: 0.0124 - acc: 0.9972 - categorical_accuracy: 0.1516 - f2_score: 0.3246 - f2_score_1: 0.2890 - f2_score_2: 0.2513 - f2_score_3: 0.2166 - f2_score_4: 0.1980 - f2_score_5: 0.1861 - f2_score_6: 0.1358 - f2_score_7: 0.0984 - val_loss: 0.0116 - val_acc: 0.9973 - val_categorical_accuracy: 0.1626 - val_f2_score: 0.3580 - val_f2_score_1: 0.3184 - val_f2_score_2: 0.2746 - val_f2_score_3: 0.2364 - val_f2_score_4: 0.2133 - val_f2_score_5: 0.2002 - val_f2_score_6: 0.1433 - val_f2_score_7: 0.1033
# Epoch 14/200
#  - 18s - loss: 0.0122 - acc: 0.9972 - categorical_accuracy: 0.1563 - f2_score: 0.3305 - f2_score_1: 0.2962 - f2_score_2: 0.2588 - f2_score_3: 0.2240 - f2_score_4: 0.2047 - f2_score_5: 0.1926 - f2_score_6: 0.1421 - f2_score_7: 0.1033 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1599 - val_f2_score: 0.3637 - val_f2_score_1: 0.3263 - val_f2_score_2: 0.2837 - val_f2_score_3: 0.2459 - val_f2_score_4: 0.2249 - val_f2_score_5: 0.2103 - val_f2_score_6: 0.1521 - val_f2_score_7: 0.1099
# Epoch 15/200
#  - 18s - loss: 0.0121 - acc: 0.9972 - categorical_accuracy: 0.1596 - f2_score: 0.3369 - f2_score_1: 0.3028 - f2_score_2: 0.2656 - f2_score_3: 0.2303 - f2_score_4: 0.2115 - f2_score_5: 0.1995 - f2_score_6: 0.1482 - f2_score_7: 0.1082 - val_loss: 0.0114 - val_acc: 0.9973 - val_categorical_accuracy: 0.1609 - val_f2_score: 0.3687 - val_f2_score_1: 0.3301 - val_f2_score_2: 0.2888 - val_f2_score_3: 0.2504 - val_f2_score_4: 0.2291 - val_f2_score_5: 0.2159 - val_f2_score_6: 0.1575 - val_f2_score_7: 0.1152
# Epoch 16/200
#  - 18s - loss: 0.0120 - acc: 0.9972 - categorical_accuracy: 0.1634 - f2_score: 0.3435 - f2_score_1: 0.3089 - f2_score_2: 0.2721 - f2_score_3: 0.2372 - f2_score_4: 0.2172 - f2_score_5: 0.2053 - f2_score_6: 0.1529 - f2_score_7: 0.1122 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1655 - val_f2_score: 0.3756 - val_f2_score_1: 0.3414 - val_f2_score_2: 0.3024 - val_f2_score_3: 0.2661 - val_f2_score_4: 0.2455 - val_f2_score_5: 0.2331 - val_f2_score_6: 0.1732 - val_f2_score_7: 0.1271
# Epoch 17/200
#  - 18s - loss: 0.0119 - acc: 0.9973 - categorical_accuracy: 0.1670 - f2_score: 0.3494 - f2_score_1: 0.3155 - f2_score_2: 0.2787 - f2_score_3: 0.2432 - f2_score_4: 0.2241 - f2_score_5: 0.2112 - f2_score_6: 0.1576 - f2_score_7: 0.1166 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1703 - val_f2_score: 0.3793 - val_f2_score_1: 0.3457 - val_f2_score_2: 0.3061 - val_f2_score_3: 0.2686 - val_f2_score_4: 0.2488 - val_f2_score_5: 0.2353 - val_f2_score_6: 0.1761 - val_f2_score_7: 0.1310
# Epoch 18/200
#  - 18s - loss: 0.0118 - acc: 0.9973 - categorical_accuracy: 0.1703 - f2_score: 0.3532 - f2_score_1: 0.3211 - f2_score_2: 0.2836 - f2_score_3: 0.2479 - f2_score_4: 0.2279 - f2_score_5: 0.2156 - f2_score_6: 0.1626 - f2_score_7: 0.1208 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1666 - val_f2_score: 0.3820 - val_f2_score_1: 0.3502 - val_f2_score_2: 0.3126 - val_f2_score_3: 0.2755 - val_f2_score_4: 0.2551 - val_f2_score_5: 0.2415 - val_f2_score_6: 0.1822 - val_f2_score_7: 0.1356
# Epoch 19/200
#  - 18s - loss: 0.0117 - acc: 0.9973 - categorical_accuracy: 0.1728 - f2_score: 0.3579 - f2_score_1: 0.3248 - f2_score_2: 0.2884 - f2_score_3: 0.2531 - f2_score_4: 0.2336 - f2_score_5: 0.2214 - f2_score_6: 0.1673 - f2_score_7: 0.1251 - val_loss: 0.0111 - val_acc: 0.9973 - val_categorical_accuracy: 0.1749 - val_f2_score: 0.3861 - val_f2_score_1: 0.3545 - val_f2_score_2: 0.3176 - val_f2_score_3: 0.2811 - val_f2_score_4: 0.2605 - val_f2_score_5: 0.2472 - val_f2_score_6: 0.1852 - val_f2_score_7: 0.1388
# Epoch 20/200
#  - 18s - loss: 0.0116 - acc: 0.9973 - categorical_accuracy: 0.1760 - f2_score: 0.3625 - f2_score_1: 0.3299 - f2_score_2: 0.2936 - f2_score_3: 0.2579 - f2_score_4: 0.2385 - f2_score_5: 0.2260 - f2_score_6: 0.1705 - f2_score_7: 0.1271 - val_loss: 0.0111 - val_acc: 0.9973 - val_categorical_accuracy: 0.1800 - val_f2_score: 0.3887 - val_f2_score_1: 0.3564 - val_f2_score_2: 0.3191 - val_f2_score_3: 0.2810 - val_f2_score_4: 0.2603 - val_f2_score_5: 0.2476 - val_f2_score_6: 0.1876 - val_f2_score_7: 0.1414
# Epoch 21/200
#  - 18s - loss: 0.0115 - acc: 0.9973 - categorical_accuracy: 0.1780 - f2_score: 0.3670 - f2_score_1: 0.3349 - f2_score_2: 0.2982 - f2_score_3: 0.2623 - f2_score_4: 0.2427 - f2_score_5: 0.2303 - f2_score_6: 0.1756 - f2_score_7: 0.1312 - val_loss: 0.0110 - val_acc: 0.9973 - val_categorical_accuracy: 0.1731 - val_f2_score: 0.3924 - val_f2_score_1: 0.3639 - val_f2_score_2: 0.3274 - val_f2_score_3: 0.2920 - val_f2_score_4: 0.2709 - val_f2_score_5: 0.2581 - val_f2_score_6: 0.1980 - val_f2_score_7: 0.1494
# Epoch 22/200
#  - 18s - loss: 0.0114 - acc: 0.9973 - categorical_accuracy: 0.1812 - f2_score: 0.3712 - f2_score_1: 0.3390 - f2_score_2: 0.3030 - f2_score_3: 0.2675 - f2_score_4: 0.2471 - f2_score_5: 0.2342 - f2_score_6: 0.1793 - f2_score_7: 0.1344 - val_loss: 0.0110 - val_acc: 0.9974 - val_categorical_accuracy: 0.1765 - val_f2_score: 0.3959 - val_f2_score_1: 0.3678 - val_f2_score_2: 0.3325 - val_f2_score_3: 0.2965 - val_f2_score_4: 0.2753 - val_f2_score_5: 0.2621 - val_f2_score_6: 0.2028 - val_f2_score_7: 0.1535
# Epoch 23/200
#  - 18s - loss: 0.0113 - acc: 0.9973 - categorical_accuracy: 0.1832 - f2_score: 0.3745 - f2_score_1: 0.3429 - f2_score_2: 0.3064 - f2_score_3: 0.2709 - f2_score_4: 0.2511 - f2_score_5: 0.2388 - f2_score_6: 0.1843 - f2_score_7: 0.1392 - val_loss: 0.0109 - val_acc: 0.9974 - val_categorical_accuracy: 0.1785 - val_f2_score: 0.3967 - val_f2_score_1: 0.3666 - val_f2_score_2: 0.3300 - val_f2_score_3: 0.2946 - val_f2_score_4: 0.2745 - val_f2_score_5: 0.2620 - val_f2_score_6: 0.2018 - val_f2_score_7: 0.1540
# Epoch 24/200
#  - 18s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1881 - f2_score: 0.3783 - f2_score_1: 0.3480 - f2_score_2: 0.3114 - f2_score_3: 0.2760 - f2_score_4: 0.2559 - f2_score_5: 0.2428 - f2_score_6: 0.1862 - f2_score_7: 0.1407 - val_loss: 0.0109 - val_acc: 0.9974 - val_categorical_accuracy: 0.1753 - val_f2_score: 0.3982 - val_f2_score_1: 0.3699 - val_f2_score_2: 0.3367 - val_f2_score_3: 0.3019 - val_f2_score_4: 0.2814 - val_f2_score_5: 0.2685 - val_f2_score_6: 0.2096 - val_f2_score_7: 0.1606
# Epoch 25/200
#  - 18s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1905 - f2_score: 0.3826 - f2_score_1: 0.3515 - f2_score_2: 0.3153 - f2_score_3: 0.2798 - f2_score_4: 0.2602 - f2_score_5: 0.2474 - f2_score_6: 0.1901 - f2_score_7: 0.1440 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1831 - val_f2_score: 0.4017 - val_f2_score_1: 0.3740 - val_f2_score_2: 0.3389 - val_f2_score_3: 0.3045 - val_f2_score_4: 0.2841 - val_f2_score_5: 0.2716 - val_f2_score_6: 0.2133 - val_f2_score_7: 0.1633
# Epoch 26/200
#  - 18s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1918 - f2_score: 0.3852 - f2_score_1: 0.3548 - f2_score_2: 0.3188 - f2_score_3: 0.2824 - f2_score_4: 0.2628 - f2_score_5: 0.2501 - f2_score_6: 0.1931 - f2_score_7: 0.1468 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1774 - val_f2_score: 0.4037 - val_f2_score_1: 0.3771 - val_f2_score_2: 0.3442 - val_f2_score_3: 0.3097 - val_f2_score_4: 0.2899 - val_f2_score_5: 0.2764 - val_f2_score_6: 0.2173 - val_f2_score_7: 0.1673
# Epoch 27/200
#  - 18s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1949 - f2_score: 0.3883 - f2_score_1: 0.3581 - f2_score_2: 0.3220 - f2_score_3: 0.2876 - f2_score_4: 0.2674 - f2_score_5: 0.2543 - f2_score_6: 0.1977 - f2_score_7: 0.1505 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1827 - val_f2_score: 0.4061 - val_f2_score_1: 0.3825 - val_f2_score_2: 0.3504 - val_f2_score_3: 0.3167 - val_f2_score_4: 0.2971 - val_f2_score_5: 0.2841 - val_f2_score_6: 0.2242 - val_f2_score_7: 0.1726
# Epoch 28/200
#  - 18s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1979 - f2_score: 0.3918 - f2_score_1: 0.3622 - f2_score_2: 0.3265 - f2_score_3: 0.2898 - f2_score_4: 0.2697 - f2_score_5: 0.2567 - f2_score_6: 0.1992 - f2_score_7: 0.1524 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1889 - val_f2_score: 0.4089 - val_f2_score_1: 0.3827 - val_f2_score_2: 0.3496 - val_f2_score_3: 0.3148 - val_f2_score_4: 0.2949 - val_f2_score_5: 0.2825 - val_f2_score_6: 0.2218 - val_f2_score_7: 0.1710
# Epoch 29/200
#  - 18s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.2017 - f2_score: 0.3952 - f2_score_1: 0.3650 - f2_score_2: 0.3293 - f2_score_3: 0.2946 - f2_score_4: 0.2743 - f2_score_5: 0.2614 - f2_score_6: 0.2025 - f2_score_7: 0.1553 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1939 - val_f2_score: 0.4097 - val_f2_score_1: 0.3837 - val_f2_score_2: 0.3501 - val_f2_score_3: 0.3159 - val_f2_score_4: 0.2958 - val_f2_score_5: 0.2835 - val_f2_score_6: 0.2228 - val_f2_score_7: 0.1728
# Epoch 30/200
#  - 18s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.2024 - f2_score: 0.3974 - f2_score_1: 0.3680 - f2_score_2: 0.3331 - f2_score_3: 0.2977 - f2_score_4: 0.2778 - f2_score_5: 0.2652 - f2_score_6: 0.2062 - f2_score_7: 0.1579 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1944 - val_f2_score: 0.4127 - val_f2_score_1: 0.3868 - val_f2_score_2: 0.3531 - val_f2_score_3: 0.3189 - val_f2_score_4: 0.2987 - val_f2_score_5: 0.2857 - val_f2_score_6: 0.2256 - val_f2_score_7: 0.1748
# Epoch 31/200
#  - 18s - loss: 0.0108 - acc: 0.9974 - categorical_accuracy: 0.2064 - f2_score: 0.4009 - f2_score_1: 0.3715 - f2_score_2: 0.3359 - f2_score_3: 0.3007 - f2_score_4: 0.2803 - f2_score_5: 0.2669 - f2_score_6: 0.2085 - f2_score_7: 0.1609 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1948 - val_f2_score: 0.4133 - val_f2_score_1: 0.3894 - val_f2_score_2: 0.3574 - val_f2_score_3: 0.3240 - val_f2_score_4: 0.3034 - val_f2_score_5: 0.2914 - val_f2_score_6: 0.2324 - val_f2_score_7: 0.1806
# Epoch 32/200
#  - 18s - loss: 0.0108 - acc: 0.9974 - categorical_accuracy: 0.2082 - f2_score: 0.4035 - f2_score_1: 0.3749 - f2_score_2: 0.3394 - f2_score_3: 0.3041 - f2_score_4: 0.2838 - f2_score_5: 0.2712 - f2_score_6: 0.2123 - f2_score_7: 0.1639 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1922 - val_f2_score: 0.4151 - val_f2_score_1: 0.3908 - val_f2_score_2: 0.3597 - val_f2_score_3: 0.3260 - val_f2_score_4: 0.3064 - val_f2_score_5: 0.2945 - val_f2_score_6: 0.2364 - val_f2_score_7: 0.1835
# Epoch 33/200
#  - 18s - loss: 0.0107 - acc: 0.9974 - categorical_accuracy: 0.2107 - f2_score: 0.4064 - f2_score_1: 0.3779 - f2_score_2: 0.3423 - f2_score_3: 0.3067 - f2_score_4: 0.2866 - f2_score_5: 0.2738 - f2_score_6: 0.2150 - f2_score_7: 0.1668 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.2000 - val_f2_score: 0.4171 - val_f2_score_1: 0.3939 - val_f2_score_2: 0.3615 - val_f2_score_3: 0.3295 - val_f2_score_4: 0.3085 - val_f2_score_5: 0.2958 - val_f2_score_6: 0.2370 - val_f2_score_7: 0.1840
# Epoch 34/200
#  - 18s - loss: 0.0106 - acc: 0.9974 - categorical_accuracy: 0.2127 - f2_score: 0.4089 - f2_score_1: 0.3812 - f2_score_2: 0.3462 - f2_score_3: 0.3104 - f2_score_4: 0.2900 - f2_score_5: 0.2764 - f2_score_6: 0.2171 - f2_score_7: 0.1685 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.2011 - val_f2_score: 0.4189 - val_f2_score_1: 0.3969 - val_f2_score_2: 0.3665 - val_f2_score_3: 0.3345 - val_f2_score_4: 0.3144 - val_f2_score_5: 0.3012 - val_f2_score_6: 0.2433 - val_f2_score_7: 0.1895
# Epoch 35/200
#  - 18s - loss: 0.0106 - acc: 0.9974 - categorical_accuracy: 0.2148 - f2_score: 0.4117 - f2_score_1: 0.3825 - f2_score_2: 0.3479 - f2_score_3: 0.3136 - f2_score_4: 0.2931 - f2_score_5: 0.2801 - f2_score_6: 0.2213 - f2_score_7: 0.1723 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1978 - val_f2_score: 0.4196 - val_f2_score_1: 0.3989 - val_f2_score_2: 0.3697 - val_f2_score_3: 0.3360 - val_f2_score_4: 0.3173 - val_f2_score_5: 0.3035 - val_f2_score_6: 0.2443 - val_f2_score_7: 0.1927
# Epoch 36/200
#  - 18s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.2161 - f2_score: 0.4140 - f2_score_1: 0.3858 - f2_score_2: 0.3517 - f2_score_3: 0.3163 - f2_score_4: 0.2961 - f2_score_5: 0.2831 - f2_score_6: 0.2236 - f2_score_7: 0.1735 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.2005 - val_f2_score: 0.4209 - val_f2_score_1: 0.3989 - val_f2_score_2: 0.3690 - val_f2_score_3: 0.3367 - val_f2_score_4: 0.3177 - val_f2_score_5: 0.3049 - val_f2_score_6: 0.2470 - val_f2_score_7: 0.1943
# Epoch 37/200
#  - 18s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.2199 - f2_score: 0.4164 - f2_score_1: 0.3894 - f2_score_2: 0.3551 - f2_score_3: 0.3201 - f2_score_4: 0.2993 - f2_score_5: 0.2867 - f2_score_6: 0.2266 - f2_score_7: 0.1765 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.2055 - val_f2_score: 0.4213 - val_f2_score_1: 0.3976 - val_f2_score_2: 0.3674 - val_f2_score_3: 0.3346 - val_f2_score_4: 0.3152 - val_f2_score_5: 0.3023 - val_f2_score_6: 0.2434 - val_f2_score_7: 0.1932
# Epoch 38/200
#  - 18s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.2218 - f2_score: 0.4194 - f2_score_1: 0.3922 - f2_score_2: 0.3581 - f2_score_3: 0.3221 - f2_score_4: 0.3012 - f2_score_5: 0.2886 - f2_score_6: 0.2290 - f2_score_7: 0.1792 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.1996 - val_f2_score: 0.4242 - val_f2_score_1: 0.4043 - val_f2_score_2: 0.3749 - val_f2_score_3: 0.3431 - val_f2_score_4: 0.3245 - val_f2_score_5: 0.3116 - val_f2_score_6: 0.2541 - val_f2_score_7: 0.2012
# Epoch 39/200
#  - 18s - loss: 0.0104 - acc: 0.9974 - categorical_accuracy: 0.2240 - f2_score: 0.4224 - f2_score_1: 0.3951 - f2_score_2: 0.3602 - f2_score_3: 0.3248 - f2_score_4: 0.3041 - f2_score_5: 0.2916 - f2_score_6: 0.2320 - f2_score_7: 0.1818 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2076 - val_f2_score: 0.4257 - val_f2_score_1: 0.4028 - val_f2_score_2: 0.3731 - val_f2_score_3: 0.3404 - val_f2_score_4: 0.3213 - val_f2_score_5: 0.3088 - val_f2_score_6: 0.2511 - val_f2_score_7: 0.1990
# Epoch 40/200
#  - 18s - loss: 0.0104 - acc: 0.9974 - categorical_accuracy: 0.2277 - f2_score: 0.4234 - f2_score_1: 0.3961 - f2_score_2: 0.3625 - f2_score_3: 0.3274 - f2_score_4: 0.3077 - f2_score_5: 0.2944 - f2_score_6: 0.2347 - f2_score_7: 0.1846 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2094 - val_f2_score: 0.4258 - val_f2_score_1: 0.4033 - val_f2_score_2: 0.3736 - val_f2_score_3: 0.3412 - val_f2_score_4: 0.3229 - val_f2_score_5: 0.3107 - val_f2_score_6: 0.2527 - val_f2_score_7: 0.2011
# Epoch 41/200
#  - 18s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.2300 - f2_score: 0.4262 - f2_score_1: 0.4003 - f2_score_2: 0.3656 - f2_score_3: 0.3312 - f2_score_4: 0.3110 - f2_score_5: 0.2977 - f2_score_6: 0.2374 - f2_score_7: 0.1869 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2069 - val_f2_score: 0.4271 - val_f2_score_1: 0.4056 - val_f2_score_2: 0.3771 - val_f2_score_3: 0.3453 - val_f2_score_4: 0.3252 - val_f2_score_5: 0.3132 - val_f2_score_6: 0.2550 - val_f2_score_7: 0.2040
# Epoch 42/200
#  - 18s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.2301 - f2_score: 0.4286 - f2_score_1: 0.4025 - f2_score_2: 0.3685 - f2_score_3: 0.3343 - f2_score_4: 0.3137 - f2_score_5: 0.3006 - f2_score_6: 0.2399 - f2_score_7: 0.1884 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2090 - val_f2_score: 0.4289 - val_f2_score_1: 0.4085 - val_f2_score_2: 0.3798 - val_f2_score_3: 0.3495 - val_f2_score_4: 0.3307 - val_f2_score_5: 0.3193 - val_f2_score_6: 0.2618 - val_f2_score_7: 0.2094
# Epoch 43/200
#  - 18s - loss: 0.0102 - acc: 0.9974 - categorical_accuracy: 0.2327 - f2_score: 0.4308 - f2_score_1: 0.4050 - f2_score_2: 0.3711 - f2_score_3: 0.3367 - f2_score_4: 0.3158 - f2_score_5: 0.3029 - f2_score_6: 0.2432 - f2_score_7: 0.1914 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2129 - val_f2_score: 0.4297 - val_f2_score_1: 0.4099 - val_f2_score_2: 0.3808 - val_f2_score_3: 0.3499 - val_f2_score_4: 0.3312 - val_f2_score_5: 0.3188 - val_f2_score_6: 0.2605 - val_f2_score_7: 0.2086
# Epoch 44/200
#  - 18s - loss: 0.0102 - acc: 0.9974 - categorical_accuracy: 0.2353 - f2_score: 0.4331 - f2_score_1: 0.4076 - f2_score_2: 0.3734 - f2_score_3: 0.3388 - f2_score_4: 0.3186 - f2_score_5: 0.3056 - f2_score_6: 0.2445 - f2_score_7: 0.1939 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2128 - val_f2_score: 0.4302 - val_f2_score_1: 0.4089 - val_f2_score_2: 0.3800 - val_f2_score_3: 0.3487 - val_f2_score_4: 0.3306 - val_f2_score_5: 0.3179 - val_f2_score_6: 0.2613 - val_f2_score_7: 0.2092
# Epoch 45/200
#  - 18s - loss: 0.0102 - acc: 0.9974 - categorical_accuracy: 0.2388 - f2_score: 0.4360 - f2_score_1: 0.4092 - f2_score_2: 0.3759 - f2_score_3: 0.3414 - f2_score_4: 0.3217 - f2_score_5: 0.3087 - f2_score_6: 0.2478 - f2_score_7: 0.1956 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2193 - val_f2_score: 0.4317 - val_f2_score_1: 0.4110 - val_f2_score_2: 0.3810 - val_f2_score_3: 0.3519 - val_f2_score_4: 0.3326 - val_f2_score_5: 0.3198 - val_f2_score_6: 0.2623 - val_f2_score_7: 0.2110
# Epoch 46/200
#  - 18s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2382 - f2_score: 0.4380 - f2_score_1: 0.4124 - f2_score_2: 0.3779 - f2_score_3: 0.3431 - f2_score_4: 0.3229 - f2_score_5: 0.3096 - f2_score_6: 0.2497 - f2_score_7: 0.1982 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2170 - val_f2_score: 0.4330 - val_f2_score_1: 0.4116 - val_f2_score_2: 0.3836 - val_f2_score_3: 0.3532 - val_f2_score_4: 0.3351 - val_f2_score_5: 0.3235 - val_f2_score_6: 0.2659 - val_f2_score_7: 0.2146
# Epoch 47/200
#  - 18s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2411 - f2_score: 0.4410 - f2_score_1: 0.4146 - f2_score_2: 0.3805 - f2_score_3: 0.3462 - f2_score_4: 0.3263 - f2_score_5: 0.3134 - f2_score_6: 0.2535 - f2_score_7: 0.2011 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2137 - val_f2_score: 0.4337 - val_f2_score_1: 0.4132 - val_f2_score_2: 0.3863 - val_f2_score_3: 0.3563 - val_f2_score_4: 0.3382 - val_f2_score_5: 0.3264 - val_f2_score_6: 0.2694 - val_f2_score_7: 0.2176
# Epoch 48/200
#  - 18s - loss: 0.0100 - acc: 0.9975 - categorical_accuracy: 0.2440 - f2_score: 0.4418 - f2_score_1: 0.4169 - f2_score_2: 0.3832 - f2_score_3: 0.3492 - f2_score_4: 0.3289 - f2_score_5: 0.3157 - f2_score_6: 0.2557 - f2_score_7: 0.2034 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2186 - val_f2_score: 0.4350 - val_f2_score_1: 0.4165 - val_f2_score_2: 0.3896 - val_f2_score_3: 0.3589 - val_f2_score_4: 0.3415 - val_f2_score_5: 0.3294 - val_f2_score_6: 0.2717 - val_f2_score_7: 0.2191
# Epoch 49/200
#  - 18s - loss: 0.0100 - acc: 0.9975 - categorical_accuracy: 0.2464 - f2_score: 0.4436 - f2_score_1: 0.4193 - f2_score_2: 0.3861 - f2_score_3: 0.3522 - f2_score_4: 0.3324 - f2_score_5: 0.3192 - f2_score_6: 0.2586 - f2_score_7: 0.2051 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2129 - val_f2_score: 0.4365 - val_f2_score_1: 0.4185 - val_f2_score_2: 0.3920 - val_f2_score_3: 0.3630 - val_f2_score_4: 0.3450 - val_f2_score_5: 0.3333 - val_f2_score_6: 0.2765 - val_f2_score_7: 0.2240
# Epoch 50/200
#  - 18s - loss: 0.0100 - acc: 0.9975 - categorical_accuracy: 0.2501 - f2_score: 0.4456 - f2_score_1: 0.4205 - f2_score_2: 0.3876 - f2_score_3: 0.3537 - f2_score_4: 0.3340 - f2_score_5: 0.3207 - f2_score_6: 0.2604 - f2_score_7: 0.2077 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2252 - val_f2_score: 0.4362 - val_f2_score_1: 0.4160 - val_f2_score_2: 0.3879 - val_f2_score_3: 0.3591 - val_f2_score_4: 0.3413 - val_f2_score_5: 0.3298 - val_f2_score_6: 0.2720 - val_f2_score_7: 0.2218
# Epoch 51/200
#  - 18s - loss: 0.0099 - acc: 0.9975 - categorical_accuracy: 0.2525 - f2_score: 0.4491 - f2_score_1: 0.4247 - f2_score_2: 0.3924 - f2_score_3: 0.3579 - f2_score_4: 0.3375 - f2_score_5: 0.3242 - f2_score_6: 0.2624 - f2_score_7: 0.2107 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2151 - val_f2_score: 0.4380 - val_f2_score_1: 0.4196 - val_f2_score_2: 0.3928 - val_f2_score_3: 0.3634 - val_f2_score_4: 0.3454 - val_f2_score_5: 0.3333 - val_f2_score_6: 0.2767 - val_f2_score_7: 0.2251
# Epoch 52/200
#  - 18s - loss: 0.0099 - acc: 0.9975 - categorical_accuracy: 0.2527 - f2_score: 0.4501 - f2_score_1: 0.4263 - f2_score_2: 0.3941 - f2_score_3: 0.3603 - f2_score_4: 0.3401 - f2_score_5: 0.3277 - f2_score_6: 0.2656 - f2_score_7: 0.2122 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2233 - val_f2_score: 0.4389 - val_f2_score_1: 0.4193 - val_f2_score_2: 0.3914 - val_f2_score_3: 0.3625 - val_f2_score_4: 0.3441 - val_f2_score_5: 0.3318 - val_f2_score_6: 0.2761 - val_f2_score_7: 0.2240
# Epoch 53/200
#  - 18s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2549 - f2_score: 0.4529 - f2_score_1: 0.4281 - f2_score_2: 0.3957 - f2_score_3: 0.3617 - f2_score_4: 0.3414 - f2_score_5: 0.3286 - f2_score_6: 0.2683 - f2_score_7: 0.2146 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2203 - val_f2_score: 0.4389 - val_f2_score_1: 0.4199 - val_f2_score_2: 0.3932 - val_f2_score_3: 0.3633 - val_f2_score_4: 0.3461 - val_f2_score_5: 0.3349 - val_f2_score_6: 0.2780 - val_f2_score_7: 0.2265
# Epoch 54/200
#  - 18s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2570 - f2_score: 0.4545 - f2_score_1: 0.4302 - f2_score_2: 0.3985 - f2_score_3: 0.3653 - f2_score_4: 0.3454 - f2_score_5: 0.3319 - f2_score_6: 0.2711 - f2_score_7: 0.2167 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2236 - val_f2_score: 0.4412 - val_f2_score_1: 0.4232 - val_f2_score_2: 0.3968 - val_f2_score_3: 0.3679 - val_f2_score_4: 0.3499 - val_f2_score_5: 0.3381 - val_f2_score_6: 0.2819 - val_f2_score_7: 0.2295
# Epoch 55/200
#  - 18s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2606 - f2_score: 0.4568 - f2_score_1: 0.4327 - f2_score_2: 0.4008 - f2_score_3: 0.3671 - f2_score_4: 0.3474 - f2_score_5: 0.3344 - f2_score_6: 0.2735 - f2_score_7: 0.2199 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2286 - val_f2_score: 0.4409 - val_f2_score_1: 0.4237 - val_f2_score_2: 0.3982 - val_f2_score_3: 0.3703 - val_f2_score_4: 0.3529 - val_f2_score_5: 0.3405 - val_f2_score_6: 0.2841 - val_f2_score_7: 0.2311
# Epoch 56/200
#  - 18s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2626 - f2_score: 0.4575 - f2_score_1: 0.4345 - f2_score_2: 0.4021 - f2_score_3: 0.3686 - f2_score_4: 0.3485 - f2_score_5: 0.3359 - f2_score_6: 0.2753 - f2_score_7: 0.2216 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2218 - val_f2_score: 0.4419 - val_f2_score_1: 0.4231 - val_f2_score_2: 0.3979 - val_f2_score_3: 0.3693 - val_f2_score_4: 0.3519 - val_f2_score_5: 0.3405 - val_f2_score_6: 0.2849 - val_f2_score_7: 0.2325
# Epoch 57/200
#  - 18s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2621 - f2_score: 0.4609 - f2_score_1: 0.4379 - f2_score_2: 0.4057 - f2_score_3: 0.3726 - f2_score_4: 0.3527 - f2_score_5: 0.3399 - f2_score_6: 0.2775 - f2_score_7: 0.2230 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2287 - val_f2_score: 0.4420 - val_f2_score_1: 0.4232 - val_f2_score_2: 0.3972 - val_f2_score_3: 0.3691 - val_f2_score_4: 0.3523 - val_f2_score_5: 0.3406 - val_f2_score_6: 0.2850 - val_f2_score_7: 0.2333
# Epoch 58/200
#  - 18s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2670 - f2_score: 0.4613 - f2_score_1: 0.4390 - f2_score_2: 0.4080 - f2_score_3: 0.3755 - f2_score_4: 0.3553 - f2_score_5: 0.3422 - f2_score_6: 0.2809 - f2_score_7: 0.2261 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2314 - val_f2_score: 0.4430 - val_f2_score_1: 0.4247 - val_f2_score_2: 0.3971 - val_f2_score_3: 0.3685 - val_f2_score_4: 0.3508 - val_f2_score_5: 0.3392 - val_f2_score_6: 0.2840 - val_f2_score_7: 0.2329
# Epoch 59/200
#  - 18s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2680 - f2_score: 0.4641 - f2_score_1: 0.4405 - f2_score_2: 0.4096 - f2_score_3: 0.3763 - f2_score_4: 0.3564 - f2_score_5: 0.3434 - f2_score_6: 0.2828 - f2_score_7: 0.2288 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2309 - val_f2_score: 0.4435 - val_f2_score_1: 0.4265 - val_f2_score_2: 0.3994 - val_f2_score_3: 0.3715 - val_f2_score_4: 0.3537 - val_f2_score_5: 0.3417 - val_f2_score_6: 0.2868 - val_f2_score_7: 0.2345
# Epoch 60/200
#  - 18s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2698 - f2_score: 0.4654 - f2_score_1: 0.4425 - f2_score_2: 0.4111 - f2_score_3: 0.3792 - f2_score_4: 0.3593 - f2_score_5: 0.3465 - f2_score_6: 0.2857 - f2_score_7: 0.2304 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2275 - val_f2_score: 0.4436 - val_f2_score_1: 0.4257 - val_f2_score_2: 0.3992 - val_f2_score_3: 0.3716 - val_f2_score_4: 0.3540 - val_f2_score_5: 0.3427 - val_f2_score_6: 0.2873 - val_f2_score_7: 0.2361
# Epoch 61/200
#  - 18s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2729 - f2_score: 0.4681 - f2_score_1: 0.4456 - f2_score_2: 0.4139 - f2_score_3: 0.3813 - f2_score_4: 0.3611 - f2_score_5: 0.3480 - f2_score_6: 0.2861 - f2_score_7: 0.2321 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2346 - val_f2_score: 0.4441 - val_f2_score_1: 0.4282 - val_f2_score_2: 0.4020 - val_f2_score_3: 0.3748 - val_f2_score_4: 0.3577 - val_f2_score_5: 0.3461 - val_f2_score_6: 0.2912 - val_f2_score_7: 0.2398
# Epoch 62/200
#  - 18s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2746 - f2_score: 0.4697 - f2_score_1: 0.4475 - f2_score_2: 0.4161 - f2_score_3: 0.3826 - f2_score_4: 0.3636 - f2_score_5: 0.3507 - f2_score_6: 0.2894 - f2_score_7: 0.2350 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2320 - val_f2_score: 0.4448 - val_f2_score_1: 0.4272 - val_f2_score_2: 0.4013 - val_f2_score_3: 0.3740 - val_f2_score_4: 0.3565 - val_f2_score_5: 0.3454 - val_f2_score_6: 0.2919 - val_f2_score_7: 0.2415
# Epoch 63/200
#  - 18s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2769 - f2_score: 0.4710 - f2_score_1: 0.4489 - f2_score_2: 0.4179 - f2_score_3: 0.3851 - f2_score_4: 0.3659 - f2_score_5: 0.3529 - f2_score_6: 0.2927 - f2_score_7: 0.2387 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2367 - val_f2_score: 0.4453 - val_f2_score_1: 0.4294 - val_f2_score_2: 0.4035 - val_f2_score_3: 0.3765 - val_f2_score_4: 0.3592 - val_f2_score_5: 0.3481 - val_f2_score_6: 0.2923 - val_f2_score_7: 0.2412
# Epoch 64/200
#  - 18s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2792 - f2_score: 0.4737 - f2_score_1: 0.4512 - f2_score_2: 0.4206 - f2_score_3: 0.3877 - f2_score_4: 0.3681 - f2_score_5: 0.3554 - f2_score_6: 0.2948 - f2_score_7: 0.2397 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2330 - val_f2_score: 0.4462 - val_f2_score_1: 0.4315 - val_f2_score_2: 0.4077 - val_f2_score_3: 0.3804 - val_f2_score_4: 0.3631 - val_f2_score_5: 0.3518 - val_f2_score_6: 0.2983 - val_f2_score_7: 0.2468
# Epoch 65/200
#  - 18s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2790 - f2_score: 0.4757 - f2_score_1: 0.4538 - f2_score_2: 0.4225 - f2_score_3: 0.3895 - f2_score_4: 0.3704 - f2_score_5: 0.3578 - f2_score_6: 0.2968 - f2_score_7: 0.2424 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2393 - val_f2_score: 0.4469 - val_f2_score_1: 0.4306 - val_f2_score_2: 0.4046 - val_f2_score_3: 0.3761 - val_f2_score_4: 0.3596 - val_f2_score_5: 0.3472 - val_f2_score_6: 0.2938 - val_f2_score_7: 0.2435
# Epoch 66/200
#  - 18s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2839 - f2_score: 0.4780 - f2_score_1: 0.4560 - f2_score_2: 0.4255 - f2_score_3: 0.3931 - f2_score_4: 0.3737 - f2_score_5: 0.3608 - f2_score_6: 0.2996 - f2_score_7: 0.2442 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2371 - val_f2_score: 0.4468 - val_f2_score_1: 0.4285 - val_f2_score_2: 0.4034 - val_f2_score_3: 0.3741 - val_f2_score_4: 0.3571 - val_f2_score_5: 0.3456 - val_f2_score_6: 0.2922 - val_f2_score_7: 0.2429
# Epoch 67/200
#  - 18s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2839 - f2_score: 0.4790 - f2_score_1: 0.4570 - f2_score_2: 0.4267 - f2_score_3: 0.3943 - f2_score_4: 0.3751 - f2_score_5: 0.3623 - f2_score_6: 0.3019 - f2_score_7: 0.2467 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2385 - val_f2_score: 0.4480 - val_f2_score_1: 0.4329 - val_f2_score_2: 0.4075 - val_f2_score_3: 0.3801 - val_f2_score_4: 0.3643 - val_f2_score_5: 0.3525 - val_f2_score_6: 0.2985 - val_f2_score_7: 0.2484
# Epoch 68/200
#  - 18s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2884 - f2_score: 0.4811 - f2_score_1: 0.4599 - f2_score_2: 0.4296 - f2_score_3: 0.3967 - f2_score_4: 0.3774 - f2_score_5: 0.3646 - f2_score_6: 0.3038 - f2_score_7: 0.2488 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2373 - val_f2_score: 0.4487 - val_f2_score_1: 0.4335 - val_f2_score_2: 0.4088 - val_f2_score_3: 0.3823 - val_f2_score_4: 0.3652 - val_f2_score_5: 0.3543 - val_f2_score_6: 0.3002 - val_f2_score_7: 0.2501
# Epoch 69/200
#  - 18s - loss: 0.0093 - acc: 0.9976 - categorical_accuracy: 0.2894 - f2_score: 0.4826 - f2_score_1: 0.4607 - f2_score_2: 0.4306 - f2_score_3: 0.3982 - f2_score_4: 0.3787 - f2_score_5: 0.3659 - f2_score_6: 0.3048 - f2_score_7: 0.2501 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2356 - val_f2_score: 0.4485 - val_f2_score_1: 0.4319 - val_f2_score_2: 0.4071 - val_f2_score_3: 0.3800 - val_f2_score_4: 0.3635 - val_f2_score_5: 0.3520 - val_f2_score_6: 0.2993 - val_f2_score_7: 0.2502
# Epoch 70/200
#  - 18s - loss: 0.0093 - acc: 0.9976 - categorical_accuracy: 0.2916 - f2_score: 0.4847 - f2_score_1: 0.4634 - f2_score_2: 0.4330 - f2_score_3: 0.4015 - f2_score_4: 0.3825 - f2_score_5: 0.3692 - f2_score_6: 0.3090 - f2_score_7: 0.2529 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2443 - val_f2_score: 0.4497 - val_f2_score_1: 0.4333 - val_f2_score_2: 0.4075 - val_f2_score_3: 0.3800 - val_f2_score_4: 0.3631 - val_f2_score_5: 0.3519 - val_f2_score_6: 0.2980 - val_f2_score_7: 0.2485
# Epoch 71/200
#  - 18s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.2935 - f2_score: 0.4860 - f2_score_1: 0.4653 - f2_score_2: 0.4355 - f2_score_3: 0.4029 - f2_score_4: 0.3836 - f2_score_5: 0.3707 - f2_score_6: 0.3106 - f2_score_7: 0.2548 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2408 - val_f2_score: 0.4497 - val_f2_score_1: 0.4335 - val_f2_score_2: 0.4083 - val_f2_score_3: 0.3801 - val_f2_score_4: 0.3631 - val_f2_score_5: 0.3518 - val_f2_score_6: 0.2995 - val_f2_score_7: 0.2496
# Epoch 72/200
#  - 18s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.2973 - f2_score: 0.4877 - f2_score_1: 0.4672 - f2_score_2: 0.4372 - f2_score_3: 0.4052 - f2_score_4: 0.3862 - f2_score_5: 0.3736 - f2_score_6: 0.3136 - f2_score_7: 0.2582 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2453 - val_f2_score: 0.4498 - val_f2_score_1: 0.4327 - val_f2_score_2: 0.4062 - val_f2_score_3: 0.3783 - val_f2_score_4: 0.3619 - val_f2_score_5: 0.3506 - val_f2_score_6: 0.2979 - val_f2_score_7: 0.2478
# Epoch 73/200
#  - 18s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.2993 - f2_score: 0.4900 - f2_score_1: 0.4695 - f2_score_2: 0.4396 - f2_score_3: 0.4077 - f2_score_4: 0.3889 - f2_score_5: 0.3761 - f2_score_6: 0.3160 - f2_score_7: 0.2601 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2458 - val_f2_score: 0.4508 - val_f2_score_1: 0.4354 - val_f2_score_2: 0.4101 - val_f2_score_3: 0.3829 - val_f2_score_4: 0.3669 - val_f2_score_5: 0.3564 - val_f2_score_6: 0.3040 - val_f2_score_7: 0.2559
# Epoch 74/200
#  - 18s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.3004 - f2_score: 0.4921 - f2_score_1: 0.4713 - f2_score_2: 0.4410 - f2_score_3: 0.4094 - f2_score_4: 0.3904 - f2_score_5: 0.3777 - f2_score_6: 0.3177 - f2_score_7: 0.2626 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2429 - val_f2_score: 0.4512 - val_f2_score_1: 0.4369 - val_f2_score_2: 0.4122 - val_f2_score_3: 0.3859 - val_f2_score_4: 0.3695 - val_f2_score_5: 0.3590 - val_f2_score_6: 0.3064 - val_f2_score_7: 0.2570
# Epoch 75/200
#  - 18s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.3030 - f2_score: 0.4937 - f2_score_1: 0.4735 - f2_score_2: 0.4431 - f2_score_3: 0.4116 - f2_score_4: 0.3928 - f2_score_5: 0.3800 - f2_score_6: 0.3201 - f2_score_7: 0.2645 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2436 - val_f2_score: 0.4515 - val_f2_score_1: 0.4368 - val_f2_score_2: 0.4123 - val_f2_score_3: 0.3858 - val_f2_score_4: 0.3696 - val_f2_score_5: 0.3590 - val_f2_score_6: 0.3053 - val_f2_score_7: 0.2568
# Epoch 76/200
#  - 18s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.3052 - f2_score: 0.4951 - f2_score_1: 0.4749 - f2_score_2: 0.4457 - f2_score_3: 0.4143 - f2_score_4: 0.3950 - f2_score_5: 0.3824 - f2_score_6: 0.3229 - f2_score_7: 0.2672 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2471 - val_f2_score: 0.4518 - val_f2_score_1: 0.4348 - val_f2_score_2: 0.4098 - val_f2_score_3: 0.3822 - val_f2_score_4: 0.3654 - val_f2_score_5: 0.3542 - val_f2_score_6: 0.3024 - val_f2_score_7: 0.2537
# Epoch 77/200
#  - 18s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.3061 - f2_score: 0.4968 - f2_score_1: 0.4768 - f2_score_2: 0.4475 - f2_score_3: 0.4161 - f2_score_4: 0.3978 - f2_score_5: 0.3855 - f2_score_6: 0.3249 - f2_score_7: 0.2689 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2408 - val_f2_score: 0.4516 - val_f2_score_1: 0.4364 - val_f2_score_2: 0.4115 - val_f2_score_3: 0.3869 - val_f2_score_4: 0.3709 - val_f2_score_5: 0.3595 - val_f2_score_6: 0.3086 - val_f2_score_7: 0.2605
# Epoch 78/200
#  - 18s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.3068 - f2_score: 0.4989 - f2_score_1: 0.4790 - f2_score_2: 0.4495 - f2_score_3: 0.4181 - f2_score_4: 0.3993 - f2_score_5: 0.3867 - f2_score_6: 0.3264 - f2_score_7: 0.2702 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2391 - val_f2_score: 0.4526 - val_f2_score_1: 0.4369 - val_f2_score_2: 0.4127 - val_f2_score_3: 0.3868 - val_f2_score_4: 0.3711 - val_f2_score_5: 0.3597 - val_f2_score_6: 0.3086 - val_f2_score_7: 0.2603
# Epoch 79/200
#  - 18s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.3091 - f2_score: 0.5006 - f2_score_1: 0.4806 - f2_score_2: 0.4527 - f2_score_3: 0.4213 - f2_score_4: 0.4024 - f2_score_5: 0.3898 - f2_score_6: 0.3286 - f2_score_7: 0.2735 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2513 - val_f2_score: 0.4530 - val_f2_score_1: 0.4366 - val_f2_score_2: 0.4118 - val_f2_score_3: 0.3843 - val_f2_score_4: 0.3682 - val_f2_score_5: 0.3572 - val_f2_score_6: 0.3056 - val_f2_score_7: 0.2576
# Epoch 80/200
#  - 18s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3131 - f2_score: 0.5025 - f2_score_1: 0.4836 - f2_score_2: 0.4554 - f2_score_3: 0.4239 - f2_score_4: 0.4053 - f2_score_5: 0.3928 - f2_score_6: 0.3329 - f2_score_7: 0.2759 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2459 - val_f2_score: 0.4534 - val_f2_score_1: 0.4377 - val_f2_score_2: 0.4121 - val_f2_score_3: 0.3861 - val_f2_score_4: 0.3708 - val_f2_score_5: 0.3604 - val_f2_score_6: 0.3092 - val_f2_score_7: 0.2617
# Epoch 81/200
#  - 18s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3144 - f2_score: 0.5037 - f2_score_1: 0.4846 - f2_score_2: 0.4560 - f2_score_3: 0.4246 - f2_score_4: 0.4056 - f2_score_5: 0.3932 - f2_score_6: 0.3325 - f2_score_7: 0.2763 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2471 - val_f2_score: 0.4536 - val_f2_score_1: 0.4384 - val_f2_score_2: 0.4140 - val_f2_score_3: 0.3881 - val_f2_score_4: 0.3719 - val_f2_score_5: 0.3613 - val_f2_score_6: 0.3097 - val_f2_score_7: 0.2611
# Epoch 82/200
#  - 18s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3181 - f2_score: 0.5062 - f2_score_1: 0.4867 - f2_score_2: 0.4594 - f2_score_3: 0.4282 - f2_score_4: 0.4087 - f2_score_5: 0.3966 - f2_score_6: 0.3358 - f2_score_7: 0.2804 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2557 - val_f2_score: 0.4544 - val_f2_score_1: 0.4402 - val_f2_score_2: 0.4156 - val_f2_score_3: 0.3886 - val_f2_score_4: 0.3722 - val_f2_score_5: 0.3622 - val_f2_score_6: 0.3111 - val_f2_score_7: 0.2629
# Epoch 83/200
#  - 18s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3183 - f2_score: 0.5073 - f2_score_1: 0.4880 - f2_score_2: 0.4600 - f2_score_3: 0.4289 - f2_score_4: 0.4105 - f2_score_5: 0.3984 - f2_score_6: 0.3383 - f2_score_7: 0.2821 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2442 - val_f2_score: 0.4542 - val_f2_score_1: 0.4400 - val_f2_score_2: 0.4170 - val_f2_score_3: 0.3916 - val_f2_score_4: 0.3758 - val_f2_score_5: 0.3655 - val_f2_score_6: 0.3148 - val_f2_score_7: 0.2681
# Epoch 84/200
#  - 18s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.3226 - f2_score: 0.5088 - f2_score_1: 0.4906 - f2_score_2: 0.4623 - f2_score_3: 0.4322 - f2_score_4: 0.4138 - f2_score_5: 0.4020 - f2_score_6: 0.3422 - f2_score_7: 0.2864 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2504 - val_f2_score: 0.4556 - val_f2_score_1: 0.4400 - val_f2_score_2: 0.4160 - val_f2_score_3: 0.3893 - val_f2_score_4: 0.3739 - val_f2_score_5: 0.3629 - val_f2_score_6: 0.3124 - val_f2_score_7: 0.2643
# Epoch 85/200
#  - 18s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.3215 - f2_score: 0.5109 - f2_score_1: 0.4916 - f2_score_2: 0.4630 - f2_score_3: 0.4328 - f2_score_4: 0.4146 - f2_score_5: 0.4025 - f2_score_6: 0.3431 - f2_score_7: 0.2872 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2521 - val_f2_score: 0.4546 - val_f2_score_1: 0.4415 - val_f2_score_2: 0.4174 - val_f2_score_3: 0.3907 - val_f2_score_4: 0.3743 - val_f2_score_5: 0.3645 - val_f2_score_6: 0.3145 - val_f2_score_7: 0.2666
# Epoch 86/200
#  - 18s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.3261 - f2_score: 0.5126 - f2_score_1: 0.4947 - f2_score_2: 0.4660 - f2_score_3: 0.4358 - f2_score_4: 0.4175 - f2_score_5: 0.4050 - f2_score_6: 0.3450 - f2_score_7: 0.2892 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2515 - val_f2_score: 0.4553 - val_f2_score_1: 0.4410 - val_f2_score_2: 0.4179 - val_f2_score_3: 0.3924 - val_f2_score_4: 0.3775 - val_f2_score_5: 0.3673 - val_f2_score_6: 0.3171 - val_f2_score_7: 0.2690
# Epoch 87/200
#  - 18s - loss: 0.0087 - acc: 0.9976 - categorical_accuracy: 0.3276 - f2_score: 0.5147 - f2_score_1: 0.4961 - f2_score_2: 0.4686 - f2_score_3: 0.4380 - f2_score_4: 0.4194 - f2_score_5: 0.4071 - f2_score_6: 0.3475 - f2_score_7: 0.2920 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2478 - val_f2_score: 0.4555 - val_f2_score_1: 0.4408 - val_f2_score_2: 0.4175 - val_f2_score_3: 0.3918 - val_f2_score_4: 0.3762 - val_f2_score_5: 0.3658 - val_f2_score_6: 0.3164 - val_f2_score_7: 0.2685
# Epoch 88/200
#  - 18s - loss: 0.0087 - acc: 0.9977 - categorical_accuracy: 0.3277 - f2_score: 0.5161 - f2_score_1: 0.4982 - f2_score_2: 0.4704 - f2_score_3: 0.4401 - f2_score_4: 0.4217 - f2_score_5: 0.4092 - f2_score_6: 0.3494 - f2_score_7: 0.2936 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2520 - val_f2_score: 0.4559 - val_f2_score_1: 0.4416 - val_f2_score_2: 0.4178 - val_f2_score_3: 0.3925 - val_f2_score_4: 0.3772 - val_f2_score_5: 0.3674 - val_f2_score_6: 0.3174 - val_f2_score_7: 0.2712
# Epoch 89/200
#  - 18s - loss: 0.0087 - acc: 0.9977 - categorical_accuracy: 0.3307 - f2_score: 0.5167 - f2_score_1: 0.4996 - f2_score_2: 0.4717 - f2_score_3: 0.4415 - f2_score_4: 0.4233 - f2_score_5: 0.4111 - f2_score_6: 0.3526 - f2_score_7: 0.2968 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2517 - val_f2_score: 0.4557 - val_f2_score_1: 0.4386 - val_f2_score_2: 0.4144 - val_f2_score_3: 0.3876 - val_f2_score_4: 0.3721 - val_f2_score_5: 0.3612 - val_f2_score_6: 0.3124 - val_f2_score_7: 0.2661
# Epoch 90/200
#  - 18s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3327 - f2_score: 0.5197 - f2_score_1: 0.5020 - f2_score_2: 0.4744 - f2_score_3: 0.4442 - f2_score_4: 0.4262 - f2_score_5: 0.4139 - f2_score_6: 0.3542 - f2_score_7: 0.2986 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2551 - val_f2_score: 0.4561 - val_f2_score_1: 0.4414 - val_f2_score_2: 0.4183 - val_f2_score_3: 0.3931 - val_f2_score_4: 0.3770 - val_f2_score_5: 0.3670 - val_f2_score_6: 0.3180 - val_f2_score_7: 0.2709
# Epoch 91/200
#  - 18s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3353 - f2_score: 0.5207 - f2_score_1: 0.5035 - f2_score_2: 0.4758 - f2_score_3: 0.4465 - f2_score_4: 0.4285 - f2_score_5: 0.4160 - f2_score_6: 0.3567 - f2_score_7: 0.3010 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2517 - val_f2_score: 0.4569 - val_f2_score_1: 0.4442 - val_f2_score_2: 0.4216 - val_f2_score_3: 0.3959 - val_f2_score_4: 0.3808 - val_f2_score_5: 0.3707 - val_f2_score_6: 0.3219 - val_f2_score_7: 0.2745
# Epoch 92/200
#  - 18s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3346 - f2_score: 0.5220 - f2_score_1: 0.5043 - f2_score_2: 0.4771 - f2_score_3: 0.4474 - f2_score_4: 0.4291 - f2_score_5: 0.4174 - f2_score_6: 0.3581 - f2_score_7: 0.3018 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2551 - val_f2_score: 0.4571 - val_f2_score_1: 0.4423 - val_f2_score_2: 0.4193 - val_f2_score_3: 0.3945 - val_f2_score_4: 0.3785 - val_f2_score_5: 0.3676 - val_f2_score_6: 0.3177 - val_f2_score_7: 0.2710
# Epoch 93/200
#  - 18s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3378 - f2_score: 0.5233 - f2_score_1: 0.5061 - f2_score_2: 0.4789 - f2_score_3: 0.4490 - f2_score_4: 0.4315 - f2_score_5: 0.4198 - f2_score_6: 0.3609 - f2_score_7: 0.3048 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2541 - val_f2_score: 0.4563 - val_f2_score_1: 0.4405 - val_f2_score_2: 0.4175 - val_f2_score_3: 0.3917 - val_f2_score_4: 0.3764 - val_f2_score_5: 0.3661 - val_f2_score_6: 0.3169 - val_f2_score_7: 0.2709
# Epoch 94/200
#  - 18s - loss: 0.0085 - acc: 0.9977 - categorical_accuracy: 0.3415 - f2_score: 0.5258 - f2_score_1: 0.5087 - f2_score_2: 0.4813 - f2_score_3: 0.4518 - f2_score_4: 0.4344 - f2_score_5: 0.4224 - f2_score_6: 0.3637 - f2_score_7: 0.3075 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2545 - val_f2_score: 0.4577 - val_f2_score_1: 0.4438 - val_f2_score_2: 0.4222 - val_f2_score_3: 0.3981 - val_f2_score_4: 0.3825 - val_f2_score_5: 0.3718 - val_f2_score_6: 0.3220 - val_f2_score_7: 0.2758
# Epoch 95/200
#  - 18s - loss: 0.0085 - acc: 0.9977 - categorical_accuracy: 0.3426 - f2_score: 0.5273 - f2_score_1: 0.5105 - f2_score_2: 0.4834 - f2_score_3: 0.4541 - f2_score_4: 0.4354 - f2_score_5: 0.4235 - f2_score_6: 0.3647 - f2_score_7: 0.3087 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2554 - val_f2_score: 0.4565 - val_f2_score_1: 0.4423 - val_f2_score_2: 0.4190 - val_f2_score_3: 0.3926 - val_f2_score_4: 0.3770 - val_f2_score_5: 0.3669 - val_f2_score_6: 0.3193 - val_f2_score_7: 0.2734
# Epoch 96/200
#  - 18s - loss: 0.0085 - acc: 0.9977 - categorical_accuracy: 0.3448 - f2_score: 0.5290 - f2_score_1: 0.5114 - f2_score_2: 0.4840 - f2_score_3: 0.4551 - f2_score_4: 0.4376 - f2_score_5: 0.4253 - f2_score_6: 0.3673 - f2_score_7: 0.3122 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2579 - val_f2_score: 0.4571 - val_f2_score_1: 0.4435 - val_f2_score_2: 0.4215 - val_f2_score_3: 0.3964 - val_f2_score_4: 0.3807 - val_f2_score_5: 0.3702 - val_f2_score_6: 0.3225 - val_f2_score_7: 0.2766
# Epoch 97/200
#  - 18s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3465 - f2_score: 0.5298 - f2_score_1: 0.5132 - f2_score_2: 0.4873 - f2_score_3: 0.4582 - f2_score_4: 0.4405 - f2_score_5: 0.4291 - f2_score_6: 0.3715 - f2_score_7: 0.3153 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2591 - val_f2_score: 0.4586 - val_f2_score_1: 0.4455 - val_f2_score_2: 0.4232 - val_f2_score_3: 0.3983 - val_f2_score_4: 0.3822 - val_f2_score_5: 0.3725 - val_f2_score_6: 0.3246 - val_f2_score_7: 0.2787
# Epoch 98/200
#  - 18s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3498 - f2_score: 0.5320 - f2_score_1: 0.5160 - f2_score_2: 0.4893 - f2_score_3: 0.4604 - f2_score_4: 0.4425 - f2_score_5: 0.4306 - f2_score_6: 0.3719 - f2_score_7: 0.3167 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2544 - val_f2_score: 0.4578 - val_f2_score_1: 0.4430 - val_f2_score_2: 0.4195 - val_f2_score_3: 0.3947 - val_f2_score_4: 0.3803 - val_f2_score_5: 0.3694 - val_f2_score_6: 0.3221 - val_f2_score_7: 0.2772
# Epoch 99/200
#  - 18s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3496 - f2_score: 0.5337 - f2_score_1: 0.5174 - f2_score_2: 0.4918 - f2_score_3: 0.4625 - f2_score_4: 0.4449 - f2_score_5: 0.4327 - f2_score_6: 0.3732 - f2_score_7: 0.3173 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2623 - val_f2_score: 0.4573 - val_f2_score_1: 0.4418 - val_f2_score_2: 0.4184 - val_f2_score_3: 0.3922 - val_f2_score_4: 0.3765 - val_f2_score_5: 0.3660 - val_f2_score_6: 0.3182 - val_f2_score_7: 0.2738
# Epoch 100/200
#  - 18s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3525 - f2_score: 0.5356 - f2_score_1: 0.5194 - f2_score_2: 0.4934 - f2_score_3: 0.4641 - f2_score_4: 0.4465 - f2_score_5: 0.4346 - f2_score_6: 0.3762 - f2_score_7: 0.3206 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2538 - val_f2_score: 0.4582 - val_f2_score_1: 0.4439 - val_f2_score_2: 0.4227 - val_f2_score_3: 0.3977 - val_f2_score_4: 0.3823 - val_f2_score_5: 0.3730 - val_f2_score_6: 0.3254 - val_f2_score_7: 0.2807
# Epoch 101/200
#  - 18s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.3525 - f2_score: 0.5375 - f2_score_1: 0.5211 - f2_score_2: 0.4959 - f2_score_3: 0.4671 - f2_score_4: 0.4494 - f2_score_5: 0.4374 - f2_score_6: 0.3791 - f2_score_7: 0.3228 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2664 - val_f2_score: 0.4579 - val_f2_score_1: 0.4433 - val_f2_score_2: 0.4198 - val_f2_score_3: 0.3951 - val_f2_score_4: 0.3799 - val_f2_score_5: 0.3693 - val_f2_score_6: 0.3221 - val_f2_score_7: 0.2776
# Epoch 102/200
#  - 18s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.3553 - f2_score: 0.5388 - f2_score_1: 0.5232 - f2_score_2: 0.4969 - f2_score_3: 0.4680 - f2_score_4: 0.4503 - f2_score_5: 0.4379 - f2_score_6: 0.3802 - f2_score_7: 0.3236 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2538 - val_f2_score: 0.4597 - val_f2_score_1: 0.4458 - val_f2_score_2: 0.4247 - val_f2_score_3: 0.4016 - val_f2_score_4: 0.3861 - val_f2_score_5: 0.3762 - val_f2_score_6: 0.3299 - val_f2_score_7: 0.2855
# Epoch 103/200
#  - 18s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.3606 - f2_score: 0.5400 - f2_score_1: 0.5252 - f2_score_2: 0.4995 - f2_score_3: 0.4715 - f2_score_4: 0.4539 - f2_score_5: 0.4416 - f2_score_6: 0.3840 - f2_score_7: 0.3275 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2592 - val_f2_score: 0.4589 - val_f2_score_1: 0.4450 - val_f2_score_2: 0.4224 - val_f2_score_3: 0.3984 - val_f2_score_4: 0.3834 - val_f2_score_5: 0.3737 - val_f2_score_6: 0.3266 - val_f2_score_7: 0.2820
# Epoch 104/200
#  - 18s - loss: 0.0082 - acc: 0.9977 - categorical_accuracy: 0.3617 - f2_score: 0.5419 - f2_score_1: 0.5259 - f2_score_2: 0.5009 - f2_score_3: 0.4718 - f2_score_4: 0.4540 - f2_score_5: 0.4423 - f2_score_6: 0.3854 - f2_score_7: 0.3293 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2575 - val_f2_score: 0.4578 - val_f2_score_1: 0.4422 - val_f2_score_2: 0.4193 - val_f2_score_3: 0.3947 - val_f2_score_4: 0.3801 - val_f2_score_5: 0.3696 - val_f2_score_6: 0.3230 - val_f2_score_7: 0.2790
# Epoch 105/200
#  - 18s - loss: 0.0082 - acc: 0.9977 - categorical_accuracy: 0.3612 - f2_score: 0.5432 - f2_score_1: 0.5272 - f2_score_2: 0.5018 - f2_score_3: 0.4732 - f2_score_4: 0.4561 - f2_score_5: 0.4444 - f2_score_6: 0.3876 - f2_score_7: 0.3316 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2640 - val_f2_score: 0.4592 - val_f2_score_1: 0.4437 - val_f2_score_2: 0.4212 - val_f2_score_3: 0.3958 - val_f2_score_4: 0.3807 - val_f2_score_5: 0.3709 - val_f2_score_6: 0.3244 - val_f2_score_7: 0.2799
# Epoch 106/200
#  - 18s - loss: 0.0082 - acc: 0.9978 - categorical_accuracy: 0.3638 - f2_score: 0.5454 - f2_score_1: 0.5302 - f2_score_2: 0.5046 - f2_score_3: 0.4760 - f2_score_4: 0.4584 - f2_score_5: 0.4465 - f2_score_6: 0.3890 - f2_score_7: 0.3335 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2586 - val_f2_score: 0.4591 - val_f2_score_1: 0.4441 - val_f2_score_2: 0.4227 - val_f2_score_3: 0.3982 - val_f2_score_4: 0.3827 - val_f2_score_5: 0.3731 - val_f2_score_6: 0.3286 - val_f2_score_7: 0.2844
# Epoch 107/200
#  - 18s - loss: 0.0082 - acc: 0.9978 - categorical_accuracy: 0.3658 - f2_score: 0.5470 - f2_score_1: 0.5313 - f2_score_2: 0.5061 - f2_score_3: 0.4782 - f2_score_4: 0.4606 - f2_score_5: 0.4491 - f2_score_6: 0.3917 - f2_score_7: 0.3358 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2609 - val_f2_score: 0.4594 - val_f2_score_1: 0.4449 - val_f2_score_2: 0.4224 - val_f2_score_3: 0.3991 - val_f2_score_4: 0.3845 - val_f2_score_5: 0.3746 - val_f2_score_6: 0.3290 - val_f2_score_7: 0.2858
# Epoch 108/200
#  - 18s - loss: 0.0081 - acc: 0.9978 - categorical_accuracy: 0.3669 - f2_score: 0.5476 - f2_score_1: 0.5327 - f2_score_2: 0.5073 - f2_score_3: 0.4792 - f2_score_4: 0.4621 - f2_score_5: 0.4506 - f2_score_6: 0.3930 - f2_score_7: 0.3381 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2681 - val_f2_score: 0.4586 - val_f2_score_1: 0.4435 - val_f2_score_2: 0.4203 - val_f2_score_3: 0.3959 - val_f2_score_4: 0.3812 - val_f2_score_5: 0.3714 - val_f2_score_6: 0.3251 - val_f2_score_7: 0.2819
# Epoch 109/200
#  - 18s - loss: 0.0081 - acc: 0.9978 - categorical_accuracy: 0.3704 - f2_score: 0.5497 - f2_score_1: 0.5348 - f2_score_2: 0.5098 - f2_score_3: 0.4819 - f2_score_4: 0.4648 - f2_score_5: 0.4533 - f2_score_6: 0.3960 - f2_score_7: 0.3404 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2641 - val_f2_score: 0.4590 - val_f2_score_1: 0.4455 - val_f2_score_2: 0.4232 - val_f2_score_3: 0.3983 - val_f2_score_4: 0.3842 - val_f2_score_5: 0.3748 - val_f2_score_6: 0.3287 - val_f2_score_7: 0.2850
# Epoch 110/200
#  - 18s - loss: 0.0081 - acc: 0.9978 - categorical_accuracy: 0.3715 - f2_score: 0.5519 - f2_score_1: 0.5366 - f2_score_2: 0.5119 - f2_score_3: 0.4842 - f2_score_4: 0.4673 - f2_score_5: 0.4556 - f2_score_6: 0.3987 - f2_score_7: 0.3443 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2642 - val_f2_score: 0.4589 - val_f2_score_1: 0.4425 - val_f2_score_2: 0.4195 - val_f2_score_3: 0.3934 - val_f2_score_4: 0.3786 - val_f2_score_5: 0.3689 - val_f2_score_6: 0.3238 - val_f2_score_7: 0.2803
# Epoch 111/200
#  - 18s - loss: 0.0080 - acc: 0.9978 - categorical_accuracy: 0.3740 - f2_score: 0.5532 - f2_score_1: 0.5392 - f2_score_2: 0.5150 - f2_score_3: 0.4870 - f2_score_4: 0.4697 - f2_score_5: 0.4583 - f2_score_6: 0.4012 - f2_score_7: 0.3461 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2671 - val_f2_score: 0.4597 - val_f2_score_1: 0.4447 - val_f2_score_2: 0.4222 - val_f2_score_3: 0.3973 - val_f2_score_4: 0.3819 - val_f2_score_5: 0.3723 - val_f2_score_6: 0.3275 - val_f2_score_7: 0.2846
# Epoch 112/200
#  - 18s - loss: 0.0080 - acc: 0.9978 - categorical_accuracy: 0.3750 - f2_score: 0.5542 - f2_score_1: 0.5399 - f2_score_2: 0.5157 - f2_score_3: 0.4885 - f2_score_4: 0.4714 - f2_score_5: 0.4599 - f2_score_6: 0.4030 - f2_score_7: 0.3478 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2701 - val_f2_score: 0.4601 - val_f2_score_1: 0.4463 - val_f2_score_2: 0.4239 - val_f2_score_3: 0.3999 - val_f2_score_4: 0.3853 - val_f2_score_5: 0.3751 - val_f2_score_6: 0.3302 - val_f2_score_7: 0.2871
# Epoch 113/200
#  - 18s - loss: 0.0080 - acc: 0.9978 - categorical_accuracy: 0.3773 - f2_score: 0.5549 - f2_score_1: 0.5405 - f2_score_2: 0.5159 - f2_score_3: 0.4894 - f2_score_4: 0.4728 - f2_score_5: 0.4619 - f2_score_6: 0.4050 - f2_score_7: 0.3492 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2679 - val_f2_score: 0.4595 - val_f2_score_1: 0.4440 - val_f2_score_2: 0.4215 - val_f2_score_3: 0.3967 - val_f2_score_4: 0.3823 - val_f2_score_5: 0.3728 - val_f2_score_6: 0.3289 - val_f2_score_7: 0.2852
# Epoch 00113: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
print('Best f2 score is: %.2f' % best_thr_val)
# Out:
# Best threshold is: 0.1
# Best f2 score is: 0.46

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                                      attribute_ids
# 0  10023b2cc4ed5f68                          223 343 369 766 1039 1059
# 1  100fbe75ed8fd887                             121 231 1039 1059 1085
# 2  101b627524a04f19                     79 121 180 482 497 498 728 961
# 3  10234480c41284c6  13 51 147 480 483 501 725 737 738 776 830 923 ...
# 4  1023b0e2636dcea8  29 147 156 189 227 283 322 584 744 813 896 903...
# 5   1039cd6cf85845c                                13 405 896 903 1092
# 6   103a5b3f83fbe88                         194 744 813 1046 1092 1099
# 7  10413aaae8d6a9a2                               51 147 813 1046 1092
# 8  10423822b93a65ab                                          13 51 147
# 9  1052bf702cb099f7                                188 597 612 671 780
