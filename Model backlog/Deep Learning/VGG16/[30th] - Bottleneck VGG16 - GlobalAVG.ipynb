# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
from keras.layers import GlobalAveragePooling2D

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 11s - loss: 0.1347 - acc: 0.9793 - categorical_accuracy: 0.0123 - f2_score: 0.0758 - f2_score_1: 0.0581 - f2_score_2: 0.0337 - f2_score_3: 0.0141 - f2_score_4: 0.0062 - f2_score_5: 0.0037 - f2_score_6: 0.0017 - f2_score_7: 0.0011 - val_loss: 0.0314 - val_acc: 0.9971 - val_categorical_accuracy: 0.0223 - val_f2_score: 0.1417 - val_f2_score_1: 0.0877 - val_f2_score_2: 0.0506 - val_f2_score_3: 0.0250 - val_f2_score_4: 0.0112 - val_f2_score_5: 0.0047 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 2/200
#  - 10s - loss: 0.0229 - acc: 0.9971 - categorical_accuracy: 0.0384 - f2_score: 0.1582 - f2_score_1: 0.0977 - f2_score_2: 0.0575 - f2_score_3: 0.0308 - f2_score_4: 0.0183 - f2_score_5: 0.0112 - f2_score_6: 7.4011e-05 - f2_score_7: 0.0000e+00 - val_loss: 0.0183 - val_acc: 0.9971 - val_categorical_accuracy: 0.0483 - val_f2_score: 0.1659 - val_f2_score_1: 0.1021 - val_f2_score_2: 0.0591 - val_f2_score_3: 0.0333 - val_f2_score_4: 0.0208 - val_f2_score_5: 0.0135 - val_f2_score_6: 1.9462e-04 - val_f2_score_7: 0.0000e+00
# Epoch 3/200
#  - 10s - loss: 0.0165 - acc: 0.9971 - categorical_accuracy: 0.0583 - f2_score: 0.1871 - f2_score_1: 0.1212 - f2_score_2: 0.0712 - f2_score_3: 0.0407 - f2_score_4: 0.0274 - f2_score_5: 0.0197 - f2_score_6: 8.5450e-04 - f2_score_7: 2.2897e-06 - val_loss: 0.0154 - val_acc: 0.9971 - val_categorical_accuracy: 0.0650 - val_f2_score: 0.1959 - val_f2_score_1: 0.1284 - val_f2_score_2: 0.0782 - val_f2_score_3: 0.0456 - val_f2_score_4: 0.0313 - val_f2_score_5: 0.0228 - val_f2_score_6: 0.0018 - val_f2_score_7: 3.6344e-05
# Epoch 4/200
#  - 10s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0730 - f2_score: 0.2090 - f2_score_1: 0.1438 - f2_score_2: 0.0909 - f2_score_3: 0.0539 - f2_score_4: 0.0377 - f2_score_5: 0.0286 - f2_score_6: 0.0031 - f2_score_7: 7.8836e-05 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0718 - val_f2_score: 0.2106 - val_f2_score_1: 0.1461 - val_f2_score_2: 0.0949 - val_f2_score_3: 0.0602 - val_f2_score_4: 0.0439 - val_f2_score_5: 0.0347 - val_f2_score_6: 0.0053 - val_f2_score_7: 4.2698e-04
# Epoch 5/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0834 - f2_score: 0.2242 - f2_score_1: 0.1606 - f2_score_2: 0.1064 - f2_score_3: 0.0673 - f2_score_4: 0.0496 - f2_score_5: 0.0394 - f2_score_6: 0.0074 - f2_score_7: 7.7291e-04 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0778 - val_f2_score: 0.2259 - val_f2_score_1: 0.1607 - val_f2_score_2: 0.1072 - val_f2_score_3: 0.0712 - val_f2_score_4: 0.0544 - val_f2_score_5: 0.0447 - val_f2_score_6: 0.0110 - val_f2_score_7: 0.0018
# Epoch 6/200
#  - 10s - loss: 0.0136 - acc: 0.9971 - categorical_accuracy: 0.0905 - f2_score: 0.2365 - f2_score_1: 0.1738 - f2_score_2: 0.1203 - f2_score_3: 0.0794 - f2_score_4: 0.0607 - f2_score_5: 0.0497 - f2_score_6: 0.0134 - f2_score_7: 0.0028 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0887 - val_f2_score: 0.2391 - val_f2_score_1: 0.1744 - val_f2_score_2: 0.1210 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0634 - val_f2_score_5: 0.0532 - val_f2_score_6: 0.0162 - val_f2_score_7: 0.0043
# Epoch 7/200
#  - 10s - loss: 0.0134 - acc: 0.9971 - categorical_accuracy: 0.0951 - f2_score: 0.2475 - f2_score_1: 0.1850 - f2_score_2: 0.1311 - f2_score_3: 0.0886 - f2_score_4: 0.0694 - f2_score_5: 0.0583 - f2_score_6: 0.0192 - f2_score_7: 0.0053 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0868 - val_f2_score: 0.2482 - val_f2_score_1: 0.1829 - val_f2_score_2: 0.1292 - val_f2_score_3: 0.0905 - val_f2_score_4: 0.0718 - val_f2_score_5: 0.0607 - val_f2_score_6: 0.0216 - val_f2_score_7: 0.0071
# Epoch 8/200
#  - 10s - loss: 0.0132 - acc: 0.9971 - categorical_accuracy: 0.0982 - f2_score: 0.2568 - f2_score_1: 0.1942 - f2_score_2: 0.1403 - f2_score_3: 0.0975 - f2_score_4: 0.0778 - f2_score_5: 0.0662 - f2_score_6: 0.0250 - f2_score_7: 0.0081 - val_loss: 0.0132 - val_acc: 0.9971 - val_categorical_accuracy: 0.0909 - val_f2_score: 0.2581 - val_f2_score_1: 0.1929 - val_f2_score_2: 0.1376 - val_f2_score_3: 0.0982 - val_f2_score_4: 0.0784 - val_f2_score_5: 0.0683 - val_f2_score_6: 0.0264 - val_f2_score_7: 0.0104
# Epoch 9/200
#  - 10s - loss: 0.0130 - acc: 0.9971 - categorical_accuracy: 0.0999 - f2_score: 0.2649 - f2_score_1: 0.2035 - f2_score_2: 0.1487 - f2_score_3: 0.1054 - f2_score_4: 0.0846 - f2_score_5: 0.0729 - f2_score_6: 0.0302 - f2_score_7: 0.0112 - val_loss: 0.0130 - val_acc: 0.9971 - val_categorical_accuracy: 0.0963 - val_f2_score: 0.2630 - val_f2_score_1: 0.1985 - val_f2_score_2: 0.1425 - val_f2_score_3: 0.1005 - val_f2_score_4: 0.0811 - val_f2_score_5: 0.0704 - val_f2_score_6: 0.0290 - val_f2_score_7: 0.0127
# Epoch 10/200
#  - 10s - loss: 0.0129 - acc: 0.9971 - categorical_accuracy: 0.1027 - f2_score: 0.2713 - f2_score_1: 0.2111 - f2_score_2: 0.1561 - f2_score_3: 0.1120 - f2_score_4: 0.0906 - f2_score_5: 0.0784 - f2_score_6: 0.0345 - f2_score_7: 0.0140 - val_loss: 0.0129 - val_acc: 0.9971 - val_categorical_accuracy: 0.0942 - val_f2_score: 0.2705 - val_f2_score_1: 0.2081 - val_f2_score_2: 0.1530 - val_f2_score_3: 0.1108 - val_f2_score_4: 0.0906 - val_f2_score_5: 0.0788 - val_f2_score_6: 0.0353 - val_f2_score_7: 0.0157
# Epoch 11/200
#  - 10s - loss: 0.0128 - acc: 0.9971 - categorical_accuracy: 0.1053 - f2_score: 0.2771 - f2_score_1: 0.2177 - f2_score_2: 0.1625 - f2_score_3: 0.1191 - f2_score_4: 0.0975 - f2_score_5: 0.0850 - f2_score_6: 0.0391 - f2_score_7: 0.0169 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.0975 - val_f2_score: 0.2760 - val_f2_score_1: 0.2129 - val_f2_score_2: 0.1571 - val_f2_score_3: 0.1138 - val_f2_score_4: 0.0940 - val_f2_score_5: 0.0822 - val_f2_score_6: 0.0379 - val_f2_score_7: 0.0172
# Epoch 12/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1060 - f2_score: 0.2824 - f2_score_1: 0.2234 - f2_score_2: 0.1684 - f2_score_3: 0.1242 - f2_score_4: 0.1028 - f2_score_5: 0.0902 - f2_score_6: 0.0436 - f2_score_7: 0.0196 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1004 - val_f2_score: 0.2818 - val_f2_score_1: 0.2192 - val_f2_score_2: 0.1640 - val_f2_score_3: 0.1205 - val_f2_score_4: 0.0998 - val_f2_score_5: 0.0884 - val_f2_score_6: 0.0425 - val_f2_score_7: 0.0201
# Epoch 13/200
#  - 10s - loss: 0.0126 - acc: 0.9972 - categorical_accuracy: 0.1082 - f2_score: 0.2873 - f2_score_1: 0.2290 - f2_score_2: 0.1738 - f2_score_3: 0.1290 - f2_score_4: 0.1072 - f2_score_5: 0.0944 - f2_score_6: 0.0475 - f2_score_7: 0.0225 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1052 - val_f2_score: 0.2859 - val_f2_score_1: 0.2252 - val_f2_score_2: 0.1703 - val_f2_score_3: 0.1257 - val_f2_score_4: 0.1044 - val_f2_score_5: 0.0928 - val_f2_score_6: 0.0469 - val_f2_score_7: 0.0227
# Epoch 14/200
#  - 10s - loss: 0.0125 - acc: 0.9972 - categorical_accuracy: 0.1099 - f2_score: 0.2918 - f2_score_1: 0.2335 - f2_score_2: 0.1783 - f2_score_3: 0.1335 - f2_score_4: 0.1115 - f2_score_5: 0.0985 - f2_score_6: 0.0514 - f2_score_7: 0.0254 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1007 - val_f2_score: 0.2903 - val_f2_score_1: 0.2305 - val_f2_score_2: 0.1764 - val_f2_score_3: 0.1313 - val_f2_score_4: 0.1098 - val_f2_score_5: 0.0979 - val_f2_score_6: 0.0514 - val_f2_score_7: 0.0258
# Epoch 15/200
#  - 10s - loss: 0.0125 - acc: 0.9972 - categorical_accuracy: 0.1106 - f2_score: 0.2956 - f2_score_1: 0.2382 - f2_score_2: 0.1829 - f2_score_3: 0.1381 - f2_score_4: 0.1155 - f2_score_5: 0.1030 - f2_score_6: 0.0546 - f2_score_7: 0.0279 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1025 - val_f2_score: 0.2927 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1776 - val_f2_score_3: 0.1336 - val_f2_score_4: 0.1122 - val_f2_score_5: 0.1001 - val_f2_score_6: 0.0538 - val_f2_score_7: 0.0281
# Epoch 16/200
#  - 10s - loss: 0.0124 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2990 - f2_score_1: 0.2424 - f2_score_2: 0.1867 - f2_score_3: 0.1416 - f2_score_4: 0.1192 - f2_score_5: 0.1061 - f2_score_6: 0.0575 - f2_score_7: 0.0303 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.0978 - val_f2_score: 0.2982 - val_f2_score_1: 0.2378 - val_f2_score_2: 0.1823 - val_f2_score_3: 0.1383 - val_f2_score_4: 0.1158 - val_f2_score_5: 0.1035 - val_f2_score_6: 0.0568 - val_f2_score_7: 0.0303
# Epoch 17/200
#  - 10s - loss: 0.0123 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.3020 - f2_score_1: 0.2462 - f2_score_2: 0.1907 - f2_score_3: 0.1456 - f2_score_4: 0.1231 - f2_score_5: 0.1097 - f2_score_6: 0.0604 - f2_score_7: 0.0323 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1025 - val_f2_score: 0.3005 - val_f2_score_1: 0.2415 - val_f2_score_2: 0.1852 - val_f2_score_3: 0.1413 - val_f2_score_4: 0.1189 - val_f2_score_5: 0.1062 - val_f2_score_6: 0.0588 - val_f2_score_7: 0.0324
# Epoch 18/200
#  - 10s - loss: 0.0123 - acc: 0.9972 - categorical_accuracy: 0.1132 - f2_score: 0.3048 - f2_score_1: 0.2497 - f2_score_2: 0.1941 - f2_score_3: 0.1487 - f2_score_4: 0.1260 - f2_score_5: 0.1125 - f2_score_6: 0.0626 - f2_score_7: 0.0341 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1011 - val_f2_score: 0.3037 - val_f2_score_1: 0.2453 - val_f2_score_2: 0.1903 - val_f2_score_3: 0.1459 - val_f2_score_4: 0.1242 - val_f2_score_5: 0.1112 - val_f2_score_6: 0.0633 - val_f2_score_7: 0.0346
# Epoch 19/200
#  - 10s - loss: 0.0122 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.3078 - f2_score_1: 0.2528 - f2_score_2: 0.1976 - f2_score_3: 0.1518 - f2_score_4: 0.1294 - f2_score_5: 0.1160 - f2_score_6: 0.0654 - f2_score_7: 0.0362 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1037 - val_f2_score: 0.3060 - val_f2_score_1: 0.2492 - val_f2_score_2: 0.1938 - val_f2_score_3: 0.1485 - val_f2_score_4: 0.1266 - val_f2_score_5: 0.1131 - val_f2_score_6: 0.0642 - val_f2_score_7: 0.0357
# Epoch 20/200
#  - 10s - loss: 0.0122 - acc: 0.9972 - categorical_accuracy: 0.1138 - f2_score: 0.3102 - f2_score_1: 0.2558 - f2_score_2: 0.2003 - f2_score_3: 0.1546 - f2_score_4: 0.1320 - f2_score_5: 0.1183 - f2_score_6: 0.0674 - f2_score_7: 0.0379 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1037 - val_f2_score: 0.3091 - val_f2_score_1: 0.2517 - val_f2_score_2: 0.1965 - val_f2_score_3: 0.1515 - val_f2_score_4: 0.1296 - val_f2_score_5: 0.1172 - val_f2_score_6: 0.0676 - val_f2_score_7: 0.0382
# Epoch 21/200
#  - 10s - loss: 0.0121 - acc: 0.9972 - categorical_accuracy: 0.1148 - f2_score: 0.3126 - f2_score_1: 0.2586 - f2_score_2: 0.2036 - f2_score_3: 0.1576 - f2_score_4: 0.1350 - f2_score_5: 0.1211 - f2_score_6: 0.0699 - f2_score_7: 0.0396 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1076 - val_f2_score: 0.3100 - val_f2_score_1: 0.2550 - val_f2_score_2: 0.1992 - val_f2_score_3: 0.1538 - val_f2_score_4: 0.1315 - val_f2_score_5: 0.1183 - val_f2_score_6: 0.0683 - val_f2_score_7: 0.0396
# Epoch 22/200
#  - 10s - loss: 0.0121 - acc: 0.9972 - categorical_accuracy: 0.1154 - f2_score: 0.3146 - f2_score_1: 0.2612 - f2_score_2: 0.2063 - f2_score_3: 0.1603 - f2_score_4: 0.1376 - f2_score_5: 0.1239 - f2_score_6: 0.0721 - f2_score_7: 0.0413 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1048 - val_f2_score: 0.3124 - val_f2_score_1: 0.2565 - val_f2_score_2: 0.2008 - val_f2_score_3: 0.1548 - val_f2_score_4: 0.1330 - val_f2_score_5: 0.1198 - val_f2_score_6: 0.0702 - val_f2_score_7: 0.0415
# Epoch 23/200
#  - 10s - loss: 0.0121 - acc: 0.9972 - categorical_accuracy: 0.1161 - f2_score: 0.3167 - f2_score_1: 0.2639 - f2_score_2: 0.2090 - f2_score_3: 0.1625 - f2_score_4: 0.1395 - f2_score_5: 0.1260 - f2_score_6: 0.0741 - f2_score_7: 0.0430 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1077 - val_f2_score: 0.3140 - val_f2_score_1: 0.2586 - val_f2_score_2: 0.2028 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1345 - val_f2_score_5: 0.1208 - val_f2_score_6: 0.0707 - val_f2_score_7: 0.0419
# Epoch 24/200
#  - 10s - loss: 0.0120 - acc: 0.9972 - categorical_accuracy: 0.1161 - f2_score: 0.3184 - f2_score_1: 0.2660 - f2_score_2: 0.2113 - f2_score_3: 0.1644 - f2_score_4: 0.1416 - f2_score_5: 0.1282 - f2_score_6: 0.0757 - f2_score_7: 0.0444 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1050 - val_f2_score: 0.3156 - val_f2_score_1: 0.2614 - val_f2_score_2: 0.2063 - val_f2_score_3: 0.1606 - val_f2_score_4: 0.1389 - val_f2_score_5: 0.1260 - val_f2_score_6: 0.0749 - val_f2_score_7: 0.0440
# Epoch 25/200
#  - 10s - loss: 0.0120 - acc: 0.9972 - categorical_accuracy: 0.1166 - f2_score: 0.3204 - f2_score_1: 0.2683 - f2_score_2: 0.2138 - f2_score_3: 0.1671 - f2_score_4: 0.1443 - f2_score_5: 0.1305 - f2_score_6: 0.0782 - f2_score_7: 0.0459 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1062 - val_f2_score: 0.3174 - val_f2_score_1: 0.2635 - val_f2_score_2: 0.2086 - val_f2_score_3: 0.1622 - val_f2_score_4: 0.1407 - val_f2_score_5: 0.1271 - val_f2_score_6: 0.0764 - val_f2_score_7: 0.0460
# Epoch 26/200
#  - 10s - loss: 0.0120 - acc: 0.9972 - categorical_accuracy: 0.1173 - f2_score: 0.3221 - f2_score_1: 0.2704 - f2_score_2: 0.2162 - f2_score_3: 0.1689 - f2_score_4: 0.1461 - f2_score_5: 0.1321 - f2_score_6: 0.0794 - f2_score_7: 0.0475 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1041 - val_f2_score: 0.3182 - val_f2_score_1: 0.2652 - val_f2_score_2: 0.2097 - val_f2_score_3: 0.1642 - val_f2_score_4: 0.1425 - val_f2_score_5: 0.1294 - val_f2_score_6: 0.0785 - val_f2_score_7: 0.0469
# Epoch 27/200
#  - 10s - loss: 0.0119 - acc: 0.9972 - categorical_accuracy: 0.1181 - f2_score: 0.3237 - f2_score_1: 0.2725 - f2_score_2: 0.2182 - f2_score_3: 0.1713 - f2_score_4: 0.1480 - f2_score_5: 0.1340 - f2_score_6: 0.0812 - f2_score_7: 0.0486 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1054 - val_f2_score: 0.3204 - val_f2_score_1: 0.2673 - val_f2_score_2: 0.2127 - val_f2_score_3: 0.1668 - val_f2_score_4: 0.1444 - val_f2_score_5: 0.1318 - val_f2_score_6: 0.0808 - val_f2_score_7: 0.0487
# Epoch 28/200
#  - 10s - loss: 0.0119 - acc: 0.9972 - categorical_accuracy: 0.1180 - f2_score: 0.3252 - f2_score_1: 0.2744 - f2_score_2: 0.2201 - f2_score_3: 0.1732 - f2_score_4: 0.1500 - f2_score_5: 0.1358 - f2_score_6: 0.0828 - f2_score_7: 0.0499 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1087 - val_f2_score: 0.3229 - val_f2_score_1: 0.2713 - val_f2_score_2: 0.2163 - val_f2_score_3: 0.1695 - val_f2_score_4: 0.1468 - val_f2_score_5: 0.1335 - val_f2_score_6: 0.0813 - val_f2_score_7: 0.0494
# Epoch 29/200
#  - 10s - loss: 0.0119 - acc: 0.9972 - categorical_accuracy: 0.1188 - f2_score: 0.3267 - f2_score_1: 0.2765 - f2_score_2: 0.2220 - f2_score_3: 0.1751 - f2_score_4: 0.1519 - f2_score_5: 0.1377 - f2_score_6: 0.0844 - f2_score_7: 0.0511 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.3236 - val_f2_score_1: 0.2711 - val_f2_score_2: 0.2155 - val_f2_score_3: 0.1690 - val_f2_score_4: 0.1462 - val_f2_score_5: 0.1334 - val_f2_score_6: 0.0816 - val_f2_score_7: 0.0495
# Epoch 30/200
#  - 10s - loss: 0.0118 - acc: 0.9972 - categorical_accuracy: 0.1189 - f2_score: 0.3279 - f2_score_1: 0.2780 - f2_score_2: 0.2238 - f2_score_3: 0.1768 - f2_score_4: 0.1530 - f2_score_5: 0.1392 - f2_score_6: 0.0855 - f2_score_7: 0.0523 - val_loss: 0.0120 - val_acc: 0.9972 - val_categorical_accuracy: 0.1074 - val_f2_score: 0.3252 - val_f2_score_1: 0.2739 - val_f2_score_2: 0.2191 - val_f2_score_3: 0.1734 - val_f2_score_4: 0.1505 - val_f2_score_5: 0.1373 - val_f2_score_6: 0.0852 - val_f2_score_7: 0.0514
# Epoch 31/200
#  - 10s - loss: 0.0118 - acc: 0.9972 - categorical_accuracy: 0.1192 - f2_score: 0.3293 - f2_score_1: 0.2800 - f2_score_2: 0.2256 - f2_score_3: 0.1788 - f2_score_4: 0.1551 - f2_score_5: 0.1412 - f2_score_6: 0.0873 - f2_score_7: 0.0533 - val_loss: 0.0120 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.3265 - val_f2_score_1: 0.2742 - val_f2_score_2: 0.2187 - val_f2_score_3: 0.1726 - val_f2_score_4: 0.1497 - val_f2_score_5: 0.1356 - val_f2_score_6: 0.0841 - val_f2_score_7: 0.0518
# Epoch 32/200
#  - 10s - loss: 0.0118 - acc: 0.9972 - categorical_accuracy: 0.1195 - f2_score: 0.3311 - f2_score_1: 0.2815 - f2_score_2: 0.2275 - f2_score_3: 0.1803 - f2_score_4: 0.1565 - f2_score_5: 0.1425 - f2_score_6: 0.0884 - f2_score_7: 0.0545 - val_loss: 0.0120 - val_acc: 0.9972 - val_categorical_accuracy: 0.1120 - val_f2_score: 0.3272 - val_f2_score_1: 0.2766 - val_f2_score_2: 0.2214 - val_f2_score_3: 0.1755 - val_f2_score_4: 0.1519 - val_f2_score_5: 0.1379 - val_f2_score_6: 0.0856 - val_f2_score_7: 0.0528
# Epoch 33/200
#  - 10s - loss: 0.0118 - acc: 0.9972 - categorical_accuracy: 0.1203 - f2_score: 0.3319 - f2_score_1: 0.2831 - f2_score_2: 0.2290 - f2_score_3: 0.1819 - f2_score_4: 0.1578 - f2_score_5: 0.1438 - f2_score_6: 0.0898 - f2_score_7: 0.0554 - val_loss: 0.0120 - val_acc: 0.9972 - val_categorical_accuracy: 0.1106 - val_f2_score: 0.3285 - val_f2_score_1: 0.2779 - val_f2_score_2: 0.2222 - val_f2_score_3: 0.1768 - val_f2_score_4: 0.1533 - val_f2_score_5: 0.1394 - val_f2_score_6: 0.0871 - val_f2_score_7: 0.0538
# Epoch 34/200
#  - 10s - loss: 0.0117 - acc: 0.9972 - categorical_accuracy: 0.1204 - f2_score: 0.3331 - f2_score_1: 0.2846 - f2_score_2: 0.2304 - f2_score_3: 0.1835 - f2_score_4: 0.1593 - f2_score_5: 0.1452 - f2_score_6: 0.0909 - f2_score_7: 0.0565 - val_loss: 0.0120 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.3304 - val_f2_score_1: 0.2800 - val_f2_score_2: 0.2254 - val_f2_score_3: 0.1793 - val_f2_score_4: 0.1557 - val_f2_score_5: 0.1414 - val_f2_score_6: 0.0891 - val_f2_score_7: 0.0554
# Epoch 35/200
#  - 10s - loss: 0.0117 - acc: 0.9972 - categorical_accuracy: 0.1207 - f2_score: 0.3345 - f2_score_1: 0.2859 - f2_score_2: 0.2317 - f2_score_3: 0.1851 - f2_score_4: 0.1609 - f2_score_5: 0.1469 - f2_score_6: 0.0922 - f2_score_7: 0.0577 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1125 - val_f2_score: 0.3311 - val_f2_score_1: 0.2812 - val_f2_score_2: 0.2265 - val_f2_score_3: 0.1798 - val_f2_score_4: 0.1565 - val_f2_score_5: 0.1425 - val_f2_score_6: 0.0902 - val_f2_score_7: 0.0561
# Epoch 36/200
#  - 10s - loss: 0.0117 - acc: 0.9972 - categorical_accuracy: 0.1210 - f2_score: 0.3354 - f2_score_1: 0.2873 - f2_score_2: 0.2336 - f2_score_3: 0.1863 - f2_score_4: 0.1620 - f2_score_5: 0.1481 - f2_score_6: 0.0933 - f2_score_7: 0.0586 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1096 - val_f2_score: 0.3326 - val_f2_score_1: 0.2840 - val_f2_score_2: 0.2294 - val_f2_score_3: 0.1830 - val_f2_score_4: 0.1595 - val_f2_score_5: 0.1451 - val_f2_score_6: 0.0912 - val_f2_score_7: 0.0569
# Epoch 37/200
#  - 10s - loss: 0.0117 - acc: 0.9972 - categorical_accuracy: 0.1216 - f2_score: 0.3365 - f2_score_1: 0.2889 - f2_score_2: 0.2351 - f2_score_3: 0.1882 - f2_score_4: 0.1638 - f2_score_5: 0.1497 - f2_score_6: 0.0947 - f2_score_7: 0.0596 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1133 - val_f2_score: 0.3323 - val_f2_score_1: 0.2825 - val_f2_score_2: 0.2280 - val_f2_score_3: 0.1809 - val_f2_score_4: 0.1570 - val_f2_score_5: 0.1430 - val_f2_score_6: 0.0896 - val_f2_score_7: 0.0565
# Epoch 38/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1231 - f2_score: 0.3380 - f2_score_1: 0.2903 - f2_score_2: 0.2363 - f2_score_3: 0.1891 - f2_score_4: 0.1651 - f2_score_5: 0.1506 - f2_score_6: 0.0955 - f2_score_7: 0.0602 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1092 - val_f2_score: 0.3331 - val_f2_score_1: 0.2834 - val_f2_score_2: 0.2295 - val_f2_score_3: 0.1833 - val_f2_score_4: 0.1599 - val_f2_score_5: 0.1458 - val_f2_score_6: 0.0929 - val_f2_score_7: 0.0582
# Epoch 39/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1225 - f2_score: 0.3387 - f2_score_1: 0.2911 - f2_score_2: 0.2375 - f2_score_3: 0.1904 - f2_score_4: 0.1667 - f2_score_5: 0.1520 - f2_score_6: 0.0967 - f2_score_7: 0.0613 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.3344 - val_f2_score_1: 0.2846 - val_f2_score_2: 0.2313 - val_f2_score_3: 0.1844 - val_f2_score_4: 0.1610 - val_f2_score_5: 0.1469 - val_f2_score_6: 0.0939 - val_f2_score_7: 0.0592
# Epoch 40/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1227 - f2_score: 0.3397 - f2_score_1: 0.2926 - f2_score_2: 0.2393 - f2_score_3: 0.1920 - f2_score_4: 0.1679 - f2_score_5: 0.1530 - f2_score_6: 0.0978 - f2_score_7: 0.0619 - val_loss: 0.0119 - val_acc: 0.9972 - val_categorical_accuracy: 0.1109 - val_f2_score: 0.3349 - val_f2_score_1: 0.2845 - val_f2_score_2: 0.2306 - val_f2_score_3: 0.1836 - val_f2_score_4: 0.1607 - val_f2_score_5: 0.1466 - val_f2_score_6: 0.0939 - val_f2_score_7: 0.0596
# Epoch 41/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1233 - f2_score: 0.3407 - f2_score_1: 0.2940 - f2_score_2: 0.2402 - f2_score_3: 0.1931 - f2_score_4: 0.1693 - f2_score_5: 0.1545 - f2_score_6: 0.0988 - f2_score_7: 0.0629 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.3365 - val_f2_score_1: 0.2873 - val_f2_score_2: 0.2337 - val_f2_score_3: 0.1869 - val_f2_score_4: 0.1638 - val_f2_score_5: 0.1493 - val_f2_score_6: 0.0953 - val_f2_score_7: 0.0602
# Epoch 42/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.3417 - f2_score_1: 0.2946 - f2_score_2: 0.2413 - f2_score_3: 0.1941 - f2_score_4: 0.1698 - f2_score_5: 0.1555 - f2_score_6: 0.0995 - f2_score_7: 0.0635 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1129 - val_f2_score: 0.3376 - val_f2_score_1: 0.2886 - val_f2_score_2: 0.2347 - val_f2_score_3: 0.1873 - val_f2_score_4: 0.1639 - val_f2_score_5: 0.1491 - val_f2_score_6: 0.0958 - val_f2_score_7: 0.0607
# Epoch 43/200
#  - 10s - loss: 0.0116 - acc: 0.9972 - categorical_accuracy: 0.1234 - f2_score: 0.3429 - f2_score_1: 0.2961 - f2_score_2: 0.2426 - f2_score_3: 0.1956 - f2_score_4: 0.1712 - f2_score_5: 0.1569 - f2_score_6: 0.1005 - f2_score_7: 0.0647 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1152 - val_f2_score: 0.3376 - val_f2_score_1: 0.2884 - val_f2_score_2: 0.2358 - val_f2_score_3: 0.1886 - val_f2_score_4: 0.1652 - val_f2_score_5: 0.1507 - val_f2_score_6: 0.0971 - val_f2_score_7: 0.0618
# Epoch 44/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.3435 - f2_score_1: 0.2969 - f2_score_2: 0.2439 - f2_score_3: 0.1965 - f2_score_4: 0.1727 - f2_score_5: 0.1579 - f2_score_6: 0.1015 - f2_score_7: 0.0651 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1161 - val_f2_score: 0.3392 - val_f2_score_1: 0.2912 - val_f2_score_2: 0.2378 - val_f2_score_3: 0.1908 - val_f2_score_4: 0.1672 - val_f2_score_5: 0.1527 - val_f2_score_6: 0.0983 - val_f2_score_7: 0.0626
# Epoch 45/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.3444 - f2_score_1: 0.2981 - f2_score_2: 0.2454 - f2_score_3: 0.1978 - f2_score_4: 0.1737 - f2_score_5: 0.1593 - f2_score_6: 0.1029 - f2_score_7: 0.0661 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1171 - val_f2_score: 0.3399 - val_f2_score_1: 0.2913 - val_f2_score_2: 0.2390 - val_f2_score_3: 0.1912 - val_f2_score_4: 0.1674 - val_f2_score_5: 0.1528 - val_f2_score_6: 0.0980 - val_f2_score_7: 0.0624
# Epoch 46/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1258 - f2_score: 0.3453 - f2_score_1: 0.2990 - f2_score_2: 0.2462 - f2_score_3: 0.1987 - f2_score_4: 0.1744 - f2_score_5: 0.1599 - f2_score_6: 0.1031 - f2_score_7: 0.0667 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1110 - val_f2_score: 0.3402 - val_f2_score_1: 0.2926 - val_f2_score_2: 0.2401 - val_f2_score_3: 0.1931 - val_f2_score_4: 0.1691 - val_f2_score_5: 0.1553 - val_f2_score_6: 0.1005 - val_f2_score_7: 0.0639
# Epoch 47/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.3462 - f2_score_1: 0.3002 - f2_score_2: 0.2476 - f2_score_3: 0.2000 - f2_score_4: 0.1760 - f2_score_5: 0.1611 - f2_score_6: 0.1042 - f2_score_7: 0.0675 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1179 - val_f2_score: 0.3412 - val_f2_score_1: 0.2925 - val_f2_score_2: 0.2399 - val_f2_score_3: 0.1925 - val_f2_score_4: 0.1688 - val_f2_score_5: 0.1543 - val_f2_score_6: 0.1000 - val_f2_score_7: 0.0645
# Epoch 48/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1260 - f2_score: 0.3471 - f2_score_1: 0.3011 - f2_score_2: 0.2483 - f2_score_3: 0.2010 - f2_score_4: 0.1766 - f2_score_5: 0.1618 - f2_score_6: 0.1050 - f2_score_7: 0.0683 - val_loss: 0.0118 - val_acc: 0.9972 - val_categorical_accuracy: 0.1144 - val_f2_score: 0.3424 - val_f2_score_1: 0.2949 - val_f2_score_2: 0.2421 - val_f2_score_3: 0.1955 - val_f2_score_4: 0.1715 - val_f2_score_5: 0.1566 - val_f2_score_6: 0.1021 - val_f2_score_7: 0.0655
# Epoch 49/200
#  - 10s - loss: 0.0115 - acc: 0.9972 - categorical_accuracy: 0.1256 - f2_score: 0.3480 - f2_score_1: 0.3021 - f2_score_2: 0.2493 - f2_score_3: 0.2025 - f2_score_4: 0.1782 - f2_score_5: 0.1634 - f2_score_6: 0.1061 - f2_score_7: 0.0691 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1174 - val_f2_score: 0.3428 - val_f2_score_1: 0.2937 - val_f2_score_2: 0.2404 - val_f2_score_3: 0.1931 - val_f2_score_4: 0.1692 - val_f2_score_5: 0.1548 - val_f2_score_6: 0.1012 - val_f2_score_7: 0.0651
# Epoch 50/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1266 - f2_score: 0.3489 - f2_score_1: 0.3031 - f2_score_2: 0.2504 - f2_score_3: 0.2030 - f2_score_4: 0.1788 - f2_score_5: 0.1643 - f2_score_6: 0.1068 - f2_score_7: 0.0697 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1156 - val_f2_score: 0.3430 - val_f2_score_1: 0.2953 - val_f2_score_2: 0.2435 - val_f2_score_3: 0.1966 - val_f2_score_4: 0.1724 - val_f2_score_5: 0.1578 - val_f2_score_6: 0.1029 - val_f2_score_7: 0.0662
# Epoch 51/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1272 - f2_score: 0.3495 - f2_score_1: 0.3040 - f2_score_2: 0.2516 - f2_score_3: 0.2037 - f2_score_4: 0.1796 - f2_score_5: 0.1648 - f2_score_6: 0.1072 - f2_score_7: 0.0702 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1157 - val_f2_score: 0.3437 - val_f2_score_1: 0.2969 - val_f2_score_2: 0.2448 - val_f2_score_3: 0.1978 - val_f2_score_4: 0.1741 - val_f2_score_5: 0.1593 - val_f2_score_6: 0.1050 - val_f2_score_7: 0.0680
# Epoch 52/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1271 - f2_score: 0.3502 - f2_score_1: 0.3048 - f2_score_2: 0.2527 - f2_score_3: 0.2050 - f2_score_4: 0.1810 - f2_score_5: 0.1663 - f2_score_6: 0.1079 - f2_score_7: 0.0710 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1156 - val_f2_score: 0.3449 - val_f2_score_1: 0.2964 - val_f2_score_2: 0.2451 - val_f2_score_3: 0.1983 - val_f2_score_4: 0.1746 - val_f2_score_5: 0.1599 - val_f2_score_6: 0.1059 - val_f2_score_7: 0.0689
# Epoch 53/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1272 - f2_score: 0.3507 - f2_score_1: 0.3056 - f2_score_2: 0.2532 - f2_score_3: 0.2057 - f2_score_4: 0.1816 - f2_score_5: 0.1669 - f2_score_6: 0.1089 - f2_score_7: 0.0715 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1162 - val_f2_score: 0.3460 - val_f2_score_1: 0.2982 - val_f2_score_2: 0.2465 - val_f2_score_3: 0.1992 - val_f2_score_4: 0.1755 - val_f2_score_5: 0.1608 - val_f2_score_6: 0.1059 - val_f2_score_7: 0.0693
# Epoch 54/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1273 - f2_score: 0.3517 - f2_score_1: 0.3064 - f2_score_2: 0.2543 - f2_score_3: 0.2073 - f2_score_4: 0.1824 - f2_score_5: 0.1681 - f2_score_6: 0.1101 - f2_score_7: 0.0724 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1174 - val_f2_score: 0.3462 - val_f2_score_1: 0.2995 - val_f2_score_2: 0.2476 - val_f2_score_3: 0.2006 - val_f2_score_4: 0.1768 - val_f2_score_5: 0.1614 - val_f2_score_6: 0.1066 - val_f2_score_7: 0.0695
# Epoch 55/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1280 - f2_score: 0.3524 - f2_score_1: 0.3074 - f2_score_2: 0.2550 - f2_score_3: 0.2077 - f2_score_4: 0.1832 - f2_score_5: 0.1689 - f2_score_6: 0.1103 - f2_score_7: 0.0729 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1160 - val_f2_score: 0.3467 - val_f2_score_1: 0.2976 - val_f2_score_2: 0.2465 - val_f2_score_3: 0.1992 - val_f2_score_4: 0.1765 - val_f2_score_5: 0.1623 - val_f2_score_6: 0.1080 - val_f2_score_7: 0.0712
# Epoch 56/200
#  - 10s - loss: 0.0114 - acc: 0.9972 - categorical_accuracy: 0.1283 - f2_score: 0.3530 - f2_score_1: 0.3085 - f2_score_2: 0.2561 - f2_score_3: 0.2090 - f2_score_4: 0.1842 - f2_score_5: 0.1694 - f2_score_6: 0.1114 - f2_score_7: 0.0735 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1156 - val_f2_score: 0.3465 - val_f2_score_1: 0.2988 - val_f2_score_2: 0.2471 - val_f2_score_3: 0.2005 - val_f2_score_4: 0.1771 - val_f2_score_5: 0.1623 - val_f2_score_6: 0.1073 - val_f2_score_7: 0.0704
# Epoch 57/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1287 - f2_score: 0.3538 - f2_score_1: 0.3088 - f2_score_2: 0.2569 - f2_score_3: 0.2094 - f2_score_4: 0.1848 - f2_score_5: 0.1703 - f2_score_6: 0.1119 - f2_score_7: 0.0739 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1138 - val_f2_score: 0.3472 - val_f2_score_1: 0.3004 - val_f2_score_2: 0.2491 - val_f2_score_3: 0.2022 - val_f2_score_4: 0.1790 - val_f2_score_5: 0.1638 - val_f2_score_6: 0.1087 - val_f2_score_7: 0.0715
# Epoch 58/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1287 - f2_score: 0.3548 - f2_score_1: 0.3097 - f2_score_2: 0.2578 - f2_score_3: 0.2106 - f2_score_4: 0.1860 - f2_score_5: 0.1712 - f2_score_6: 0.1126 - f2_score_7: 0.0747 - val_loss: 0.0117 - val_acc: 0.9972 - val_categorical_accuracy: 0.1187 - val_f2_score: 0.3473 - val_f2_score_1: 0.3011 - val_f2_score_2: 0.2497 - val_f2_score_3: 0.2034 - val_f2_score_4: 0.1797 - val_f2_score_5: 0.1652 - val_f2_score_6: 0.1098 - val_f2_score_7: 0.0723
# Epoch 59/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1290 - f2_score: 0.3553 - f2_score_1: 0.3105 - f2_score_2: 0.2585 - f2_score_3: 0.2114 - f2_score_4: 0.1868 - f2_score_5: 0.1719 - f2_score_6: 0.1135 - f2_score_7: 0.0753 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1165 - val_f2_score: 0.3479 - val_f2_score_1: 0.3012 - val_f2_score_2: 0.2501 - val_f2_score_3: 0.2036 - val_f2_score_4: 0.1800 - val_f2_score_5: 0.1656 - val_f2_score_6: 0.1096 - val_f2_score_7: 0.0724
# Epoch 60/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1298 - f2_score: 0.3561 - f2_score_1: 0.3115 - f2_score_2: 0.2594 - f2_score_3: 0.2119 - f2_score_4: 0.1873 - f2_score_5: 0.1727 - f2_score_6: 0.1140 - f2_score_7: 0.0758 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1127 - val_f2_score: 0.3489 - val_f2_score_1: 0.3021 - val_f2_score_2: 0.2514 - val_f2_score_3: 0.2054 - val_f2_score_4: 0.1814 - val_f2_score_5: 0.1674 - val_f2_score_6: 0.1111 - val_f2_score_7: 0.0734
# Epoch 61/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1296 - f2_score: 0.3565 - f2_score_1: 0.3121 - f2_score_2: 0.2601 - f2_score_3: 0.2131 - f2_score_4: 0.1880 - f2_score_5: 0.1735 - f2_score_6: 0.1147 - f2_score_7: 0.0762 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1193 - val_f2_score: 0.3489 - val_f2_score_1: 0.3026 - val_f2_score_2: 0.2525 - val_f2_score_3: 0.2058 - val_f2_score_4: 0.1822 - val_f2_score_5: 0.1679 - val_f2_score_6: 0.1115 - val_f2_score_7: 0.0743
# Epoch 62/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1303 - f2_score: 0.3571 - f2_score_1: 0.3129 - f2_score_2: 0.2614 - f2_score_3: 0.2141 - f2_score_4: 0.1892 - f2_score_5: 0.1744 - f2_score_6: 0.1155 - f2_score_7: 0.0772 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1196 - val_f2_score: 0.3497 - val_f2_score_1: 0.3036 - val_f2_score_2: 0.2533 - val_f2_score_3: 0.2063 - val_f2_score_4: 0.1820 - val_f2_score_5: 0.1676 - val_f2_score_6: 0.1120 - val_f2_score_7: 0.0742
# Epoch 63/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1299 - f2_score: 0.3576 - f2_score_1: 0.3136 - f2_score_2: 0.2619 - f2_score_3: 0.2145 - f2_score_4: 0.1897 - f2_score_5: 0.1749 - f2_score_6: 0.1159 - f2_score_7: 0.0773 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1186 - val_f2_score: 0.3494 - val_f2_score_1: 0.3036 - val_f2_score_2: 0.2531 - val_f2_score_3: 0.2070 - val_f2_score_4: 0.1836 - val_f2_score_5: 0.1697 - val_f2_score_6: 0.1137 - val_f2_score_7: 0.0756
# Epoch 64/200
#  - 10s - loss: 0.0113 - acc: 0.9972 - categorical_accuracy: 0.1303 - f2_score: 0.3581 - f2_score_1: 0.3143 - f2_score_2: 0.2624 - f2_score_3: 0.2152 - f2_score_4: 0.1907 - f2_score_5: 0.1759 - f2_score_6: 0.1170 - f2_score_7: 0.0779 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1201 - val_f2_score: 0.3504 - val_f2_score_1: 0.3039 - val_f2_score_2: 0.2530 - val_f2_score_3: 0.2060 - val_f2_score_4: 0.1818 - val_f2_score_5: 0.1672 - val_f2_score_6: 0.1113 - val_f2_score_7: 0.0744
# Epoch 65/200
#  - 10s - loss: 0.0112 - acc: 0.9972 - categorical_accuracy: 0.1310 - f2_score: 0.3591 - f2_score_1: 0.3151 - f2_score_2: 0.2632 - f2_score_3: 0.2164 - f2_score_4: 0.1915 - f2_score_5: 0.1767 - f2_score_6: 0.1175 - f2_score_7: 0.0787 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1216 - val_f2_score: 0.3507 - val_f2_score_1: 0.3042 - val_f2_score_2: 0.2534 - val_f2_score_3: 0.2071 - val_f2_score_4: 0.1828 - val_f2_score_5: 0.1679 - val_f2_score_6: 0.1118 - val_f2_score_7: 0.0742
# Epoch 66/200
#  - 10s - loss: 0.0112 - acc: 0.9972 - categorical_accuracy: 0.1310 - f2_score: 0.3595 - f2_score_1: 0.3159 - f2_score_2: 0.2640 - f2_score_3: 0.2169 - f2_score_4: 0.1921 - f2_score_5: 0.1771 - f2_score_6: 0.1176 - f2_score_7: 0.0787 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.3517 - val_f2_score_1: 0.3054 - val_f2_score_2: 0.2548 - val_f2_score_3: 0.2076 - val_f2_score_4: 0.1835 - val_f2_score_5: 0.1692 - val_f2_score_6: 0.1129 - val_f2_score_7: 0.0750
# Epoch 67/200
#  - 10s - loss: 0.0112 - acc: 0.9972 - categorical_accuracy: 0.1312 - f2_score: 0.3602 - f2_score_1: 0.3160 - f2_score_2: 0.2644 - f2_score_3: 0.2175 - f2_score_4: 0.1925 - f2_score_5: 0.1777 - f2_score_6: 0.1184 - f2_score_7: 0.0794 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1170 - val_f2_score: 0.3532 - val_f2_score_1: 0.3078 - val_f2_score_2: 0.2579 - val_f2_score_3: 0.2112 - val_f2_score_4: 0.1875 - val_f2_score_5: 0.1738 - val_f2_score_6: 0.1164 - val_f2_score_7: 0.0781
# Epoch 68/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1315 - f2_score: 0.3608 - f2_score_1: 0.3171 - f2_score_2: 0.2654 - f2_score_3: 0.2185 - f2_score_4: 0.1935 - f2_score_5: 0.1788 - f2_score_6: 0.1194 - f2_score_7: 0.0801 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1207 - val_f2_score: 0.3522 - val_f2_score_1: 0.3068 - val_f2_score_2: 0.2566 - val_f2_score_3: 0.2099 - val_f2_score_4: 0.1862 - val_f2_score_5: 0.1706 - val_f2_score_6: 0.1142 - val_f2_score_7: 0.0765
# Epoch 69/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1318 - f2_score: 0.3613 - f2_score_1: 0.3178 - f2_score_2: 0.2661 - f2_score_3: 0.2192 - f2_score_4: 0.1941 - f2_score_5: 0.1793 - f2_score_6: 0.1199 - f2_score_7: 0.0806 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1223 - val_f2_score: 0.3527 - val_f2_score_1: 0.3076 - val_f2_score_2: 0.2576 - val_f2_score_3: 0.2114 - val_f2_score_4: 0.1873 - val_f2_score_5: 0.1724 - val_f2_score_6: 0.1154 - val_f2_score_7: 0.0770
# Epoch 70/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1322 - f2_score: 0.3620 - f2_score_1: 0.3182 - f2_score_2: 0.2668 - f2_score_3: 0.2198 - f2_score_4: 0.1947 - f2_score_5: 0.1796 - f2_score_6: 0.1203 - f2_score_7: 0.0807 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1183 - val_f2_score: 0.3530 - val_f2_score_1: 0.3081 - val_f2_score_2: 0.2573 - val_f2_score_3: 0.2111 - val_f2_score_4: 0.1877 - val_f2_score_5: 0.1734 - val_f2_score_6: 0.1170 - val_f2_score_7: 0.0785
# Epoch 71/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1325 - f2_score: 0.3623 - f2_score_1: 0.3188 - f2_score_2: 0.2674 - f2_score_3: 0.2206 - f2_score_4: 0.1955 - f2_score_5: 0.1805 - f2_score_6: 0.1211 - f2_score_7: 0.0814 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.3537 - val_f2_score_1: 0.3081 - val_f2_score_2: 0.2579 - val_f2_score_3: 0.2110 - val_f2_score_4: 0.1880 - val_f2_score_5: 0.1735 - val_f2_score_6: 0.1170 - val_f2_score_7: 0.0790
# Epoch 72/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1321 - f2_score: 0.3630 - f2_score_1: 0.3194 - f2_score_2: 0.2682 - f2_score_3: 0.2211 - f2_score_4: 0.1964 - f2_score_5: 0.1813 - f2_score_6: 0.1221 - f2_score_7: 0.0821 - val_loss: 0.0116 - val_acc: 0.9972 - val_categorical_accuracy: 0.1222 - val_f2_score: 0.3541 - val_f2_score_1: 0.3085 - val_f2_score_2: 0.2572 - val_f2_score_3: 0.2106 - val_f2_score_4: 0.1872 - val_f2_score_5: 0.1718 - val_f2_score_6: 0.1150 - val_f2_score_7: 0.0773
# Epoch 73/200
#  - 10s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1325 - f2_score: 0.3634 - f2_score_1: 0.3199 - f2_score_2: 0.2685 - f2_score_3: 0.2218 - f2_score_4: 0.1968 - f2_score_5: 0.1817 - f2_score_6: 0.1222 - f2_score_7: 0.0823 - val_loss: 0.0115 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.3537 - val_f2_score_1: 0.3087 - val_f2_score_2: 0.2577 - val_f2_score_3: 0.2113 - val_f2_score_4: 0.1880 - val_f2_score_5: 0.1729 - val_f2_score_6: 0.1163 - val_f2_score_7: 0.0789
# Epoch 74/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1328 - f2_score: 0.3637 - f2_score_1: 0.3202 - f2_score_2: 0.2694 - f2_score_3: 0.2221 - f2_score_4: 0.1975 - f2_score_5: 0.1825 - f2_score_6: 0.1228 - f2_score_7: 0.0828 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.3542 - val_f2_score_1: 0.3088 - val_f2_score_2: 0.2588 - val_f2_score_3: 0.2113 - val_f2_score_4: 0.1890 - val_f2_score_5: 0.1741 - val_f2_score_6: 0.1187 - val_f2_score_7: 0.0808
# Epoch 75/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1328 - f2_score: 0.3643 - f2_score_1: 0.3212 - f2_score_2: 0.2700 - f2_score_3: 0.2230 - f2_score_4: 0.1981 - f2_score_5: 0.1830 - f2_score_6: 0.1235 - f2_score_7: 0.0834 - val_loss: 0.0115 - val_acc: 0.9972 - val_categorical_accuracy: 0.1230 - val_f2_score: 0.3552 - val_f2_score_1: 0.3094 - val_f2_score_2: 0.2588 - val_f2_score_3: 0.2119 - val_f2_score_4: 0.1885 - val_f2_score_5: 0.1733 - val_f2_score_6: 0.1166 - val_f2_score_7: 0.0793
# Epoch 76/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1339 - f2_score: 0.3649 - f2_score_1: 0.3214 - f2_score_2: 0.2709 - f2_score_3: 0.2235 - f2_score_4: 0.1987 - f2_score_5: 0.1837 - f2_score_6: 0.1240 - f2_score_7: 0.0836 - val_loss: 0.0115 - val_acc: 0.9972 - val_categorical_accuracy: 0.1223 - val_f2_score: 0.3555 - val_f2_score_1: 0.3107 - val_f2_score_2: 0.2610 - val_f2_score_3: 0.2137 - val_f2_score_4: 0.1900 - val_f2_score_5: 0.1751 - val_f2_score_6: 0.1186 - val_f2_score_7: 0.0800
# Epoch 77/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1337 - f2_score: 0.3652 - f2_score_1: 0.3224 - f2_score_2: 0.2712 - f2_score_3: 0.2240 - f2_score_4: 0.1993 - f2_score_5: 0.1840 - f2_score_6: 0.1242 - f2_score_7: 0.0841 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1232 - val_f2_score: 0.3551 - val_f2_score_1: 0.3099 - val_f2_score_2: 0.2601 - val_f2_score_3: 0.2135 - val_f2_score_4: 0.1899 - val_f2_score_5: 0.1745 - val_f2_score_6: 0.1177 - val_f2_score_7: 0.0799
# Epoch 78/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1342 - f2_score: 0.3656 - f2_score_1: 0.3227 - f2_score_2: 0.2714 - f2_score_3: 0.2247 - f2_score_4: 0.1996 - f2_score_5: 0.1849 - f2_score_6: 0.1248 - f2_score_7: 0.0845 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1209 - val_f2_score: 0.3563 - val_f2_score_1: 0.3122 - val_f2_score_2: 0.2614 - val_f2_score_3: 0.2142 - val_f2_score_4: 0.1916 - val_f2_score_5: 0.1763 - val_f2_score_6: 0.1193 - val_f2_score_7: 0.0809
# Epoch 79/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1334 - f2_score: 0.3663 - f2_score_1: 0.3234 - f2_score_2: 0.2725 - f2_score_3: 0.2253 - f2_score_4: 0.2003 - f2_score_5: 0.1855 - f2_score_6: 0.1252 - f2_score_7: 0.0848 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1226 - val_f2_score: 0.3567 - val_f2_score_1: 0.3126 - val_f2_score_2: 0.2626 - val_f2_score_3: 0.2162 - val_f2_score_4: 0.1931 - val_f2_score_5: 0.1784 - val_f2_score_6: 0.1206 - val_f2_score_7: 0.0825
# Epoch 80/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1338 - f2_score: 0.3666 - f2_score_1: 0.3239 - f2_score_2: 0.2731 - f2_score_3: 0.2262 - f2_score_4: 0.2014 - f2_score_5: 0.1864 - f2_score_6: 0.1261 - f2_score_7: 0.0855 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1268 - val_f2_score: 0.3570 - val_f2_score_1: 0.3127 - val_f2_score_2: 0.2616 - val_f2_score_3: 0.2149 - val_f2_score_4: 0.1903 - val_f2_score_5: 0.1756 - val_f2_score_6: 0.1171 - val_f2_score_7: 0.0800
# Epoch 81/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1346 - f2_score: 0.3671 - f2_score_1: 0.3244 - f2_score_2: 0.2736 - f2_score_3: 0.2264 - f2_score_4: 0.2015 - f2_score_5: 0.1864 - f2_score_6: 0.1265 - f2_score_7: 0.0854 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1198 - val_f2_score: 0.3576 - val_f2_score_1: 0.3146 - val_f2_score_2: 0.2638 - val_f2_score_3: 0.2175 - val_f2_score_4: 0.1943 - val_f2_score_5: 0.1796 - val_f2_score_6: 0.1221 - val_f2_score_7: 0.0835
# Epoch 82/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1343 - f2_score: 0.3675 - f2_score_1: 0.3252 - f2_score_2: 0.2742 - f2_score_3: 0.2270 - f2_score_4: 0.2020 - f2_score_5: 0.1872 - f2_score_6: 0.1273 - f2_score_7: 0.0862 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1230 - val_f2_score: 0.3575 - val_f2_score_1: 0.3140 - val_f2_score_2: 0.2647 - val_f2_score_3: 0.2182 - val_f2_score_4: 0.1949 - val_f2_score_5: 0.1795 - val_f2_score_6: 0.1209 - val_f2_score_7: 0.0828
# Epoch 83/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1352 - f2_score: 0.3680 - f2_score_1: 0.3254 - f2_score_2: 0.2748 - f2_score_3: 0.2281 - f2_score_4: 0.2028 - f2_score_5: 0.1874 - f2_score_6: 0.1273 - f2_score_7: 0.0866 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.3582 - val_f2_score_1: 0.3148 - val_f2_score_2: 0.2649 - val_f2_score_3: 0.2177 - val_f2_score_4: 0.1949 - val_f2_score_5: 0.1806 - val_f2_score_6: 0.1224 - val_f2_score_7: 0.0840
# Epoch 84/200
#  - 10s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1352 - f2_score: 0.3684 - f2_score_1: 0.3261 - f2_score_2: 0.2752 - f2_score_3: 0.2284 - f2_score_4: 0.2034 - f2_score_5: 0.1883 - f2_score_6: 0.1281 - f2_score_7: 0.0871 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1237 - val_f2_score: 0.3583 - val_f2_score_1: 0.3155 - val_f2_score_2: 0.2659 - val_f2_score_3: 0.2189 - val_f2_score_4: 0.1961 - val_f2_score_5: 0.1802 - val_f2_score_6: 0.1219 - val_f2_score_7: 0.0832
# Epoch 85/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1355 - f2_score: 0.3691 - f2_score_1: 0.3265 - f2_score_2: 0.2759 - f2_score_3: 0.2290 - f2_score_4: 0.2038 - f2_score_5: 0.1887 - f2_score_6: 0.1283 - f2_score_7: 0.0870 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1233 - val_f2_score: 0.3586 - val_f2_score_1: 0.3145 - val_f2_score_2: 0.2640 - val_f2_score_3: 0.2175 - val_f2_score_4: 0.1948 - val_f2_score_5: 0.1797 - val_f2_score_6: 0.1222 - val_f2_score_7: 0.0836
# Epoch 86/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1352 - f2_score: 0.3693 - f2_score_1: 0.3267 - f2_score_2: 0.2763 - f2_score_3: 0.2294 - f2_score_4: 0.2044 - f2_score_5: 0.1892 - f2_score_6: 0.1288 - f2_score_7: 0.0877 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1228 - val_f2_score: 0.3594 - val_f2_score_1: 0.3157 - val_f2_score_2: 0.2655 - val_f2_score_3: 0.2184 - val_f2_score_4: 0.1954 - val_f2_score_5: 0.1810 - val_f2_score_6: 0.1228 - val_f2_score_7: 0.0845
# Epoch 87/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1358 - f2_score: 0.3697 - f2_score_1: 0.3277 - f2_score_2: 0.2773 - f2_score_3: 0.2300 - f2_score_4: 0.2047 - f2_score_5: 0.1897 - f2_score_6: 0.1295 - f2_score_7: 0.0881 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.3592 - val_f2_score_1: 0.3163 - val_f2_score_2: 0.2678 - val_f2_score_3: 0.2218 - val_f2_score_4: 0.1989 - val_f2_score_5: 0.1843 - val_f2_score_6: 0.1251 - val_f2_score_7: 0.0856
# Epoch 88/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1361 - f2_score: 0.3703 - f2_score_1: 0.3282 - f2_score_2: 0.2775 - f2_score_3: 0.2308 - f2_score_4: 0.2056 - f2_score_5: 0.1906 - f2_score_6: 0.1300 - f2_score_7: 0.0885 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1222 - val_f2_score: 0.3590 - val_f2_score_1: 0.3148 - val_f2_score_2: 0.2654 - val_f2_score_3: 0.2187 - val_f2_score_4: 0.1961 - val_f2_score_5: 0.1810 - val_f2_score_6: 0.1232 - val_f2_score_7: 0.0848
# Epoch 89/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1360 - f2_score: 0.3707 - f2_score_1: 0.3283 - f2_score_2: 0.2779 - f2_score_3: 0.2313 - f2_score_4: 0.2061 - f2_score_5: 0.1910 - f2_score_6: 0.1303 - f2_score_7: 0.0891 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1224 - val_f2_score: 0.3597 - val_f2_score_1: 0.3163 - val_f2_score_2: 0.2664 - val_f2_score_3: 0.2198 - val_f2_score_4: 0.1966 - val_f2_score_5: 0.1818 - val_f2_score_6: 0.1237 - val_f2_score_7: 0.0852
# Epoch 90/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1369 - f2_score: 0.3709 - f2_score_1: 0.3291 - f2_score_2: 0.2786 - f2_score_3: 0.2315 - f2_score_4: 0.2066 - f2_score_5: 0.1911 - f2_score_6: 0.1307 - f2_score_7: 0.0893 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1198 - val_f2_score: 0.3603 - val_f2_score_1: 0.3173 - val_f2_score_2: 0.2680 - val_f2_score_3: 0.2204 - val_f2_score_4: 0.1980 - val_f2_score_5: 0.1838 - val_f2_score_6: 0.1253 - val_f2_score_7: 0.0862
# Epoch 91/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1363 - f2_score: 0.3715 - f2_score_1: 0.3294 - f2_score_2: 0.2793 - f2_score_3: 0.2324 - f2_score_4: 0.2071 - f2_score_5: 0.1920 - f2_score_6: 0.1313 - f2_score_7: 0.0898 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1228 - val_f2_score: 0.3600 - val_f2_score_1: 0.3169 - val_f2_score_2: 0.2669 - val_f2_score_3: 0.2204 - val_f2_score_4: 0.1976 - val_f2_score_5: 0.1830 - val_f2_score_6: 0.1251 - val_f2_score_7: 0.0863
# Epoch 92/200
#  - 10s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1369 - f2_score: 0.3717 - f2_score_1: 0.3297 - f2_score_2: 0.2795 - f2_score_3: 0.2323 - f2_score_4: 0.2076 - f2_score_5: 0.1923 - f2_score_6: 0.1316 - f2_score_7: 0.0900 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1220 - val_f2_score: 0.3606 - val_f2_score_1: 0.3175 - val_f2_score_2: 0.2687 - val_f2_score_3: 0.2216 - val_f2_score_4: 0.1983 - val_f2_score_5: 0.1846 - val_f2_score_6: 0.1254 - val_f2_score_7: 0.0871
# Epoch 93/200
# ...
# Epoch 171/200
#  - 10s - loss: 0.0106 - acc: 0.9973 - categorical_accuracy: 0.1491 - f2_score: 0.3920 - f2_score_1: 0.3539 - f2_score_2: 0.3075 - f2_score_3: 0.2614 - f2_score_4: 0.2363 - f2_score_5: 0.2207 - f2_score_6: 0.1567 - f2_score_7: 0.1114 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1316 - val_f2_score: 0.3725 - val_f2_score_1: 0.3364 - val_f2_score_2: 0.2908 - val_f2_score_3: 0.2457 - val_f2_score_4: 0.2219 - val_f2_score_5: 0.2067 - val_f2_score_6: 0.1471 - val_f2_score_7: 0.1046
# Epoch 172/200
#  - 10s - loss: 0.0106 - acc: 0.9973 - categorical_accuracy: 0.1484 - f2_score: 0.3924 - f2_score_1: 0.3539 - f2_score_2: 0.3076 - f2_score_3: 0.2614 - f2_score_4: 0.2362 - f2_score_5: 0.2206 - f2_score_6: 0.1566 - f2_score_7: 0.1114 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1318 - val_f2_score: 0.3730 - val_f2_score_1: 0.3370 - val_f2_score_2: 0.2915 - val_f2_score_3: 0.2467 - val_f2_score_4: 0.2225 - val_f2_score_5: 0.2083 - val_f2_score_6: 0.1481 - val_f2_score_7: 0.1054
# Epoch 173/200
#  - 10s - loss: 0.0106 - acc: 0.9973 - categorical_accuracy: 0.1487 - f2_score: 0.3924 - f2_score_1: 0.3542 - f2_score_2: 0.3079 - f2_score_3: 0.2618 - f2_score_4: 0.2366 - f2_score_5: 0.2212 - f2_score_6: 0.1574 - f2_score_7: 0.1117 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1328 - val_f2_score: 0.3733 - val_f2_score_1: 0.3367 - val_f2_score_2: 0.2918 - val_f2_score_3: 0.2464 - val_f2_score_4: 0.2222 - val_f2_score_5: 0.2076 - val_f2_score_6: 0.1473 - val_f2_score_7: 0.1052
# Epoch 174/200
#  - 10s - loss: 0.0106 - acc: 0.9973 - categorical_accuracy: 0.1486 - f2_score: 0.3927 - f2_score_1: 0.3546 - f2_score_2: 0.3084 - f2_score_3: 0.2624 - f2_score_4: 0.2371 - f2_score_5: 0.2214 - f2_score_6: 0.1576 - f2_score_7: 0.1118 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1338 - val_f2_score: 0.3723 - val_f2_score_1: 0.3351 - val_f2_score_2: 0.2892 - val_f2_score_3: 0.2438 - val_f2_score_4: 0.2200 - val_f2_score_5: 0.2054 - val_f2_score_6: 0.1463 - val_f2_score_7: 0.1039
# Epoch 175/200
#  - 10s - loss: 0.0106 - acc: 0.9973 - categorical_accuracy: 0.1487 - f2_score: 0.3929 - f2_score_1: 0.3544 - f2_score_2: 0.3083 - f2_score_3: 0.2625 - f2_score_4: 0.2370 - f2_score_5: 0.2214 - f2_score_6: 0.1577 - f2_score_7: 0.1120 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1343 - val_f2_score: 0.3732 - val_f2_score_1: 0.3369 - val_f2_score_2: 0.2921 - val_f2_score_3: 0.2463 - val_f2_score_4: 0.2229 - val_f2_score_5: 0.2084 - val_f2_score_6: 0.1477 - val_f2_score_7: 0.1051
# Epoch 176/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1489 - f2_score: 0.3932 - f2_score_1: 0.3549 - f2_score_2: 0.3088 - f2_score_3: 0.2628 - f2_score_4: 0.2374 - f2_score_5: 0.2218 - f2_score_6: 0.1579 - f2_score_7: 0.1120 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1347 - val_f2_score: 0.3736 - val_f2_score_1: 0.3371 - val_f2_score_2: 0.2917 - val_f2_score_3: 0.2467 - val_f2_score_4: 0.2225 - val_f2_score_5: 0.2081 - val_f2_score_6: 0.1480 - val_f2_score_7: 0.1050
# Epoch 177/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1494 - f2_score: 0.3934 - f2_score_1: 0.3551 - f2_score_2: 0.3090 - f2_score_3: 0.2629 - f2_score_4: 0.2378 - f2_score_5: 0.2220 - f2_score_6: 0.1580 - f2_score_7: 0.1123 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1344 - val_f2_score: 0.3734 - val_f2_score_1: 0.3380 - val_f2_score_2: 0.2928 - val_f2_score_3: 0.2474 - val_f2_score_4: 0.2243 - val_f2_score_5: 0.2093 - val_f2_score_6: 0.1489 - val_f2_score_7: 0.1063
# Epoch 178/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1493 - f2_score: 0.3935 - f2_score_1: 0.3553 - f2_score_2: 0.3095 - f2_score_3: 0.2630 - f2_score_4: 0.2383 - f2_score_5: 0.2223 - f2_score_6: 0.1581 - f2_score_7: 0.1127 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1345 - val_f2_score: 0.3736 - val_f2_score_1: 0.3357 - val_f2_score_2: 0.2903 - val_f2_score_3: 0.2450 - val_f2_score_4: 0.2200 - val_f2_score_5: 0.2053 - val_f2_score_6: 0.1460 - val_f2_score_7: 0.1045
# Epoch 179/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1483 - f2_score: 0.3937 - f2_score_1: 0.3555 - f2_score_2: 0.3093 - f2_score_3: 0.2635 - f2_score_4: 0.2384 - f2_score_5: 0.2225 - f2_score_6: 0.1585 - f2_score_7: 0.1128 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1345 - val_f2_score: 0.3732 - val_f2_score_1: 0.3355 - val_f2_score_2: 0.2898 - val_f2_score_3: 0.2448 - val_f2_score_4: 0.2207 - val_f2_score_5: 0.2054 - val_f2_score_6: 0.1465 - val_f2_score_7: 0.1043
# Epoch 180/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1493 - f2_score: 0.3937 - f2_score_1: 0.3557 - f2_score_2: 0.3096 - f2_score_3: 0.2635 - f2_score_4: 0.2381 - f2_score_5: 0.2226 - f2_score_6: 0.1588 - f2_score_7: 0.1129 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1325 - val_f2_score: 0.3734 - val_f2_score_1: 0.3378 - val_f2_score_2: 0.2935 - val_f2_score_3: 0.2483 - val_f2_score_4: 0.2242 - val_f2_score_5: 0.2099 - val_f2_score_6: 0.1495 - val_f2_score_7: 0.1067
# Epoch 181/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1489 - f2_score: 0.3942 - f2_score_1: 0.3557 - f2_score_2: 0.3099 - f2_score_3: 0.2640 - f2_score_4: 0.2389 - f2_score_5: 0.2233 - f2_score_6: 0.1591 - f2_score_7: 0.1134 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1327 - val_f2_score: 0.3738 - val_f2_score_1: 0.3375 - val_f2_score_2: 0.2920 - val_f2_score_3: 0.2468 - val_f2_score_4: 0.2230 - val_f2_score_5: 0.2083 - val_f2_score_6: 0.1484 - val_f2_score_7: 0.1062
# Epoch 182/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1494 - f2_score: 0.3942 - f2_score_1: 0.3560 - f2_score_2: 0.3101 - f2_score_3: 0.2644 - f2_score_4: 0.2390 - f2_score_5: 0.2235 - f2_score_6: 0.1591 - f2_score_7: 0.1136 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.3734 - val_f2_score_1: 0.3372 - val_f2_score_2: 0.2926 - val_f2_score_3: 0.2476 - val_f2_score_4: 0.2230 - val_f2_score_5: 0.2090 - val_f2_score_6: 0.1493 - val_f2_score_7: 0.1065
# Epoch 183/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1492 - f2_score: 0.3944 - f2_score_1: 0.3566 - f2_score_2: 0.3103 - f2_score_3: 0.2646 - f2_score_4: 0.2392 - f2_score_5: 0.2238 - f2_score_6: 0.1593 - f2_score_7: 0.1136 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1341 - val_f2_score: 0.3735 - val_f2_score_1: 0.3363 - val_f2_score_2: 0.2911 - val_f2_score_3: 0.2457 - val_f2_score_4: 0.2219 - val_f2_score_5: 0.2069 - val_f2_score_6: 0.1476 - val_f2_score_7: 0.1056
# Epoch 184/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1496 - f2_score: 0.3945 - f2_score_1: 0.3565 - f2_score_2: 0.3107 - f2_score_3: 0.2645 - f2_score_4: 0.2395 - f2_score_5: 0.2239 - f2_score_6: 0.1599 - f2_score_7: 0.1138 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1341 - val_f2_score: 0.3739 - val_f2_score_1: 0.3366 - val_f2_score_2: 0.2918 - val_f2_score_3: 0.2472 - val_f2_score_4: 0.2229 - val_f2_score_5: 0.2085 - val_f2_score_6: 0.1488 - val_f2_score_7: 0.1064
# Epoch 185/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1494 - f2_score: 0.3946 - f2_score_1: 0.3566 - f2_score_2: 0.3108 - f2_score_3: 0.2650 - f2_score_4: 0.2396 - f2_score_5: 0.2238 - f2_score_6: 0.1599 - f2_score_7: 0.1140 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1348 - val_f2_score: 0.3741 - val_f2_score_1: 0.3386 - val_f2_score_2: 0.2942 - val_f2_score_3: 0.2484 - val_f2_score_4: 0.2246 - val_f2_score_5: 0.2102 - val_f2_score_6: 0.1494 - val_f2_score_7: 0.1065
# Epoch 186/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1497 - f2_score: 0.3948 - f2_score_1: 0.3569 - f2_score_2: 0.3111 - f2_score_3: 0.2654 - f2_score_4: 0.2401 - f2_score_5: 0.2243 - f2_score_6: 0.1603 - f2_score_7: 0.1143 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1336 - val_f2_score: 0.3743 - val_f2_score_1: 0.3379 - val_f2_score_2: 0.2923 - val_f2_score_3: 0.2473 - val_f2_score_4: 0.2230 - val_f2_score_5: 0.2082 - val_f2_score_6: 0.1484 - val_f2_score_7: 0.1063
# Epoch 187/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1503 - f2_score: 0.3951 - f2_score_1: 0.3571 - f2_score_2: 0.3115 - f2_score_3: 0.2653 - f2_score_4: 0.2404 - f2_score_5: 0.2247 - f2_score_6: 0.1604 - f2_score_7: 0.1144 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1327 - val_f2_score: 0.3741 - val_f2_score_1: 0.3379 - val_f2_score_2: 0.2925 - val_f2_score_3: 0.2475 - val_f2_score_4: 0.2238 - val_f2_score_5: 0.2088 - val_f2_score_6: 0.1500 - val_f2_score_7: 0.1073
# Epoch 188/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1495 - f2_score: 0.3953 - f2_score_1: 0.3575 - f2_score_2: 0.3114 - f2_score_3: 0.2654 - f2_score_4: 0.2402 - f2_score_5: 0.2245 - f2_score_6: 0.1603 - f2_score_7: 0.1144 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1323 - val_f2_score: 0.3749 - val_f2_score_1: 0.3384 - val_f2_score_2: 0.2926 - val_f2_score_3: 0.2472 - val_f2_score_4: 0.2234 - val_f2_score_5: 0.2086 - val_f2_score_6: 0.1492 - val_f2_score_7: 0.1068
# Epoch 189/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1497 - f2_score: 0.3955 - f2_score_1: 0.3575 - f2_score_2: 0.3120 - f2_score_3: 0.2659 - f2_score_4: 0.2407 - f2_score_5: 0.2250 - f2_score_6: 0.1611 - f2_score_7: 0.1148 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1352 - val_f2_score: 0.3747 - val_f2_score_1: 0.3378 - val_f2_score_2: 0.2933 - val_f2_score_3: 0.2486 - val_f2_score_4: 0.2244 - val_f2_score_5: 0.2101 - val_f2_score_6: 0.1501 - val_f2_score_7: 0.1080
# Epoch 190/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1506 - f2_score: 0.3954 - f2_score_1: 0.3574 - f2_score_2: 0.3119 - f2_score_3: 0.2659 - f2_score_4: 0.2409 - f2_score_5: 0.2252 - f2_score_6: 0.1607 - f2_score_7: 0.1149 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1339 - val_f2_score: 0.3752 - val_f2_score_1: 0.3380 - val_f2_score_2: 0.2931 - val_f2_score_3: 0.2478 - val_f2_score_4: 0.2235 - val_f2_score_5: 0.2087 - val_f2_score_6: 0.1494 - val_f2_score_7: 0.1074
# Epoch 191/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1495 - f2_score: 0.3959 - f2_score_1: 0.3578 - f2_score_2: 0.3123 - f2_score_3: 0.2664 - f2_score_4: 0.2411 - f2_score_5: 0.2253 - f2_score_6: 0.1613 - f2_score_7: 0.1151 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1365 - val_f2_score: 0.3749 - val_f2_score_1: 0.3387 - val_f2_score_2: 0.2941 - val_f2_score_3: 0.2488 - val_f2_score_4: 0.2246 - val_f2_score_5: 0.2098 - val_f2_score_6: 0.1493 - val_f2_score_7: 0.1078
# Epoch 192/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1503 - f2_score: 0.3959 - f2_score_1: 0.3581 - f2_score_2: 0.3126 - f2_score_3: 0.2666 - f2_score_4: 0.2415 - f2_score_5: 0.2259 - f2_score_6: 0.1614 - f2_score_7: 0.1152 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1312 - val_f2_score: 0.3738 - val_f2_score_1: 0.3376 - val_f2_score_2: 0.2925 - val_f2_score_3: 0.2475 - val_f2_score_4: 0.2236 - val_f2_score_5: 0.2088 - val_f2_score_6: 0.1499 - val_f2_score_7: 0.1078
# Epoch 193/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1506 - f2_score: 0.3959 - f2_score_1: 0.3583 - f2_score_2: 0.3126 - f2_score_3: 0.2666 - f2_score_4: 0.2416 - f2_score_5: 0.2258 - f2_score_6: 0.1614 - f2_score_7: 0.1153 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1317 - val_f2_score: 0.3754 - val_f2_score_1: 0.3402 - val_f2_score_2: 0.2957 - val_f2_score_3: 0.2512 - val_f2_score_4: 0.2267 - val_f2_score_5: 0.2121 - val_f2_score_6: 0.1517 - val_f2_score_7: 0.1093
# Epoch 194/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1504 - f2_score: 0.3961 - f2_score_1: 0.3582 - f2_score_2: 0.3131 - f2_score_3: 0.2670 - f2_score_4: 0.2419 - f2_score_5: 0.2261 - f2_score_6: 0.1619 - f2_score_7: 0.1154 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1332 - val_f2_score: 0.3751 - val_f2_score_1: 0.3385 - val_f2_score_2: 0.2940 - val_f2_score_3: 0.2497 - val_f2_score_4: 0.2255 - val_f2_score_5: 0.2109 - val_f2_score_6: 0.1517 - val_f2_score_7: 0.1096
# Epoch 195/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1509 - f2_score: 0.3965 - f2_score_1: 0.3586 - f2_score_2: 0.3132 - f2_score_3: 0.2673 - f2_score_4: 0.2422 - f2_score_5: 0.2263 - f2_score_6: 0.1620 - f2_score_7: 0.1158 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1323 - val_f2_score: 0.3748 - val_f2_score_1: 0.3382 - val_f2_score_2: 0.2937 - val_f2_score_3: 0.2484 - val_f2_score_4: 0.2242 - val_f2_score_5: 0.2098 - val_f2_score_6: 0.1499 - val_f2_score_7: 0.1078
# Epoch 196/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1509 - f2_score: 0.3966 - f2_score_1: 0.3588 - f2_score_2: 0.3132 - f2_score_3: 0.2671 - f2_score_4: 0.2420 - f2_score_5: 0.2265 - f2_score_6: 0.1620 - f2_score_7: 0.1158 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1351 - val_f2_score: 0.3752 - val_f2_score_1: 0.3386 - val_f2_score_2: 0.2940 - val_f2_score_3: 0.2494 - val_f2_score_4: 0.2254 - val_f2_score_5: 0.2107 - val_f2_score_6: 0.1509 - val_f2_score_7: 0.1083
# Epoch 197/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1505 - f2_score: 0.3967 - f2_score_1: 0.3590 - f2_score_2: 0.3136 - f2_score_3: 0.2680 - f2_score_4: 0.2424 - f2_score_5: 0.2270 - f2_score_6: 0.1624 - f2_score_7: 0.1162 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1330 - val_f2_score: 0.3748 - val_f2_score_1: 0.3388 - val_f2_score_2: 0.2944 - val_f2_score_3: 0.2495 - val_f2_score_4: 0.2256 - val_f2_score_5: 0.2113 - val_f2_score_6: 0.1513 - val_f2_score_7: 0.1084
# Epoch 198/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1508 - f2_score: 0.3970 - f2_score_1: 0.3591 - f2_score_2: 0.3135 - f2_score_3: 0.2679 - f2_score_4: 0.2423 - f2_score_5: 0.2269 - f2_score_6: 0.1625 - f2_score_7: 0.1161 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1336 - val_f2_score: 0.3750 - val_f2_score_1: 0.3395 - val_f2_score_2: 0.2941 - val_f2_score_3: 0.2502 - val_f2_score_4: 0.2258 - val_f2_score_5: 0.2114 - val_f2_score_6: 0.1517 - val_f2_score_7: 0.1093
# Epoch 199/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1509 - f2_score: 0.3970 - f2_score_1: 0.3595 - f2_score_2: 0.3139 - f2_score_3: 0.2682 - f2_score_4: 0.2433 - f2_score_5: 0.2273 - f2_score_6: 0.1630 - f2_score_7: 0.1165 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1321 - val_f2_score: 0.3750 - val_f2_score_1: 0.3385 - val_f2_score_2: 0.2926 - val_f2_score_3: 0.2477 - val_f2_score_4: 0.2243 - val_f2_score_5: 0.2088 - val_f2_score_6: 0.1497 - val_f2_score_7: 0.1081
# Epoch 200/200
#  - 10s - loss: 0.0105 - acc: 0.9973 - categorical_accuracy: 0.1515 - f2_score: 0.3971 - f2_score_1: 0.3591 - f2_score_2: 0.3141 - f2_score_3: 0.2681 - f2_score_4: 0.2429 - f2_score_5: 0.2272 - f2_score_6: 0.1628 - f2_score_7: 0.1166 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.3747 - val_f2_score_1: 0.3405 - val_f2_score_2: 0.2958 - val_f2_score_3: 0.2517 - val_f2_score_4: 0.2276 - val_f2_score_5: 0.2128 - val_f2_score_6: 0.1534 - val_f2_score_7: 0.1105

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
print('Best f2 score is: %.2f' % best_thr_val)
# Out:
# Best threshold is: 0.1
# Best f2 score is: 0.37

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                     attribute_ids
# 0  10023b2cc4ed5f68              121 343 369 766 1059
# 1  100fbe75ed8fd887          121 188 231 369 489 1039
# 2  101b627524a04f19    79 121 147 497 498 718 813 961
# 3  10234480c41284c6  13 147 483 776 813 830 1046 1092
# 4  1023b0e2636dcea8                           671 813
# 5   1039cd6cf85845c   13 147 194 405 813 896 903 1092
# 6   103a5b3f83fbe88          147 194 671 780 813 1092
# 7  10413aaae8d6a9a2          51 147 671 813 1046 1092
# 8  10423822b93a65ab                       51 147 1092
# 9  1052bf702cb099f7                       188 597 671
