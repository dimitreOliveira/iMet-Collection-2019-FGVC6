# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 27s - loss: 0.0175 - acc: 0.9957 - categorical_accuracy: 0.1061 - f2_score: 0.2438 - f2_score_1: 0.2114 - f2_score_2: 0.1798 - f2_score_3: 0.1514 - f2_score_4: 0.1369 - f2_score_5: 0.1278 - f2_score_6: 0.0904 - f2_score_7: 0.0631 - val_loss: 0.0119 - val_acc: 0.9973 - val_categorical_accuracy: 0.1699 - val_f2_score: 0.3313 - val_f2_score_1: 0.2848 - val_f2_score_2: 0.2363 - val_f2_score_3: 0.1966 - val_f2_score_4: 0.1757 - val_f2_score_5: 0.1629 - val_f2_score_6: 0.1125 - val_f2_score_7: 0.0778
# Epoch 2/200
#  - 24s - loss: 0.0119 - acc: 0.9972 - categorical_accuracy: 0.1509 - f2_score: 0.3429 - f2_score_1: 0.3084 - f2_score_2: 0.2707 - f2_score_3: 0.2347 - f2_score_4: 0.2157 - f2_score_5: 0.2036 - f2_score_6: 0.1514 - f2_score_7: 0.1115 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1276 - val_f2_score: 0.3640 - val_f2_score_1: 0.3178 - val_f2_score_2: 0.2744 - val_f2_score_3: 0.2359 - val_f2_score_4: 0.2156 - val_f2_score_5: 0.2040 - val_f2_score_6: 0.1512 - val_f2_score_7: 0.1116
# Epoch 3/200
#  - 24s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1694 - f2_score: 0.3759 - f2_score_1: 0.3451 - f2_score_2: 0.3069 - f2_score_3: 0.2712 - f2_score_4: 0.2509 - f2_score_5: 0.2383 - f2_score_6: 0.1815 - f2_score_7: 0.1374 - val_loss: 0.0110 - val_acc: 0.9973 - val_categorical_accuracy: 0.1468 - val_f2_score: 0.3862 - val_f2_score_1: 0.3514 - val_f2_score_2: 0.3126 - val_f2_score_3: 0.2760 - val_f2_score_4: 0.2550 - val_f2_score_5: 0.2418 - val_f2_score_6: 0.1828 - val_f2_score_7: 0.1366
# Epoch 4/200
#  - 24s - loss: 0.0108 - acc: 0.9974 - categorical_accuracy: 0.1833 - f2_score: 0.3990 - f2_score_1: 0.3690 - f2_score_2: 0.3330 - f2_score_3: 0.2968 - f2_score_4: 0.2763 - f2_score_5: 0.2630 - f2_score_6: 0.2031 - f2_score_7: 0.1564 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1739 - val_f2_score: 0.3947 - val_f2_score_1: 0.3570 - val_f2_score_2: 0.3174 - val_f2_score_3: 0.2806 - val_f2_score_4: 0.2600 - val_f2_score_5: 0.2464 - val_f2_score_6: 0.1901 - val_f2_score_7: 0.1459
# Epoch 5/200
#  - 24s - loss: 0.0104 - acc: 0.9974 - categorical_accuracy: 0.1957 - f2_score: 0.4175 - f2_score_1: 0.3898 - f2_score_2: 0.3544 - f2_score_3: 0.3186 - f2_score_4: 0.2979 - f2_score_5: 0.2844 - f2_score_6: 0.2241 - f2_score_7: 0.1735 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1727 - val_f2_score: 0.4104 - val_f2_score_1: 0.3794 - val_f2_score_2: 0.3420 - val_f2_score_3: 0.3066 - val_f2_score_4: 0.2862 - val_f2_score_5: 0.2738 - val_f2_score_6: 0.2142 - val_f2_score_7: 0.1637
# Epoch 6/200
#  - 24s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2060 - f2_score: 0.4339 - f2_score_1: 0.4072 - f2_score_2: 0.3723 - f2_score_3: 0.3373 - f2_score_4: 0.3170 - f2_score_5: 0.3030 - f2_score_6: 0.2412 - f2_score_7: 0.1895 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.1825 - val_f2_score: 0.4228 - val_f2_score_1: 0.3946 - val_f2_score_2: 0.3595 - val_f2_score_3: 0.3256 - val_f2_score_4: 0.3048 - val_f2_score_5: 0.2913 - val_f2_score_6: 0.2307 - val_f2_score_7: 0.1794
# Epoch 7/200
#  - 25s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2163 - f2_score: 0.4483 - f2_score_1: 0.4236 - f2_score_2: 0.3900 - f2_score_3: 0.3545 - f2_score_4: 0.3335 - f2_score_5: 0.3200 - f2_score_6: 0.2569 - f2_score_7: 0.2035 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.1996 - val_f2_score: 0.4246 - val_f2_score_1: 0.3951 - val_f2_score_2: 0.3602 - val_f2_score_3: 0.3256 - val_f2_score_4: 0.3038 - val_f2_score_5: 0.2902 - val_f2_score_6: 0.2275 - val_f2_score_7: 0.1767
# Epoch 8/200
#  - 24s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2270 - f2_score: 0.4623 - f2_score_1: 0.4384 - f2_score_2: 0.4059 - f2_score_3: 0.3704 - f2_score_4: 0.3495 - f2_score_5: 0.3356 - f2_score_6: 0.2718 - f2_score_7: 0.2173 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.1983 - val_f2_score: 0.4259 - val_f2_score_1: 0.3948 - val_f2_score_2: 0.3580 - val_f2_score_3: 0.3237 - val_f2_score_4: 0.3039 - val_f2_score_5: 0.2905 - val_f2_score_6: 0.2295 - val_f2_score_7: 0.1817
# Epoch 9/200
#  - 24s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2372 - f2_score: 0.4753 - f2_score_1: 0.4529 - f2_score_2: 0.4209 - f2_score_3: 0.3858 - f2_score_4: 0.3645 - f2_score_5: 0.3505 - f2_score_6: 0.2865 - f2_score_7: 0.2311 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2085 - val_f2_score: 0.4316 - val_f2_score_1: 0.4014 - val_f2_score_2: 0.3660 - val_f2_score_3: 0.3328 - val_f2_score_4: 0.3138 - val_f2_score_5: 0.3023 - val_f2_score_6: 0.2459 - val_f2_score_7: 0.1986
# Epoch 10/200
#  - 24s - loss: 0.0090 - acc: 0.9975 - categorical_accuracy: 0.2473 - f2_score: 0.4873 - f2_score_1: 0.4661 - f2_score_2: 0.4342 - f2_score_3: 0.3994 - f2_score_4: 0.3786 - f2_score_5: 0.3650 - f2_score_6: 0.3010 - f2_score_7: 0.2442 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2215 - val_f2_score: 0.4394 - val_f2_score_1: 0.4110 - val_f2_score_2: 0.3797 - val_f2_score_3: 0.3471 - val_f2_score_4: 0.3275 - val_f2_score_5: 0.3143 - val_f2_score_6: 0.2548 - val_f2_score_7: 0.2056
# Epoch 11/200
#  - 24s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.2551 - f2_score: 0.4993 - f2_score_1: 0.4794 - f2_score_2: 0.4481 - f2_score_3: 0.4135 - f2_score_4: 0.3930 - f2_score_5: 0.3800 - f2_score_6: 0.3153 - f2_score_7: 0.2582 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2076 - val_f2_score: 0.4396 - val_f2_score_1: 0.4125 - val_f2_score_2: 0.3800 - val_f2_score_3: 0.3482 - val_f2_score_4: 0.3295 - val_f2_score_5: 0.3169 - val_f2_score_6: 0.2608 - val_f2_score_7: 0.2084
# Epoch 12/200
#  - 24s - loss: 0.0086 - acc: 0.9976 - categorical_accuracy: 0.2631 - f2_score: 0.5108 - f2_score_1: 0.4919 - f2_score_2: 0.4609 - f2_score_3: 0.4272 - f2_score_4: 0.4071 - f2_score_5: 0.3936 - f2_score_6: 0.3298 - f2_score_7: 0.2707 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2141 - val_f2_score: 0.4406 - val_f2_score_1: 0.4112 - val_f2_score_2: 0.3776 - val_f2_score_3: 0.3449 - val_f2_score_4: 0.3262 - val_f2_score_5: 0.3132 - val_f2_score_6: 0.2580 - val_f2_score_7: 0.2109
# Epoch 13/200
#  - 24s - loss: 0.0084 - acc: 0.9976 - categorical_accuracy: 0.2730 - f2_score: 0.5225 - f2_score_1: 0.5045 - f2_score_2: 0.4740 - f2_score_3: 0.4409 - f2_score_4: 0.4205 - f2_score_5: 0.4077 - f2_score_6: 0.3431 - f2_score_7: 0.2837 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2248 - val_f2_score: 0.4453 - val_f2_score_1: 0.4155 - val_f2_score_2: 0.3843 - val_f2_score_3: 0.3523 - val_f2_score_4: 0.3338 - val_f2_score_5: 0.3220 - val_f2_score_6: 0.2674 - val_f2_score_7: 0.2172
# Epoch 14/200
#  - 24s - loss: 0.0082 - acc: 0.9977 - categorical_accuracy: 0.2820 - f2_score: 0.5331 - f2_score_1: 0.5162 - f2_score_2: 0.4872 - f2_score_3: 0.4545 - f2_score_4: 0.4346 - f2_score_5: 0.4215 - f2_score_6: 0.3568 - f2_score_7: 0.2968 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2356 - val_f2_score: 0.4477 - val_f2_score_1: 0.4202 - val_f2_score_2: 0.3875 - val_f2_score_3: 0.3549 - val_f2_score_4: 0.3370 - val_f2_score_5: 0.3251 - val_f2_score_6: 0.2707 - val_f2_score_7: 0.2220
# Epoch 15/200
#  - 24s - loss: 0.0080 - acc: 0.9977 - categorical_accuracy: 0.2912 - f2_score: 0.5447 - f2_score_1: 0.5290 - f2_score_2: 0.5005 - f2_score_3: 0.4679 - f2_score_4: 0.4477 - f2_score_5: 0.4344 - f2_score_6: 0.3693 - f2_score_7: 0.3098 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2335 - val_f2_score: 0.4487 - val_f2_score_1: 0.4224 - val_f2_score_2: 0.3906 - val_f2_score_3: 0.3599 - val_f2_score_4: 0.3426 - val_f2_score_5: 0.3306 - val_f2_score_6: 0.2767 - val_f2_score_7: 0.2308
# Epoch 16/200
#  - 24s - loss: 0.0078 - acc: 0.9977 - categorical_accuracy: 0.2976 - f2_score: 0.5560 - f2_score_1: 0.5418 - f2_score_2: 0.5140 - f2_score_3: 0.4820 - f2_score_4: 0.4621 - f2_score_5: 0.4488 - f2_score_6: 0.3838 - f2_score_7: 0.3232 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2470 - val_f2_score: 0.4515 - val_f2_score_1: 0.4274 - val_f2_score_2: 0.3972 - val_f2_score_3: 0.3656 - val_f2_score_4: 0.3478 - val_f2_score_5: 0.3362 - val_f2_score_6: 0.2819 - val_f2_score_7: 0.2359
# Epoch 17/200
#  - 24s - loss: 0.0076 - acc: 0.9978 - categorical_accuracy: 0.3053 - f2_score: 0.5672 - f2_score_1: 0.5532 - f2_score_2: 0.5259 - f2_score_3: 0.4946 - f2_score_4: 0.4747 - f2_score_5: 0.4617 - f2_score_6: 0.3962 - f2_score_7: 0.3352 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2420 - val_f2_score: 0.4521 - val_f2_score_1: 0.4272 - val_f2_score_2: 0.3965 - val_f2_score_3: 0.3655 - val_f2_score_4: 0.3477 - val_f2_score_5: 0.3371 - val_f2_score_6: 0.2822 - val_f2_score_7: 0.2349
# Epoch 18/200
#  - 24s - loss: 0.0074 - acc: 0.9978 - categorical_accuracy: 0.3100 - f2_score: 0.5788 - f2_score_1: 0.5656 - f2_score_2: 0.5396 - f2_score_3: 0.5078 - f2_score_4: 0.4876 - f2_score_5: 0.4748 - f2_score_6: 0.4106 - f2_score_7: 0.3490 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2392 - val_f2_score: 0.4539 - val_f2_score_1: 0.4308 - val_f2_score_2: 0.4022 - val_f2_score_3: 0.3724 - val_f2_score_4: 0.3555 - val_f2_score_5: 0.3442 - val_f2_score_6: 0.2919 - val_f2_score_7: 0.2457
# Epoch 19/200
#  - 24s - loss: 0.0072 - acc: 0.9978 - categorical_accuracy: 0.3203 - f2_score: 0.5884 - f2_score_1: 0.5764 - f2_score_2: 0.5511 - f2_score_3: 0.5211 - f2_score_4: 0.5022 - f2_score_5: 0.4893 - f2_score_6: 0.4248 - f2_score_7: 0.3609 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2435 - val_f2_score: 0.4538 - val_f2_score_1: 0.4288 - val_f2_score_2: 0.4003 - val_f2_score_3: 0.3719 - val_f2_score_4: 0.3569 - val_f2_score_5: 0.3462 - val_f2_score_6: 0.2961 - val_f2_score_7: 0.2491
# Epoch 20/200
#  - 24s - loss: 0.0071 - acc: 0.9979 - categorical_accuracy: 0.3275 - f2_score: 0.5992 - f2_score_1: 0.5883 - f2_score_2: 0.5639 - f2_score_3: 0.5339 - f2_score_4: 0.5151 - f2_score_5: 0.5023 - f2_score_6: 0.4388 - f2_score_7: 0.3770 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2454 - val_f2_score: 0.4550 - val_f2_score_1: 0.4297 - val_f2_score_2: 0.3994 - val_f2_score_3: 0.3721 - val_f2_score_4: 0.3551 - val_f2_score_5: 0.3440 - val_f2_score_6: 0.2918 - val_f2_score_7: 0.2457
# Epoch 21/200
#  - 24s - loss: 0.0069 - acc: 0.9979 - categorical_accuracy: 0.3318 - f2_score: 0.6094 - f2_score_1: 0.5998 - f2_score_2: 0.5759 - f2_score_3: 0.5465 - f2_score_4: 0.5280 - f2_score_5: 0.5157 - f2_score_6: 0.4523 - f2_score_7: 0.3896 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2467 - val_f2_score: 0.4548 - val_f2_score_1: 0.4318 - val_f2_score_2: 0.4048 - val_f2_score_3: 0.3768 - val_f2_score_4: 0.3600 - val_f2_score_5: 0.3491 - val_f2_score_6: 0.2995 - val_f2_score_7: 0.2543
# Epoch 00021: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.1

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                                      attribute_ids
# 0  10023b2cc4ed5f68                           121 343 369 477 766 1059
# 1  100fbe75ed8fd887                                  121 231 1039 1059
# 2  101b627524a04f19                                 79 280 482 497 498
# 3  10234480c41284c6  13 51 147 480 483 501 725 737 738 776 813 830 ...
# 4  1023b0e2636dcea8               147 156 322 584 738 813 835 954 1092
# 5   1039cd6cf85845c                                13 405 896 903 1092
# 6   103a5b3f83fbe88                               194 519 744 813 1092
# 7  10413aaae8d6a9a2                               51 147 813 1046 1092
# 8  10423822b93a65ab                               51 111 147 1046 1092
# 9  1052bf702cb099f7                                    147 188 671 723
