# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 21s - loss: 0.0324 - acc: 0.9894 - categorical_accuracy: 0.0462 - f2_score: 0.1239 - f2_score_1: 0.1001 - f2_score_2: 0.0793 - f2_score_3: 0.0627 - f2_score_4: 0.0544 - f2_score_5: 0.0493 - f2_score_6: 0.0302 - f2_score_7: 0.0183 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0762 - val_f2_score: 0.2341 - val_f2_score_1: 0.1750 - val_f2_score_2: 0.1317 - val_f2_score_3: 0.0983 - val_f2_score_4: 0.0839 - val_f2_score_5: 0.0755 - val_f2_score_6: 0.0369 - val_f2_score_7: 0.0112
# Epoch 2/200
#  - 19s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.2161 - f2_score_1: 0.1755 - f2_score_2: 0.1396 - f2_score_3: 0.1092 - f2_score_4: 0.0942 - f2_score_5: 0.0852 - f2_score_6: 0.0514 - f2_score_7: 0.0305 - val_loss: 0.0133 - val_acc: 0.9972 - val_categorical_accuracy: 0.1044 - val_f2_score: 0.3139 - val_f2_score_1: 0.2793 - val_f2_score_2: 0.2364 - val_f2_score_3: 0.1958 - val_f2_score_4: 0.1733 - val_f2_score_5: 0.1596 - val_f2_score_6: 0.1061 - val_f2_score_7: 0.0700
# Epoch 3/200
#  - 19s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1102 - f2_score: 0.2656 - f2_score_1: 0.2256 - f2_score_2: 0.1839 - f2_score_3: 0.1491 - f2_score_4: 0.1311 - f2_score_5: 0.1201 - f2_score_6: 0.0778 - f2_score_7: 0.0507 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1233 - val_f2_score: 0.3421 - val_f2_score_1: 0.3317 - val_f2_score_2: 0.2976 - val_f2_score_3: 0.2567 - val_f2_score_4: 0.2330 - val_f2_score_5: 0.2178 - val_f2_score_6: 0.1522 - val_f2_score_7: 0.1026
# Epoch 4/200
#  - 19s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1306 - f2_score: 0.2961 - f2_score_1: 0.2571 - f2_score_2: 0.2160 - f2_score_3: 0.1782 - f2_score_4: 0.1580 - f2_score_5: 0.1460 - f2_score_6: 0.0983 - f2_score_7: 0.0656 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1313 - val_f2_score: 0.3584 - val_f2_score_1: 0.3488 - val_f2_score_2: 0.3206 - val_f2_score_3: 0.2833 - val_f2_score_4: 0.2614 - val_f2_score_5: 0.2456 - val_f2_score_6: 0.1781 - val_f2_score_7: 0.1252
# Epoch 5/200
#  - 19s - loss: 0.0125 - acc: 0.9972 - categorical_accuracy: 0.1446 - f2_score: 0.3184 - f2_score_1: 0.2812 - f2_score_2: 0.2398 - f2_score_3: 0.2012 - f2_score_4: 0.1804 - f2_score_5: 0.1682 - f2_score_6: 0.1160 - f2_score_7: 0.0807 - val_loss: 0.0125 - val_acc: 0.9973 - val_categorical_accuracy: 0.1411 - val_f2_score: 0.3689 - val_f2_score_1: 0.3670 - val_f2_score_2: 0.3443 - val_f2_score_3: 0.3096 - val_f2_score_4: 0.2863 - val_f2_score_5: 0.2704 - val_f2_score_6: 0.1958 - val_f2_score_7: 0.1373
# Epoch 6/200
#  - 19s - loss: 0.0122 - acc: 0.9972 - categorical_accuracy: 0.1534 - f2_score: 0.3356 - f2_score_1: 0.3011 - f2_score_2: 0.2603 - f2_score_3: 0.2206 - f2_score_4: 0.1992 - f2_score_5: 0.1860 - f2_score_6: 0.1310 - f2_score_7: 0.0929 - val_loss: 0.0120 - val_acc: 0.9973 - val_categorical_accuracy: 0.1481 - val_f2_score: 0.3785 - val_f2_score_1: 0.3769 - val_f2_score_2: 0.3545 - val_f2_score_3: 0.3210 - val_f2_score_4: 0.3000 - val_f2_score_5: 0.2856 - val_f2_score_6: 0.2124 - val_f2_score_7: 0.1545
# Epoch 7/200
#  - 19s - loss: 0.0119 - acc: 0.9973 - categorical_accuracy: 0.1643 - f2_score: 0.3493 - f2_score_1: 0.3156 - f2_score_2: 0.2757 - f2_score_3: 0.2369 - f2_score_4: 0.2149 - f2_score_5: 0.2008 - f2_score_6: 0.1438 - f2_score_7: 0.1037 - val_loss: 0.0119 - val_acc: 0.9973 - val_categorical_accuracy: 0.1682 - val_f2_score: 0.3862 - val_f2_score_1: 0.3875 - val_f2_score_2: 0.3666 - val_f2_score_3: 0.3371 - val_f2_score_4: 0.3165 - val_f2_score_5: 0.3029 - val_f2_score_6: 0.2311 - val_f2_score_7: 0.1679
# Epoch 8/200
#  - 19s - loss: 0.0116 - acc: 0.9973 - categorical_accuracy: 0.1737 - f2_score: 0.3609 - f2_score_1: 0.3288 - f2_score_2: 0.2895 - f2_score_3: 0.2502 - f2_score_4: 0.2287 - f2_score_5: 0.2148 - f2_score_6: 0.1557 - f2_score_7: 0.1137 - val_loss: 0.0115 - val_acc: 0.9973 - val_categorical_accuracy: 0.1712 - val_f2_score: 0.3976 - val_f2_score_1: 0.3943 - val_f2_score_2: 0.3696 - val_f2_score_3: 0.3380 - val_f2_score_4: 0.3188 - val_f2_score_5: 0.3049 - val_f2_score_6: 0.2364 - val_f2_score_7: 0.1756
# Epoch 9/200
#  - 19s - loss: 0.0114 - acc: 0.9973 - categorical_accuracy: 0.1809 - f2_score: 0.3704 - f2_score_1: 0.3394 - f2_score_2: 0.3014 - f2_score_3: 0.2626 - f2_score_4: 0.2405 - f2_score_5: 0.2267 - f2_score_6: 0.1660 - f2_score_7: 0.1226 - val_loss: 0.0114 - val_acc: 0.9973 - val_categorical_accuracy: 0.1757 - val_f2_score: 0.4001 - val_f2_score_1: 0.3966 - val_f2_score_2: 0.3752 - val_f2_score_3: 0.3430 - val_f2_score_4: 0.3225 - val_f2_score_5: 0.3089 - val_f2_score_6: 0.2405 - val_f2_score_7: 0.1808
# Epoch 10/200
#  - 19s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1889 - f2_score: 0.3794 - f2_score_1: 0.3494 - f2_score_2: 0.3113 - f2_score_3: 0.2737 - f2_score_4: 0.2522 - f2_score_5: 0.2382 - f2_score_6: 0.1770 - f2_score_7: 0.1312 - val_loss: 0.0112 - val_acc: 0.9974 - val_categorical_accuracy: 0.1865 - val_f2_score: 0.4065 - val_f2_score_1: 0.4010 - val_f2_score_2: 0.3775 - val_f2_score_3: 0.3468 - val_f2_score_4: 0.3287 - val_f2_score_5: 0.3143 - val_f2_score_6: 0.2485 - val_f2_score_7: 0.1881
# Epoch 11/200
#  - 19s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1932 - f2_score: 0.3868 - f2_score_1: 0.3584 - f2_score_2: 0.3221 - f2_score_3: 0.2845 - f2_score_4: 0.2627 - f2_score_5: 0.2484 - f2_score_6: 0.1856 - f2_score_7: 0.1385 - val_loss: 0.0110 - val_acc: 0.9974 - val_categorical_accuracy: 0.1933 - val_f2_score: 0.4130 - val_f2_score_1: 0.4074 - val_f2_score_2: 0.3832 - val_f2_score_3: 0.3524 - val_f2_score_4: 0.3318 - val_f2_score_5: 0.3179 - val_f2_score_6: 0.2515 - val_f2_score_7: 0.1910
# Epoch 12/200
#  - 19s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.2028 - f2_score: 0.3956 - f2_score_1: 0.3676 - f2_score_2: 0.3304 - f2_score_3: 0.2929 - f2_score_4: 0.2715 - f2_score_5: 0.2579 - f2_score_6: 0.1951 - f2_score_7: 0.1474 - val_loss: 0.0109 - val_acc: 0.9974 - val_categorical_accuracy: 0.1896 - val_f2_score: 0.4166 - val_f2_score_1: 0.4125 - val_f2_score_2: 0.3919 - val_f2_score_3: 0.3626 - val_f2_score_4: 0.3433 - val_f2_score_5: 0.3296 - val_f2_score_6: 0.2641 - val_f2_score_7: 0.2049
# Epoch 13/200
#  - 19s - loss: 0.0108 - acc: 0.9974 - categorical_accuracy: 0.2067 - f2_score: 0.4029 - f2_score_1: 0.3755 - f2_score_2: 0.3403 - f2_score_3: 0.3024 - f2_score_4: 0.2804 - f2_score_5: 0.2665 - f2_score_6: 0.2045 - f2_score_7: 0.1560 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1921 - val_f2_score: 0.4210 - val_f2_score_1: 0.4170 - val_f2_score_2: 0.3953 - val_f2_score_3: 0.3644 - val_f2_score_4: 0.3450 - val_f2_score_5: 0.3315 - val_f2_score_6: 0.2683 - val_f2_score_7: 0.2102
# Epoch 14/200
#  - 19s - loss: 0.0106 - acc: 0.9974 - categorical_accuracy: 0.2149 - f2_score: 0.4091 - f2_score_1: 0.3824 - f2_score_2: 0.3481 - f2_score_3: 0.3116 - f2_score_4: 0.2898 - f2_score_5: 0.2763 - f2_score_6: 0.2133 - f2_score_7: 0.1632 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.2057 - val_f2_score: 0.4239 - val_f2_score_1: 0.4204 - val_f2_score_2: 0.3989 - val_f2_score_3: 0.3690 - val_f2_score_4: 0.3499 - val_f2_score_5: 0.3354 - val_f2_score_6: 0.2711 - val_f2_score_7: 0.2119
# Epoch 15/200
#  - 19s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.2206 - f2_score: 0.4156 - f2_score_1: 0.3897 - f2_score_2: 0.3560 - f2_score_3: 0.3200 - f2_score_4: 0.2987 - f2_score_5: 0.2850 - f2_score_6: 0.2222 - f2_score_7: 0.1710 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.2119 - val_f2_score: 0.4286 - val_f2_score_1: 0.4201 - val_f2_score_2: 0.3962 - val_f2_score_3: 0.3659 - val_f2_score_4: 0.3472 - val_f2_score_5: 0.3342 - val_f2_score_6: 0.2711 - val_f2_score_7: 0.2143
# Epoch 16/200
#  - 19s - loss: 0.0104 - acc: 0.9974 - categorical_accuracy: 0.2262 - f2_score: 0.4225 - f2_score_1: 0.3970 - f2_score_2: 0.3634 - f2_score_3: 0.3278 - f2_score_4: 0.3065 - f2_score_5: 0.2926 - f2_score_6: 0.2289 - f2_score_7: 0.1770 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.2084 - val_f2_score: 0.4303 - val_f2_score_1: 0.4222 - val_f2_score_2: 0.3992 - val_f2_score_3: 0.3697 - val_f2_score_4: 0.3510 - val_f2_score_5: 0.3380 - val_f2_score_6: 0.2762 - val_f2_score_7: 0.2211
# Epoch 17/200
#  - 19s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.2338 - f2_score: 0.4270 - f2_score_1: 0.4033 - f2_score_2: 0.3707 - f2_score_3: 0.3365 - f2_score_4: 0.3148 - f2_score_5: 0.3012 - f2_score_6: 0.2379 - f2_score_7: 0.1856 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2117 - val_f2_score: 0.4344 - val_f2_score_1: 0.4238 - val_f2_score_2: 0.4005 - val_f2_score_3: 0.3707 - val_f2_score_4: 0.3517 - val_f2_score_5: 0.3397 - val_f2_score_6: 0.2793 - val_f2_score_7: 0.2229
# Epoch 18/200
#  - 19s - loss: 0.0102 - acc: 0.9974 - categorical_accuracy: 0.2364 - f2_score: 0.4322 - f2_score_1: 0.4094 - f2_score_2: 0.3771 - f2_score_3: 0.3422 - f2_score_4: 0.3212 - f2_score_5: 0.3070 - f2_score_6: 0.2438 - f2_score_7: 0.1914 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2100 - val_f2_score: 0.4349 - val_f2_score_1: 0.4287 - val_f2_score_2: 0.4074 - val_f2_score_3: 0.3787 - val_f2_score_4: 0.3591 - val_f2_score_5: 0.3461 - val_f2_score_6: 0.2814 - val_f2_score_7: 0.2225
# Epoch 19/200
#  - 19s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2421 - f2_score: 0.4383 - f2_score_1: 0.4152 - f2_score_2: 0.3841 - f2_score_3: 0.3495 - f2_score_4: 0.3286 - f2_score_5: 0.3151 - f2_score_6: 0.2511 - f2_score_7: 0.1979 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2128 - val_f2_score: 0.4382 - val_f2_score_1: 0.4281 - val_f2_score_2: 0.4052 - val_f2_score_3: 0.3764 - val_f2_score_4: 0.3598 - val_f2_score_5: 0.3471 - val_f2_score_6: 0.2860 - val_f2_score_7: 0.2306
# Epoch 20/200
#  - 19s - loss: 0.0100 - acc: 0.9975 - categorical_accuracy: 0.2472 - f2_score: 0.4430 - f2_score_1: 0.4201 - f2_score_2: 0.3886 - f2_score_3: 0.3546 - f2_score_4: 0.3343 - f2_score_5: 0.3215 - f2_score_6: 0.2582 - f2_score_7: 0.2050 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2217 - val_f2_score: 0.4411 - val_f2_score_1: 0.4327 - val_f2_score_2: 0.4089 - val_f2_score_3: 0.3792 - val_f2_score_4: 0.3595 - val_f2_score_5: 0.3472 - val_f2_score_6: 0.2850 - val_f2_score_7: 0.2289
# Epoch 21/200
#  - 19s - loss: 0.0099 - acc: 0.9975 - categorical_accuracy: 0.2551 - f2_score: 0.4490 - f2_score_1: 0.4275 - f2_score_2: 0.3963 - f2_score_3: 0.3624 - f2_score_4: 0.3421 - f2_score_5: 0.3287 - f2_score_6: 0.2650 - f2_score_7: 0.2112 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2281 - val_f2_score: 0.4419 - val_f2_score_1: 0.4322 - val_f2_score_2: 0.4094 - val_f2_score_3: 0.3796 - val_f2_score_4: 0.3624 - val_f2_score_5: 0.3491 - val_f2_score_6: 0.2880 - val_f2_score_7: 0.2340
# Epoch 22/200
#  - 19s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2592 - f2_score: 0.4528 - f2_score_1: 0.4317 - f2_score_2: 0.4010 - f2_score_3: 0.3675 - f2_score_4: 0.3475 - f2_score_5: 0.3343 - f2_score_6: 0.2718 - f2_score_7: 0.2176 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2238 - val_f2_score: 0.4454 - val_f2_score_1: 0.4339 - val_f2_score_2: 0.4101 - val_f2_score_3: 0.3811 - val_f2_score_4: 0.3622 - val_f2_score_5: 0.3501 - val_f2_score_6: 0.2903 - val_f2_score_7: 0.2366
# Epoch 23/200
#  - 19s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2647 - f2_score: 0.4570 - f2_score_1: 0.4367 - f2_score_2: 0.4064 - f2_score_3: 0.3735 - f2_score_4: 0.3534 - f2_score_5: 0.3404 - f2_score_6: 0.2778 - f2_score_7: 0.2232 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2372 - val_f2_score: 0.4476 - val_f2_score_1: 0.4368 - val_f2_score_2: 0.4145 - val_f2_score_3: 0.3860 - val_f2_score_4: 0.3668 - val_f2_score_5: 0.3543 - val_f2_score_6: 0.2945 - val_f2_score_7: 0.2392
# Epoch 24/200
#  - 19s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2680 - f2_score: 0.4621 - f2_score_1: 0.4423 - f2_score_2: 0.4131 - f2_score_3: 0.3797 - f2_score_4: 0.3598 - f2_score_5: 0.3468 - f2_score_6: 0.2839 - f2_score_7: 0.2288 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2368 - val_f2_score: 0.4485 - val_f2_score_1: 0.4385 - val_f2_score_2: 0.4178 - val_f2_score_3: 0.3899 - val_f2_score_4: 0.3712 - val_f2_score_5: 0.3580 - val_f2_score_6: 0.2963 - val_f2_score_7: 0.2416
# Epoch 25/200
#  - 19s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2740 - f2_score: 0.4666 - f2_score_1: 0.4477 - f2_score_2: 0.4187 - f2_score_3: 0.3860 - f2_score_4: 0.3668 - f2_score_5: 0.3539 - f2_score_6: 0.2908 - f2_score_7: 0.2350 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2379 - val_f2_score: 0.4506 - val_f2_score_1: 0.4408 - val_f2_score_2: 0.4194 - val_f2_score_3: 0.3921 - val_f2_score_4: 0.3755 - val_f2_score_5: 0.3633 - val_f2_score_6: 0.3046 - val_f2_score_7: 0.2506
# Epoch 26/200
#  - 19s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2796 - f2_score: 0.4701 - f2_score_1: 0.4524 - f2_score_2: 0.4245 - f2_score_3: 0.3924 - f2_score_4: 0.3725 - f2_score_5: 0.3585 - f2_score_6: 0.2963 - f2_score_7: 0.2411 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2310 - val_f2_score: 0.4524 - val_f2_score_1: 0.4414 - val_f2_score_2: 0.4162 - val_f2_score_3: 0.3900 - val_f2_score_4: 0.3727 - val_f2_score_5: 0.3610 - val_f2_score_6: 0.2998 - val_f2_score_7: 0.2467
# Epoch 27/200
#  - 19s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2821 - f2_score: 0.4747 - f2_score_1: 0.4558 - f2_score_2: 0.4275 - f2_score_3: 0.3960 - f2_score_4: 0.3770 - f2_score_5: 0.3639 - f2_score_6: 0.3020 - f2_score_7: 0.2475 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2418 - val_f2_score: 0.4520 - val_f2_score_1: 0.4418 - val_f2_score_2: 0.4210 - val_f2_score_3: 0.3943 - val_f2_score_4: 0.3782 - val_f2_score_5: 0.3672 - val_f2_score_6: 0.3095 - val_f2_score_7: 0.2566
# Epoch 28/200
#  - 19s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2883 - f2_score: 0.4781 - f2_score_1: 0.4608 - f2_score_2: 0.4328 - f2_score_3: 0.4019 - f2_score_4: 0.3826 - f2_score_5: 0.3699 - f2_score_6: 0.3087 - f2_score_7: 0.2525 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2395 - val_f2_score: 0.4525 - val_f2_score_1: 0.4433 - val_f2_score_2: 0.4210 - val_f2_score_3: 0.3956 - val_f2_score_4: 0.3791 - val_f2_score_5: 0.3673 - val_f2_score_6: 0.3106 - val_f2_score_7: 0.2579
# Epoch 29/200
#  - 19s - loss: 0.0093 - acc: 0.9976 - categorical_accuracy: 0.2927 - f2_score: 0.4810 - f2_score_1: 0.4640 - f2_score_2: 0.4367 - f2_score_3: 0.4055 - f2_score_4: 0.3868 - f2_score_5: 0.3740 - f2_score_6: 0.3123 - f2_score_7: 0.2570 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2451 - val_f2_score: 0.4526 - val_f2_score_1: 0.4414 - val_f2_score_2: 0.4191 - val_f2_score_3: 0.3916 - val_f2_score_4: 0.3746 - val_f2_score_5: 0.3630 - val_f2_score_6: 0.3075 - val_f2_score_7: 0.2569
# Epoch 30/200
#  - 19s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.2946 - f2_score: 0.4853 - f2_score_1: 0.4686 - f2_score_2: 0.4413 - f2_score_3: 0.4099 - f2_score_4: 0.3912 - f2_score_5: 0.3790 - f2_score_6: 0.3176 - f2_score_7: 0.2627 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2499 - val_f2_score: 0.4539 - val_f2_score_1: 0.4460 - val_f2_score_2: 0.4270 - val_f2_score_3: 0.4003 - val_f2_score_4: 0.3835 - val_f2_score_5: 0.3718 - val_f2_score_6: 0.3140 - val_f2_score_7: 0.2607
# Epoch 31/200
#  - 19s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.3015 - f2_score: 0.4882 - f2_score_1: 0.4720 - f2_score_2: 0.4463 - f2_score_3: 0.4160 - f2_score_4: 0.3974 - f2_score_5: 0.3851 - f2_score_6: 0.3233 - f2_score_7: 0.2672 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2536 - val_f2_score: 0.4565 - val_f2_score_1: 0.4435 - val_f2_score_2: 0.4204 - val_f2_score_3: 0.3919 - val_f2_score_4: 0.3747 - val_f2_score_5: 0.3626 - val_f2_score_6: 0.3079 - val_f2_score_7: 0.2598
# Epoch 32/200
#  - 19s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.3056 - f2_score: 0.4917 - f2_score_1: 0.4760 - f2_score_2: 0.4504 - f2_score_3: 0.4205 - f2_score_4: 0.4015 - f2_score_5: 0.3890 - f2_score_6: 0.3278 - f2_score_7: 0.2714 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2461 - val_f2_score: 0.4586 - val_f2_score_1: 0.4477 - val_f2_score_2: 0.4279 - val_f2_score_3: 0.4036 - val_f2_score_4: 0.3870 - val_f2_score_5: 0.3757 - val_f2_score_6: 0.3206 - val_f2_score_7: 0.2676
# Epoch 33/200
#  - 19s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.3078 - f2_score: 0.4952 - f2_score_1: 0.4796 - f2_score_2: 0.4527 - f2_score_3: 0.4228 - f2_score_4: 0.4043 - f2_score_5: 0.3918 - f2_score_6: 0.3309 - f2_score_7: 0.2760 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2510 - val_f2_score: 0.4590 - val_f2_score_1: 0.4466 - val_f2_score_2: 0.4247 - val_f2_score_3: 0.3990 - val_f2_score_4: 0.3836 - val_f2_score_5: 0.3725 - val_f2_score_6: 0.3179 - val_f2_score_7: 0.2670
# Epoch 34/200
#  - 19s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.3139 - f2_score: 0.4983 - f2_score_1: 0.4835 - f2_score_2: 0.4572 - f2_score_3: 0.4277 - f2_score_4: 0.4098 - f2_score_5: 0.3975 - f2_score_6: 0.3383 - f2_score_7: 0.2824 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2522 - val_f2_score: 0.4597 - val_f2_score_1: 0.4471 - val_f2_score_2: 0.4251 - val_f2_score_3: 0.3997 - val_f2_score_4: 0.3841 - val_f2_score_5: 0.3741 - val_f2_score_6: 0.3202 - val_f2_score_7: 0.2688
# Epoch 35/200
#  - 19s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3157 - f2_score: 0.5010 - f2_score_1: 0.4862 - f2_score_2: 0.4610 - f2_score_3: 0.4318 - f2_score_4: 0.4137 - f2_score_5: 0.4014 - f2_score_6: 0.3423 - f2_score_7: 0.2869 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2629 - val_f2_score: 0.4603 - val_f2_score_1: 0.4481 - val_f2_score_2: 0.4258 - val_f2_score_3: 0.3982 - val_f2_score_4: 0.3817 - val_f2_score_5: 0.3702 - val_f2_score_6: 0.3156 - val_f2_score_7: 0.2663
# Epoch 36/200
#  - 19s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3219 - f2_score: 0.5049 - f2_score_1: 0.4905 - f2_score_2: 0.4652 - f2_score_3: 0.4361 - f2_score_4: 0.4188 - f2_score_5: 0.4068 - f2_score_6: 0.3475 - f2_score_7: 0.2916 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2565 - val_f2_score: 0.4613 - val_f2_score_1: 0.4487 - val_f2_score_2: 0.4269 - val_f2_score_3: 0.4016 - val_f2_score_4: 0.3856 - val_f2_score_5: 0.3756 - val_f2_score_6: 0.3244 - val_f2_score_7: 0.2746
# Epoch 37/200
#  - 19s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.3251 - f2_score: 0.5074 - f2_score_1: 0.4932 - f2_score_2: 0.4684 - f2_score_3: 0.4398 - f2_score_4: 0.4223 - f2_score_5: 0.4103 - f2_score_6: 0.3519 - f2_score_7: 0.2961 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2623 - val_f2_score: 0.4598 - val_f2_score_1: 0.4480 - val_f2_score_2: 0.4255 - val_f2_score_3: 0.3994 - val_f2_score_4: 0.3832 - val_f2_score_5: 0.3724 - val_f2_score_6: 0.3194 - val_f2_score_7: 0.2717
# Epoch 38/200
#  - 19s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.3292 - f2_score: 0.5098 - f2_score_1: 0.4954 - f2_score_2: 0.4709 - f2_score_3: 0.4428 - f2_score_4: 0.4255 - f2_score_5: 0.4132 - f2_score_6: 0.3551 - f2_score_7: 0.2991 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2633 - val_f2_score: 0.4605 - val_f2_score_1: 0.4492 - val_f2_score_2: 0.4274 - val_f2_score_3: 0.4026 - val_f2_score_4: 0.3876 - val_f2_score_5: 0.3765 - val_f2_score_6: 0.3240 - val_f2_score_7: 0.2746
# Epoch 39/200
#  - 19s - loss: 0.0087 - acc: 0.9976 - categorical_accuracy: 0.3355 - f2_score: 0.5142 - f2_score_1: 0.5004 - f2_score_2: 0.4760 - f2_score_3: 0.4474 - f2_score_4: 0.4302 - f2_score_5: 0.4186 - f2_score_6: 0.3603 - f2_score_7: 0.3045 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2590 - val_f2_score: 0.4607 - val_f2_score_1: 0.4497 - val_f2_score_2: 0.4269 - val_f2_score_3: 0.4016 - val_f2_score_4: 0.3850 - val_f2_score_5: 0.3746 - val_f2_score_6: 0.3220 - val_f2_score_7: 0.2720
# Epoch 40/200
#  - 19s - loss: 0.0087 - acc: 0.9977 - categorical_accuracy: 0.3356 - f2_score: 0.5158 - f2_score_1: 0.5029 - f2_score_2: 0.4792 - f2_score_3: 0.4512 - f2_score_4: 0.4333 - f2_score_5: 0.4210 - f2_score_6: 0.3635 - f2_score_7: 0.3076 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2596 - val_f2_score: 0.4633 - val_f2_score_1: 0.4485 - val_f2_score_2: 0.4244 - val_f2_score_3: 0.3987 - val_f2_score_4: 0.3835 - val_f2_score_5: 0.3729 - val_f2_score_6: 0.3202 - val_f2_score_7: 0.2735
# Epoch 41/200
#  - 19s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3397 - f2_score: 0.5190 - f2_score_1: 0.5063 - f2_score_2: 0.4828 - f2_score_3: 0.4556 - f2_score_4: 0.4379 - f2_score_5: 0.4264 - f2_score_6: 0.3690 - f2_score_7: 0.3135 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2541 - val_f2_score: 0.4632 - val_f2_score_1: 0.4524 - val_f2_score_2: 0.4311 - val_f2_score_3: 0.4072 - val_f2_score_4: 0.3917 - val_f2_score_5: 0.3806 - val_f2_score_6: 0.3303 - val_f2_score_7: 0.2801
# Epoch 42/200
#  - 19s - loss: 0.0086 - acc: 0.9977 - categorical_accuracy: 0.3422 - f2_score: 0.5204 - f2_score_1: 0.5076 - f2_score_2: 0.4845 - f2_score_3: 0.4572 - f2_score_4: 0.4401 - f2_score_5: 0.4286 - f2_score_6: 0.3710 - f2_score_7: 0.3165 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2651 - val_f2_score: 0.4635 - val_f2_score_1: 0.4517 - val_f2_score_2: 0.4301 - val_f2_score_3: 0.4051 - val_f2_score_4: 0.3881 - val_f2_score_5: 0.3783 - val_f2_score_6: 0.3256 - val_f2_score_7: 0.2772
# Epoch 43/200
#  - 19s - loss: 0.0085 - acc: 0.9977 - categorical_accuracy: 0.3440 - f2_score: 0.5235 - f2_score_1: 0.5107 - f2_score_2: 0.4875 - f2_score_3: 0.4603 - f2_score_4: 0.4434 - f2_score_5: 0.4318 - f2_score_6: 0.3748 - f2_score_7: 0.3196 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2620 - val_f2_score: 0.4638 - val_f2_score_1: 0.4530 - val_f2_score_2: 0.4305 - val_f2_score_3: 0.4056 - val_f2_score_4: 0.3912 - val_f2_score_5: 0.3807 - val_f2_score_6: 0.3298 - val_f2_score_7: 0.2810
# Epoch 44/200
#  - 19s - loss: 0.0085 - acc: 0.9977 - categorical_accuracy: 0.3504 - f2_score: 0.5275 - f2_score_1: 0.5152 - f2_score_2: 0.4919 - f2_score_3: 0.4650 - f2_score_4: 0.4484 - f2_score_5: 0.4370 - f2_score_6: 0.3797 - f2_score_7: 0.3251 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2681 - val_f2_score: 0.4635 - val_f2_score_1: 0.4491 - val_f2_score_2: 0.4280 - val_f2_score_3: 0.4044 - val_f2_score_4: 0.3895 - val_f2_score_5: 0.3797 - val_f2_score_6: 0.3313 - val_f2_score_7: 0.2834
# Epoch 45/200
#  - 19s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3542 - f2_score: 0.5286 - f2_score_1: 0.5159 - f2_score_2: 0.4936 - f2_score_3: 0.4672 - f2_score_4: 0.4507 - f2_score_5: 0.4396 - f2_score_6: 0.3843 - f2_score_7: 0.3294 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2663 - val_f2_score: 0.4631 - val_f2_score_1: 0.4519 - val_f2_score_2: 0.4314 - val_f2_score_3: 0.4073 - val_f2_score_4: 0.3927 - val_f2_score_5: 0.3829 - val_f2_score_6: 0.3345 - val_f2_score_7: 0.2860
# Epoch 46/200
#  - 19s - loss: 0.0084 - acc: 0.9977 - categorical_accuracy: 0.3550 - f2_score: 0.5313 - f2_score_1: 0.5199 - f2_score_2: 0.4966 - f2_score_3: 0.4707 - f2_score_4: 0.4543 - f2_score_5: 0.4433 - f2_score_6: 0.3872 - f2_score_7: 0.3321 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2745 - val_f2_score: 0.4655 - val_f2_score_1: 0.4519 - val_f2_score_2: 0.4289 - val_f2_score_3: 0.4038 - val_f2_score_4: 0.3885 - val_f2_score_5: 0.3786 - val_f2_score_6: 0.3286 - val_f2_score_7: 0.2821
# Epoch 47/200
#  - 19s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.3596 - f2_score: 0.5338 - f2_score_1: 0.5225 - f2_score_2: 0.5005 - f2_score_3: 0.4744 - f2_score_4: 0.4577 - f2_score_5: 0.4462 - f2_score_6: 0.3908 - f2_score_7: 0.3364 - val_loss: 0.0098 - val_acc: 0.9975 - val_categorical_accuracy: 0.2683 - val_f2_score: 0.4644 - val_f2_score_1: 0.4513 - val_f2_score_2: 0.4277 - val_f2_score_3: 0.4040 - val_f2_score_4: 0.3892 - val_f2_score_5: 0.3794 - val_f2_score_6: 0.3313 - val_f2_score_7: 0.2838
# Epoch 48/200
#  - 19s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.3636 - f2_score: 0.5360 - f2_score_1: 0.5248 - f2_score_2: 0.5030 - f2_score_3: 0.4774 - f2_score_4: 0.4611 - f2_score_5: 0.4497 - f2_score_6: 0.3938 - f2_score_7: 0.3393 - val_loss: 0.0099 - val_acc: 0.9975 - val_categorical_accuracy: 0.2685 - val_f2_score: 0.4657 - val_f2_score_1: 0.4510 - val_f2_score_2: 0.4308 - val_f2_score_3: 0.4060 - val_f2_score_4: 0.3907 - val_f2_score_5: 0.3811 - val_f2_score_6: 0.3327 - val_f2_score_7: 0.2850
# Epoch 00048: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.1

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                                   attribute_ids
# 0  10023b2cc4ed5f68       121 223 337 343 344 369 587 766 1039 1059
# 1  100fbe75ed8fd887                               121 231 1039 1059
# 2  101b627524a04f19              79 180 182 280 482 497 498 718 728
# 3  10234480c41284c6  13 51 147 480 483 737 738 776 813 830 923 1046
# 4  1023b0e2636dcea8       147 156 283 322 584 612 813 954 1046 1092
# 5   1039cd6cf85845c                                 13 405 896 1092
# 6   103a5b3f83fbe88                  194 744 747 813 1046 1092 1099
# 7  10413aaae8d6a9a2                                 51 147 813 1092
# 8  10423822b93a65ab                                     51 147 1022
# 9  1052bf702cb099f7         147 188 335 377 477 554 597 612 671 780
