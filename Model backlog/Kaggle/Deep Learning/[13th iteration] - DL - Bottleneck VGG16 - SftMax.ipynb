# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="softmax"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 9s - loss: 17.5617 - acc: 0.0184 - categorical_accuracy: 0.0184 - f2_score: 0.0012 - f2_score_1: 7.7623e-04 - f2_score_2: 5.6308e-04 - f2_score_3: 4.6907e-04 - f2_score_4: 3.5394e-04 - f2_score_5: 2.6820e-04 - val_loss: 16.9751 - val_acc: 0.0114 - val_categorical_accuracy: 0.0114 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 8s - loss: 16.8835 - acc: 0.0148 - categorical_accuracy: 0.0148 - f2_score: 3.7260e-04 - f2_score_1: 1.8193e-04 - f2_score_2: 9.7875e-05 - f2_score_3: 5.3489e-05 - f2_score_4: 3.4622e-05 - f2_score_5: 2.2448e-05 - val_loss: 16.9057 - val_acc: 0.0112 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 8s - loss: 16.8411 - acc: 0.0139 - categorical_accuracy: 0.0139 - f2_score: 7.0821e-04 - f2_score_1: 3.8762e-04 - f2_score_2: 2.4545e-04 - f2_score_3: 1.4443e-04 - f2_score_4: 8.1781e-05 - f2_score_5: 6.3882e-05 - val_loss: 16.8456 - val_acc: 0.0117 - val_categorical_accuracy: 0.0117 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 4/200
#  - 8s - loss: 16.8188 - acc: 0.0141 - categorical_accuracy: 0.0141 - f2_score: 5.9254e-04 - f2_score_1: 2.9652e-04 - f2_score_2: 1.9816e-04 - f2_score_3: 1.3955e-04 - f2_score_4: 9.0815e-05 - f2_score_5: 6.6646e-05 - val_loss: 16.8620 - val_acc: 0.0112 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 5/200
#  - 8s - loss: 16.8113 - acc: 0.0143 - categorical_accuracy: 0.0143 - f2_score: 4.9368e-04 - f2_score_1: 2.5278e-04 - f2_score_2: 1.4682e-04 - f2_score_3: 9.9178e-05 - f2_score_4: 5.1417e-05 - f2_score_5: 2.3155e-05 - val_loss: 16.8609 - val_acc: 0.0112 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 6/200
#  - 8s - loss: 16.7983 - acc: 0.0151 - categorical_accuracy: 0.0151 - f2_score: 8.6240e-04 - f2_score_1: 5.1967e-04 - f2_score_2: 3.3504e-04 - f2_score_3: 2.3575e-04 - f2_score_4: 1.1917e-04 - f2_score_5: 6.8220e-05 - val_loss: 16.8521 - val_acc: 0.0124 - val_categorical_accuracy: 0.0124 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 7/200
#  - 8s - loss: 16.7956 - acc: 0.0143 - categorical_accuracy: 0.0143 - f2_score: 9.8294e-04 - f2_score_1: 5.0833e-04 - f2_score_2: 3.1882e-04 - f2_score_3: 1.9528e-04 - f2_score_4: 1.1765e-04 - f2_score_5: 8.5476e-05 - val_loss: 16.8482 - val_acc: 0.0113 - val_categorical_accuracy: 0.0113 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 8/200
#  - 8s - loss: 16.7939 - acc: 0.0146 - categorical_accuracy: 0.0146 - f2_score: 9.1201e-04 - f2_score_1: 5.8799e-04 - f2_score_2: 4.3490e-04 - f2_score_3: 3.1986e-04 - f2_score_4: 1.7817e-04 - f2_score_5: 1.2124e-04 - val_loss: 16.8465 - val_acc: 0.0121 - val_categorical_accuracy: 0.0121 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 9/200
#  - 9s - loss: 16.7951 - acc: 0.0147 - categorical_accuracy: 0.0147 - f2_score: 8.3026e-04 - f2_score_1: 4.9122e-04 - f2_score_2: 3.6308e-04 - f2_score_3: 2.7191e-04 - f2_score_4: 1.9075e-04 - f2_score_5: 1.3945e-04 - val_loss: 16.7949 - val_acc: 0.0112 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 10/200
#  - 8s - loss: 16.6572 - acc: 0.0227 - categorical_accuracy: 0.0227 - f2_score: 0.0026 - f2_score_1: 0.0014 - f2_score_2: 8.1881e-04 - f2_score_3: 4.6384e-04 - f2_score_4: 2.2025e-04 - f2_score_5: 1.1305e-04 - val_loss: 16.4216 - val_acc: 0.0270 - val_categorical_accuracy: 0.0270 - val_f2_score: 5.0882e-05 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 11/200
#  - 8s - loss: 16.5547 - acc: 0.0287 - categorical_accuracy: 0.0287 - f2_score: 0.0039 - f2_score_1: 0.0020 - f2_score_2: 0.0012 - f2_score_3: 7.8966e-04 - f2_score_4: 3.8274e-04 - f2_score_5: 2.1088e-04 - val_loss: 16.3141 - val_acc: 0.0277 - val_categorical_accuracy: 0.0277 - val_f2_score: 0.0024 - val_f2_score_1: 6.4156e-04 - val_f2_score_2: 7.3067e-05 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 12/200
#  - 8s - loss: 16.5034 - acc: 0.0303 - categorical_accuracy: 0.0303 - f2_score: 0.0050 - f2_score_1: 0.0028 - f2_score_2: 0.0016 - f2_score_3: 9.6805e-04 - f2_score_4: 5.2792e-04 - f2_score_5: 3.0700e-04 - val_loss: 16.4388 - val_acc: 0.0205 - val_categorical_accuracy: 0.0205 - val_f2_score: 3.0623e-04 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 13/200
#  - 8s - loss: 16.4673 - acc: 0.0320 - categorical_accuracy: 0.0320 - f2_score: 0.0058 - f2_score_1: 0.0032 - f2_score_2: 0.0019 - f2_score_3: 0.0012 - f2_score_4: 6.1715e-04 - f2_score_5: 3.0393e-04 - val_loss: 16.3645 - val_acc: 0.0325 - val_categorical_accuracy: 0.0325 - val_f2_score: 0.0016 - val_f2_score_1: 4.3320e-04 - val_f2_score_2: 1.5238e-04 - val_f2_score_3: 1.0903e-05 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 14/200
#  - 8s - loss: 16.4457 - acc: 0.0336 - categorical_accuracy: 0.0336 - f2_score: 0.0070 - f2_score_1: 0.0038 - f2_score_2: 0.0024 - f2_score_3: 0.0015 - f2_score_4: 6.3578e-04 - f2_score_5: 3.5843e-04 - val_loss: 16.4230 - val_acc: 0.0372 - val_categorical_accuracy: 0.0372 - val_f2_score: 0.0019 - val_f2_score_1: 7.5471e-04 - val_f2_score_2: 1.3699e-04 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 15/200
#  - 8s - loss: 16.4180 - acc: 0.0354 - categorical_accuracy: 0.0354 - f2_score: 0.0071 - f2_score_1: 0.0040 - f2_score_2: 0.0025 - f2_score_3: 0.0017 - f2_score_4: 8.7614e-04 - f2_score_5: 4.8848e-04 - val_loss: 16.3648 - val_acc: 0.0270 - val_categorical_accuracy: 0.0270 - val_f2_score: 0.0012 - val_f2_score_1: 3.8471e-04 - val_f2_score_2: 2.3461e-04 - val_f2_score_3: 8.1964e-05 - val_f2_score_4: 5.0882e-05 - val_f2_score_5: 0.0000e+00
# Epoch 16/200
#  - 8s - loss: 16.3960 - acc: 0.0368 - categorical_accuracy: 0.0368 - f2_score: 0.0084 - f2_score_1: 0.0052 - f2_score_2: 0.0033 - f2_score_3: 0.0022 - f2_score_4: 0.0013 - f2_score_5: 7.0241e-04 - val_loss: 16.0814 - val_acc: 0.0488 - val_categorical_accuracy: 0.0488 - val_f2_score: 0.0028 - val_f2_score_1: 9.7299e-04 - val_f2_score_2: 3.0365e-04 - val_f2_score_3: 1.3469e-05 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 17/200
#  - 8s - loss: 16.3556 - acc: 0.0387 - categorical_accuracy: 0.0387 - f2_score: 0.0098 - f2_score_1: 0.0059 - f2_score_2: 0.0040 - f2_score_3: 0.0028 - f2_score_4: 0.0015 - f2_score_5: 8.4212e-04 - val_loss: 16.1586 - val_acc: 0.0448 - val_categorical_accuracy: 0.0448 - val_f2_score: 0.0045 - val_f2_score_1: 0.0022 - val_f2_score_2: 0.0013 - val_f2_score_3: 6.8967e-04 - val_f2_score_4: 1.3480e-04 - val_f2_score_5: 0.0000e+00
# Epoch 18/200
#  - 8s - loss: 16.3545 - acc: 0.0383 - categorical_accuracy: 0.0383 - f2_score: 0.0094 - f2_score_1: 0.0054 - f2_score_2: 0.0036 - f2_score_3: 0.0026 - f2_score_4: 0.0013 - f2_score_5: 7.4150e-04 - val_loss: 16.4659 - val_acc: 0.0254 - val_categorical_accuracy: 0.0254 - val_f2_score: 6.2164e-05 - val_f2_score_1: 1.7613e-05 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 19/200
#  - 8s - loss: 16.3337 - acc: 0.0396 - categorical_accuracy: 0.0396 - f2_score: 0.0103 - f2_score_1: 0.0062 - f2_score_2: 0.0041 - f2_score_3: 0.0029 - f2_score_4: 0.0015 - f2_score_5: 8.4818e-04 - val_loss: 16.1146 - val_acc: 0.0424 - val_categorical_accuracy: 0.0424 - val_f2_score: 0.0014 - val_f2_score_1: 9.6637e-04 - val_f2_score_2: 7.5827e-04 - val_f2_score_3: 6.0471e-04 - val_f2_score_4: 3.3269e-04 - val_f2_score_5: 1.1155e-04
# Epoch 20/200
#  - 8s - loss: 15.9281 - acc: 0.0538 - categorical_accuracy: 0.0538 - f2_score: 0.0154 - f2_score_1: 0.0088 - f2_score_2: 0.0053 - f2_score_3: 0.0034 - f2_score_4: 0.0016 - f2_score_5: 7.8824e-04 - val_loss: 15.4536 - val_acc: 0.0728 - val_categorical_accuracy: 0.0728 - val_f2_score: 0.0081 - val_f2_score_1: 0.0019 - val_f2_score_2: 4.1880e-04 - val_f2_score_3: 5.2839e-05 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 21/200
#  - 8s - loss: 15.8301 - acc: 0.0562 - categorical_accuracy: 0.0562 - f2_score: 0.0161 - f2_score_1: 0.0092 - f2_score_2: 0.0057 - f2_score_3: 0.0039 - f2_score_4: 0.0018 - f2_score_5: 9.3151e-04 - val_loss: 15.3448 - val_acc: 0.0716 - val_categorical_accuracy: 0.0716 - val_f2_score: 0.0170 - val_f2_score_1: 0.0062 - val_f2_score_2: 0.0012 - val_f2_score_3: 2.7962e-04 - val_f2_score_4: 9.3936e-05 - val_f2_score_5: 0.0000e+00
# Epoch 22/200
#  - 8s - loss: 15.7771 - acc: 0.0606 - categorical_accuracy: 0.0606 - f2_score: 0.0174 - f2_score_1: 0.0099 - f2_score_2: 0.0064 - f2_score_3: 0.0042 - f2_score_4: 0.0021 - f2_score_5: 0.0012 - val_loss: 15.2493 - val_acc: 0.0710 - val_categorical_accuracy: 0.0710 - val_f2_score: 0.0199 - val_f2_score_1: 0.0097 - val_f2_score_2: 0.0041 - val_f2_score_3: 0.0024 - val_f2_score_4: 7.4734e-04 - val_f2_score_5: 3.2291e-04
# Epoch 23/200
#  - 8s - loss: 15.7389 - acc: 0.0611 - categorical_accuracy: 0.0611 - f2_score: 0.0175 - f2_score_1: 0.0100 - f2_score_2: 0.0064 - f2_score_3: 0.0042 - f2_score_4: 0.0020 - f2_score_5: 0.0012 - val_loss: 15.2352 - val_acc: 0.0588 - val_categorical_accuracy: 0.0588 - val_f2_score: 0.0148 - val_f2_score_1: 0.0054 - val_f2_score_2: 0.0024 - val_f2_score_3: 0.0013 - val_f2_score_4: 4.5011e-04 - val_f2_score_5: 1.7026e-04
# Epoch 24/200
#  - 8s - loss: 15.7120 - acc: 0.0609 - categorical_accuracy: 0.0609 - f2_score: 0.0179 - f2_score_1: 0.0105 - f2_score_2: 0.0067 - f2_score_3: 0.0043 - f2_score_4: 0.0024 - f2_score_5: 0.0013 - val_loss: 15.2814 - val_acc: 0.0616 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.0070 - val_f2_score_1: 0.0024 - val_f2_score_2: 6.2036e-04 - val_f2_score_3: 1.4482e-04 - val_f2_score_4: 7.6323e-05 - val_f2_score_5: 0.0000e+00
# Epoch 25/200
#  - 8s - loss: 15.6742 - acc: 0.0621 - categorical_accuracy: 0.0621 - f2_score: 0.0191 - f2_score_1: 0.0113 - f2_score_2: 0.0072 - f2_score_3: 0.0048 - f2_score_4: 0.0024 - f2_score_5: 0.0013 - val_loss: 15.3107 - val_acc: 0.0661 - val_categorical_accuracy: 0.0661 - val_f2_score: 0.0061 - val_f2_score_1: 0.0023 - val_f2_score_2: 9.3517e-04 - val_f2_score_3: 4.1904e-04 - val_f2_score_4: 6.0274e-05 - val_f2_score_5: 0.0000e+00
# Epoch 26/200
#  - 8s - loss: 15.6187 - acc: 0.0641 - categorical_accuracy: 0.0641 - f2_score: 0.0206 - f2_score_1: 0.0122 - f2_score_2: 0.0077 - f2_score_3: 0.0053 - f2_score_4: 0.0026 - f2_score_5: 0.0014 - val_loss: 15.1570 - val_acc: 0.0711 - val_categorical_accuracy: 0.0711 - val_f2_score: 0.0121 - val_f2_score_1: 0.0049 - val_f2_score_2: 0.0026 - val_f2_score_3: 0.0016 - val_f2_score_4: 3.9923e-04 - val_f2_score_5: 6.8495e-05
# Epoch 27/200
#  - 8s - loss: 15.6144 - acc: 0.0666 - categorical_accuracy: 0.0666 - f2_score: 0.0214 - f2_score_1: 0.0126 - f2_score_2: 0.0079 - f2_score_3: 0.0053 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 15.1226 - val_acc: 0.0797 - val_categorical_accuracy: 0.0797 - val_f2_score: 0.0185 - val_f2_score_1: 0.0091 - val_f2_score_2: 0.0039 - val_f2_score_3: 0.0015 - val_f2_score_4: 1.1703e-04 - val_f2_score_5: 0.0000e+00
# Epoch 28/200
#  - 8s - loss: 15.5849 - acc: 0.0685 - categorical_accuracy: 0.0685 - f2_score: 0.0211 - f2_score_1: 0.0122 - f2_score_2: 0.0079 - f2_score_3: 0.0052 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 15.0693 - val_acc: 0.0873 - val_categorical_accuracy: 0.0873 - val_f2_score: 0.0198 - val_f2_score_1: 0.0099 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0031 - val_f2_score_4: 5.6626e-04 - val_f2_score_5: 2.5441e-05
# Epoch 29/200
#  - 8s - loss: 15.5631 - acc: 0.0681 - categorical_accuracy: 0.0681 - f2_score: 0.0225 - f2_score_1: 0.0133 - f2_score_2: 0.0087 - f2_score_3: 0.0060 - f2_score_4: 0.0029 - f2_score_5: 0.0015 - val_loss: 14.9926 - val_acc: 0.0693 - val_categorical_accuracy: 0.0693 - val_f2_score: 0.0208 - val_f2_score_1: 0.0092 - val_f2_score_2: 0.0033 - val_f2_score_3: 0.0015 - val_f2_score_4: 7.4136e-05 - val_f2_score_5: 0.0000e+00
# Epoch 30/200
#  - 8s - loss: 15.3402 - acc: 0.0736 - categorical_accuracy: 0.0736 - f2_score: 0.0240 - f2_score_1: 0.0137 - f2_score_2: 0.0080 - f2_score_3: 0.0051 - f2_score_4: 0.0023 - f2_score_5: 0.0014 - val_loss: 14.7827 - val_acc: 0.0893 - val_categorical_accuracy: 0.0893 - val_f2_score: 0.0212 - val_f2_score_1: 0.0101 - val_f2_score_2: 0.0045 - val_f2_score_3: 0.0016 - val_f2_score_4: 6.8495e-05 - val_f2_score_5: 0.0000e+00
# Epoch 31/200
#  - 8s - loss: 15.2826 - acc: 0.0748 - categorical_accuracy: 0.0748 - f2_score: 0.0243 - f2_score_1: 0.0139 - f2_score_2: 0.0085 - f2_score_3: 0.0053 - f2_score_4: 0.0026 - f2_score_5: 0.0013 - val_loss: 14.7875 - val_acc: 0.0879 - val_categorical_accuracy: 0.0879 - val_f2_score: 0.0207 - val_f2_score_1: 0.0075 - val_f2_score_2: 0.0027 - val_f2_score_3: 8.0122e-04 - val_f2_score_4: 9.3936e-05 - val_f2_score_5: 4.3054e-05
# Epoch 32/200
#  - 8s - loss: 15.2708 - acc: 0.0764 - categorical_accuracy: 0.0764 - f2_score: 0.0250 - f2_score_1: 0.0142 - f2_score_2: 0.0085 - f2_score_3: 0.0056 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.7142 - val_acc: 0.0922 - val_categorical_accuracy: 0.0922 - val_f2_score: 0.0225 - val_f2_score_1: 0.0091 - val_f2_score_2: 0.0032 - val_f2_score_3: 0.0011 - val_f2_score_4: 2.6420e-04 - val_f2_score_5: 0.0000e+00
# Epoch 33/200
#  - 8s - loss: 15.2592 - acc: 0.0743 - categorical_accuracy: 0.0743 - f2_score: 0.0248 - f2_score_1: 0.0140 - f2_score_2: 0.0088 - f2_score_3: 0.0058 - f2_score_4: 0.0026 - f2_score_5: 0.0014 - val_loss: 14.6832 - val_acc: 0.0978 - val_categorical_accuracy: 0.0978 - val_f2_score: 0.0285 - val_f2_score_1: 0.0121 - val_f2_score_2: 0.0042 - val_f2_score_3: 0.0017 - val_f2_score_4: 1.7026e-04 - val_f2_score_5: 4.3054e-05
# Epoch 34/200
#  - 8s - loss: 15.2396 - acc: 0.0789 - categorical_accuracy: 0.0789 - f2_score: 0.0256 - f2_score_1: 0.0146 - f2_score_2: 0.0089 - f2_score_3: 0.0055 - f2_score_4: 0.0026 - f2_score_5: 0.0013 - val_loss: 14.6627 - val_acc: 0.0866 - val_categorical_accuracy: 0.0866 - val_f2_score: 0.0212 - val_f2_score_1: 0.0089 - val_f2_score_2: 0.0042 - val_f2_score_3: 0.0025 - val_f2_score_4: 0.0011 - val_f2_score_5: 5.2917e-04
# Epoch 35/200
#  - 9s - loss: 15.2289 - acc: 0.0793 - categorical_accuracy: 0.0793 - f2_score: 0.0252 - f2_score_1: 0.0144 - f2_score_2: 0.0085 - f2_score_3: 0.0054 - f2_score_4: 0.0026 - f2_score_5: 0.0013 - val_loss: 14.6632 - val_acc: 0.0788 - val_categorical_accuracy: 0.0788 - val_f2_score: 0.0192 - val_f2_score_1: 0.0069 - val_f2_score_2: 0.0027 - val_f2_score_3: 0.0014 - val_f2_score_4: 5.4679e-04 - val_f2_score_5: 1.8318e-04
# Epoch 36/200
#  - 8s - loss: 15.2181 - acc: 0.0783 - categorical_accuracy: 0.0783 - f2_score: 0.0261 - f2_score_1: 0.0148 - f2_score_2: 0.0090 - f2_score_3: 0.0058 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.7350 - val_acc: 0.0821 - val_categorical_accuracy: 0.0821 - val_f2_score: 0.0139 - val_f2_score_1: 0.0062 - val_f2_score_2: 0.0027 - val_f2_score_3: 0.0012 - val_f2_score_4: 5.3990e-04 - val_f2_score_5: 1.7809e-04
# Epoch 37/200
#  - 8s - loss: 15.2033 - acc: 0.0803 - categorical_accuracy: 0.0803 - f2_score: 0.0262 - f2_score_1: 0.0153 - f2_score_2: 0.0095 - f2_score_3: 0.0061 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.6043 - val_acc: 0.0771 - val_categorical_accuracy: 0.0771 - val_f2_score: 0.0302 - val_f2_score_1: 0.0167 - val_f2_score_2: 0.0077 - val_f2_score_3: 0.0037 - val_f2_score_4: 0.0012 - val_f2_score_5: 6.1802e-04
# Epoch 38/200
#  - 8s - loss: 15.1909 - acc: 0.0789 - categorical_accuracy: 0.0789 - f2_score: 0.0264 - f2_score_1: 0.0150 - f2_score_2: 0.0091 - f2_score_3: 0.0058 - f2_score_4: 0.0026 - f2_score_5: 0.0014 - val_loss: 14.6812 - val_acc: 0.0724 - val_categorical_accuracy: 0.0724 - val_f2_score: 0.0233 - val_f2_score_1: 0.0110 - val_f2_score_2: 0.0049 - val_f2_score_3: 0.0021 - val_f2_score_4: 3.8670e-04 - val_f2_score_5: 2.5441e-05
# Epoch 39/200
#  - 8s - loss: 15.1850 - acc: 0.0798 - categorical_accuracy: 0.0798 - f2_score: 0.0266 - f2_score_1: 0.0152 - f2_score_2: 0.0095 - f2_score_3: 0.0062 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.6614 - val_acc: 0.0884 - val_categorical_accuracy: 0.0884 - val_f2_score: 0.0219 - val_f2_score_1: 0.0103 - val_f2_score_2: 0.0054 - val_f2_score_3: 0.0025 - val_f2_score_4: 8.4856e-04 - val_f2_score_5: 1.5265e-04
# Epoch 40/200
#  - 8s - loss: 15.0556 - acc: 0.0826 - categorical_accuracy: 0.0826 - f2_score: 0.0281 - f2_score_1: 0.0160 - f2_score_2: 0.0093 - f2_score_3: 0.0057 - f2_score_4: 0.0027 - f2_score_5: 0.0014 - val_loss: 14.5018 - val_acc: 0.0959 - val_categorical_accuracy: 0.0959 - val_f2_score: 0.0278 - val_f2_score_1: 0.0112 - val_f2_score_2: 0.0050 - val_f2_score_3: 0.0026 - val_f2_score_4: 0.0012 - val_f2_score_5: 5.7223e-04
# Epoch 41/200
#  - 8s - loss: 15.0346 - acc: 0.0854 - categorical_accuracy: 0.0854 - f2_score: 0.0285 - f2_score_1: 0.0157 - f2_score_2: 0.0090 - f2_score_3: 0.0056 - f2_score_4: 0.0026 - f2_score_5: 0.0014 - val_loss: 14.5802 - val_acc: 0.0870 - val_categorical_accuracy: 0.0870 - val_f2_score: 0.0212 - val_f2_score_1: 0.0079 - val_f2_score_2: 0.0035 - val_f2_score_3: 0.0019 - val_f2_score_4: 6.6381e-04 - val_f2_score_5: 5.0373e-04
# Epoch 42/200
#  - 8s - loss: 15.0182 - acc: 0.0829 - categorical_accuracy: 0.0829 - f2_score: 0.0283 - f2_score_1: 0.0158 - f2_score_2: 0.0094 - f2_score_3: 0.0061 - f2_score_4: 0.0029 - f2_score_5: 0.0015 - val_loss: 14.4940 - val_acc: 0.0845 - val_categorical_accuracy: 0.0845 - val_f2_score: 0.0266 - val_f2_score_1: 0.0112 - val_f2_score_2: 0.0050 - val_f2_score_3: 0.0026 - val_f2_score_4: 7.4014e-04 - val_f2_score_5: 2.7476e-04
# Epoch 43/200
#  - 8s - loss: 15.0095 - acc: 0.0839 - categorical_accuracy: 0.0839 - f2_score: 0.0292 - f2_score_1: 0.0165 - f2_score_2: 0.0097 - f2_score_3: 0.0061 - f2_score_4: 0.0028 - f2_score_5: 0.0013 - val_loss: 14.4920 - val_acc: 0.0935 - val_categorical_accuracy: 0.0935 - val_f2_score: 0.0275 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0028 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.2076e-04
# Epoch 44/200
#  - 8s - loss: 14.9976 - acc: 0.0864 - categorical_accuracy: 0.0864 - f2_score: 0.0298 - f2_score_1: 0.0172 - f2_score_2: 0.0101 - f2_score_3: 0.0062 - f2_score_4: 0.0028 - f2_score_5: 0.0015 - val_loss: 14.4560 - val_acc: 0.0959 - val_categorical_accuracy: 0.0959 - val_f2_score: 0.0255 - val_f2_score_1: 0.0109 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0011 - val_f2_score_5: 3.0529e-04
# Epoch 45/200
#  - 8s - loss: 14.9974 - acc: 0.0852 - categorical_accuracy: 0.0852 - f2_score: 0.0292 - f2_score_1: 0.0166 - f2_score_2: 0.0098 - f2_score_3: 0.0061 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.4825 - val_acc: 0.0893 - val_categorical_accuracy: 0.0893 - val_f2_score: 0.0227 - val_f2_score_1: 0.0099 - val_f2_score_2: 0.0046 - val_f2_score_3: 0.0026 - val_f2_score_4: 0.0013 - val_f2_score_5: 5.2135e-04
# Epoch 46/200
#  - 9s - loss: 14.9899 - acc: 0.0859 - categorical_accuracy: 0.0859 - f2_score: 0.0287 - f2_score_1: 0.0163 - f2_score_2: 0.0100 - f2_score_3: 0.0064 - f2_score_4: 0.0029 - f2_score_5: 0.0017 - val_loss: 14.4857 - val_acc: 0.0832 - val_categorical_accuracy: 0.0832 - val_f2_score: 0.0262 - val_f2_score_1: 0.0113 - val_f2_score_2: 0.0047 - val_f2_score_3: 0.0024 - val_f2_score_4: 7.9337e-04 - val_f2_score_5: 2.5441e-05
# Epoch 47/200
#  - 8s - loss: 14.9873 - acc: 0.0852 - categorical_accuracy: 0.0852 - f2_score: 0.0294 - f2_score_1: 0.0165 - f2_score_2: 0.0098 - f2_score_3: 0.0059 - f2_score_4: 0.0026 - f2_score_5: 0.0013 - val_loss: 14.4765 - val_acc: 0.1021 - val_categorical_accuracy: 0.1021 - val_f2_score: 0.0270 - val_f2_score_1: 0.0121 - val_f2_score_2: 0.0062 - val_f2_score_3: 0.0030 - val_f2_score_4: 8.7768e-04 - val_f2_score_5: 3.6635e-04
# Epoch 48/200
#  - 8s - loss: 14.9743 - acc: 0.0865 - categorical_accuracy: 0.0865 - f2_score: 0.0289 - f2_score_1: 0.0167 - f2_score_2: 0.0099 - f2_score_3: 0.0061 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.4910 - val_acc: 0.0911 - val_categorical_accuracy: 0.0911 - val_f2_score: 0.0228 - val_f2_score_1: 0.0095 - val_f2_score_2: 0.0039 - val_f2_score_3: 0.0020 - val_f2_score_4: 5.5461e-04 - val_f2_score_5: 9.1588e-05
# Epoch 49/200
#  - 8s - loss: 14.9716 - acc: 0.0864 - categorical_accuracy: 0.0864 - f2_score: 0.0300 - f2_score_1: 0.0172 - f2_score_2: 0.0104 - f2_score_3: 0.0064 - f2_score_4: 0.0031 - f2_score_5: 0.0017 - val_loss: 14.4651 - val_acc: 0.0953 - val_categorical_accuracy: 0.0953 - val_f2_score: 0.0255 - val_f2_score_1: 0.0108 - val_f2_score_2: 0.0048 - val_f2_score_3: 0.0024 - val_f2_score_4: 7.1939e-04 - val_f2_score_5: 1.1938e-04
# Epoch 50/200
#  - 8s - loss: 14.9155 - acc: 0.0875 - categorical_accuracy: 0.0875 - f2_score: 0.0300 - f2_score_1: 0.0168 - f2_score_2: 0.0095 - f2_score_3: 0.0059 - f2_score_4: 0.0026 - f2_score_5: 0.0015 - val_loss: 14.4201 - val_acc: 0.0950 - val_categorical_accuracy: 0.0950 - val_f2_score: 0.0233 - val_f2_score_1: 0.0099 - val_f2_score_2: 0.0045 - val_f2_score_3: 0.0026 - val_f2_score_4: 0.0013 - val_f2_score_5: 5.0373e-04
# Epoch 51/200
#  - 8s - loss: 14.9081 - acc: 0.0868 - categorical_accuracy: 0.0868 - f2_score: 0.0301 - f2_score_1: 0.0171 - f2_score_2: 0.0103 - f2_score_3: 0.0064 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.4018 - val_acc: 0.0864 - val_categorical_accuracy: 0.0864 - val_f2_score: 0.0260 - val_f2_score_1: 0.0115 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0028 - val_f2_score_4: 0.0014 - val_f2_score_5: 5.8006e-04
# Epoch 52/200
#  - 8s - loss: 14.8987 - acc: 0.0878 - categorical_accuracy: 0.0878 - f2_score: 0.0302 - f2_score_1: 0.0170 - f2_score_2: 0.0098 - f2_score_3: 0.0059 - f2_score_4: 0.0027 - f2_score_5: 0.0013 - val_loss: 14.3875 - val_acc: 0.0988 - val_categorical_accuracy: 0.0988 - val_f2_score: 0.0295 - val_f2_score_1: 0.0123 - val_f2_score_2: 0.0057 - val_f2_score_3: 0.0036 - val_f2_score_4: 0.0019 - val_f2_score_5: 9.4132e-04
# Epoch 53/200
#  - 8s - loss: 14.9071 - acc: 0.0852 - categorical_accuracy: 0.0852 - f2_score: 0.0299 - f2_score_1: 0.0168 - f2_score_2: 0.0100 - f2_score_3: 0.0062 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.4346 - val_acc: 0.0886 - val_categorical_accuracy: 0.0886 - val_f2_score: 0.0240 - val_f2_score_1: 0.0099 - val_f2_score_2: 0.0048 - val_f2_score_3: 0.0027 - val_f2_score_4: 7.5814e-04 - val_f2_score_5: 1.6791e-04
# Epoch 54/200
#  - 8s - loss: 14.8853 - acc: 0.0866 - categorical_accuracy: 0.0866 - f2_score: 0.0303 - f2_score_1: 0.0169 - f2_score_2: 0.0101 - f2_score_3: 0.0062 - f2_score_4: 0.0028 - f2_score_5: 0.0015 - val_loss: 14.4014 - val_acc: 0.0991 - val_categorical_accuracy: 0.0991 - val_f2_score: 0.0282 - val_f2_score_1: 0.0123 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0029 - val_f2_score_4: 8.6768e-04 - val_f2_score_5: 4.6303e-04
# Epoch 55/200
#  - 8s - loss: 14.8922 - acc: 0.0873 - categorical_accuracy: 0.0873 - f2_score: 0.0302 - f2_score_1: 0.0172 - f2_score_2: 0.0102 - f2_score_3: 0.0064 - f2_score_4: 0.0028 - f2_score_5: 0.0015 - val_loss: 14.4037 - val_acc: 0.0831 - val_categorical_accuracy: 0.0831 - val_f2_score: 0.0254 - val_f2_score_1: 0.0106 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0033 - val_f2_score_4: 9.6183e-04 - val_f2_score_5: 4.6811e-04
# Epoch 56/200
#  - 8s - loss: 14.8802 - acc: 0.0870 - categorical_accuracy: 0.0870 - f2_score: 0.0300 - f2_score_1: 0.0168 - f2_score_2: 0.0101 - f2_score_3: 0.0063 - f2_score_4: 0.0028 - f2_score_5: 0.0015 - val_loss: 14.3842 - val_acc: 0.0901 - val_categorical_accuracy: 0.0901 - val_f2_score: 0.0271 - val_f2_score_1: 0.0124 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0025 - val_f2_score_4: 7.8335e-04 - val_f2_score_5: 7.1235e-05
# Epoch 57/200
#  - 8s - loss: 14.8844 - acc: 0.0876 - categorical_accuracy: 0.0876 - f2_score: 0.0309 - f2_score_1: 0.0176 - f2_score_2: 0.0104 - f2_score_3: 0.0067 - f2_score_4: 0.0032 - f2_score_5: 0.0019 - val_loss: 14.4005 - val_acc: 0.0928 - val_categorical_accuracy: 0.0928 - val_f2_score: 0.0255 - val_f2_score_1: 0.0104 - val_f2_score_2: 0.0048 - val_f2_score_3: 0.0029 - val_f2_score_4: 8.7478e-04 - val_f2_score_5: 4.1214e-04
# Epoch 58/200
#  - 8s - loss: 14.8784 - acc: 0.0885 - categorical_accuracy: 0.0885 - f2_score: 0.0304 - f2_score_1: 0.0173 - f2_score_2: 0.0103 - f2_score_3: 0.0063 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.3914 - val_acc: 0.0986 - val_categorical_accuracy: 0.0986 - val_f2_score: 0.0246 - val_f2_score_1: 0.0111 - val_f2_score_2: 0.0054 - val_f2_score_3: 0.0029 - val_f2_score_4: 0.0012 - val_f2_score_5: 5.2917e-04
# Epoch 59/200
#  - 8s - loss: 14.8777 - acc: 0.0902 - categorical_accuracy: 0.0902 - f2_score: 0.0306 - f2_score_1: 0.0173 - f2_score_2: 0.0105 - f2_score_3: 0.0066 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3825 - val_acc: 0.0898 - val_categorical_accuracy: 0.0898 - val_f2_score: 0.0304 - val_f2_score_1: 0.0138 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0032 - val_f2_score_4: 0.0017 - val_f2_score_5: 6.6381e-04
# Epoch 60/200
#  - 8s - loss: 14.8420 - acc: 0.0896 - categorical_accuracy: 0.0896 - f2_score: 0.0309 - f2_score_1: 0.0173 - f2_score_2: 0.0100 - f2_score_3: 0.0062 - f2_score_4: 0.0028 - f2_score_5: 0.0017 - val_loss: 14.3590 - val_acc: 0.0929 - val_categorical_accuracy: 0.0929 - val_f2_score: 0.0274 - val_f2_score_1: 0.0118 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0013 - val_f2_score_5: 6.0550e-04
# Epoch 61/200
#  - 8s - loss: 14.8480 - acc: 0.0882 - categorical_accuracy: 0.0882 - f2_score: 0.0304 - f2_score_1: 0.0171 - f2_score_2: 0.0101 - f2_score_3: 0.0065 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3445 - val_acc: 0.0909 - val_categorical_accuracy: 0.0909 - val_f2_score: 0.0289 - val_f2_score_1: 0.0133 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0013 - val_f2_score_5: 6.0550e-04
# Epoch 62/200
#  - 8s - loss: 14.8444 - acc: 0.0885 - categorical_accuracy: 0.0885 - f2_score: 0.0307 - f2_score_1: 0.0175 - f2_score_2: 0.0105 - f2_score_3: 0.0065 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3554 - val_acc: 0.0884 - val_categorical_accuracy: 0.0884 - val_f2_score: 0.0254 - val_f2_score_1: 0.0105 - val_f2_score_2: 0.0048 - val_f2_score_3: 0.0027 - val_f2_score_4: 0.0011 - val_f2_score_5: 4.5794e-04
# Epoch 63/200
#  - 8s - loss: 14.8387 - acc: 0.0879 - categorical_accuracy: 0.0879 - f2_score: 0.0307 - f2_score_1: 0.0174 - f2_score_2: 0.0101 - f2_score_3: 0.0066 - f2_score_4: 0.0030 - f2_score_5: 0.0017 - val_loss: 14.3345 - val_acc: 0.0941 - val_categorical_accuracy: 0.0941 - val_f2_score: 0.0283 - val_f2_score_1: 0.0123 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0032 - val_f2_score_4: 0.0015 - val_f2_score_5: 6.2076e-04
# Epoch 64/200
#  - 8s - loss: 14.8387 - acc: 0.0881 - categorical_accuracy: 0.0881 - f2_score: 0.0310 - f2_score_1: 0.0173 - f2_score_2: 0.0104 - f2_score_3: 0.0063 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.3489 - val_acc: 0.0890 - val_categorical_accuracy: 0.0890 - val_f2_score: 0.0277 - val_f2_score_1: 0.0127 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0013 - val_f2_score_5: 4.8338e-04
# Epoch 65/200
#  - 8s - loss: 14.8250 - acc: 0.0901 - categorical_accuracy: 0.0901 - f2_score: 0.0315 - f2_score_1: 0.0179 - f2_score_2: 0.0107 - f2_score_3: 0.0067 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3266 - val_acc: 0.0910 - val_categorical_accuracy: 0.0910 - val_f2_score: 0.0292 - val_f2_score_1: 0.0124 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0015 - val_f2_score_5: 8.4973e-04
# Epoch 66/200
#  - 8s - loss: 14.8215 - acc: 0.0879 - categorical_accuracy: 0.0879 - f2_score: 0.0317 - f2_score_1: 0.0177 - f2_score_2: 0.0102 - f2_score_3: 0.0063 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3309 - val_acc: 0.0982 - val_categorical_accuracy: 0.0982 - val_f2_score: 0.0299 - val_f2_score_1: 0.0136 - val_f2_score_2: 0.0069 - val_f2_score_3: 0.0037 - val_f2_score_4: 0.0017 - val_f2_score_5: 0.0012
# Epoch 67/200
#  - 8s - loss: 14.8304 - acc: 0.0889 - categorical_accuracy: 0.0889 - f2_score: 0.0316 - f2_score_1: 0.0179 - f2_score_2: 0.0106 - f2_score_3: 0.0063 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.3377 - val_acc: 0.0909 - val_categorical_accuracy: 0.0909 - val_f2_score: 0.0285 - val_f2_score_1: 0.0129 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0018 - val_f2_score_5: 9.4132e-04
# Epoch 68/200
#  - 8s - loss: 14.8156 - acc: 0.0911 - categorical_accuracy: 0.0911 - f2_score: 0.0314 - f2_score_1: 0.0177 - f2_score_2: 0.0107 - f2_score_3: 0.0065 - f2_score_4: 0.0031 - f2_score_5: 0.0016 - val_loss: 14.3193 - val_acc: 0.0909 - val_categorical_accuracy: 0.0909 - val_f2_score: 0.0283 - val_f2_score_1: 0.0132 - val_f2_score_2: 0.0063 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0018 - val_f2_score_5: 0.0011
# Epoch 69/200
#  - 8s - loss: 14.8167 - acc: 0.0896 - categorical_accuracy: 0.0896 - f2_score: 0.0316 - f2_score_1: 0.0184 - f2_score_2: 0.0111 - f2_score_3: 0.0069 - f2_score_4: 0.0031 - f2_score_5: 0.0017 - val_loss: 14.3541 - val_acc: 0.0899 - val_categorical_accuracy: 0.0899 - val_f2_score: 0.0256 - val_f2_score_1: 0.0106 - val_f2_score_2: 0.0048 - val_f2_score_3: 0.0027 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.2076e-04
# Epoch 70/200
#  - 8s - loss: 14.8015 - acc: 0.0891 - categorical_accuracy: 0.0891 - f2_score: 0.0316 - f2_score_1: 0.0178 - f2_score_2: 0.0104 - f2_score_3: 0.0065 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.3275 - val_acc: 0.0948 - val_categorical_accuracy: 0.0948 - val_f2_score: 0.0290 - val_f2_score_1: 0.0131 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0017 - val_f2_score_5: 9.0061e-04
# Epoch 71/200
#  - 8s - loss: 14.8023 - acc: 0.0883 - categorical_accuracy: 0.0883 - f2_score: 0.0306 - f2_score_1: 0.0176 - f2_score_2: 0.0103 - f2_score_3: 0.0065 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.3193 - val_acc: 0.0951 - val_categorical_accuracy: 0.0951 - val_f2_score: 0.0294 - val_f2_score_1: 0.0137 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0013 - val_f2_score_5: 5.8006e-04
# Epoch 72/200
#  - 9s - loss: 14.8012 - acc: 0.0892 - categorical_accuracy: 0.0892 - f2_score: 0.0318 - f2_score_1: 0.0179 - f2_score_2: 0.0104 - f2_score_3: 0.0065 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.3190 - val_acc: 0.0910 - val_categorical_accuracy: 0.0910 - val_f2_score: 0.0287 - val_f2_score_1: 0.0126 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0016 - val_f2_score_5: 7.5814e-04
# Epoch 73/200
#  - 8s - loss: 14.8038 - acc: 0.0887 - categorical_accuracy: 0.0887 - f2_score: 0.0312 - f2_score_1: 0.0172 - f2_score_2: 0.0099 - f2_score_3: 0.0061 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.3166 - val_acc: 0.0956 - val_categorical_accuracy: 0.0956 - val_f2_score: 0.0285 - val_f2_score_1: 0.0125 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.4641e-04
# Epoch 74/200
#  - 8s - loss: 14.8007 - acc: 0.0889 - categorical_accuracy: 0.0889 - f2_score: 0.0316 - f2_score_1: 0.0174 - f2_score_2: 0.0102 - f2_score_3: 0.0062 - f2_score_4: 0.0028 - f2_score_5: 0.0014 - val_loss: 14.3189 - val_acc: 0.0957 - val_categorical_accuracy: 0.0957 - val_f2_score: 0.0300 - val_f2_score_1: 0.0140 - val_f2_score_2: 0.0067 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.2585e-04
# Epoch 75/200
#  - 8s - loss: 14.8035 - acc: 0.0894 - categorical_accuracy: 0.0894 - f2_score: 0.0305 - f2_score_1: 0.0172 - f2_score_2: 0.0101 - f2_score_3: 0.0064 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3250 - val_acc: 0.0929 - val_categorical_accuracy: 0.0929 - val_f2_score: 0.0271 - val_f2_score_1: 0.0116 - val_f2_score_2: 0.0052 - val_f2_score_3: 0.0029 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.0041e-04
# Epoch 76/200
#  - 8s - loss: 14.7951 - acc: 0.0896 - categorical_accuracy: 0.0896 - f2_score: 0.0311 - f2_score_1: 0.0176 - f2_score_2: 0.0105 - f2_score_3: 0.0065 - f2_score_4: 0.0030 - f2_score_5: 0.0018 - val_loss: 14.3152 - val_acc: 0.0915 - val_categorical_accuracy: 0.0915 - val_f2_score: 0.0282 - val_f2_score_1: 0.0121 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0032 - val_f2_score_4: 0.0014 - val_f2_score_5: 5.8006e-04
# Epoch 77/200
#  - 8s - loss: 14.8080 - acc: 0.0899 - categorical_accuracy: 0.0899 - f2_score: 0.0312 - f2_score_1: 0.0173 - f2_score_2: 0.0103 - f2_score_3: 0.0063 - f2_score_4: 0.0030 - f2_score_5: 0.0015 - val_loss: 14.3130 - val_acc: 0.0937 - val_categorical_accuracy: 0.0937 - val_f2_score: 0.0285 - val_f2_score_1: 0.0127 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0017 - val_f2_score_5: 0.0012
# Epoch 78/200
#  - 8s - loss: 14.8002 - acc: 0.0893 - categorical_accuracy: 0.0893 - f2_score: 0.0310 - f2_score_1: 0.0178 - f2_score_2: 0.0104 - f2_score_3: 0.0066 - f2_score_4: 0.0031 - f2_score_5: 0.0016 - val_loss: 14.3042 - val_acc: 0.0933 - val_categorical_accuracy: 0.0933 - val_f2_score: 0.0300 - val_f2_score_1: 0.0139 - val_f2_score_2: 0.0064 - val_f2_score_3: 0.0037 - val_f2_score_4: 0.0016 - val_f2_score_5: 0.0010
# Epoch 79/200
#  - 8s - loss: 14.7972 - acc: 0.0887 - categorical_accuracy: 0.0887 - f2_score: 0.0318 - f2_score_1: 0.0179 - f2_score_2: 0.0109 - f2_score_3: 0.0068 - f2_score_4: 0.0033 - f2_score_5: 0.0019 - val_loss: 14.3203 - val_acc: 0.0910 - val_categorical_accuracy: 0.0910 - val_f2_score: 0.0291 - val_f2_score_1: 0.0133 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.0041e-04
# Epoch 80/200
#  - 8s - loss: 14.7794 - acc: 0.0895 - categorical_accuracy: 0.0895 - f2_score: 0.0319 - f2_score_1: 0.0181 - f2_score_2: 0.0104 - f2_score_3: 0.0063 - f2_score_4: 0.0029 - f2_score_5: 0.0015 - val_loss: 14.3067 - val_acc: 0.0950 - val_categorical_accuracy: 0.0950 - val_f2_score: 0.0277 - val_f2_score_1: 0.0123 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.2096e-04
# Epoch 81/200
#  - 9s - loss: 14.7917 - acc: 0.0888 - categorical_accuracy: 0.0888 - f2_score: 0.0315 - f2_score_1: 0.0177 - f2_score_2: 0.0102 - f2_score_3: 0.0061 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.2984 - val_acc: 0.0961 - val_categorical_accuracy: 0.0961 - val_f2_score: 0.0296 - val_f2_score_1: 0.0136 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.9220e-04
# Epoch 82/200
#  - 8s - loss: 14.7801 - acc: 0.0893 - categorical_accuracy: 0.0893 - f2_score: 0.0321 - f2_score_1: 0.0185 - f2_score_2: 0.0107 - f2_score_3: 0.0066 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.3069 - val_acc: 0.0953 - val_categorical_accuracy: 0.0953 - val_f2_score: 0.0277 - val_f2_score_1: 0.0122 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0016 - val_f2_score_5: 8.5482e-04
# Epoch 83/200
#  - 9s - loss: 14.7813 - acc: 0.0910 - categorical_accuracy: 0.0910 - f2_score: 0.0315 - f2_score_1: 0.0177 - f2_score_2: 0.0104 - f2_score_3: 0.0065 - f2_score_4: 0.0030 - f2_score_5: 0.0017 - val_loss: 14.3043 - val_acc: 0.0954 - val_categorical_accuracy: 0.0954 - val_f2_score: 0.0282 - val_f2_score_1: 0.0125 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0015 - val_f2_score_5: 8.5482e-04
# Epoch 84/200
#  - 8s - loss: 14.7899 - acc: 0.0906 - categorical_accuracy: 0.0906 - f2_score: 0.0315 - f2_score_1: 0.0176 - f2_score_2: 0.0105 - f2_score_3: 0.0065 - f2_score_4: 0.0029 - f2_score_5: 0.0014 - val_loss: 14.3054 - val_acc: 0.0942 - val_categorical_accuracy: 0.0942 - val_f2_score: 0.0276 - val_f2_score_1: 0.0121 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0032 - val_f2_score_4: 0.0015 - val_f2_score_5: 8.3447e-04
# Epoch 85/200
#  - 8s - loss: 14.7786 - acc: 0.0906 - categorical_accuracy: 0.0906 - f2_score: 0.0319 - f2_score_1: 0.0181 - f2_score_2: 0.0106 - f2_score_3: 0.0064 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.2988 - val_acc: 0.0971 - val_categorical_accuracy: 0.0971 - val_f2_score: 0.0290 - val_f2_score_1: 0.0137 - val_f2_score_2: 0.0063 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0015 - val_f2_score_5: 8.5482e-04
# Epoch 86/200
#  - 8s - loss: 14.7760 - acc: 0.0908 - categorical_accuracy: 0.0908 - f2_score: 0.0327 - f2_score_1: 0.0187 - f2_score_2: 0.0110 - f2_score_3: 0.0067 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.3058 - val_acc: 0.0945 - val_categorical_accuracy: 0.0945 - val_f2_score: 0.0284 - val_f2_score_1: 0.0129 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0032 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.2605e-04
# Epoch 87/200
#  - 8s - loss: 14.7862 - acc: 0.0909 - categorical_accuracy: 0.0909 - f2_score: 0.0317 - f2_score_1: 0.0178 - f2_score_2: 0.0104 - f2_score_3: 0.0063 - f2_score_4: 0.0031 - f2_score_5: 0.0016 - val_loss: 14.2998 - val_acc: 0.0944 - val_categorical_accuracy: 0.0944 - val_f2_score: 0.0289 - val_f2_score_1: 0.0128 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0016 - val_f2_score_5: 8.7517e-04
# Epoch 88/200
#  - 8s - loss: 14.7880 - acc: 0.0896 - categorical_accuracy: 0.0896 - f2_score: 0.0315 - f2_score_1: 0.0179 - f2_score_2: 0.0107 - f2_score_3: 0.0067 - f2_score_4: 0.0029 - f2_score_5: 0.0014 - val_loss: 14.3092 - val_acc: 0.0922 - val_categorical_accuracy: 0.0922 - val_f2_score: 0.0275 - val_f2_score_1: 0.0124 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.5129e-04
# Epoch 89/200
#  - 8s - loss: 14.7698 - acc: 0.0895 - categorical_accuracy: 0.0895 - f2_score: 0.0316 - f2_score_1: 0.0177 - f2_score_2: 0.0105 - f2_score_3: 0.0067 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.2985 - val_acc: 0.0951 - val_categorical_accuracy: 0.0951 - val_f2_score: 0.0285 - val_f2_score_1: 0.0127 - val_f2_score_2: 0.0055 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0014 - val_f2_score_5: 7.3779e-04
# Epoch 90/200
#  - 8s - loss: 14.7855 - acc: 0.0897 - categorical_accuracy: 0.0897 - f2_score: 0.0316 - f2_score_1: 0.0182 - f2_score_2: 0.0106 - f2_score_3: 0.0068 - f2_score_4: 0.0032 - f2_score_5: 0.0017 - val_loss: 14.2981 - val_acc: 0.0942 - val_categorical_accuracy: 0.0942 - val_f2_score: 0.0286 - val_f2_score_1: 0.0129 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0017 - val_f2_score_5: 9.7185e-04
# Epoch 91/200
#  - 8s - loss: 14.7774 - acc: 0.0893 - categorical_accuracy: 0.0893 - f2_score: 0.0310 - f2_score_1: 0.0175 - f2_score_2: 0.0103 - f2_score_3: 0.0062 - f2_score_4: 0.0027 - f2_score_5: 0.0015 - val_loss: 14.3015 - val_acc: 0.0949 - val_categorical_accuracy: 0.0949 - val_f2_score: 0.0286 - val_f2_score_1: 0.0129 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0015 - val_f2_score_5: 9.2605e-04
# Epoch 92/200
#  - 8s - loss: 14.7778 - acc: 0.0904 - categorical_accuracy: 0.0904 - f2_score: 0.0321 - f2_score_1: 0.0183 - f2_score_2: 0.0108 - f2_score_3: 0.0067 - f2_score_4: 0.0033 - f2_score_5: 0.0018 - val_loss: 14.2975 - val_acc: 0.0951 - val_categorical_accuracy: 0.0951 - val_f2_score: 0.0291 - val_f2_score_1: 0.0130 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0017 - val_f2_score_5: 9.2096e-04
# Epoch 93/200
#  - 8s - loss: 14.7758 - acc: 0.0908 - categorical_accuracy: 0.0908 - f2_score: 0.0313 - f2_score_1: 0.0175 - f2_score_2: 0.0103 - f2_score_3: 0.0064 - f2_score_4: 0.0028 - f2_score_5: 0.0015 - val_loss: 14.2978 - val_acc: 0.0942 - val_categorical_accuracy: 0.0942 - val_f2_score: 0.0286 - val_f2_score_1: 0.0127 - val_f2_score_2: 0.0057 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0017 - val_f2_score_5: 9.9220e-04
# Epoch 94/200
#  - 8s - loss: 14.7761 - acc: 0.0887 - categorical_accuracy: 0.0887 - f2_score: 0.0318 - f2_score_1: 0.0183 - f2_score_2: 0.0106 - f2_score_3: 0.0065 - f2_score_4: 0.0028 - f2_score_5: 0.0016 - val_loss: 14.2990 - val_acc: 0.0956 - val_categorical_accuracy: 0.0956 - val_f2_score: 0.0280 - val_f2_score_1: 0.0124 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.0061e-04
# Epoch 95/200
#  - 8s - loss: 14.7811 - acc: 0.0926 - categorical_accuracy: 0.0926 - f2_score: 0.0315 - f2_score_1: 0.0175 - f2_score_2: 0.0101 - f2_score_3: 0.0063 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.3028 - val_acc: 0.0951 - val_categorical_accuracy: 0.0951 - val_f2_score: 0.0278 - val_f2_score_1: 0.0122 - val_f2_score_2: 0.0056 - val_f2_score_3: 0.0031 - val_f2_score_4: 0.0016 - val_f2_score_5: 8.7517e-04
# Epoch 96/200
#  - 8s - loss: 14.7710 - acc: 0.0903 - categorical_accuracy: 0.0903 - f2_score: 0.0323 - f2_score_1: 0.0186 - f2_score_2: 0.0110 - f2_score_3: 0.0067 - f2_score_4: 0.0031 - f2_score_5: 0.0019 - val_loss: 14.2906 - val_acc: 0.0958 - val_categorical_accuracy: 0.0958 - val_f2_score: 0.0297 - val_f2_score_1: 0.0135 - val_f2_score_2: 0.0062 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0015 - val_f2_score_5: 8.2938e-04
# Epoch 97/200
#  - 8s - loss: 14.7752 - acc: 0.0902 - categorical_accuracy: 0.0902 - f2_score: 0.0319 - f2_score_1: 0.0177 - f2_score_2: 0.0106 - f2_score_3: 0.0067 - f2_score_4: 0.0031 - f2_score_5: 0.0018 - val_loss: 14.2908 - val_acc: 0.0969 - val_categorical_accuracy: 0.0969 - val_f2_score: 0.0290 - val_f2_score_1: 0.0134 - val_f2_score_2: 0.0062 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0014 - val_f2_score_5: 6.9200e-04
# Epoch 98/200
#  - 8s - loss: 14.7710 - acc: 0.0900 - categorical_accuracy: 0.0900 - f2_score: 0.0321 - f2_score_1: 0.0180 - f2_score_2: 0.0106 - f2_score_3: 0.0064 - f2_score_4: 0.0029 - f2_score_5: 0.0016 - val_loss: 14.2924 - val_acc: 0.0960 - val_categorical_accuracy: 0.0960 - val_f2_score: 0.0291 - val_f2_score_1: 0.0131 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0015 - val_f2_score_5: 9.2605e-04
# Epoch 99/200
#  - 8s - loss: 14.7740 - acc: 0.0891 - categorical_accuracy: 0.0891 - f2_score: 0.0324 - f2_score_1: 0.0185 - f2_score_2: 0.0108 - f2_score_3: 0.0066 - f2_score_4: 0.0030 - f2_score_5: 0.0017 - val_loss: 14.2945 - val_acc: 0.0955 - val_categorical_accuracy: 0.0955 - val_f2_score: 0.0290 - val_f2_score_1: 0.0130 - val_f2_score_2: 0.0058 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0014 - val_f2_score_5: 8.5482e-04
# Epoch 100/200
#  - 8s - loss: 14.7700 - acc: 0.0891 - categorical_accuracy: 0.0891 - f2_score: 0.0320 - f2_score_1: 0.0181 - f2_score_2: 0.0106 - f2_score_3: 0.0065 - f2_score_4: 0.0030 - f2_score_5: 0.0017 - val_loss: 14.2929 - val_acc: 0.0954 - val_categorical_accuracy: 0.0954 - val_f2_score: 0.0288 - val_f2_score_1: 0.0130 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0015 - val_f2_score_5: 9.0061e-04
# Epoch 101/200
#  - 8s - loss: 14.7630 - acc: 0.0905 - categorical_accuracy: 0.0905 - f2_score: 0.0321 - f2_score_1: 0.0182 - f2_score_2: 0.0108 - f2_score_3: 0.0066 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.2934 - val_acc: 0.0953 - val_categorical_accuracy: 0.0953 - val_f2_score: 0.0288 - val_f2_score_1: 0.0129 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0014 - val_f2_score_5: 8.0902e-04
# Epoch 102/200
#  - 8s - loss: 14.7772 - acc: 0.0913 - categorical_accuracy: 0.0913 - f2_score: 0.0325 - f2_score_1: 0.0187 - f2_score_2: 0.0111 - f2_score_3: 0.0069 - f2_score_4: 0.0033 - f2_score_5: 0.0018 - val_loss: 14.2936 - val_acc: 0.0954 - val_categorical_accuracy: 0.0954 - val_f2_score: 0.0293 - val_f2_score_1: 0.0134 - val_f2_score_2: 0.0061 - val_f2_score_3: 0.0035 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.0061e-04
# Epoch 103/200
#  - 8s - loss: 14.7643 - acc: 0.0893 - categorical_accuracy: 0.0893 - f2_score: 0.0328 - f2_score_1: 0.0185 - f2_score_2: 0.0111 - f2_score_3: 0.0069 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.2928 - val_acc: 0.0954 - val_categorical_accuracy: 0.0954 - val_f2_score: 0.0287 - val_f2_score_1: 0.0130 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0017 - val_f2_score_5: 9.4641e-04
# Epoch 104/200
#  - 8s - loss: 14.7720 - acc: 0.0895 - categorical_accuracy: 0.0895 - f2_score: 0.0311 - f2_score_1: 0.0176 - f2_score_2: 0.0104 - f2_score_3: 0.0065 - f2_score_4: 0.0031 - f2_score_5: 0.0017 - val_loss: 14.2974 - val_acc: 0.0954 - val_categorical_accuracy: 0.0954 - val_f2_score: 0.0286 - val_f2_score_1: 0.0131 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.0061e-04
# Epoch 105/200
#  - 8s - loss: 14.7711 - acc: 0.0895 - categorical_accuracy: 0.0895 - f2_score: 0.0323 - f2_score_1: 0.0185 - f2_score_2: 0.0108 - f2_score_3: 0.0068 - f2_score_4: 0.0031 - f2_score_5: 0.0016 - val_loss: 14.2947 - val_acc: 0.0959 - val_categorical_accuracy: 0.0959 - val_f2_score: 0.0289 - val_f2_score_1: 0.0132 - val_f2_score_2: 0.0060 - val_f2_score_3: 0.0034 - val_f2_score_4: 0.0014 - val_f2_score_5: 8.5482e-04
# Epoch 106/200
#  - 8s - loss: 14.7708 - acc: 0.0896 - categorical_accuracy: 0.0896 - f2_score: 0.0317 - f2_score_1: 0.0180 - f2_score_2: 0.0105 - f2_score_3: 0.0063 - f2_score_4: 0.0030 - f2_score_5: 0.0016 - val_loss: 14.2943 - val_acc: 0.0960 - val_categorical_accuracy: 0.0960 - val_f2_score: 0.0289 - val_f2_score_1: 0.0131 - val_f2_score_2: 0.0059 - val_f2_score_3: 0.0033 - val_f2_score_4: 0.0016 - val_f2_score_5: 9.0061e-04
# Epoch 00106: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id    attribute_ids
# 0  10023b2cc4ed5f68              121
# 1  100fbe75ed8fd887              121
# 2  101b627524a04f19              813
# 3  10234480c41284c6              813
# 4  1023b0e2636dcea8              813
# 5   1039cd6cf85845c  13 405 896 1092
# 6   103a5b3f83fbe88              813
# 7  10413aaae8d6a9a2              813
# 8  10423822b93a65ab              813
# 9  1052bf702cb099f7              813
