# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 10s - loss: 0.0313 - acc: 0.9921 - categorical_accuracy: 0.0315 - f2_score: 0.0782 - f2_score_1: 0.0601 - f2_score_2: 0.0453 - f2_score_3: 0.0340 - f2_score_4: 0.0182 - f2_score_5: 0.0095 - val_loss: 0.0156 - val_acc: 0.9971 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0622 - val_f2_score_1: 0.0317 - val_f2_score_2: 0.0034 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 9s - loss: 0.0176 - acc: 0.9971 - categorical_accuracy: 0.0365 - f2_score: 0.0917 - f2_score_1: 0.0589 - f2_score_2: 0.0350 - f2_score_3: 0.0197 - f2_score_4: 0.0049 - f2_score_5: 0.0011 - val_loss: 0.0151 - val_acc: 0.9971 - val_categorical_accuracy: 0.0114 - val_f2_score: 0.0956 - val_f2_score_1: 0.0572 - val_f2_score_2: 0.0355 - val_f2_score_3: 0.0139 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 9s - loss: 0.0167 - acc: 0.9971 - categorical_accuracy: 0.0400 - f2_score: 0.0964 - f2_score_1: 0.0584 - f2_score_2: 0.0321 - f2_score_3: 0.0161 - f2_score_4: 0.0029 - f2_score_5: 3.3793e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0167 - val_f2_score: 0.1078 - val_f2_score_1: 0.0691 - val_f2_score_2: 0.0426 - val_f2_score_3: 0.0226 - val_f2_score_4: 5.3593e-05 - val_f2_score_5: 0.0000e+00
# Epoch 4/200
#  - 9s - loss: 0.0163 - acc: 0.9971 - categorical_accuracy: 0.0441 - f2_score: 0.0999 - f2_score_1: 0.0599 - f2_score_2: 0.0327 - f2_score_3: 0.0158 - f2_score_4: 0.0030 - f2_score_5: 3.3529e-04 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0232 - val_f2_score: 0.1070 - val_f2_score_1: 0.0709 - val_f2_score_2: 0.0450 - val_f2_score_3: 0.0262 - val_f2_score_4: 0.0010 - val_f2_score_5: 0.0000e+00
# Epoch 5/200
#  - 9s - loss: 0.0160 - acc: 0.9971 - categorical_accuracy: 0.0475 - f2_score: 0.1038 - f2_score_1: 0.0625 - f2_score_2: 0.0348 - f2_score_3: 0.0175 - f2_score_4: 0.0034 - f2_score_5: 4.1778e-04 - val_loss: 0.0147 - val_acc: 0.9971 - val_categorical_accuracy: 0.0252 - val_f2_score: 0.1137 - val_f2_score_1: 0.0726 - val_f2_score_2: 0.0454 - val_f2_score_3: 0.0253 - val_f2_score_4: 0.0017 - val_f2_score_5: 0.0000e+00
# Epoch 6/200
#  - 9s - loss: 0.0158 - acc: 0.9971 - categorical_accuracy: 0.0475 - f2_score: 0.1069 - f2_score_1: 0.0646 - f2_score_2: 0.0363 - f2_score_3: 0.0184 - f2_score_4: 0.0034 - f2_score_5: 4.3408e-04 - val_loss: 0.0146 - val_acc: 0.9971 - val_categorical_accuracy: 0.0298 - val_f2_score: 0.1190 - val_f2_score_1: 0.0800 - val_f2_score_2: 0.0535 - val_f2_score_3: 0.0311 - val_f2_score_4: 0.0035 - val_f2_score_5: 0.0000e+00
# Epoch 7/200
#  - 9s - loss: 0.0157 - acc: 0.9971 - categorical_accuracy: 0.0504 - f2_score: 0.1102 - f2_score_1: 0.0680 - f2_score_2: 0.0380 - f2_score_3: 0.0190 - f2_score_4: 0.0036 - f2_score_5: 4.3416e-04 - val_loss: 0.0145 - val_acc: 0.9971 - val_categorical_accuracy: 0.0400 - val_f2_score: 0.1167 - val_f2_score_1: 0.0747 - val_f2_score_2: 0.0434 - val_f2_score_3: 0.0181 - val_f2_score_4: 5.6406e-05 - val_f2_score_5: 0.0000e+00
# Epoch 8/200
#  - 9s - loss: 0.0155 - acc: 0.9971 - categorical_accuracy: 0.0536 - f2_score: 0.1138 - f2_score_1: 0.0704 - f2_score_2: 0.0402 - f2_score_3: 0.0206 - f2_score_4: 0.0038 - f2_score_5: 4.8350e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0448 - val_f2_score: 0.1177 - val_f2_score_1: 0.0718 - val_f2_score_2: 0.0389 - val_f2_score_3: 0.0164 - val_f2_score_4: 6.4861e-05 - val_f2_score_5: 0.0000e+00
# Epoch 9/200
#  - 9s - loss: 0.0154 - acc: 0.9971 - categorical_accuracy: 0.0551 - f2_score: 0.1164 - f2_score_1: 0.0722 - f2_score_2: 0.0413 - f2_score_3: 0.0217 - f2_score_4: 0.0043 - f2_score_5: 5.1275e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0457 - val_f2_score: 0.1215 - val_f2_score_1: 0.0766 - val_f2_score_2: 0.0434 - val_f2_score_3: 0.0205 - val_f2_score_4: 1.0510e-04 - val_f2_score_5: 0.0000e+00
# Epoch 10/200
#  - 9s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0563 - f2_score: 0.1176 - f2_score_1: 0.0729 - f2_score_2: 0.0420 - f2_score_3: 0.0218 - f2_score_4: 0.0040 - f2_score_5: 4.5113e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0436 - val_f2_score: 0.1312 - val_f2_score_1: 0.0863 - val_f2_score_2: 0.0530 - val_f2_score_3: 0.0295 - val_f2_score_4: 0.0017 - val_f2_score_5: 0.0000e+00
# Epoch 11/200
#  - 9s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0573 - f2_score: 0.1195 - f2_score_1: 0.0746 - f2_score_2: 0.0433 - f2_score_3: 0.0225 - f2_score_4: 0.0042 - f2_score_5: 4.7068e-04 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0446 - val_f2_score: 0.1353 - val_f2_score_1: 0.0897 - val_f2_score_2: 0.0542 - val_f2_score_3: 0.0286 - val_f2_score_4: 0.0011 - val_f2_score_5: 0.0000e+00
# Epoch 12/200
#  - 9s - loss: 0.0152 - acc: 0.9971 - categorical_accuracy: 0.0578 - f2_score: 0.1208 - f2_score_1: 0.0759 - f2_score_2: 0.0444 - f2_score_3: 0.0228 - f2_score_4: 0.0042 - f2_score_5: 4.4137e-04 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0444 - val_f2_score: 0.1307 - val_f2_score_1: 0.0852 - val_f2_score_2: 0.0518 - val_f2_score_3: 0.0286 - val_f2_score_4: 0.0013 - val_f2_score_5: 0.0000e+00
# Epoch 13/200
#  - 9s - loss: 0.0152 - acc: 0.9971 - categorical_accuracy: 0.0566 - f2_score: 0.1212 - f2_score_1: 0.0762 - f2_score_2: 0.0439 - f2_score_3: 0.0227 - f2_score_4: 0.0040 - f2_score_5: 4.5423e-04 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0487 - val_f2_score: 0.1370 - val_f2_score_1: 0.0917 - val_f2_score_2: 0.0561 - val_f2_score_3: 0.0310 - val_f2_score_4: 0.0011 - val_f2_score_5: 0.0000e+00
# Epoch 14/200
#  - 9s - loss: 0.0152 - acc: 0.9971 - categorical_accuracy: 0.0604 - f2_score: 0.1232 - f2_score_1: 0.0783 - f2_score_2: 0.0454 - f2_score_3: 0.0243 - f2_score_4: 0.0045 - f2_score_5: 4.9367e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0529 - val_f2_score: 0.1348 - val_f2_score_1: 0.0879 - val_f2_score_2: 0.0505 - val_f2_score_3: 0.0245 - val_f2_score_4: 1.7616e-04 - val_f2_score_5: 0.0000e+00
# Epoch 15/200
#  - 9s - loss: 0.0151 - acc: 0.9971 - categorical_accuracy: 0.0607 - f2_score: 0.1243 - f2_score_1: 0.0779 - f2_score_2: 0.0455 - f2_score_3: 0.0243 - f2_score_4: 0.0045 - f2_score_5: 5.2687e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0488 - val_f2_score: 0.1382 - val_f2_score_1: 0.0919 - val_f2_score_2: 0.0565 - val_f2_score_3: 0.0315 - val_f2_score_4: 0.0022 - val_f2_score_5: 0.0000e+00
# Epoch 16/200
#  - 9s - loss: 0.0151 - acc: 0.9971 - categorical_accuracy: 0.0604 - f2_score: 0.1247 - f2_score_1: 0.0797 - f2_score_2: 0.0469 - f2_score_3: 0.0245 - f2_score_4: 0.0047 - f2_score_5: 5.3250e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0499 - val_f2_score: 0.1420 - val_f2_score_1: 0.0946 - val_f2_score_2: 0.0576 - val_f2_score_3: 0.0317 - val_f2_score_4: 0.0016 - val_f2_score_5: 0.0000e+00
# Epoch 17/200
#  - 9s - loss: 0.0151 - acc: 0.9971 - categorical_accuracy: 0.0626 - f2_score: 0.1263 - f2_score_1: 0.0806 - f2_score_2: 0.0475 - f2_score_3: 0.0252 - f2_score_4: 0.0048 - f2_score_5: 6.0419e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0505 - val_f2_score: 0.1425 - val_f2_score_1: 0.0966 - val_f2_score_2: 0.0596 - val_f2_score_3: 0.0342 - val_f2_score_4: 0.0014 - val_f2_score_5: 0.0000e+00
# Epoch 18/200
#  - 9s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0634 - f2_score: 0.1268 - f2_score_1: 0.0814 - f2_score_2: 0.0485 - f2_score_3: 0.0260 - f2_score_4: 0.0051 - f2_score_5: 5.7330e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0524 - val_f2_score: 0.1416 - val_f2_score_1: 0.0964 - val_f2_score_2: 0.0594 - val_f2_score_3: 0.0336 - val_f2_score_4: 0.0016 - val_f2_score_5: 0.0000e+00
# Epoch 19/200
#  - 9s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0648 - f2_score: 0.1280 - f2_score_1: 0.0822 - f2_score_2: 0.0489 - f2_score_3: 0.0262 - f2_score_4: 0.0048 - f2_score_5: 6.4397e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0541 - val_f2_score: 0.1489 - val_f2_score_1: 0.1026 - val_f2_score_2: 0.0645 - val_f2_score_3: 0.0374 - val_f2_score_4: 0.0020 - val_f2_score_5: 2.5441e-05
# Epoch 20/200
#  - 9s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0645 - f2_score: 0.1293 - f2_score_1: 0.0835 - f2_score_2: 0.0497 - f2_score_3: 0.0266 - f2_score_4: 0.0052 - f2_score_5: 6.6414e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0556 - val_f2_score: 0.1462 - val_f2_score_1: 0.0998 - val_f2_score_2: 0.0616 - val_f2_score_3: 0.0352 - val_f2_score_4: 0.0018 - val_f2_score_5: 2.5441e-05
# Epoch 21/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0632 - f2_score: 0.1294 - f2_score_1: 0.0838 - f2_score_2: 0.0497 - f2_score_3: 0.0264 - f2_score_4: 0.0052 - f2_score_5: 6.7149e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0589 - val_f2_score: 0.1462 - val_f2_score_1: 0.1001 - val_f2_score_2: 0.0623 - val_f2_score_3: 0.0356 - val_f2_score_4: 0.0015 - val_f2_score_5: 2.5441e-05
# Epoch 22/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0645 - f2_score: 0.1302 - f2_score_1: 0.0840 - f2_score_2: 0.0504 - f2_score_3: 0.0273 - f2_score_4: 0.0054 - f2_score_5: 6.7152e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0533 - val_f2_score: 0.1448 - val_f2_score_1: 0.0987 - val_f2_score_2: 0.0616 - val_f2_score_3: 0.0369 - val_f2_score_4: 0.0029 - val_f2_score_5: 2.5441e-05
# Epoch 23/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0648 - f2_score: 0.1295 - f2_score_1: 0.0834 - f2_score_2: 0.0507 - f2_score_3: 0.0276 - f2_score_4: 0.0051 - f2_score_5: 6.5241e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0568 - val_f2_score: 0.1487 - val_f2_score_1: 0.1029 - val_f2_score_2: 0.0654 - val_f2_score_3: 0.0384 - val_f2_score_4: 0.0031 - val_f2_score_5: 2.5441e-05
# Epoch 24/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0657 - f2_score: 0.1313 - f2_score_1: 0.0852 - f2_score_2: 0.0514 - f2_score_3: 0.0280 - f2_score_4: 0.0054 - f2_score_5: 5.9936e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0561 - val_f2_score: 0.1495 - val_f2_score_1: 0.1031 - val_f2_score_2: 0.0644 - val_f2_score_3: 0.0375 - val_f2_score_4: 0.0028 - val_f2_score_5: 2.5441e-05
# Epoch 25/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0660 - f2_score: 0.1312 - f2_score_1: 0.0847 - f2_score_2: 0.0510 - f2_score_3: 0.0281 - f2_score_4: 0.0054 - f2_score_5: 6.6581e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0546 - val_f2_score: 0.1504 - val_f2_score_1: 0.1052 - val_f2_score_2: 0.0676 - val_f2_score_3: 0.0403 - val_f2_score_4: 0.0035 - val_f2_score_5: 2.5441e-05
# Epoch 26/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0661 - f2_score: 0.1315 - f2_score_1: 0.0852 - f2_score_2: 0.0517 - f2_score_3: 0.0283 - f2_score_4: 0.0055 - f2_score_5: 6.8727e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0517 - val_f2_score: 0.1511 - val_f2_score_1: 0.1054 - val_f2_score_2: 0.0678 - val_f2_score_3: 0.0418 - val_f2_score_4: 0.0058 - val_f2_score_5: 2.5441e-05
# Epoch 27/200
#  - 9s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0668 - f2_score: 0.1325 - f2_score_1: 0.0862 - f2_score_2: 0.0519 - f2_score_3: 0.0289 - f2_score_4: 0.0059 - f2_score_5: 7.3129e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0598 - val_f2_score: 0.1489 - val_f2_score_1: 0.1022 - val_f2_score_2: 0.0646 - val_f2_score_3: 0.0379 - val_f2_score_4: 0.0024 - val_f2_score_5: 2.5441e-05
# Epoch 28/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0672 - f2_score: 0.1332 - f2_score_1: 0.0863 - f2_score_2: 0.0522 - f2_score_3: 0.0285 - f2_score_4: 0.0058 - f2_score_5: 7.0089e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0559 - val_f2_score: 0.1525 - val_f2_score_1: 0.1074 - val_f2_score_2: 0.0698 - val_f2_score_3: 0.0433 - val_f2_score_4: 0.0050 - val_f2_score_5: 5.0882e-05
# Epoch 29/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0664 - f2_score: 0.1330 - f2_score_1: 0.0870 - f2_score_2: 0.0530 - f2_score_3: 0.0293 - f2_score_4: 0.0057 - f2_score_5: 7.3841e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0579 - val_f2_score: 0.1527 - val_f2_score_1: 0.1076 - val_f2_score_2: 0.0692 - val_f2_score_3: 0.0415 - val_f2_score_4: 0.0043 - val_f2_score_5: 5.0882e-05
# Epoch 30/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0670 - f2_score: 0.1335 - f2_score_1: 0.0874 - f2_score_2: 0.0532 - f2_score_3: 0.0293 - f2_score_4: 0.0058 - f2_score_5: 7.1247e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0573 - val_f2_score: 0.1521 - val_f2_score_1: 0.1056 - val_f2_score_2: 0.0671 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0037 - val_f2_score_5: 5.0882e-05
# Epoch 31/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0675 - f2_score: 0.1338 - f2_score_1: 0.0870 - f2_score_2: 0.0532 - f2_score_3: 0.0293 - f2_score_4: 0.0057 - f2_score_5: 7.9292e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0555 - val_f2_score: 0.1541 - val_f2_score_1: 0.1085 - val_f2_score_2: 0.0703 - val_f2_score_3: 0.0436 - val_f2_score_4: 0.0059 - val_f2_score_5: 5.0882e-05
# Epoch 32/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0677 - f2_score: 0.1349 - f2_score_1: 0.0874 - f2_score_2: 0.0534 - f2_score_3: 0.0293 - f2_score_4: 0.0060 - f2_score_5: 7.2478e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0563 - val_f2_score: 0.1528 - val_f2_score_1: 0.1069 - val_f2_score_2: 0.0683 - val_f2_score_3: 0.0415 - val_f2_score_4: 0.0045 - val_f2_score_5: 5.0882e-05
# Epoch 33/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0673 - f2_score: 0.1346 - f2_score_1: 0.0876 - f2_score_2: 0.0533 - f2_score_3: 0.0295 - f2_score_4: 0.0062 - f2_score_5: 7.5537e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1538 - val_f2_score_1: 0.1082 - val_f2_score_2: 0.0686 - val_f2_score_3: 0.0408 - val_f2_score_4: 0.0035 - val_f2_score_5: 5.0882e-05
# Epoch 34/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0684 - f2_score: 0.1348 - f2_score_1: 0.0880 - f2_score_2: 0.0536 - f2_score_3: 0.0300 - f2_score_4: 0.0059 - f2_score_5: 7.2132e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1541 - val_f2_score_1: 0.1080 - val_f2_score_2: 0.0686 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0033 - val_f2_score_5: 5.0882e-05
# Epoch 35/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0691 - f2_score: 0.1352 - f2_score_1: 0.0872 - f2_score_2: 0.0532 - f2_score_3: 0.0293 - f2_score_4: 0.0062 - f2_score_5: 8.5215e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0568 - val_f2_score: 0.1557 - val_f2_score_1: 0.1108 - val_f2_score_2: 0.0718 - val_f2_score_3: 0.0445 - val_f2_score_4: 0.0061 - val_f2_score_5: 5.0882e-05
# Epoch 36/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0690 - f2_score: 0.1348 - f2_score_1: 0.0885 - f2_score_2: 0.0542 - f2_score_3: 0.0296 - f2_score_4: 0.0062 - f2_score_5: 8.1995e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0595 - val_f2_score: 0.1557 - val_f2_score_1: 0.1105 - val_f2_score_2: 0.0709 - val_f2_score_3: 0.0428 - val_f2_score_4: 0.0045 - val_f2_score_5: 5.0882e-05
# Epoch 37/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0688 - f2_score: 0.1352 - f2_score_1: 0.0884 - f2_score_2: 0.0542 - f2_score_3: 0.0302 - f2_score_4: 0.0063 - f2_score_5: 8.6636e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0598 - val_f2_score: 0.1567 - val_f2_score_1: 0.1103 - val_f2_score_2: 0.0707 - val_f2_score_3: 0.0429 - val_f2_score_4: 0.0043 - val_f2_score_5: 7.6323e-05
# Epoch 38/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0690 - f2_score: 0.1358 - f2_score_1: 0.0887 - f2_score_2: 0.0542 - f2_score_3: 0.0304 - f2_score_4: 0.0064 - f2_score_5: 9.9404e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0575 - val_f2_score: 0.1579 - val_f2_score_1: 0.1123 - val_f2_score_2: 0.0740 - val_f2_score_3: 0.0464 - val_f2_score_4: 0.0072 - val_f2_score_5: 7.6323e-05
# Epoch 39/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0695 - f2_score: 0.1364 - f2_score_1: 0.0888 - f2_score_2: 0.0540 - f2_score_3: 0.0301 - f2_score_4: 0.0063 - f2_score_5: 7.9672e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0592 - val_f2_score: 0.1548 - val_f2_score_1: 0.1082 - val_f2_score_2: 0.0690 - val_f2_score_3: 0.0416 - val_f2_score_4: 0.0041 - val_f2_score_5: 1.0176e-04
# Epoch 40/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0685 - f2_score: 0.1353 - f2_score_1: 0.0884 - f2_score_2: 0.0538 - f2_score_3: 0.0297 - f2_score_4: 0.0063 - f2_score_5: 8.2673e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0626 - val_f2_score: 0.1562 - val_f2_score_1: 0.1099 - val_f2_score_2: 0.0701 - val_f2_score_3: 0.0420 - val_f2_score_4: 0.0039 - val_f2_score_5: 1.0176e-04
# Epoch 41/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1354 - f2_score_1: 0.0885 - f2_score_2: 0.0542 - f2_score_3: 0.0305 - f2_score_4: 0.0065 - f2_score_5: 9.2656e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0593 - val_f2_score: 0.1572 - val_f2_score_1: 0.1107 - val_f2_score_2: 0.0715 - val_f2_score_3: 0.0440 - val_f2_score_4: 0.0054 - val_f2_score_5: 1.0176e-04
# Epoch 42/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0690 - f2_score: 0.1365 - f2_score_1: 0.0891 - f2_score_2: 0.0553 - f2_score_3: 0.0309 - f2_score_4: 0.0067 - f2_score_5: 8.9391e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0592 - val_f2_score: 0.1566 - val_f2_score_1: 0.1103 - val_f2_score_2: 0.0707 - val_f2_score_3: 0.0434 - val_f2_score_4: 0.0053 - val_f2_score_5: 1.0176e-04
# Epoch 43/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0692 - f2_score: 0.1365 - f2_score_1: 0.0897 - f2_score_2: 0.0550 - f2_score_3: 0.0308 - f2_score_4: 0.0064 - f2_score_5: 9.5503e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1564 - val_f2_score_1: 0.1102 - val_f2_score_2: 0.0706 - val_f2_score_3: 0.0426 - val_f2_score_4: 0.0042 - val_f2_score_5: 1.0176e-04
# Epoch 44/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0699 - f2_score: 0.1362 - f2_score_1: 0.0893 - f2_score_2: 0.0544 - f2_score_3: 0.0303 - f2_score_4: 0.0063 - f2_score_5: 9.8845e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0610 - val_f2_score: 0.1575 - val_f2_score_1: 0.1106 - val_f2_score_2: 0.0716 - val_f2_score_3: 0.0436 - val_f2_score_4: 0.0050 - val_f2_score_5: 1.0176e-04
# Epoch 45/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0701 - f2_score: 0.1364 - f2_score_1: 0.0888 - f2_score_2: 0.0551 - f2_score_3: 0.0304 - f2_score_4: 0.0066 - f2_score_5: 9.3082e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0594 - val_f2_score: 0.1577 - val_f2_score_1: 0.1113 - val_f2_score_2: 0.0720 - val_f2_score_3: 0.0445 - val_f2_score_4: 0.0059 - val_f2_score_5: 1.0176e-04
# Epoch 46/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0711 - f2_score: 0.1369 - f2_score_1: 0.0894 - f2_score_2: 0.0551 - f2_score_3: 0.0310 - f2_score_4: 0.0062 - f2_score_5: 8.9456e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1579 - val_f2_score_1: 0.1121 - val_f2_score_2: 0.0720 - val_f2_score_3: 0.0441 - val_f2_score_4: 0.0052 - val_f2_score_5: 1.0176e-04
# Epoch 47/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1368 - f2_score_1: 0.0898 - f2_score_2: 0.0553 - f2_score_3: 0.0310 - f2_score_4: 0.0065 - f2_score_5: 9.2388e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0611 - val_f2_score: 0.1577 - val_f2_score_1: 0.1115 - val_f2_score_2: 0.0726 - val_f2_score_3: 0.0449 - val_f2_score_4: 0.0055 - val_f2_score_5: 1.0176e-04
# Epoch 48/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0701 - f2_score: 0.1368 - f2_score_1: 0.0898 - f2_score_2: 0.0548 - f2_score_3: 0.0306 - f2_score_4: 0.0065 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1585 - val_f2_score_1: 0.1126 - val_f2_score_2: 0.0731 - val_f2_score_3: 0.0454 - val_f2_score_4: 0.0061 - val_f2_score_5: 1.0176e-04
# Epoch 49/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0707 - f2_score: 0.1372 - f2_score_1: 0.0906 - f2_score_2: 0.0559 - f2_score_3: 0.0315 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0613 - val_f2_score: 0.1581 - val_f2_score_1: 0.1116 - val_f2_score_2: 0.0722 - val_f2_score_3: 0.0444 - val_f2_score_4: 0.0054 - val_f2_score_5: 1.0176e-04
# Epoch 50/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0696 - f2_score: 0.1370 - f2_score_1: 0.0899 - f2_score_2: 0.0554 - f2_score_3: 0.0314 - f2_score_4: 0.0067 - f2_score_5: 9.1829e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0609 - val_f2_score: 0.1584 - val_f2_score_1: 0.1119 - val_f2_score_2: 0.0721 - val_f2_score_3: 0.0444 - val_f2_score_4: 0.0053 - val_f2_score_5: 1.0176e-04
# Epoch 51/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0702 - f2_score: 0.1373 - f2_score_1: 0.0904 - f2_score_2: 0.0549 - f2_score_3: 0.0308 - f2_score_4: 0.0064 - f2_score_5: 8.8931e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1582 - val_f2_score_1: 0.1119 - val_f2_score_2: 0.0725 - val_f2_score_3: 0.0450 - val_f2_score_4: 0.0061 - val_f2_score_5: 1.0176e-04
# Epoch 52/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0711 - f2_score: 0.1372 - f2_score_1: 0.0906 - f2_score_2: 0.0554 - f2_score_3: 0.0315 - f2_score_4: 0.0067 - f2_score_5: 9.7065e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1581 - val_f2_score_1: 0.1116 - val_f2_score_2: 0.0721 - val_f2_score_3: 0.0445 - val_f2_score_4: 0.0055 - val_f2_score_5: 1.0176e-04
# Epoch 53/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1372 - f2_score_1: 0.0896 - f2_score_2: 0.0552 - f2_score_3: 0.0312 - f2_score_4: 0.0063 - f2_score_5: 9.2965e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1583 - val_f2_score_1: 0.1120 - val_f2_score_2: 0.0721 - val_f2_score_3: 0.0443 - val_f2_score_4: 0.0052 - val_f2_score_5: 1.0176e-04
# Epoch 54/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1365 - f2_score_1: 0.0896 - f2_score_2: 0.0548 - f2_score_3: 0.0309 - f2_score_4: 0.0064 - f2_score_5: 8.8148e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0602 - val_f2_score: 0.1586 - val_f2_score_1: 0.1129 - val_f2_score_2: 0.0732 - val_f2_score_3: 0.0454 - val_f2_score_4: 0.0062 - val_f2_score_5: 1.0176e-04
# Epoch 55/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1367 - f2_score_1: 0.0900 - f2_score_2: 0.0554 - f2_score_3: 0.0311 - f2_score_4: 0.0068 - f2_score_5: 9.2466e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0610 - val_f2_score: 0.1585 - val_f2_score_1: 0.1125 - val_f2_score_2: 0.0726 - val_f2_score_3: 0.0449 - val_f2_score_4: 0.0056 - val_f2_score_5: 1.0176e-04
# Epoch 56/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0688 - f2_score: 0.1368 - f2_score_1: 0.0903 - f2_score_2: 0.0557 - f2_score_3: 0.0311 - f2_score_4: 0.0067 - f2_score_5: 9.4665e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1589 - val_f2_score_1: 0.1126 - val_f2_score_2: 0.0728 - val_f2_score_3: 0.0450 - val_f2_score_4: 0.0056 - val_f2_score_5: 1.0176e-04
# Epoch 57/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1383 - f2_score_1: 0.0911 - f2_score_2: 0.0558 - f2_score_3: 0.0313 - f2_score_4: 0.0066 - f2_score_5: 9.5679e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0618 - val_f2_score: 0.1585 - val_f2_score_1: 0.1120 - val_f2_score_2: 0.0723 - val_f2_score_3: 0.0447 - val_f2_score_4: 0.0053 - val_f2_score_5: 1.0176e-04
# Epoch 58/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1377 - f2_score_1: 0.0902 - f2_score_2: 0.0553 - f2_score_3: 0.0311 - f2_score_4: 0.0068 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1586 - val_f2_score_1: 0.1122 - val_f2_score_2: 0.0725 - val_f2_score_3: 0.0449 - val_f2_score_4: 0.0054 - val_f2_score_5: 1.0176e-04
# Epoch 59/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0709 - f2_score: 0.1372 - f2_score_1: 0.0904 - f2_score_2: 0.0553 - f2_score_3: 0.0306 - f2_score_4: 0.0067 - f2_score_5: 9.9153e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1589 - val_f2_score_1: 0.1128 - val_f2_score_2: 0.0731 - val_f2_score_3: 0.0456 - val_f2_score_4: 0.0063 - val_f2_score_5: 1.0176e-04
# Epoch 60/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1369 - f2_score_1: 0.0901 - f2_score_2: 0.0554 - f2_score_3: 0.0314 - f2_score_4: 0.0068 - f2_score_5: 9.7413e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0606 - val_f2_score: 0.1590 - val_f2_score_1: 0.1129 - val_f2_score_2: 0.0731 - val_f2_score_3: 0.0454 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 61/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0710 - f2_score: 0.1369 - f2_score_1: 0.0904 - f2_score_2: 0.0555 - f2_score_3: 0.0312 - f2_score_4: 0.0066 - f2_score_5: 9.2892e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0610 - val_f2_score: 0.1592 - val_f2_score_1: 0.1130 - val_f2_score_2: 0.0732 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 62/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0693 - f2_score: 0.1370 - f2_score_1: 0.0903 - f2_score_2: 0.0555 - f2_score_3: 0.0314 - f2_score_4: 0.0069 - f2_score_5: 9.6309e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0611 - val_f2_score: 0.1593 - val_f2_score_1: 0.1133 - val_f2_score_2: 0.0735 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 63/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0696 - f2_score: 0.1374 - f2_score_1: 0.0899 - f2_score_2: 0.0552 - f2_score_3: 0.0308 - f2_score_4: 0.0068 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0740 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0061 - val_f2_score_5: 1.0176e-04
# Epoch 64/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0695 - f2_score: 0.1377 - f2_score_1: 0.0906 - f2_score_2: 0.0564 - f2_score_3: 0.0321 - f2_score_4: 0.0071 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0611 - val_f2_score: 0.1593 - val_f2_score_1: 0.1131 - val_f2_score_2: 0.0732 - val_f2_score_3: 0.0456 - val_f2_score_4: 0.0057 - val_f2_score_5: 1.0176e-04
# Epoch 65/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1372 - f2_score_1: 0.0903 - f2_score_2: 0.0557 - f2_score_3: 0.0313 - f2_score_4: 0.0068 - f2_score_5: 9.2754e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0608 - val_f2_score: 0.1595 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0063 - val_f2_score_5: 1.0176e-04
# Epoch 66/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0692 - f2_score: 0.1373 - f2_score_1: 0.0905 - f2_score_2: 0.0561 - f2_score_3: 0.0318 - f2_score_4: 0.0069 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0613 - val_f2_score: 0.1594 - val_f2_score_1: 0.1132 - val_f2_score_2: 0.0734 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0059 - val_f2_score_5: 1.0176e-04
# Epoch 67/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0712 - f2_score: 0.1378 - f2_score_1: 0.0907 - f2_score_2: 0.0559 - f2_score_3: 0.0316 - f2_score_4: 0.0068 - f2_score_5: 9.2737e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0619 - val_f2_score: 0.1593 - val_f2_score_1: 0.1130 - val_f2_score_2: 0.0730 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0056 - val_f2_score_5: 1.0176e-04
# Epoch 68/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1375 - f2_score_1: 0.0902 - f2_score_2: 0.0557 - f2_score_3: 0.0310 - f2_score_4: 0.0065 - f2_score_5: 9.7594e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1592 - val_f2_score_1: 0.1131 - val_f2_score_2: 0.0731 - val_f2_score_3: 0.0456 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 69/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0693 - f2_score: 0.1375 - f2_score_1: 0.0904 - f2_score_2: 0.0558 - f2_score_3: 0.0313 - f2_score_4: 0.0068 - f2_score_5: 9.9816e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1594 - val_f2_score_1: 0.1133 - val_f2_score_2: 0.0733 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 70/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1385 - f2_score_1: 0.0914 - f2_score_2: 0.0556 - f2_score_3: 0.0313 - f2_score_4: 0.0064 - f2_score_5: 9.4291e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1594 - val_f2_score_1: 0.1133 - val_f2_score_2: 0.0733 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 71/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1381 - f2_score_1: 0.0905 - f2_score_2: 0.0557 - f2_score_3: 0.0315 - f2_score_4: 0.0067 - f2_score_5: 9.8839e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1595 - val_f2_score_1: 0.1133 - val_f2_score_2: 0.0733 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 72/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0686 - f2_score: 0.1376 - f2_score_1: 0.0897 - f2_score_2: 0.0551 - f2_score_3: 0.0308 - f2_score_4: 0.0070 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1595 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0735 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 73/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0701 - f2_score: 0.1380 - f2_score_1: 0.0906 - f2_score_2: 0.0557 - f2_score_3: 0.0311 - f2_score_4: 0.0064 - f2_score_5: 8.7110e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0059 - val_f2_score_5: 1.0176e-04
# Epoch 74/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0715 - f2_score: 0.1384 - f2_score_1: 0.0909 - f2_score_2: 0.0566 - f2_score_3: 0.0320 - f2_score_4: 0.0070 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1595 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0734 - val_f2_score_3: 0.0457 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 75/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0694 - f2_score: 0.1377 - f2_score_1: 0.0902 - f2_score_2: 0.0549 - f2_score_3: 0.0311 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0610 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0735 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 76/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1378 - f2_score_1: 0.0910 - f2_score_2: 0.0561 - f2_score_3: 0.0316 - f2_score_4: 0.0071 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1595 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0733 - val_f2_score_3: 0.0458 - val_f2_score_4: 0.0058 - val_f2_score_5: 1.0176e-04
# Epoch 77/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0709 - f2_score: 0.1375 - f2_score_1: 0.0908 - f2_score_2: 0.0561 - f2_score_3: 0.0315 - f2_score_4: 0.0069 - f2_score_5: 9.0967e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0613 - val_f2_score: 0.1595 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0735 - val_f2_score_3: 0.0458 - val_f2_score_4: 0.0059 - val_f2_score_5: 1.0176e-04
# Epoch 78/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1384 - f2_score_1: 0.0911 - f2_score_2: 0.0558 - f2_score_3: 0.0317 - f2_score_4: 0.0067 - f2_score_5: 9.3228e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0611 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 79/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0696 - f2_score: 0.1378 - f2_score_1: 0.0898 - f2_score_2: 0.0555 - f2_score_3: 0.0312 - f2_score_4: 0.0068 - f2_score_5: 9.6163e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0611 - val_f2_score: 0.1597 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 80/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1382 - f2_score_1: 0.0916 - f2_score_2: 0.0563 - f2_score_3: 0.0317 - f2_score_4: 0.0069 - f2_score_5: 8.8962e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1597 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 81/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0696 - f2_score: 0.1378 - f2_score_1: 0.0904 - f2_score_2: 0.0552 - f2_score_3: 0.0311 - f2_score_4: 0.0066 - f2_score_5: 9.3248e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0613 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 82/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1380 - f2_score_1: 0.0910 - f2_score_2: 0.0559 - f2_score_3: 0.0317 - f2_score_4: 0.0066 - f2_score_5: 9.1891e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 83/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0719 - f2_score: 0.1384 - f2_score_1: 0.0905 - f2_score_2: 0.0564 - f2_score_3: 0.0317 - f2_score_4: 0.0068 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 84/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1378 - f2_score_1: 0.0905 - f2_score_2: 0.0562 - f2_score_3: 0.0320 - f2_score_4: 0.0070 - f2_score_5: 9.7662e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1597 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 85/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1386 - f2_score_1: 0.0907 - f2_score_2: 0.0557 - f2_score_3: 0.0315 - f2_score_4: 0.0069 - f2_score_5: 9.5308e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0612 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 86/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0712 - f2_score: 0.1382 - f2_score_1: 0.0904 - f2_score_2: 0.0558 - f2_score_3: 0.0313 - f2_score_4: 0.0069 - f2_score_5: 9.8325e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 87/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1371 - f2_score_1: 0.0903 - f2_score_2: 0.0557 - f2_score_3: 0.0318 - f2_score_4: 0.0070 - f2_score_5: 9.5430e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 88/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0702 - f2_score: 0.1380 - f2_score_1: 0.0903 - f2_score_2: 0.0553 - f2_score_3: 0.0311 - f2_score_4: 0.0066 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 89/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0701 - f2_score: 0.1380 - f2_score_1: 0.0910 - f2_score_2: 0.0561 - f2_score_3: 0.0316 - f2_score_4: 0.0071 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 90/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1377 - f2_score_1: 0.0906 - f2_score_2: 0.0556 - f2_score_3: 0.0316 - f2_score_4: 0.0069 - f2_score_5: 9.6703e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 91/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0720 - f2_score: 0.1385 - f2_score_1: 0.0909 - f2_score_2: 0.0562 - f2_score_3: 0.0319 - f2_score_4: 0.0071 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 92/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0709 - f2_score: 0.1380 - f2_score_1: 0.0909 - f2_score_2: 0.0559 - f2_score_3: 0.0316 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 93/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0702 - f2_score: 0.1382 - f2_score_1: 0.0906 - f2_score_2: 0.0554 - f2_score_3: 0.0311 - f2_score_4: 0.0068 - f2_score_5: 8.7190e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 94/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0715 - f2_score: 0.1390 - f2_score_1: 0.0908 - f2_score_2: 0.0560 - f2_score_3: 0.0318 - f2_score_4: 0.0068 - f2_score_5: 9.5806e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 95/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0711 - f2_score: 0.1385 - f2_score_1: 0.0912 - f2_score_2: 0.0562 - f2_score_3: 0.0316 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 96/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0710 - f2_score: 0.1382 - f2_score_1: 0.0907 - f2_score_2: 0.0559 - f2_score_3: 0.0317 - f2_score_4: 0.0068 - f2_score_5: 9.5014e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 97/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0713 - f2_score: 0.1378 - f2_score_1: 0.0909 - f2_score_2: 0.0562 - f2_score_3: 0.0322 - f2_score_4: 0.0070 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0736 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 98/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0707 - f2_score: 0.1385 - f2_score_1: 0.0905 - f2_score_2: 0.0558 - f2_score_3: 0.0310 - f2_score_4: 0.0065 - f2_score_5: 9.0817e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0614 - val_f2_score: 0.1596 - val_f2_score_1: 0.1135 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 99/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1373 - f2_score_1: 0.0903 - f2_score_2: 0.0556 - f2_score_3: 0.0312 - f2_score_4: 0.0066 - f2_score_5: 9.3835e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 100/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1377 - f2_score_1: 0.0906 - f2_score_2: 0.0556 - f2_score_3: 0.0315 - f2_score_4: 0.0070 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 101/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0693 - f2_score: 0.1379 - f2_score_1: 0.0903 - f2_score_2: 0.0557 - f2_score_3: 0.0312 - f2_score_4: 0.0070 - f2_score_5: 9.9515e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 102/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1378 - f2_score_1: 0.0908 - f2_score_2: 0.0556 - f2_score_3: 0.0311 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1137 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 103/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0710 - f2_score: 0.1377 - f2_score_1: 0.0912 - f2_score_2: 0.0565 - f2_score_3: 0.0317 - f2_score_4: 0.0068 - f2_score_5: 9.6593e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 104/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1386 - f2_score_1: 0.0906 - f2_score_2: 0.0560 - f2_score_3: 0.0314 - f2_score_4: 0.0069 - f2_score_5: 9.4141e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1137 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 105/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0710 - f2_score: 0.1390 - f2_score_1: 0.0915 - f2_score_2: 0.0569 - f2_score_3: 0.0325 - f2_score_4: 0.0070 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1596 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 106/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1382 - f2_score_1: 0.0903 - f2_score_2: 0.0560 - f2_score_3: 0.0317 - f2_score_4: 0.0066 - f2_score_5: 9.8085e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0738 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 107/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0695 - f2_score: 0.1376 - f2_score_1: 0.0906 - f2_score_2: 0.0560 - f2_score_3: 0.0315 - f2_score_4: 0.0067 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1597 - val_f2_score_1: 0.1137 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0461 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 108/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1383 - f2_score_1: 0.0912 - f2_score_2: 0.0563 - f2_score_3: 0.0319 - f2_score_4: 0.0066 - f2_score_5: 9.9979e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 109/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0715 - f2_score: 0.1384 - f2_score_1: 0.0919 - f2_score_2: 0.0563 - f2_score_3: 0.0319 - f2_score_4: 0.0068 - f2_score_5: 9.0457e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 110/200
#  - 8s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1377 - f2_score_1: 0.0903 - f2_score_2: 0.0558 - f2_score_3: 0.0317 - f2_score_4: 0.0068 - f2_score_5: 9.6941e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0616 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 111/200
# ...
# Epoch 139/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1383 - f2_score_1: 0.0910 - f2_score_2: 0.0565 - f2_score_3: 0.0324 - f2_score_4: 0.0072 - f2_score_5: 9.6263e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 140/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1382 - f2_score_1: 0.0907 - f2_score_2: 0.0562 - f2_score_3: 0.0318 - f2_score_4: 0.0066 - f2_score_5: 9.4573e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 141/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0712 - f2_score: 0.1381 - f2_score_1: 0.0911 - f2_score_2: 0.0562 - f2_score_3: 0.0317 - f2_score_4: 0.0070 - f2_score_5: 9.9810e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 142/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1376 - f2_score_1: 0.0905 - f2_score_2: 0.0558 - f2_score_3: 0.0314 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 143/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0702 - f2_score: 0.1380 - f2_score_1: 0.0910 - f2_score_2: 0.0559 - f2_score_3: 0.0315 - f2_score_4: 0.0068 - f2_score_5: 9.7648e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 144/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0717 - f2_score: 0.1375 - f2_score_1: 0.0909 - f2_score_2: 0.0561 - f2_score_3: 0.0318 - f2_score_4: 0.0070 - f2_score_5: 9.2752e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 145/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1383 - f2_score_1: 0.0904 - f2_score_2: 0.0557 - f2_score_3: 0.0314 - f2_score_4: 0.0068 - f2_score_5: 9.9291e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 146/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1384 - f2_score_1: 0.0912 - f2_score_2: 0.0561 - f2_score_3: 0.0312 - f2_score_4: 0.0066 - f2_score_5: 9.8314e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 147/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0713 - f2_score: 0.1379 - f2_score_1: 0.0910 - f2_score_2: 0.0562 - f2_score_3: 0.0314 - f2_score_4: 0.0069 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 148/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1380 - f2_score_1: 0.0903 - f2_score_2: 0.0561 - f2_score_3: 0.0315 - f2_score_4: 0.0068 - f2_score_5: 9.8669e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 149/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1376 - f2_score_1: 0.0907 - f2_score_2: 0.0563 - f2_score_3: 0.0321 - f2_score_4: 0.0070 - f2_score_5: 9.7400e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 150/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0711 - f2_score: 0.1371 - f2_score_1: 0.0904 - f2_score_2: 0.0554 - f2_score_3: 0.0312 - f2_score_4: 0.0066 - f2_score_5: 9.4713e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 151/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1384 - f2_score_1: 0.0910 - f2_score_2: 0.0563 - f2_score_3: 0.0314 - f2_score_4: 0.0066 - f2_score_5: 8.9886e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 152/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1380 - f2_score_1: 0.0907 - f2_score_2: 0.0558 - f2_score_3: 0.0319 - f2_score_4: 0.0068 - f2_score_5: 9.5942e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 153/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1376 - f2_score_1: 0.0903 - f2_score_2: 0.0553 - f2_score_3: 0.0315 - f2_score_4: 0.0071 - f2_score_5: 9.8063e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 154/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0694 - f2_score: 0.1378 - f2_score_1: 0.0903 - f2_score_2: 0.0554 - f2_score_3: 0.0309 - f2_score_4: 0.0067 - f2_score_5: 8.6385e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 155/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0699 - f2_score: 0.1383 - f2_score_1: 0.0912 - f2_score_2: 0.0562 - f2_score_3: 0.0317 - f2_score_4: 0.0067 - f2_score_5: 9.1719e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 156/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1378 - f2_score_1: 0.0902 - f2_score_2: 0.0558 - f2_score_3: 0.0312 - f2_score_4: 0.0066 - f2_score_5: 9.9465e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 157/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0720 - f2_score: 0.1385 - f2_score_1: 0.0909 - f2_score_2: 0.0561 - f2_score_3: 0.0317 - f2_score_4: 0.0066 - f2_score_5: 9.6043e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 158/200
#  - 8s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1380 - f2_score_1: 0.0908 - f2_score_2: 0.0561 - f2_score_3: 0.0314 - f2_score_4: 0.0063 - f2_score_5: 8.9057e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 159/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1382 - f2_score_1: 0.0912 - f2_score_2: 0.0564 - f2_score_3: 0.0321 - f2_score_4: 0.0070 - f2_score_5: 9.8357e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 160/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0713 - f2_score: 0.1374 - f2_score_1: 0.0907 - f2_score_2: 0.0559 - f2_score_3: 0.0316 - f2_score_4: 0.0070 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 161/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0697 - f2_score: 0.1380 - f2_score_1: 0.0911 - f2_score_2: 0.0560 - f2_score_3: 0.0315 - f2_score_4: 0.0068 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 162/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0694 - f2_score: 0.1373 - f2_score_1: 0.0900 - f2_score_2: 0.0553 - f2_score_3: 0.0312 - f2_score_4: 0.0067 - f2_score_5: 8.6531e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 163/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0706 - f2_score: 0.1378 - f2_score_1: 0.0907 - f2_score_2: 0.0560 - f2_score_3: 0.0317 - f2_score_4: 0.0068 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 164/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1380 - f2_score_1: 0.0912 - f2_score_2: 0.0562 - f2_score_3: 0.0318 - f2_score_4: 0.0069 - f2_score_5: 9.7219e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 165/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1380 - f2_score_1: 0.0904 - f2_score_2: 0.0554 - f2_score_3: 0.0313 - f2_score_4: 0.0066 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 166/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0709 - f2_score: 0.1383 - f2_score_1: 0.0900 - f2_score_2: 0.0556 - f2_score_3: 0.0312 - f2_score_4: 0.0064 - f2_score_5: 8.3532e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 167/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0694 - f2_score: 0.1385 - f2_score_1: 0.0909 - f2_score_2: 0.0557 - f2_score_3: 0.0315 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 168/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0699 - f2_score: 0.1388 - f2_score_1: 0.0908 - f2_score_2: 0.0553 - f2_score_3: 0.0314 - f2_score_4: 0.0067 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 169/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0698 - f2_score: 0.1377 - f2_score_1: 0.0908 - f2_score_2: 0.0553 - f2_score_3: 0.0309 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 170/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0713 - f2_score: 0.1387 - f2_score_1: 0.0911 - f2_score_2: 0.0560 - f2_score_3: 0.0316 - f2_score_4: 0.0069 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 171/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0712 - f2_score: 0.1382 - f2_score_1: 0.0906 - f2_score_2: 0.0563 - f2_score_3: 0.0317 - f2_score_4: 0.0070 - f2_score_5: 0.0011 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 172/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0714 - f2_score: 0.1377 - f2_score_1: 0.0909 - f2_score_2: 0.0561 - f2_score_3: 0.0317 - f2_score_4: 0.0069 - f2_score_5: 9.4047e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 173/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0704 - f2_score: 0.1380 - f2_score_1: 0.0906 - f2_score_2: 0.0561 - f2_score_3: 0.0317 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 174/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0705 - f2_score: 0.1377 - f2_score_1: 0.0912 - f2_score_2: 0.0561 - f2_score_3: 0.0314 - f2_score_4: 0.0067 - f2_score_5: 0.0010 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 175/200
#  - 9s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0701 - f2_score: 0.1385 - f2_score_1: 0.0908 - f2_score_2: 0.0558 - f2_score_3: 0.0316 - f2_score_4: 0.0068 - f2_score_5: 9.7876e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0617 - val_f2_score: 0.1597 - val_f2_score_1: 0.1136 - val_f2_score_2: 0.0737 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0060 - val_f2_score_5: 1.0176e-04
# Epoch 00175: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id        attribute_ids
# 0  10023b2cc4ed5f68                  121
# 1  100fbe75ed8fd887             121 1059
# 2  101b627524a04f19                  147
# 3  10234480c41284c6     147 189 813 1092
# 4  1023b0e2636dcea8                  813
# 5   1039cd6cf85845c  13 147 813 896 1092
# 6   103a5b3f83fbe88             813 1092
# 7  10413aaae8d6a9a2         147 813 1092
# 8  10423822b93a65ab             813 1092
# 9  1052bf702cb099f7              147 813
