# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras import applications
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the bottleneck network
model_base = applications.vgg19.VGG19(weights=None, include_top=False)
model_base.load_weights('../input/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_base.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 12s - loss: 0.0257 - acc: 0.9935 - categorical_accuracy: 0.0332 - f2_score: 0.0832 - f2_score_1: 0.0614 - f2_score_2: 0.0439 - f2_score_3: 0.0310 - f2_score_4: 0.0159 - f2_score_5: 0.0082 - val_loss: 0.0151 - val_acc: 0.9971 - val_categorical_accuracy: 0.0174 - val_f2_score: 0.0646 - val_f2_score_1: 0.0378 - val_f2_score_2: 0.0170 - val_f2_score_3: 9.9156e-04 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 11s - loss: 0.0164 - acc: 0.9971 - categorical_accuracy: 0.0463 - f2_score: 0.1063 - f2_score_1: 0.0694 - f2_score_2: 0.0429 - f2_score_3: 0.0245 - f2_score_4: 0.0059 - f2_score_5: 9.4205e-04 - val_loss: 0.0146 - val_acc: 0.9971 - val_categorical_accuracy: 0.0497 - val_f2_score: 0.0939 - val_f2_score_1: 0.0556 - val_f2_score_2: 0.0323 - val_f2_score_3: 0.0115 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 11s - loss: 0.0157 - acc: 0.9971 - categorical_accuracy: 0.0555 - f2_score: 0.1181 - f2_score_1: 0.0773 - f2_score_2: 0.0484 - f2_score_3: 0.0281 - f2_score_4: 0.0064 - f2_score_5: 7.6454e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0588 - val_f2_score: 0.1137 - val_f2_score_1: 0.0686 - val_f2_score_2: 0.0392 - val_f2_score_3: 0.0221 - val_f2_score_4: 8.6236e-04 - val_f2_score_5: 0.0000e+00
# Epoch 4/200
#  - 11s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0642 - f2_score: 0.1285 - f2_score_1: 0.0852 - f2_score_2: 0.0541 - f2_score_3: 0.0321 - f2_score_4: 0.0079 - f2_score_5: 0.0011 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1212 - val_f2_score_1: 0.0789 - val_f2_score_2: 0.0498 - val_f2_score_3: 0.0271 - val_f2_score_4: 0.0020 - val_f2_score_5: 0.0000e+00
# Epoch 5/200
#  - 11s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0708 - f2_score: 0.1366 - f2_score_1: 0.0930 - f2_score_2: 0.0610 - f2_score_3: 0.0370 - f2_score_4: 0.0107 - f2_score_5: 0.0019 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0528 - val_f2_score: 0.1269 - val_f2_score_1: 0.0835 - val_f2_score_2: 0.0557 - val_f2_score_3: 0.0371 - val_f2_score_4: 0.0079 - val_f2_score_5: 2.9710e-04
# Epoch 6/200
#  - 11s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0757 - f2_score: 0.1444 - f2_score_1: 0.0994 - f2_score_2: 0.0668 - f2_score_3: 0.0428 - f2_score_4: 0.0138 - f2_score_5: 0.0032 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0643 - val_f2_score: 0.1380 - val_f2_score_1: 0.0930 - val_f2_score_2: 0.0612 - val_f2_score_3: 0.0408 - val_f2_score_4: 0.0102 - val_f2_score_5: 9.8254e-04
# Epoch 7/200
#  - 11s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0804 - f2_score: 0.1516 - f2_score_1: 0.1061 - f2_score_2: 0.0724 - f2_score_3: 0.0475 - f2_score_4: 0.0168 - f2_score_5: 0.0044 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0735 - val_f2_score: 0.1424 - val_f2_score_1: 0.0942 - val_f2_score_2: 0.0626 - val_f2_score_3: 0.0391 - val_f2_score_4: 0.0099 - val_f2_score_5: 0.0012
# Epoch 8/200
#  - 11s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0858 - f2_score: 0.1587 - f2_score_1: 0.1119 - f2_score_2: 0.0772 - f2_score_3: 0.0518 - f2_score_4: 0.0193 - f2_score_5: 0.0057 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0921 - val_f2_score: 0.1454 - val_f2_score_1: 0.0974 - val_f2_score_2: 0.0652 - val_f2_score_3: 0.0415 - val_f2_score_4: 0.0117 - val_f2_score_5: 0.0021
# Epoch 9/200
#  - 11s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0891 - f2_score: 0.1647 - f2_score_1: 0.1175 - f2_score_2: 0.0819 - f2_score_3: 0.0556 - f2_score_4: 0.0223 - f2_score_5: 0.0076 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0843 - val_f2_score: 0.1556 - val_f2_score_1: 0.1071 - val_f2_score_2: 0.0732 - val_f2_score_3: 0.0494 - val_f2_score_4: 0.0166 - val_f2_score_5: 0.0039
# Epoch 10/200
#  - 11s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0905 - f2_score: 0.1684 - f2_score_1: 0.1209 - f2_score_2: 0.0854 - f2_score_3: 0.0592 - f2_score_4: 0.0246 - f2_score_5: 0.0088 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0952 - val_f2_score: 0.1608 - val_f2_score_1: 0.1105 - val_f2_score_2: 0.0754 - val_f2_score_3: 0.0495 - val_f2_score_4: 0.0173 - val_f2_score_5: 0.0042
# Epoch 11/200
#  - 11s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0934 - f2_score: 0.1719 - f2_score_1: 0.1241 - f2_score_2: 0.0883 - f2_score_3: 0.0612 - f2_score_4: 0.0267 - f2_score_5: 0.0098 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0876 - val_f2_score: 0.1649 - val_f2_score_1: 0.1151 - val_f2_score_2: 0.0806 - val_f2_score_3: 0.0557 - val_f2_score_4: 0.0209 - val_f2_score_5: 0.0056
# Epoch 12/200
#  - 11s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0931 - f2_score: 0.1747 - f2_score_1: 0.1274 - f2_score_2: 0.0903 - f2_score_3: 0.0628 - f2_score_4: 0.0277 - f2_score_5: 0.0106 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0915 - val_f2_score: 0.1679 - val_f2_score_1: 0.1174 - val_f2_score_2: 0.0825 - val_f2_score_3: 0.0564 - val_f2_score_4: 0.0214 - val_f2_score_5: 0.0058
# Epoch 13/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0942 - f2_score: 0.1774 - f2_score_1: 0.1295 - f2_score_2: 0.0929 - f2_score_3: 0.0655 - f2_score_4: 0.0292 - f2_score_5: 0.0114 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0983 - val_f2_score: 0.1705 - val_f2_score_1: 0.1174 - val_f2_score_2: 0.0815 - val_f2_score_3: 0.0553 - val_f2_score_4: 0.0206 - val_f2_score_5: 0.0067
# Epoch 14/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0958 - f2_score: 0.1798 - f2_score_1: 0.1317 - f2_score_2: 0.0951 - f2_score_3: 0.0668 - f2_score_4: 0.0307 - f2_score_5: 0.0121 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0896 - val_f2_score: 0.1730 - val_f2_score_1: 0.1219 - val_f2_score_2: 0.0853 - val_f2_score_3: 0.0588 - val_f2_score_4: 0.0223 - val_f2_score_5: 0.0068
# Epoch 15/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0979 - f2_score: 0.1822 - f2_score_1: 0.1337 - f2_score_2: 0.0970 - f2_score_3: 0.0700 - f2_score_4: 0.0326 - f2_score_5: 0.0132 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0909 - val_f2_score: 0.1702 - val_f2_score_1: 0.1200 - val_f2_score_2: 0.0857 - val_f2_score_3: 0.0606 - val_f2_score_4: 0.0246 - val_f2_score_5: 0.0085
# Epoch 16/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0990 - f2_score: 0.1845 - f2_score_1: 0.1359 - f2_score_2: 0.0989 - f2_score_3: 0.0713 - f2_score_4: 0.0335 - f2_score_5: 0.0139 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0933 - val_f2_score: 0.1774 - val_f2_score_1: 0.1276 - val_f2_score_2: 0.0910 - val_f2_score_3: 0.0646 - val_f2_score_4: 0.0268 - val_f2_score_5: 0.0092
# Epoch 17/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0995 - f2_score: 0.1866 - f2_score_1: 0.1382 - f2_score_2: 0.1012 - f2_score_3: 0.0729 - f2_score_4: 0.0346 - f2_score_5: 0.0150 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1014 - val_f2_score: 0.1797 - val_f2_score_1: 0.1274 - val_f2_score_2: 0.0909 - val_f2_score_3: 0.0640 - val_f2_score_4: 0.0270 - val_f2_score_5: 0.0098
# Epoch 18/200
#  - 11s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1006 - f2_score: 0.1887 - f2_score_1: 0.1412 - f2_score_2: 0.1032 - f2_score_3: 0.0742 - f2_score_4: 0.0360 - f2_score_5: 0.0160 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0895 - val_f2_score: 0.1844 - val_f2_score_1: 0.1346 - val_f2_score_2: 0.0975 - val_f2_score_3: 0.0690 - val_f2_score_4: 0.0324 - val_f2_score_5: 0.0112
# Epoch 19/200
#  - 11s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1010 - f2_score: 0.1907 - f2_score_1: 0.1428 - f2_score_2: 0.1049 - f2_score_3: 0.0763 - f2_score_4: 0.0383 - f2_score_5: 0.0169 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1072 - val_f2_score: 0.1855 - val_f2_score_1: 0.1323 - val_f2_score_2: 0.0946 - val_f2_score_3: 0.0651 - val_f2_score_4: 0.0275 - val_f2_score_5: 0.0105
# Epoch 20/200
#  - 11s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1039 - f2_score: 0.1926 - f2_score_1: 0.1441 - f2_score_2: 0.1059 - f2_score_3: 0.0768 - f2_score_4: 0.0381 - f2_score_5: 0.0172 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1040 - val_f2_score: 0.1834 - val_f2_score_1: 0.1316 - val_f2_score_2: 0.0952 - val_f2_score_3: 0.0665 - val_f2_score_4: 0.0289 - val_f2_score_5: 0.0111
# Epoch 21/200
#  - 11s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1037 - f2_score: 0.1945 - f2_score_1: 0.1457 - f2_score_2: 0.1068 - f2_score_3: 0.0781 - f2_score_4: 0.0386 - f2_score_5: 0.0177 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1000 - val_f2_score: 0.1880 - val_f2_score_1: 0.1367 - val_f2_score_2: 0.0997 - val_f2_score_3: 0.0701 - val_f2_score_4: 0.0316 - val_f2_score_5: 0.0122
# Epoch 22/200
#  - 11s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1029 - f2_score: 0.1945 - f2_score_1: 0.1464 - f2_score_2: 0.1080 - f2_score_3: 0.0791 - f2_score_4: 0.0396 - f2_score_5: 0.0184 - val_loss: 0.0132 - val_acc: 0.9971 - val_categorical_accuracy: 0.1007 - val_f2_score: 0.1884 - val_f2_score_1: 0.1373 - val_f2_score_2: 0.1001 - val_f2_score_3: 0.0706 - val_f2_score_4: 0.0322 - val_f2_score_5: 0.0125
# Epoch 23/200
#  - 11s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1039 - f2_score: 0.1956 - f2_score_1: 0.1473 - f2_score_2: 0.1096 - f2_score_3: 0.0807 - f2_score_4: 0.0406 - f2_score_5: 0.0185 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.0985 - val_f2_score: 0.1868 - val_f2_score_1: 0.1364 - val_f2_score_2: 0.0998 - val_f2_score_3: 0.0717 - val_f2_score_4: 0.0349 - val_f2_score_5: 0.0138
# Epoch 24/200
#  - 11s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1042 - f2_score: 0.1964 - f2_score_1: 0.1481 - f2_score_2: 0.1102 - f2_score_3: 0.0805 - f2_score_4: 0.0412 - f2_score_5: 0.0191 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.0996 - val_f2_score: 0.1894 - val_f2_score_1: 0.1391 - val_f2_score_2: 0.1025 - val_f2_score_3: 0.0741 - val_f2_score_4: 0.0357 - val_f2_score_5: 0.0139
# Epoch 25/200
#  - 11s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1038 - f2_score: 0.1971 - f2_score_1: 0.1485 - f2_score_2: 0.1099 - f2_score_3: 0.0811 - f2_score_4: 0.0420 - f2_score_5: 0.0198 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1030 - val_f2_score: 0.1857 - val_f2_score_1: 0.1360 - val_f2_score_2: 0.0993 - val_f2_score_3: 0.0716 - val_f2_score_4: 0.0337 - val_f2_score_5: 0.0135
# Epoch 26/200
#  - 11s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1058 - f2_score: 0.1980 - f2_score_1: 0.1500 - f2_score_2: 0.1117 - f2_score_3: 0.0825 - f2_score_4: 0.0423 - f2_score_5: 0.0199 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.0969 - val_f2_score: 0.1913 - val_f2_score_1: 0.1407 - val_f2_score_2: 0.1036 - val_f2_score_3: 0.0753 - val_f2_score_4: 0.0368 - val_f2_score_5: 0.0148
# Epoch 27/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1055 - f2_score: 0.1992 - f2_score_1: 0.1510 - f2_score_2: 0.1127 - f2_score_3: 0.0835 - f2_score_4: 0.0431 - f2_score_5: 0.0204 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.0989 - val_f2_score: 0.1937 - val_f2_score_1: 0.1429 - val_f2_score_2: 0.1050 - val_f2_score_3: 0.0768 - val_f2_score_4: 0.0385 - val_f2_score_5: 0.0160
# Epoch 28/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1064 - f2_score: 0.2002 - f2_score_1: 0.1516 - f2_score_2: 0.1131 - f2_score_3: 0.0834 - f2_score_4: 0.0433 - f2_score_5: 0.0206 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1075 - val_f2_score: 0.1905 - val_f2_score_1: 0.1401 - val_f2_score_2: 0.1018 - val_f2_score_3: 0.0726 - val_f2_score_4: 0.0340 - val_f2_score_5: 0.0142
# Epoch 29/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1053 - f2_score: 0.2002 - f2_score_1: 0.1522 - f2_score_2: 0.1137 - f2_score_3: 0.0841 - f2_score_4: 0.0440 - f2_score_5: 0.0212 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.1931 - val_f2_score_1: 0.1423 - val_f2_score_2: 0.1039 - val_f2_score_3: 0.0738 - val_f2_score_4: 0.0357 - val_f2_score_5: 0.0152
# Epoch 30/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1073 - f2_score: 0.2010 - f2_score_1: 0.1533 - f2_score_2: 0.1149 - f2_score_3: 0.0856 - f2_score_4: 0.0446 - f2_score_5: 0.0214 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1056 - val_f2_score: 0.1938 - val_f2_score_1: 0.1429 - val_f2_score_2: 0.1044 - val_f2_score_3: 0.0751 - val_f2_score_4: 0.0365 - val_f2_score_5: 0.0157
# Epoch 31/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1066 - f2_score: 0.2016 - f2_score_1: 0.1531 - f2_score_2: 0.1144 - f2_score_3: 0.0850 - f2_score_4: 0.0445 - f2_score_5: 0.0215 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1051 - val_f2_score: 0.1953 - val_f2_score_1: 0.1444 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0763 - val_f2_score_4: 0.0378 - val_f2_score_5: 0.0161
# Epoch 32/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1086 - f2_score: 0.2025 - f2_score_1: 0.1540 - f2_score_2: 0.1155 - f2_score_3: 0.0855 - f2_score_4: 0.0449 - f2_score_5: 0.0217 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1029 - val_f2_score: 0.1949 - val_f2_score_1: 0.1442 - val_f2_score_2: 0.1059 - val_f2_score_3: 0.0771 - val_f2_score_4: 0.0388 - val_f2_score_5: 0.0166
# Epoch 33/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1076 - f2_score: 0.2027 - f2_score_1: 0.1545 - f2_score_2: 0.1157 - f2_score_3: 0.0861 - f2_score_4: 0.0454 - f2_score_5: 0.0220 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.1957 - val_f2_score_1: 0.1447 - val_f2_score_2: 0.1057 - val_f2_score_3: 0.0752 - val_f2_score_4: 0.0365 - val_f2_score_5: 0.0159
# Epoch 34/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1085 - f2_score: 0.2022 - f2_score_1: 0.1545 - f2_score_2: 0.1163 - f2_score_3: 0.0867 - f2_score_4: 0.0454 - f2_score_5: 0.0225 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1054 - val_f2_score: 0.1966 - val_f2_score_1: 0.1461 - val_f2_score_2: 0.1067 - val_f2_score_3: 0.0774 - val_f2_score_4: 0.0387 - val_f2_score_5: 0.0166
# Epoch 35/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1077 - f2_score: 0.2036 - f2_score_1: 0.1551 - f2_score_2: 0.1168 - f2_score_3: 0.0875 - f2_score_4: 0.0462 - f2_score_5: 0.0223 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1044 - val_f2_score: 0.1957 - val_f2_score_1: 0.1447 - val_f2_score_2: 0.1063 - val_f2_score_3: 0.0770 - val_f2_score_4: 0.0386 - val_f2_score_5: 0.0168
# Epoch 36/200
#  - 11s - loss: 0.0137 - acc: 0.9972 - categorical_accuracy: 0.1081 - f2_score: 0.2037 - f2_score_1: 0.1553 - f2_score_2: 0.1169 - f2_score_3: 0.0871 - f2_score_4: 0.0461 - f2_score_5: 0.0228 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1068 - val_f2_score: 0.1986 - val_f2_score_1: 0.1480 - val_f2_score_2: 0.1091 - val_f2_score_3: 0.0796 - val_f2_score_4: 0.0402 - val_f2_score_5: 0.0177
# Epoch 37/200
#  - 11s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1088 - f2_score: 0.2051 - f2_score_1: 0.1566 - f2_score_2: 0.1175 - f2_score_3: 0.0873 - f2_score_4: 0.0462 - f2_score_5: 0.0230 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1073 - val_f2_score: 0.1966 - val_f2_score_1: 0.1460 - val_f2_score_2: 0.1072 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0396 - val_f2_score_5: 0.0173
# Epoch 38/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1080 - f2_score: 0.2047 - f2_score_1: 0.1562 - f2_score_2: 0.1175 - f2_score_3: 0.0879 - f2_score_4: 0.0467 - f2_score_5: 0.0231 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1034 - val_f2_score: 0.1990 - val_f2_score_1: 0.1484 - val_f2_score_2: 0.1100 - val_f2_score_3: 0.0805 - val_f2_score_4: 0.0410 - val_f2_score_5: 0.0177
# Epoch 39/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1088 - f2_score: 0.2053 - f2_score_1: 0.1566 - f2_score_2: 0.1179 - f2_score_3: 0.0880 - f2_score_4: 0.0471 - f2_score_5: 0.0236 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1069 - val_f2_score: 0.1973 - val_f2_score_1: 0.1460 - val_f2_score_2: 0.1073 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0396 - val_f2_score_5: 0.0176
# Epoch 40/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1088 - f2_score: 0.2057 - f2_score_1: 0.1572 - f2_score_2: 0.1182 - f2_score_3: 0.0884 - f2_score_4: 0.0466 - f2_score_5: 0.0231 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1050 - val_f2_score: 0.1984 - val_f2_score_1: 0.1476 - val_f2_score_2: 0.1090 - val_f2_score_3: 0.0799 - val_f2_score_4: 0.0410 - val_f2_score_5: 0.0179
# Epoch 41/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2064 - f2_score_1: 0.1574 - f2_score_2: 0.1189 - f2_score_3: 0.0889 - f2_score_4: 0.0472 - f2_score_5: 0.0235 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1078 - val_f2_score: 0.1989 - val_f2_score_1: 0.1478 - val_f2_score_2: 0.1093 - val_f2_score_3: 0.0799 - val_f2_score_4: 0.0404 - val_f2_score_5: 0.0177
# Epoch 42/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1079 - f2_score: 0.2061 - f2_score_1: 0.1577 - f2_score_2: 0.1191 - f2_score_3: 0.0891 - f2_score_4: 0.0476 - f2_score_5: 0.0238 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1075 - val_f2_score: 0.1978 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1082 - val_f2_score_3: 0.0786 - val_f2_score_4: 0.0399 - val_f2_score_5: 0.0177
# Epoch 43/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1100 - f2_score: 0.2061 - f2_score_1: 0.1574 - f2_score_2: 0.1191 - f2_score_3: 0.0889 - f2_score_4: 0.0476 - f2_score_5: 0.0241 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1084 - val_f2_score: 0.1980 - val_f2_score_1: 0.1473 - val_f2_score_2: 0.1085 - val_f2_score_3: 0.0789 - val_f2_score_4: 0.0400 - val_f2_score_5: 0.0175
# Epoch 44/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1102 - f2_score: 0.2059 - f2_score_1: 0.1580 - f2_score_2: 0.1194 - f2_score_3: 0.0894 - f2_score_4: 0.0475 - f2_score_5: 0.0238 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1073 - val_f2_score: 0.1996 - val_f2_score_1: 0.1483 - val_f2_score_2: 0.1102 - val_f2_score_3: 0.0806 - val_f2_score_4: 0.0412 - val_f2_score_5: 0.0183
# Epoch 45/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1082 - f2_score: 0.2060 - f2_score_1: 0.1575 - f2_score_2: 0.1195 - f2_score_3: 0.0890 - f2_score_4: 0.0478 - f2_score_5: 0.0241 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1082 - val_f2_score: 0.2009 - val_f2_score_1: 0.1497 - val_f2_score_2: 0.1105 - val_f2_score_3: 0.0804 - val_f2_score_4: 0.0411 - val_f2_score_5: 0.0184
# Epoch 46/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1109 - f2_score: 0.2074 - f2_score_1: 0.1588 - f2_score_2: 0.1196 - f2_score_3: 0.0893 - f2_score_4: 0.0481 - f2_score_5: 0.0241 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1053 - val_f2_score: 0.2002 - val_f2_score_1: 0.1493 - val_f2_score_2: 0.1112 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0191
# Epoch 47/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1085 - f2_score: 0.2070 - f2_score_1: 0.1586 - f2_score_2: 0.1200 - f2_score_3: 0.0897 - f2_score_4: 0.0486 - f2_score_5: 0.0242 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1069 - val_f2_score: 0.2004 - val_f2_score_1: 0.1492 - val_f2_score_2: 0.1107 - val_f2_score_3: 0.0809 - val_f2_score_4: 0.0414 - val_f2_score_5: 0.0185
# Epoch 48/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1090 - f2_score: 0.2072 - f2_score_1: 0.1583 - f2_score_2: 0.1196 - f2_score_3: 0.0905 - f2_score_4: 0.0485 - f2_score_5: 0.0240 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1063 - val_f2_score: 0.2001 - val_f2_score_1: 0.1488 - val_f2_score_2: 0.1107 - val_f2_score_3: 0.0807 - val_f2_score_4: 0.0413 - val_f2_score_5: 0.0184
# Epoch 49/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2075 - f2_score_1: 0.1590 - f2_score_2: 0.1199 - f2_score_3: 0.0894 - f2_score_4: 0.0485 - f2_score_5: 0.0244 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1055 - val_f2_score: 0.1995 - val_f2_score_1: 0.1488 - val_f2_score_2: 0.1107 - val_f2_score_3: 0.0814 - val_f2_score_4: 0.0424 - val_f2_score_5: 0.0190
# Epoch 50/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1090 - f2_score: 0.2067 - f2_score_1: 0.1587 - f2_score_2: 0.1200 - f2_score_3: 0.0899 - f2_score_4: 0.0482 - f2_score_5: 0.0242 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1084 - val_f2_score: 0.2012 - val_f2_score_1: 0.1500 - val_f2_score_2: 0.1116 - val_f2_score_3: 0.0815 - val_f2_score_4: 0.0422 - val_f2_score_5: 0.0190
# Epoch 51/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1097 - f2_score: 0.2080 - f2_score_1: 0.1594 - f2_score_2: 0.1203 - f2_score_3: 0.0901 - f2_score_4: 0.0489 - f2_score_5: 0.0246 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1073 - val_f2_score: 0.2005 - val_f2_score_1: 0.1494 - val_f2_score_2: 0.1114 - val_f2_score_3: 0.0812 - val_f2_score_4: 0.0417 - val_f2_score_5: 0.0189
# Epoch 52/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2076 - f2_score_1: 0.1592 - f2_score_2: 0.1202 - f2_score_3: 0.0900 - f2_score_4: 0.0481 - f2_score_5: 0.0245 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1066 - val_f2_score: 0.2012 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0194
# Epoch 53/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1093 - f2_score: 0.2081 - f2_score_1: 0.1599 - f2_score_2: 0.1206 - f2_score_3: 0.0909 - f2_score_4: 0.0497 - f2_score_5: 0.0254 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.1997 - val_f2_score_1: 0.1484 - val_f2_score_2: 0.1104 - val_f2_score_3: 0.0803 - val_f2_score_4: 0.0412 - val_f2_score_5: 0.0186
# Epoch 54/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2078 - f2_score_1: 0.1593 - f2_score_2: 0.1210 - f2_score_3: 0.0906 - f2_score_4: 0.0487 - f2_score_5: 0.0247 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1087 - val_f2_score: 0.2011 - val_f2_score_1: 0.1499 - val_f2_score_2: 0.1112 - val_f2_score_3: 0.0810 - val_f2_score_4: 0.0414 - val_f2_score_5: 0.0187
# Epoch 55/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1084 - f2_score: 0.2091 - f2_score_1: 0.1601 - f2_score_2: 0.1203 - f2_score_3: 0.0904 - f2_score_4: 0.0490 - f2_score_5: 0.0247 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1093 - val_f2_score: 0.2001 - val_f2_score_1: 0.1490 - val_f2_score_2: 0.1107 - val_f2_score_3: 0.0806 - val_f2_score_4: 0.0413 - val_f2_score_5: 0.0186
# Epoch 56/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2081 - f2_score_1: 0.1598 - f2_score_2: 0.1213 - f2_score_3: 0.0907 - f2_score_4: 0.0492 - f2_score_5: 0.0250 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1081 - val_f2_score: 0.2007 - val_f2_score_1: 0.1495 - val_f2_score_2: 0.1112 - val_f2_score_3: 0.0811 - val_f2_score_4: 0.0417 - val_f2_score_5: 0.0187
# Epoch 57/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1094 - f2_score: 0.2084 - f2_score_1: 0.1601 - f2_score_2: 0.1210 - f2_score_3: 0.0905 - f2_score_4: 0.0489 - f2_score_5: 0.0247 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1085 - val_f2_score: 0.2007 - val_f2_score_1: 0.1493 - val_f2_score_2: 0.1112 - val_f2_score_3: 0.0811 - val_f2_score_4: 0.0419 - val_f2_score_5: 0.0190
# Epoch 58/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1106 - f2_score: 0.2086 - f2_score_1: 0.1595 - f2_score_2: 0.1206 - f2_score_3: 0.0903 - f2_score_4: 0.0489 - f2_score_5: 0.0245 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1094 - val_f2_score: 0.2006 - val_f2_score_1: 0.1492 - val_f2_score_2: 0.1108 - val_f2_score_3: 0.0807 - val_f2_score_4: 0.0414 - val_f2_score_5: 0.0187
# Epoch 59/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2086 - f2_score_1: 0.1596 - f2_score_2: 0.1206 - f2_score_3: 0.0907 - f2_score_4: 0.0487 - f2_score_5: 0.0243 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1082 - val_f2_score: 0.2010 - val_f2_score_1: 0.1496 - val_f2_score_2: 0.1113 - val_f2_score_3: 0.0811 - val_f2_score_4: 0.0420 - val_f2_score_5: 0.0191
# Epoch 60/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1102 - f2_score: 0.2088 - f2_score_1: 0.1602 - f2_score_2: 0.1209 - f2_score_3: 0.0913 - f2_score_4: 0.0489 - f2_score_5: 0.0247 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2014 - val_f2_score_1: 0.1499 - val_f2_score_2: 0.1115 - val_f2_score_3: 0.0813 - val_f2_score_4: 0.0419 - val_f2_score_5: 0.0190
# Epoch 61/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2083 - f2_score_1: 0.1596 - f2_score_2: 0.1214 - f2_score_3: 0.0911 - f2_score_4: 0.0494 - f2_score_5: 0.0249 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1082 - val_f2_score: 0.2017 - val_f2_score_1: 0.1503 - val_f2_score_2: 0.1119 - val_f2_score_3: 0.0819 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0193
# Epoch 62/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1107 - f2_score: 0.2087 - f2_score_1: 0.1602 - f2_score_2: 0.1216 - f2_score_3: 0.0921 - f2_score_4: 0.0496 - f2_score_5: 0.0247 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1083 - val_f2_score: 0.2013 - val_f2_score_1: 0.1499 - val_f2_score_2: 0.1116 - val_f2_score_3: 0.0815 - val_f2_score_4: 0.0422 - val_f2_score_5: 0.0191
# Epoch 63/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1100 - f2_score: 0.2089 - f2_score_1: 0.1605 - f2_score_2: 0.1216 - f2_score_3: 0.0913 - f2_score_4: 0.0494 - f2_score_5: 0.0248 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1087 - val_f2_score: 0.2014 - val_f2_score_1: 0.1501 - val_f2_score_2: 0.1118 - val_f2_score_3: 0.0817 - val_f2_score_4: 0.0423 - val_f2_score_5: 0.0192
# Epoch 64/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2091 - f2_score_1: 0.1604 - f2_score_2: 0.1217 - f2_score_3: 0.0908 - f2_score_4: 0.0490 - f2_score_5: 0.0245 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1085 - val_f2_score: 0.2020 - val_f2_score_1: 0.1504 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0820 - val_f2_score_4: 0.0425 - val_f2_score_5: 0.0193
# Epoch 65/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1098 - f2_score: 0.2092 - f2_score_1: 0.1603 - f2_score_2: 0.1210 - f2_score_3: 0.0909 - f2_score_4: 0.0489 - f2_score_5: 0.0248 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1086 - val_f2_score: 0.2015 - val_f2_score_1: 0.1501 - val_f2_score_2: 0.1118 - val_f2_score_3: 0.0816 - val_f2_score_4: 0.0424 - val_f2_score_5: 0.0193
# Epoch 66/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2085 - f2_score_1: 0.1602 - f2_score_2: 0.1218 - f2_score_3: 0.0917 - f2_score_4: 0.0493 - f2_score_5: 0.0249 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2017 - val_f2_score_1: 0.1502 - val_f2_score_2: 0.1117 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0424 - val_f2_score_5: 0.0193
# Epoch 67/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2082 - f2_score_1: 0.1593 - f2_score_2: 0.1212 - f2_score_3: 0.0914 - f2_score_4: 0.0496 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2014 - val_f2_score_1: 0.1500 - val_f2_score_2: 0.1115 - val_f2_score_3: 0.0815 - val_f2_score_4: 0.0423 - val_f2_score_5: 0.0192
# Epoch 68/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2093 - f2_score_1: 0.1610 - f2_score_2: 0.1217 - f2_score_3: 0.0914 - f2_score_4: 0.0496 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2017 - val_f2_score_1: 0.1502 - val_f2_score_2: 0.1118 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0194
# Epoch 69/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2093 - f2_score_1: 0.1607 - f2_score_2: 0.1217 - f2_score_3: 0.0910 - f2_score_4: 0.0496 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1092 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1121 - val_f2_score_3: 0.0819 - val_f2_score_4: 0.0427 - val_f2_score_5: 0.0195
# Epoch 70/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1095 - f2_score: 0.2087 - f2_score_1: 0.1607 - f2_score_2: 0.1220 - f2_score_3: 0.0915 - f2_score_4: 0.0501 - f2_score_5: 0.0250 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2020 - val_f2_score_1: 0.1505 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0195
# Epoch 71/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2092 - f2_score_1: 0.1610 - f2_score_2: 0.1210 - f2_score_3: 0.0910 - f2_score_4: 0.0494 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1087 - val_f2_score: 0.2019 - val_f2_score_1: 0.1505 - val_f2_score_2: 0.1121 - val_f2_score_3: 0.0820 - val_f2_score_4: 0.0427 - val_f2_score_5: 0.0195
# Epoch 72/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2090 - f2_score_1: 0.1610 - f2_score_2: 0.1218 - f2_score_3: 0.0916 - f2_score_4: 0.0497 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2017 - val_f2_score_1: 0.1504 - val_f2_score_2: 0.1119 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0195
# Epoch 73/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2088 - f2_score_1: 0.1602 - f2_score_2: 0.1210 - f2_score_3: 0.0915 - f2_score_4: 0.0498 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2017 - val_f2_score_1: 0.1504 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0819 - val_f2_score_4: 0.0427 - val_f2_score_5: 0.0195
# Epoch 74/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1109 - f2_score: 0.2094 - f2_score_1: 0.1603 - f2_score_2: 0.1216 - f2_score_3: 0.0915 - f2_score_4: 0.0499 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2018 - val_f2_score_1: 0.1505 - val_f2_score_2: 0.1119 - val_f2_score_3: 0.0820 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0195
# Epoch 75/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2087 - f2_score_1: 0.1612 - f2_score_2: 0.1215 - f2_score_3: 0.0917 - f2_score_4: 0.0496 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2019 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0427 - val_f2_score_5: 0.0195
# Epoch 76/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2083 - f2_score_1: 0.1604 - f2_score_2: 0.1215 - f2_score_3: 0.0911 - f2_score_4: 0.0492 - f2_score_5: 0.0248 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0196
# Epoch 77/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2093 - f2_score_1: 0.1609 - f2_score_2: 0.1225 - f2_score_3: 0.0923 - f2_score_4: 0.0498 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2018 - val_f2_score_1: 0.1504 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0820 - val_f2_score_4: 0.0426 - val_f2_score_5: 0.0194
# Epoch 78/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2083 - f2_score_1: 0.1601 - f2_score_2: 0.1214 - f2_score_3: 0.0911 - f2_score_4: 0.0493 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2019 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0427 - val_f2_score_5: 0.0195
# Epoch 79/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2092 - f2_score_1: 0.1606 - f2_score_2: 0.1215 - f2_score_3: 0.0911 - f2_score_4: 0.0497 - f2_score_5: 0.0250 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1086 - val_f2_score: 0.2022 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0822 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0195
# Epoch 80/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1100 - f2_score: 0.2093 - f2_score_1: 0.1605 - f2_score_2: 0.1221 - f2_score_3: 0.0915 - f2_score_4: 0.0501 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1121 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0195
# Epoch 81/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2094 - f2_score_1: 0.1611 - f2_score_2: 0.1217 - f2_score_3: 0.0914 - f2_score_4: 0.0496 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2020 - val_f2_score_1: 0.1505 - val_f2_score_2: 0.1121 - val_f2_score_3: 0.0820 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0195
# Epoch 82/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2089 - f2_score_1: 0.1607 - f2_score_2: 0.1218 - f2_score_3: 0.0919 - f2_score_4: 0.0504 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0195
# Epoch 83/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2096 - f2_score_1: 0.1609 - f2_score_2: 0.1221 - f2_score_3: 0.0919 - f2_score_4: 0.0497 - f2_score_5: 0.0250 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0196
# Epoch 84/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1121 - f2_score: 0.2096 - f2_score_1: 0.1617 - f2_score_2: 0.1224 - f2_score_3: 0.0918 - f2_score_4: 0.0496 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0196
# Epoch 85/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1113 - f2_score: 0.2095 - f2_score_1: 0.1607 - f2_score_2: 0.1216 - f2_score_3: 0.0921 - f2_score_4: 0.0497 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2021 - val_f2_score_1: 0.1506 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0821 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0196
# Epoch 86/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2094 - f2_score_1: 0.1606 - f2_score_2: 0.1216 - f2_score_3: 0.0912 - f2_score_4: 0.0500 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2022 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0822 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0196
# Epoch 87/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2092 - f2_score_1: 0.1611 - f2_score_2: 0.1221 - f2_score_3: 0.0916 - f2_score_4: 0.0500 - f2_score_5: 0.0249 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2022 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1122 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 88/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1093 - f2_score: 0.2089 - f2_score_1: 0.1605 - f2_score_2: 0.1220 - f2_score_3: 0.0920 - f2_score_4: 0.0502 - f2_score_5: 0.0258 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2022 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 89/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1101 - f2_score: 0.2092 - f2_score_1: 0.1605 - f2_score_2: 0.1213 - f2_score_3: 0.0913 - f2_score_4: 0.0502 - f2_score_5: 0.0258 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2022 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0822 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 90/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1105 - f2_score: 0.2091 - f2_score_1: 0.1613 - f2_score_2: 0.1220 - f2_score_3: 0.0915 - f2_score_4: 0.0497 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2022 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 91/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1107 - f2_score: 0.2089 - f2_score_1: 0.1601 - f2_score_2: 0.1211 - f2_score_3: 0.0911 - f2_score_4: 0.0498 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 92/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1099 - f2_score: 0.2094 - f2_score_1: 0.1606 - f2_score_2: 0.1225 - f2_score_3: 0.0922 - f2_score_4: 0.0498 - f2_score_5: 0.0249 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 93/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1105 - f2_score: 0.2096 - f2_score_1: 0.1606 - f2_score_2: 0.1217 - f2_score_3: 0.0919 - f2_score_4: 0.0500 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 94/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2089 - f2_score_1: 0.1608 - f2_score_2: 0.1215 - f2_score_3: 0.0914 - f2_score_4: 0.0501 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2022 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0822 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 95/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2097 - f2_score_1: 0.1617 - f2_score_2: 0.1223 - f2_score_3: 0.0914 - f2_score_4: 0.0500 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 96/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2087 - f2_score_1: 0.1602 - f2_score_2: 0.1219 - f2_score_3: 0.0918 - f2_score_4: 0.0502 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2022 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 97/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2097 - f2_score_1: 0.1612 - f2_score_2: 0.1224 - f2_score_3: 0.0917 - f2_score_4: 0.0502 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 98/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2086 - f2_score_1: 0.1608 - f2_score_2: 0.1223 - f2_score_3: 0.0914 - f2_score_4: 0.0498 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1092 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 99/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2093 - f2_score_1: 0.1608 - f2_score_2: 0.1223 - f2_score_3: 0.0918 - f2_score_4: 0.0502 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 100/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2102 - f2_score_1: 0.1611 - f2_score_2: 0.1222 - f2_score_3: 0.0921 - f2_score_4: 0.0504 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0824 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 101/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1117 - f2_score: 0.2091 - f2_score_1: 0.1600 - f2_score_2: 0.1216 - f2_score_3: 0.0919 - f2_score_4: 0.0503 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0824 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 102/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2094 - f2_score_1: 0.1612 - f2_score_2: 0.1216 - f2_score_3: 0.0921 - f2_score_4: 0.0504 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1089 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 103/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1101 - f2_score: 0.2089 - f2_score_1: 0.1611 - f2_score_2: 0.1221 - f2_score_3: 0.0922 - f2_score_4: 0.0503 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0824 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 104/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2090 - f2_score_1: 0.1610 - f2_score_2: 0.1215 - f2_score_3: 0.0923 - f2_score_4: 0.0502 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0824 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 105/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2097 - f2_score_1: 0.1618 - f2_score_2: 0.1227 - f2_score_3: 0.0921 - f2_score_4: 0.0502 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 106/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2093 - f2_score_1: 0.1601 - f2_score_2: 0.1215 - f2_score_3: 0.0915 - f2_score_4: 0.0494 - f2_score_5: 0.0250 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2023 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 107/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1096 - f2_score: 0.2099 - f2_score_1: 0.1614 - f2_score_2: 0.1226 - f2_score_3: 0.0923 - f2_score_4: 0.0502 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 108/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1105 - f2_score: 0.2094 - f2_score_1: 0.1613 - f2_score_2: 0.1221 - f2_score_3: 0.0921 - f2_score_4: 0.0503 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 109/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2089 - f2_score_1: 0.1609 - f2_score_2: 0.1222 - f2_score_3: 0.0922 - f2_score_4: 0.0503 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 110/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1107 - f2_score: 0.2086 - f2_score_1: 0.1609 - f2_score_2: 0.1215 - f2_score_3: 0.0917 - f2_score_4: 0.0497 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1123 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 111/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1113 - f2_score: 0.2093 - f2_score_1: 0.1609 - f2_score_2: 0.1221 - f2_score_3: 0.0922 - f2_score_4: 0.0502 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 112/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1103 - f2_score: 0.2089 - f2_score_1: 0.1604 - f2_score_2: 0.1214 - f2_score_3: 0.0913 - f2_score_4: 0.0496 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2023 - val_f2_score_1: 0.1507 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0430 - val_f2_score_5: 0.0196
# Epoch 113/200
# ...
# Epoch 164/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2087 - f2_score_1: 0.1612 - f2_score_2: 0.1218 - f2_score_3: 0.0916 - f2_score_4: 0.0500 - f2_score_5: 0.0258 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 165/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1113 - f2_score: 0.2093 - f2_score_1: 0.1602 - f2_score_2: 0.1221 - f2_score_3: 0.0922 - f2_score_4: 0.0500 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 166/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2101 - f2_score_1: 0.1612 - f2_score_2: 0.1221 - f2_score_3: 0.0914 - f2_score_4: 0.0500 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 167/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2097 - f2_score_1: 0.1610 - f2_score_2: 0.1219 - f2_score_3: 0.0916 - f2_score_4: 0.0499 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 168/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1097 - f2_score: 0.2102 - f2_score_1: 0.1618 - f2_score_2: 0.1223 - f2_score_3: 0.0921 - f2_score_4: 0.0501 - f2_score_5: 0.0259 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 169/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2096 - f2_score_1: 0.1610 - f2_score_2: 0.1220 - f2_score_3: 0.0917 - f2_score_4: 0.0506 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 170/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1109 - f2_score: 0.2092 - f2_score_1: 0.1609 - f2_score_2: 0.1225 - f2_score_3: 0.0918 - f2_score_4: 0.0500 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 171/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2097 - f2_score_1: 0.1607 - f2_score_2: 0.1216 - f2_score_3: 0.0916 - f2_score_4: 0.0493 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 172/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2091 - f2_score_1: 0.1606 - f2_score_2: 0.1216 - f2_score_3: 0.0914 - f2_score_4: 0.0499 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 173/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2097 - f2_score_1: 0.1605 - f2_score_2: 0.1217 - f2_score_3: 0.0915 - f2_score_4: 0.0498 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 174/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2089 - f2_score_1: 0.1603 - f2_score_2: 0.1216 - f2_score_3: 0.0917 - f2_score_4: 0.0504 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 175/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2092 - f2_score_1: 0.1608 - f2_score_2: 0.1225 - f2_score_3: 0.0922 - f2_score_4: 0.0501 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 176/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1117 - f2_score: 0.2099 - f2_score_1: 0.1612 - f2_score_2: 0.1222 - f2_score_3: 0.0921 - f2_score_4: 0.0499 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 177/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2092 - f2_score_1: 0.1613 - f2_score_2: 0.1217 - f2_score_3: 0.0917 - f2_score_4: 0.0496 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 178/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2099 - f2_score_1: 0.1612 - f2_score_2: 0.1224 - f2_score_3: 0.0915 - f2_score_4: 0.0499 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 179/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1103 - f2_score: 0.2093 - f2_score_1: 0.1610 - f2_score_2: 0.1216 - f2_score_3: 0.0915 - f2_score_4: 0.0494 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 180/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1107 - f2_score: 0.2102 - f2_score_1: 0.1610 - f2_score_2: 0.1222 - f2_score_3: 0.0922 - f2_score_4: 0.0499 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 181/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2092 - f2_score_1: 0.1616 - f2_score_2: 0.1219 - f2_score_3: 0.0918 - f2_score_4: 0.0501 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 182/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1106 - f2_score: 0.2089 - f2_score_1: 0.1608 - f2_score_2: 0.1220 - f2_score_3: 0.0918 - f2_score_4: 0.0501 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 183/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2094 - f2_score_1: 0.1615 - f2_score_2: 0.1223 - f2_score_3: 0.0914 - f2_score_4: 0.0499 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 184/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1111 - f2_score: 0.2094 - f2_score_1: 0.1604 - f2_score_2: 0.1218 - f2_score_3: 0.0919 - f2_score_4: 0.0495 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 185/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2096 - f2_score_1: 0.1602 - f2_score_2: 0.1215 - f2_score_3: 0.0912 - f2_score_4: 0.0502 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 186/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2102 - f2_score_1: 0.1618 - f2_score_2: 0.1225 - f2_score_3: 0.0917 - f2_score_4: 0.0495 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 187/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1107 - f2_score: 0.2098 - f2_score_1: 0.1612 - f2_score_2: 0.1217 - f2_score_3: 0.0912 - f2_score_4: 0.0497 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 188/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2096 - f2_score_1: 0.1609 - f2_score_2: 0.1223 - f2_score_3: 0.0923 - f2_score_4: 0.0501 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 189/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1105 - f2_score: 0.2087 - f2_score_1: 0.1608 - f2_score_2: 0.1218 - f2_score_3: 0.0920 - f2_score_4: 0.0500 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 190/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2099 - f2_score_1: 0.1604 - f2_score_2: 0.1222 - f2_score_3: 0.0916 - f2_score_4: 0.0499 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 191/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1105 - f2_score: 0.2089 - f2_score_1: 0.1596 - f2_score_2: 0.1215 - f2_score_3: 0.0910 - f2_score_4: 0.0499 - f2_score_5: 0.0251 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 192/200
#  - 11s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2095 - f2_score_1: 0.1607 - f2_score_2: 0.1218 - f2_score_3: 0.0913 - f2_score_4: 0.0496 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 193/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2098 - f2_score_1: 0.1613 - f2_score_2: 0.1221 - f2_score_3: 0.0917 - f2_score_4: 0.0499 - f2_score_5: 0.0254 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 194/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2095 - f2_score_1: 0.1614 - f2_score_2: 0.1223 - f2_score_3: 0.0918 - f2_score_4: 0.0493 - f2_score_5: 0.0252 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 195/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2100 - f2_score_1: 0.1611 - f2_score_2: 0.1222 - f2_score_3: 0.0925 - f2_score_4: 0.0502 - f2_score_5: 0.0258 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 196/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2090 - f2_score_1: 0.1614 - f2_score_2: 0.1231 - f2_score_3: 0.0921 - f2_score_4: 0.0503 - f2_score_5: 0.0256 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 197/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2097 - f2_score_1: 0.1612 - f2_score_2: 0.1215 - f2_score_3: 0.0919 - f2_score_4: 0.0503 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 198/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2099 - f2_score_1: 0.1611 - f2_score_2: 0.1217 - f2_score_3: 0.0914 - f2_score_4: 0.0501 - f2_score_5: 0.0257 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 199/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1117 - f2_score: 0.2089 - f2_score_1: 0.1615 - f2_score_2: 0.1225 - f2_score_3: 0.0917 - f2_score_4: 0.0498 - f2_score_5: 0.0255 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196
# Epoch 200/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2103 - f2_score_1: 0.1610 - f2_score_2: 0.1219 - f2_score_3: 0.0919 - f2_score_4: 0.0502 - f2_score_5: 0.0253 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1091 - val_f2_score: 0.2024 - val_f2_score_1: 0.1508 - val_f2_score_2: 0.1124 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0196

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_base.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id            attribute_ids
# 0  10023b2cc4ed5f68                      121
# 1  100fbe75ed8fd887                      121
# 2  101b627524a04f19                      121
# 3  10234480c41284c6        147 813 1046 1092
# 4  1023b0e2636dcea8                      671
# 5   1039cd6cf85845c  13 194 405 813 896 1092
# 6   103a5b3f83fbe88        194 813 1046 1092
# 7  10413aaae8d6a9a2             147 813 1092
# 8  10423822b93a65ab                      147
# 9  1052bf702cb099f7                      671
