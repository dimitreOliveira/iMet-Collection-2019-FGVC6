# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 7s - loss: 0.0282 - acc: 0.9926 - categorical_accuracy: 0.0331 - f2_score: 0.0758 - f2_score_1: 0.0560 - f2_score_2: 0.0410 - f2_score_3: 0.0300 - f2_score_4: 0.0156 - f2_score_5: 0.0083 - val_loss: 0.0153 - val_acc: 0.9971 - val_categorical_accuracy: 0.0115 - val_f2_score: 0.0475 - val_f2_score_1: 0.0191 - val_f2_score_2: 5.0858e-04 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 6s - loss: 0.0167 - acc: 0.9971 - categorical_accuracy: 0.0410 - f2_score: 0.0920 - f2_score_1: 0.0564 - f2_score_2: 0.0319 - f2_score_3: 0.0170 - f2_score_4: 0.0041 - f2_score_5: 7.1872e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0151 - val_f2_score: 0.0836 - val_f2_score_1: 0.0445 - val_f2_score_2: 0.0258 - val_f2_score_3: 0.0067 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 6s - loss: 0.0161 - acc: 0.9971 - categorical_accuracy: 0.0445 - f2_score: 0.0993 - f2_score_1: 0.0581 - f2_score_2: 0.0309 - f2_score_3: 0.0149 - f2_score_4: 0.0025 - f2_score_5: 2.6746e-04 - val_loss: 0.0147 - val_acc: 0.9971 - val_categorical_accuracy: 0.0249 - val_f2_score: 0.0937 - val_f2_score_1: 0.0570 - val_f2_score_2: 0.0321 - val_f2_score_3: 0.0133 - val_f2_score_4: 2.1807e-05 - val_f2_score_5: 0.0000e+00
# Epoch 4/200
#  - 6s - loss: 0.0157 - acc: 0.9971 - categorical_accuracy: 0.0474 - f2_score: 0.1041 - f2_score_1: 0.0620 - f2_score_2: 0.0334 - f2_score_3: 0.0160 - f2_score_4: 0.0024 - f2_score_5: 1.8806e-04 - val_loss: 0.0145 - val_acc: 0.9971 - val_categorical_accuracy: 0.0341 - val_f2_score: 0.0971 - val_f2_score_1: 0.0595 - val_f2_score_2: 0.0344 - val_f2_score_3: 0.0157 - val_f2_score_4: 3.6220e-04 - val_f2_score_5: 0.0000e+00
# Epoch 5/200
#  - 6s - loss: 0.0154 - acc: 0.9971 - categorical_accuracy: 0.0518 - f2_score: 0.1094 - f2_score_1: 0.0661 - f2_score_2: 0.0372 - f2_score_3: 0.0188 - f2_score_4: 0.0031 - f2_score_5: 2.5532e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0348 - val_f2_score: 0.1049 - val_f2_score_1: 0.0636 - val_f2_score_2: 0.0381 - val_f2_score_3: 0.0188 - val_f2_score_4: 9.1100e-04 - val_f2_score_5: 0.0000e+00
# Epoch 6/200
#  - 6s - loss: 0.0152 - acc: 0.9971 - categorical_accuracy: 0.0562 - f2_score: 0.1137 - f2_score_1: 0.0703 - f2_score_2: 0.0405 - f2_score_3: 0.0206 - f2_score_4: 0.0035 - f2_score_5: 2.0651e-04 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0348 - val_f2_score: 0.1101 - val_f2_score_1: 0.0706 - val_f2_score_2: 0.0457 - val_f2_score_3: 0.0254 - val_f2_score_4: 0.0026 - val_f2_score_5: 0.0000e+00
# Epoch 7/200
#  - 6s - loss: 0.0151 - acc: 0.9971 - categorical_accuracy: 0.0592 - f2_score: 0.1186 - f2_score_1: 0.0745 - f2_score_2: 0.0427 - f2_score_3: 0.0223 - f2_score_4: 0.0038 - f2_score_5: 3.1419e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0507 - val_f2_score: 0.1060 - val_f2_score_1: 0.0633 - val_f2_score_2: 0.0342 - val_f2_score_3: 0.0122 - val_f2_score_4: 1.0903e-05 - val_f2_score_5: 0.0000e+00
# Epoch 8/200
#  - 7s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0624 - f2_score: 0.1226 - f2_score_1: 0.0778 - f2_score_2: 0.0467 - f2_score_3: 0.0246 - f2_score_4: 0.0043 - f2_score_5: 3.8874e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0535 - val_f2_score: 0.1069 - val_f2_score_1: 0.0621 - val_f2_score_2: 0.0328 - val_f2_score_3: 0.0131 - val_f2_score_4: 2.0062e-05 - val_f2_score_5: 0.0000e+00
# Epoch 9/200
#  - 7s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0640 - f2_score: 0.1270 - f2_score_1: 0.0816 - f2_score_2: 0.0488 - f2_score_3: 0.0266 - f2_score_4: 0.0050 - f2_score_5: 4.4605e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0600 - val_f2_score: 0.1106 - val_f2_score_1: 0.0665 - val_f2_score_2: 0.0372 - val_f2_score_3: 0.0166 - val_f2_score_4: 1.3260e-04 - val_f2_score_5: 0.0000e+00
# Epoch 10/200
#  - 7s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0660 - f2_score: 0.1289 - f2_score_1: 0.0835 - f2_score_2: 0.0507 - f2_score_3: 0.0273 - f2_score_4: 0.0053 - f2_score_5: 4.7777e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0556 - val_f2_score: 0.1201 - val_f2_score_1: 0.0771 - val_f2_score_2: 0.0474 - val_f2_score_3: 0.0249 - val_f2_score_4: 0.0012 - val_f2_score_5: 0.0000e+00
# Epoch 11/200
#  - 7s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0674 - f2_score: 0.1312 - f2_score_1: 0.0855 - f2_score_2: 0.0522 - f2_score_3: 0.0289 - f2_score_4: 0.0056 - f2_score_5: 5.9042e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0534 - val_f2_score: 0.1241 - val_f2_score_1: 0.0783 - val_f2_score_2: 0.0461 - val_f2_score_3: 0.0236 - val_f2_score_4: 8.9927e-04 - val_f2_score_5: 0.0000e+00
# Epoch 12/200
#  - 7s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0685 - f2_score: 0.1329 - f2_score_1: 0.0865 - f2_score_2: 0.0533 - f2_score_3: 0.0299 - f2_score_4: 0.0060 - f2_score_5: 6.9326e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0580 - val_f2_score: 0.1219 - val_f2_score_1: 0.0772 - val_f2_score_2: 0.0471 - val_f2_score_3: 0.0250 - val_f2_score_4: 0.0012 - val_f2_score_5: 0.0000e+00
# Epoch 13/200
#  - 6s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0703 - f2_score: 0.1347 - f2_score_1: 0.0885 - f2_score_2: 0.0549 - f2_score_3: 0.0308 - f2_score_4: 0.0062 - f2_score_5: 6.3740e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0591 - val_f2_score: 0.1256 - val_f2_score_1: 0.0813 - val_f2_score_2: 0.0498 - val_f2_score_3: 0.0272 - val_f2_score_4: 0.0015 - val_f2_score_5: 0.0000e+00
# Epoch 14/200
#  - 6s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0712 - f2_score: 0.1367 - f2_score_1: 0.0898 - f2_score_2: 0.0555 - f2_score_3: 0.0319 - f2_score_4: 0.0068 - f2_score_5: 7.8097e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0648 - val_f2_score: 0.1258 - val_f2_score_1: 0.0789 - val_f2_score_2: 0.0472 - val_f2_score_3: 0.0224 - val_f2_score_4: 6.7144e-04 - val_f2_score_5: 2.5441e-05
# Epoch 15/200
#  - 6s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0733 - f2_score: 0.1384 - f2_score_1: 0.0914 - f2_score_2: 0.0575 - f2_score_3: 0.0331 - f2_score_4: 0.0071 - f2_score_5: 8.3841e-04 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0574 - val_f2_score: 0.1270 - val_f2_score_1: 0.0824 - val_f2_score_2: 0.0516 - val_f2_score_3: 0.0308 - val_f2_score_4: 0.0035 - val_f2_score_5: 2.5441e-05
# Epoch 16/200
#  - 6s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0739 - f2_score: 0.1399 - f2_score_1: 0.0927 - f2_score_2: 0.0586 - f2_score_3: 0.0341 - f2_score_4: 0.0076 - f2_score_5: 8.4444e-04 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0672 - val_f2_score: 0.1302 - val_f2_score_1: 0.0828 - val_f2_score_2: 0.0506 - val_f2_score_3: 0.0270 - val_f2_score_4: 0.0017 - val_f2_score_5: 5.0882e-05
# Epoch 17/200
#  - 7s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0760 - f2_score: 0.1421 - f2_score_1: 0.0948 - f2_score_2: 0.0601 - f2_score_3: 0.0353 - f2_score_4: 0.0083 - f2_score_5: 0.0011 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0665 - val_f2_score: 0.1321 - val_f2_score_1: 0.0859 - val_f2_score_2: 0.0527 - val_f2_score_3: 0.0284 - val_f2_score_4: 0.0018 - val_f2_score_5: 7.6323e-05
# Epoch 18/200
#  - 7s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0754 - f2_score: 0.1429 - f2_score_1: 0.0949 - f2_score_2: 0.0605 - f2_score_3: 0.0361 - f2_score_4: 0.0085 - f2_score_5: 0.0013 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0622 - val_f2_score: 0.1344 - val_f2_score_1: 0.0905 - val_f2_score_2: 0.0575 - val_f2_score_3: 0.0341 - val_f2_score_4: 0.0042 - val_f2_score_5: 1.0176e-04
# Epoch 19/200
#  - 6s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0765 - f2_score: 0.1443 - f2_score_1: 0.0976 - f2_score_2: 0.0626 - f2_score_3: 0.0374 - f2_score_4: 0.0090 - f2_score_5: 0.0013 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0722 - val_f2_score: 0.1364 - val_f2_score_1: 0.0901 - val_f2_score_2: 0.0567 - val_f2_score_3: 0.0320 - val_f2_score_4: 0.0029 - val_f2_score_5: 1.6393e-04
# Epoch 20/200
#  - 7s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0776 - f2_score: 0.1459 - f2_score_1: 0.0985 - f2_score_2: 0.0633 - f2_score_3: 0.0378 - f2_score_4: 0.0092 - f2_score_5: 0.0014 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0727 - val_f2_score: 0.1357 - val_f2_score_1: 0.0889 - val_f2_score_2: 0.0551 - val_f2_score_3: 0.0305 - val_f2_score_4: 0.0025 - val_f2_score_5: 1.6393e-04
# Epoch 21/200
#  - 7s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0790 - f2_score: 0.1468 - f2_score_1: 0.0989 - f2_score_2: 0.0639 - f2_score_3: 0.0385 - f2_score_4: 0.0094 - f2_score_5: 0.0015 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0768 - val_f2_score: 0.1353 - val_f2_score_1: 0.0889 - val_f2_score_2: 0.0554 - val_f2_score_3: 0.0310 - val_f2_score_4: 0.0029 - val_f2_score_5: 2.1895e-04
# Epoch 22/200
#  - 6s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0784 - f2_score: 0.1475 - f2_score_1: 0.0998 - f2_score_2: 0.0645 - f2_score_3: 0.0390 - f2_score_4: 0.0098 - f2_score_5: 0.0016 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0675 - val_f2_score: 0.1331 - val_f2_score_1: 0.0867 - val_f2_score_2: 0.0547 - val_f2_score_3: 0.0314 - val_f2_score_4: 0.0032 - val_f2_score_5: 1.3285e-04
# Epoch 23/200
#  - 6s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0799 - f2_score: 0.1482 - f2_score_1: 0.1002 - f2_score_2: 0.0650 - f2_score_3: 0.0393 - f2_score_4: 0.0102 - f2_score_5: 0.0016 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0699 - val_f2_score: 0.1372 - val_f2_score_1: 0.0918 - val_f2_score_2: 0.0584 - val_f2_score_3: 0.0348 - val_f2_score_4: 0.0048 - val_f2_score_5: 3.0707e-04
# Epoch 24/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0794 - f2_score: 0.1486 - f2_score_1: 0.1005 - f2_score_2: 0.0650 - f2_score_3: 0.0390 - f2_score_4: 0.0102 - f2_score_5: 0.0019 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0718 - val_f2_score: 0.1400 - val_f2_score_1: 0.0935 - val_f2_score_2: 0.0582 - val_f2_score_3: 0.0336 - val_f2_score_4: 0.0042 - val_f2_score_5: 2.0698e-04
# Epoch 25/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0807 - f2_score: 0.1497 - f2_score_1: 0.1014 - f2_score_2: 0.0657 - f2_score_3: 0.0402 - f2_score_4: 0.0108 - f2_score_5: 0.0019 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0696 - val_f2_score: 0.1398 - val_f2_score_1: 0.0935 - val_f2_score_2: 0.0594 - val_f2_score_3: 0.0346 - val_f2_score_4: 0.0049 - val_f2_score_5: 3.0292e-04
# Epoch 26/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0820 - f2_score: 0.1500 - f2_score_1: 0.1016 - f2_score_2: 0.0665 - f2_score_3: 0.0403 - f2_score_4: 0.0112 - f2_score_5: 0.0020 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0668 - val_f2_score: 0.1417 - val_f2_score_1: 0.0949 - val_f2_score_2: 0.0604 - val_f2_score_3: 0.0366 - val_f2_score_4: 0.0056 - val_f2_score_5: 3.0292e-04
# Epoch 27/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0806 - f2_score: 0.1510 - f2_score_1: 0.1032 - f2_score_2: 0.0668 - f2_score_3: 0.0410 - f2_score_4: 0.0111 - f2_score_5: 0.0022 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0775 - val_f2_score: 0.1376 - val_f2_score_1: 0.0909 - val_f2_score_2: 0.0581 - val_f2_score_3: 0.0338 - val_f2_score_4: 0.0044 - val_f2_score_5: 3.6252e-04
# Epoch 28/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0812 - f2_score: 0.1511 - f2_score_1: 0.1036 - f2_score_2: 0.0678 - f2_score_3: 0.0414 - f2_score_4: 0.0112 - f2_score_5: 0.0020 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0719 - val_f2_score: 0.1416 - val_f2_score_1: 0.0955 - val_f2_score_2: 0.0621 - val_f2_score_3: 0.0375 - val_f2_score_4: 0.0060 - val_f2_score_5: 4.1340e-04
# Epoch 29/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0813 - f2_score: 0.1516 - f2_score_1: 0.1040 - f2_score_2: 0.0679 - f2_score_3: 0.0424 - f2_score_4: 0.0117 - f2_score_5: 0.0024 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0736 - val_f2_score: 0.1422 - val_f2_score_1: 0.0961 - val_f2_score_2: 0.0620 - val_f2_score_3: 0.0370 - val_f2_score_4: 0.0061 - val_f2_score_5: 4.3102e-04
# Epoch 30/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0824 - f2_score: 0.1529 - f2_score_1: 0.1048 - f2_score_2: 0.0691 - f2_score_3: 0.0423 - f2_score_4: 0.0120 - f2_score_5: 0.0024 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0757 - val_f2_score: 0.1405 - val_f2_score_1: 0.0931 - val_f2_score_2: 0.0596 - val_f2_score_3: 0.0351 - val_f2_score_4: 0.0054 - val_f2_score_5: 5.0101e-04
# Epoch 31/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0821 - f2_score: 0.1525 - f2_score_1: 0.1041 - f2_score_2: 0.0685 - f2_score_3: 0.0424 - f2_score_4: 0.0122 - f2_score_5: 0.0025 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0710 - val_f2_score: 0.1433 - val_f2_score_1: 0.0960 - val_f2_score_2: 0.0621 - val_f2_score_3: 0.0379 - val_f2_score_4: 0.0064 - val_f2_score_5: 4.3885e-04
# Epoch 32/200
#  - 6s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0822 - f2_score: 0.1535 - f2_score_1: 0.1046 - f2_score_2: 0.0692 - f2_score_3: 0.0427 - f2_score_4: 0.0122 - f2_score_5: 0.0024 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0726 - val_f2_score: 0.1415 - val_f2_score_1: 0.0948 - val_f2_score_2: 0.0607 - val_f2_score_3: 0.0361 - val_f2_score_4: 0.0057 - val_f2_score_5: 4.3885e-04
# Epoch 33/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0826 - f2_score: 0.1537 - f2_score_1: 0.1053 - f2_score_2: 0.0694 - f2_score_3: 0.0432 - f2_score_4: 0.0124 - f2_score_5: 0.0024 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0777 - val_f2_score: 0.1437 - val_f2_score_1: 0.0962 - val_f2_score_2: 0.0615 - val_f2_score_3: 0.0361 - val_f2_score_4: 0.0055 - val_f2_score_5: 4.5646e-04
# Epoch 34/200
#  - 7s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0836 - f2_score: 0.1534 - f2_score_1: 0.1056 - f2_score_2: 0.0695 - f2_score_3: 0.0434 - f2_score_4: 0.0127 - f2_score_5: 0.0026 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0801 - val_f2_score: 0.1426 - val_f2_score_1: 0.0946 - val_f2_score_2: 0.0600 - val_f2_score_3: 0.0345 - val_f2_score_4: 0.0049 - val_f2_score_5: 5.1448e-04
# Epoch 35/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0849 - f2_score: 0.1546 - f2_score_1: 0.1065 - f2_score_2: 0.0701 - f2_score_3: 0.0434 - f2_score_4: 0.0126 - f2_score_5: 0.0026 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0738 - val_f2_score: 0.1449 - val_f2_score_1: 0.0979 - val_f2_score_2: 0.0633 - val_f2_score_3: 0.0391 - val_f2_score_4: 0.0069 - val_f2_score_5: 5.0101e-04
# Epoch 36/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1548 - f2_score_1: 0.1064 - f2_score_2: 0.0701 - f2_score_3: 0.0432 - f2_score_4: 0.0128 - f2_score_5: 0.0027 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0787 - val_f2_score: 0.1446 - val_f2_score_1: 0.0975 - val_f2_score_2: 0.0626 - val_f2_score_3: 0.0374 - val_f2_score_4: 0.0061 - val_f2_score_5: 5.9276e-04
# Epoch 37/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0846 - f2_score: 0.1549 - f2_score_1: 0.1068 - f2_score_2: 0.0708 - f2_score_3: 0.0441 - f2_score_4: 0.0126 - f2_score_5: 0.0026 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0773 - val_f2_score: 0.1454 - val_f2_score_1: 0.0973 - val_f2_score_2: 0.0628 - val_f2_score_3: 0.0377 - val_f2_score_4: 0.0064 - val_f2_score_5: 5.9276e-04
# Epoch 38/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1554 - f2_score_1: 0.1073 - f2_score_2: 0.0710 - f2_score_3: 0.0443 - f2_score_4: 0.0130 - f2_score_5: 0.0026 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0736 - val_f2_score: 0.1462 - val_f2_score_1: 0.0995 - val_f2_score_2: 0.0654 - val_f2_score_3: 0.0412 - val_f2_score_4: 0.0077 - val_f2_score_5: 6.0623e-04
# Epoch 39/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0848 - f2_score: 0.1560 - f2_score_1: 0.1081 - f2_score_2: 0.0720 - f2_score_3: 0.0454 - f2_score_4: 0.0137 - f2_score_5: 0.0027 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0801 - val_f2_score: 0.1436 - val_f2_score_1: 0.0954 - val_f2_score_2: 0.0613 - val_f2_score_3: 0.0363 - val_f2_score_4: 0.0057 - val_f2_score_5: 6.2384e-04
# Epoch 40/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0833 - f2_score: 0.1548 - f2_score_1: 0.1068 - f2_score_2: 0.0707 - f2_score_3: 0.0447 - f2_score_4: 0.0134 - f2_score_5: 0.0029 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0811 - val_f2_score: 0.1460 - val_f2_score_1: 0.0974 - val_f2_score_2: 0.0625 - val_f2_score_3: 0.0368 - val_f2_score_4: 0.0060 - val_f2_score_5: 5.9952e-04
# Epoch 41/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1557 - f2_score_1: 0.1078 - f2_score_2: 0.0710 - f2_score_3: 0.0446 - f2_score_4: 0.0134 - f2_score_5: 0.0028 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0774 - val_f2_score: 0.1457 - val_f2_score_1: 0.0983 - val_f2_score_2: 0.0639 - val_f2_score_3: 0.0391 - val_f2_score_4: 0.0068 - val_f2_score_5: 6.3474e-04
# Epoch 42/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1566 - f2_score_1: 0.1082 - f2_score_2: 0.0717 - f2_score_3: 0.0450 - f2_score_4: 0.0137 - f2_score_5: 0.0030 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0765 - val_f2_score: 0.1454 - val_f2_score_1: 0.0981 - val_f2_score_2: 0.0636 - val_f2_score_3: 0.0394 - val_f2_score_4: 0.0071 - val_f2_score_5: 6.3474e-04
# Epoch 43/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0839 - f2_score: 0.1561 - f2_score_1: 0.1079 - f2_score_2: 0.0717 - f2_score_3: 0.0451 - f2_score_4: 0.0135 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0799 - val_f2_score: 0.1459 - val_f2_score_1: 0.0977 - val_f2_score_2: 0.0631 - val_f2_score_3: 0.0380 - val_f2_score_4: 0.0064 - val_f2_score_5: 6.3474e-04
# Epoch 44/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1563 - f2_score_1: 0.1077 - f2_score_2: 0.0718 - f2_score_3: 0.0454 - f2_score_4: 0.0134 - f2_score_5: 0.0029 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0778 - val_f2_score: 0.1461 - val_f2_score_1: 0.0982 - val_f2_score_2: 0.0635 - val_f2_score_3: 0.0386 - val_f2_score_4: 0.0068 - val_f2_score_5: 6.3474e-04
# Epoch 45/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0841 - f2_score: 0.1563 - f2_score_1: 0.1082 - f2_score_2: 0.0719 - f2_score_3: 0.0447 - f2_score_4: 0.0135 - f2_score_5: 0.0030 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0772 - val_f2_score: 0.1464 - val_f2_score_1: 0.0987 - val_f2_score_2: 0.0642 - val_f2_score_3: 0.0396 - val_f2_score_4: 0.0073 - val_f2_score_5: 6.5354e-04
# Epoch 46/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1570 - f2_score_1: 0.1088 - f2_score_2: 0.0724 - f2_score_3: 0.0459 - f2_score_4: 0.0140 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0784 - val_f2_score: 0.1466 - val_f2_score_1: 0.0984 - val_f2_score_2: 0.0638 - val_f2_score_3: 0.0389 - val_f2_score_4: 0.0070 - val_f2_score_5: 6.5354e-04
# Epoch 47/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1571 - f2_score_1: 0.1085 - f2_score_2: 0.0724 - f2_score_3: 0.0455 - f2_score_4: 0.0136 - f2_score_5: 0.0030 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0786 - val_f2_score: 0.1466 - val_f2_score_1: 0.0993 - val_f2_score_2: 0.0648 - val_f2_score_3: 0.0398 - val_f2_score_4: 0.0074 - val_f2_score_5: 7.2353e-04
# Epoch 48/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1564 - f2_score_1: 0.1085 - f2_score_2: 0.0726 - f2_score_3: 0.0455 - f2_score_4: 0.0139 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0782 - val_f2_score: 0.1475 - val_f2_score_1: 0.1001 - val_f2_score_2: 0.0653 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0077 - val_f2_score_5: 7.3700e-04
# Epoch 49/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1575 - f2_score_1: 0.1093 - f2_score_2: 0.0730 - f2_score_3: 0.0462 - f2_score_4: 0.0141 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0795 - val_f2_score: 0.1459 - val_f2_score_1: 0.0982 - val_f2_score_2: 0.0638 - val_f2_score_3: 0.0387 - val_f2_score_4: 0.0070 - val_f2_score_5: 6.5354e-04
# Epoch 50/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1571 - f2_score_1: 0.1088 - f2_score_2: 0.0724 - f2_score_3: 0.0455 - f2_score_4: 0.0135 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0781 - val_f2_score: 0.1474 - val_f2_score_1: 0.0995 - val_f2_score_2: 0.0646 - val_f2_score_3: 0.0397 - val_f2_score_4: 0.0074 - val_f2_score_5: 6.7115e-04
# Epoch 51/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0854 - f2_score: 0.1581 - f2_score_1: 0.1093 - f2_score_2: 0.0724 - f2_score_3: 0.0462 - f2_score_4: 0.0142 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0773 - val_f2_score: 0.1469 - val_f2_score_1: 0.0995 - val_f2_score_2: 0.0650 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0077 - val_f2_score_5: 7.2353e-04
# Epoch 52/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1578 - f2_score_1: 0.1091 - f2_score_2: 0.0725 - f2_score_3: 0.0461 - f2_score_4: 0.0143 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0786 - val_f2_score: 0.1465 - val_f2_score_1: 0.0987 - val_f2_score_2: 0.0641 - val_f2_score_3: 0.0391 - val_f2_score_4: 0.0073 - val_f2_score_5: 7.5461e-04
# Epoch 53/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0846 - f2_score: 0.1571 - f2_score_1: 0.1091 - f2_score_2: 0.0731 - f2_score_3: 0.0460 - f2_score_4: 0.0138 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1472 - val_f2_score_1: 0.0994 - val_f2_score_2: 0.0647 - val_f2_score_3: 0.0393 - val_f2_score_4: 0.0073 - val_f2_score_5: 7.5047e-04
# Epoch 54/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1583 - f2_score_1: 0.1104 - f2_score_2: 0.0733 - f2_score_3: 0.0460 - f2_score_4: 0.0141 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0773 - val_f2_score: 0.1475 - val_f2_score_1: 0.1003 - val_f2_score_2: 0.0654 - val_f2_score_3: 0.0405 - val_f2_score_4: 0.0079 - val_f2_score_5: 7.9071e-04
# Epoch 55/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1577 - f2_score_1: 0.1091 - f2_score_2: 0.0724 - f2_score_3: 0.0462 - f2_score_4: 0.0142 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1472 - val_f2_score_1: 0.0997 - val_f2_score_2: 0.0648 - val_f2_score_3: 0.0396 - val_f2_score_4: 0.0075 - val_f2_score_5: 7.3269e-04
# Epoch 56/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0849 - f2_score: 0.1578 - f2_score_1: 0.1092 - f2_score_2: 0.0727 - f2_score_3: 0.0457 - f2_score_4: 0.0139 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0787 - val_f2_score: 0.1479 - val_f2_score_1: 0.1003 - val_f2_score_2: 0.0653 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0076 - val_f2_score_5: 7.8139e-04
# Epoch 57/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1581 - f2_score_1: 0.1103 - f2_score_2: 0.0736 - f2_score_3: 0.0462 - f2_score_4: 0.0142 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0804 - val_f2_score: 0.1469 - val_f2_score_1: 0.0990 - val_f2_score_2: 0.0645 - val_f2_score_3: 0.0391 - val_f2_score_4: 0.0072 - val_f2_score_5: 7.6377e-04
# Epoch 58/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1581 - f2_score_1: 0.1098 - f2_score_2: 0.0726 - f2_score_3: 0.0458 - f2_score_4: 0.0139 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0790 - val_f2_score: 0.1475 - val_f2_score_1: 0.0997 - val_f2_score_2: 0.0649 - val_f2_score_3: 0.0398 - val_f2_score_4: 0.0076 - val_f2_score_5: 7.8139e-04
# Epoch 59/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1575 - f2_score_1: 0.1093 - f2_score_2: 0.0732 - f2_score_3: 0.0465 - f2_score_4: 0.0144 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0773 - val_f2_score: 0.1476 - val_f2_score_1: 0.1002 - val_f2_score_2: 0.0656 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0079 - val_f2_score_5: 8.0832e-04
# Epoch 60/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1584 - f2_score_1: 0.1093 - f2_score_2: 0.0729 - f2_score_3: 0.0466 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0787 - val_f2_score: 0.1476 - val_f2_score_1: 0.1000 - val_f2_score_2: 0.0651 - val_f2_score_3: 0.0400 - val_f2_score_4: 0.0076 - val_f2_score_5: 7.8139e-04
# Epoch 61/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1582 - f2_score_1: 0.1094 - f2_score_2: 0.0725 - f2_score_3: 0.0461 - f2_score_4: 0.0142 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0781 - val_f2_score: 0.1477 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0657 - val_f2_score_3: 0.0405 - val_f2_score_4: 0.0079 - val_f2_score_5: 8.3377e-04
# Epoch 62/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0871 - f2_score: 0.1578 - f2_score_1: 0.1093 - f2_score_2: 0.0732 - f2_score_3: 0.0466 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0782 - val_f2_score: 0.1478 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0655 - val_f2_score_3: 0.0405 - val_f2_score_4: 0.0078 - val_f2_score_5: 8.3377e-04
# Epoch 63/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1579 - f2_score_1: 0.1096 - f2_score_2: 0.0726 - f2_score_3: 0.0457 - f2_score_4: 0.0143 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0778 - val_f2_score: 0.1480 - val_f2_score_1: 0.1008 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0409 - val_f2_score_4: 0.0080 - val_f2_score_5: 8.5138e-04
# Epoch 64/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1584 - f2_score_1: 0.1096 - f2_score_2: 0.0733 - f2_score_3: 0.0463 - f2_score_4: 0.0141 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0788 - val_f2_score: 0.1476 - val_f2_score_1: 0.1003 - val_f2_score_2: 0.0657 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0079 - val_f2_score_5: 8.8772e-04
# Epoch 65/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1576 - f2_score_1: 0.1091 - f2_score_2: 0.0728 - f2_score_3: 0.0466 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0780 - val_f2_score: 0.1478 - val_f2_score_1: 0.1006 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 66/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1584 - f2_score_1: 0.1097 - f2_score_2: 0.0740 - f2_score_3: 0.0469 - f2_score_4: 0.0148 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1477 - val_f2_score_1: 0.1001 - val_f2_score_2: 0.0655 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0078 - val_f2_score_5: 9.0282e-04
# Epoch 67/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1581 - f2_score_1: 0.1102 - f2_score_2: 0.0733 - f2_score_3: 0.0467 - f2_score_4: 0.0145 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0794 - val_f2_score: 0.1478 - val_f2_score_1: 0.1001 - val_f2_score_2: 0.0655 - val_f2_score_3: 0.0401 - val_f2_score_4: 0.0078 - val_f2_score_5: 9.0282e-04
# Epoch 68/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0848 - f2_score: 0.1581 - f2_score_1: 0.1095 - f2_score_2: 0.0730 - f2_score_3: 0.0463 - f2_score_4: 0.0142 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1481 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0405 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 69/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1586 - f2_score_1: 0.1098 - f2_score_2: 0.0741 - f2_score_3: 0.0473 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0795 - val_f2_score: 0.1478 - val_f2_score_1: 0.1003 - val_f2_score_2: 0.0656 - val_f2_score_3: 0.0402 - val_f2_score_4: 0.0079 - val_f2_score_5: 8.8935e-04
# Epoch 70/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1579 - f2_score_1: 0.1095 - f2_score_2: 0.0731 - f2_score_3: 0.0465 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0793 - val_f2_score: 0.1478 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0656 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0079 - val_f2_score_5: 9.0282e-04
# Epoch 71/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1577 - f2_score_1: 0.1097 - f2_score_2: 0.0734 - f2_score_3: 0.0463 - f2_score_4: 0.0140 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1479 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0657 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0079 - val_f2_score_5: 9.0282e-04
# Epoch 72/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1579 - f2_score_1: 0.1102 - f2_score_2: 0.0733 - f2_score_3: 0.0463 - f2_score_4: 0.0148 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1478 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0657 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0079 - val_f2_score_5: 9.0282e-04
# Epoch 73/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1584 - f2_score_1: 0.1099 - f2_score_2: 0.0734 - f2_score_3: 0.0467 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1479 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 74/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1580 - f2_score_1: 0.1094 - f2_score_2: 0.0737 - f2_score_3: 0.0463 - f2_score_4: 0.0141 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0790 - val_f2_score: 0.1480 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0404 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 75/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0871 - f2_score: 0.1588 - f2_score_1: 0.1106 - f2_score_2: 0.0745 - f2_score_3: 0.0469 - f2_score_4: 0.0147 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1479 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 76/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0849 - f2_score: 0.1586 - f2_score_1: 0.1102 - f2_score_2: 0.0734 - f2_score_3: 0.0466 - f2_score_4: 0.0144 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1480 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0405 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.0282e-04
# Epoch 77/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0846 - f2_score: 0.1589 - f2_score_1: 0.1104 - f2_score_2: 0.0736 - f2_score_3: 0.0468 - f2_score_4: 0.0144 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1480 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.0282e-04
# Epoch 78/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1583 - f2_score_1: 0.1097 - f2_score_2: 0.0734 - f2_score_3: 0.0469 - f2_score_4: 0.0142 - f2_score_5: 0.0036 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.0282e-04
# Epoch 79/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1586 - f2_score_1: 0.1091 - f2_score_2: 0.0731 - f2_score_3: 0.0467 - f2_score_4: 0.0144 - f2_score_5: 0.0031 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0790 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0408 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 80/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1587 - f2_score_1: 0.1101 - f2_score_2: 0.0738 - f2_score_3: 0.0468 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 81/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1585 - f2_score_1: 0.1105 - f2_score_2: 0.0736 - f2_score_3: 0.0467 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 82/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1589 - f2_score_1: 0.1107 - f2_score_2: 0.0736 - f2_score_3: 0.0470 - f2_score_4: 0.0142 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0791 - val_f2_score: 0.1481 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0659 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.2826e-04
# Epoch 83/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1591 - f2_score_1: 0.1101 - f2_score_2: 0.0733 - f2_score_3: 0.0468 - f2_score_4: 0.0144 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0658 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.2826e-04
# Epoch 84/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1587 - f2_score_1: 0.1103 - f2_score_2: 0.0733 - f2_score_3: 0.0467 - f2_score_4: 0.0148 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1480 - val_f2_score_1: 0.1005 - val_f2_score_2: 0.0659 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0080 - val_f2_score_5: 9.2826e-04
# Epoch 85/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1578 - f2_score_1: 0.1097 - f2_score_2: 0.0735 - f2_score_3: 0.0466 - f2_score_4: 0.0148 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 86/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1587 - f2_score_1: 0.1098 - f2_score_2: 0.0734 - f2_score_3: 0.0465 - f2_score_4: 0.0147 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 87/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1590 - f2_score_1: 0.1102 - f2_score_2: 0.0737 - f2_score_3: 0.0469 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 88/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1584 - f2_score_1: 0.1101 - f2_score_2: 0.0741 - f2_score_3: 0.0467 - f2_score_4: 0.0146 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1008 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 89/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0854 - f2_score: 0.1583 - f2_score_1: 0.1102 - f2_score_2: 0.0733 - f2_score_3: 0.0466 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 90/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1589 - f2_score_1: 0.1104 - f2_score_2: 0.0737 - f2_score_3: 0.0472 - f2_score_4: 0.0147 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 91/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1595 - f2_score_1: 0.1108 - f2_score_2: 0.0735 - f2_score_3: 0.0468 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1006 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 92/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0852 - f2_score: 0.1586 - f2_score_1: 0.1097 - f2_score_2: 0.0737 - f2_score_3: 0.0469 - f2_score_4: 0.0144 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 93/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1590 - f2_score_1: 0.1099 - f2_score_2: 0.0734 - f2_score_3: 0.0466 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 94/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1588 - f2_score_1: 0.1104 - f2_score_2: 0.0741 - f2_score_3: 0.0477 - f2_score_4: 0.0153 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 95/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1587 - f2_score_1: 0.1100 - f2_score_2: 0.0738 - f2_score_3: 0.0475 - f2_score_4: 0.0147 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1006 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 96/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0852 - f2_score: 0.1592 - f2_score_1: 0.1108 - f2_score_2: 0.0739 - f2_score_3: 0.0473 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1481 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 97/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1592 - f2_score_1: 0.1105 - f2_score_2: 0.0736 - f2_score_3: 0.0471 - f2_score_4: 0.0146 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 98/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1588 - f2_score_1: 0.1107 - f2_score_2: 0.0736 - f2_score_3: 0.0472 - f2_score_4: 0.0148 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 99/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1589 - f2_score_1: 0.1109 - f2_score_2: 0.0741 - f2_score_3: 0.0471 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 100/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1587 - f2_score_1: 0.1105 - f2_score_2: 0.0738 - f2_score_3: 0.0472 - f2_score_4: 0.0146 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 101/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1586 - f2_score_1: 0.1102 - f2_score_2: 0.0739 - f2_score_3: 0.0465 - f2_score_4: 0.0144 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 102/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1588 - f2_score_1: 0.1097 - f2_score_2: 0.0735 - f2_score_3: 0.0468 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 103/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0858 - f2_score: 0.1586 - f2_score_1: 0.1105 - f2_score_2: 0.0740 - f2_score_3: 0.0469 - f2_score_4: 0.0144 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 104/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1594 - f2_score_1: 0.1107 - f2_score_2: 0.0738 - f2_score_3: 0.0471 - f2_score_4: 0.0148 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 105/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1582 - f2_score_1: 0.1104 - f2_score_2: 0.0742 - f2_score_3: 0.0473 - f2_score_4: 0.0144 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 106/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1590 - f2_score_1: 0.1101 - f2_score_2: 0.0742 - f2_score_3: 0.0471 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 107/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0876 - f2_score: 0.1594 - f2_score_1: 0.1104 - f2_score_2: 0.0741 - f2_score_3: 0.0472 - f2_score_4: 0.0146 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 108/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1584 - f2_score_1: 0.1100 - f2_score_2: 0.0734 - f2_score_3: 0.0466 - f2_score_4: 0.0142 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 109/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1589 - f2_score_1: 0.1108 - f2_score_2: 0.0743 - f2_score_3: 0.0471 - f2_score_4: 0.0147 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 110/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1586 - f2_score_1: 0.1100 - f2_score_2: 0.0735 - f2_score_3: 0.0467 - f2_score_4: 0.0146 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 111/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0856 - f2_score: 0.1588 - f2_score_1: 0.1108 - f2_score_2: 0.0736 - f2_score_3: 0.0467 - f2_score_4: 0.0145 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1482 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0660 - val_f2_score_3: 0.0406 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 112/200
# ...
# Epoch 161/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1588 - f2_score_1: 0.1103 - f2_score_2: 0.0733 - f2_score_3: 0.0469 - f2_score_4: 0.0149 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 162/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1591 - f2_score_1: 0.1099 - f2_score_2: 0.0734 - f2_score_3: 0.0468 - f2_score_4: 0.0142 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 163/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1585 - f2_score_1: 0.1098 - f2_score_2: 0.0734 - f2_score_3: 0.0464 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 164/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0854 - f2_score: 0.1587 - f2_score_1: 0.1103 - f2_score_2: 0.0737 - f2_score_3: 0.0470 - f2_score_4: 0.0147 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 165/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1593 - f2_score_1: 0.1108 - f2_score_2: 0.0739 - f2_score_3: 0.0470 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 166/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1586 - f2_score_1: 0.1099 - f2_score_2: 0.0733 - f2_score_3: 0.0463 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 167/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0871 - f2_score: 0.1591 - f2_score_1: 0.1103 - f2_score_2: 0.0735 - f2_score_3: 0.0464 - f2_score_4: 0.0144 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 168/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0878 - f2_score: 0.1592 - f2_score_1: 0.1100 - f2_score_2: 0.0734 - f2_score_3: 0.0464 - f2_score_4: 0.0143 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 169/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0868 - f2_score: 0.1589 - f2_score_1: 0.1108 - f2_score_2: 0.0744 - f2_score_3: 0.0469 - f2_score_4: 0.0151 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 170/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1584 - f2_score_1: 0.1105 - f2_score_2: 0.0740 - f2_score_3: 0.0468 - f2_score_4: 0.0144 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 171/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1591 - f2_score_1: 0.1100 - f2_score_2: 0.0733 - f2_score_3: 0.0468 - f2_score_4: 0.0147 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 172/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1582 - f2_score_1: 0.1100 - f2_score_2: 0.0737 - f2_score_3: 0.0470 - f2_score_4: 0.0142 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 173/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1591 - f2_score_1: 0.1109 - f2_score_2: 0.0742 - f2_score_3: 0.0469 - f2_score_4: 0.0143 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 174/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0871 - f2_score: 0.1586 - f2_score_1: 0.1102 - f2_score_2: 0.0739 - f2_score_3: 0.0474 - f2_score_4: 0.0146 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 175/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0879 - f2_score: 0.1593 - f2_score_1: 0.1103 - f2_score_2: 0.0735 - f2_score_3: 0.0469 - f2_score_4: 0.0146 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 176/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1591 - f2_score_1: 0.1105 - f2_score_2: 0.0743 - f2_score_3: 0.0471 - f2_score_4: 0.0142 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 177/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1582 - f2_score_1: 0.1095 - f2_score_2: 0.0734 - f2_score_3: 0.0471 - f2_score_4: 0.0144 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 178/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1588 - f2_score_1: 0.1105 - f2_score_2: 0.0738 - f2_score_3: 0.0468 - f2_score_4: 0.0142 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 179/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1587 - f2_score_1: 0.1099 - f2_score_2: 0.0733 - f2_score_3: 0.0465 - f2_score_4: 0.0143 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 180/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1589 - f2_score_1: 0.1100 - f2_score_2: 0.0740 - f2_score_3: 0.0470 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 181/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0851 - f2_score: 0.1583 - f2_score_1: 0.1103 - f2_score_2: 0.0737 - f2_score_3: 0.0470 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 182/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1584 - f2_score_1: 0.1099 - f2_score_2: 0.0731 - f2_score_3: 0.0470 - f2_score_4: 0.0143 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 183/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1592 - f2_score_1: 0.1104 - f2_score_2: 0.0739 - f2_score_3: 0.0470 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 184/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0853 - f2_score: 0.1577 - f2_score_1: 0.1104 - f2_score_2: 0.0741 - f2_score_3: 0.0467 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 185/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1588 - f2_score_1: 0.1102 - f2_score_2: 0.0735 - f2_score_3: 0.0470 - f2_score_4: 0.0149 - f2_score_5: 0.0036 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 186/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0851 - f2_score: 0.1582 - f2_score_1: 0.1094 - f2_score_2: 0.0732 - f2_score_3: 0.0466 - f2_score_4: 0.0145 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 187/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1589 - f2_score_1: 0.1105 - f2_score_2: 0.0740 - f2_score_3: 0.0471 - f2_score_4: 0.0145 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 188/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1588 - f2_score_1: 0.1105 - f2_score_2: 0.0741 - f2_score_3: 0.0467 - f2_score_4: 0.0144 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 189/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0875 - f2_score: 0.1580 - f2_score_1: 0.1104 - f2_score_2: 0.0738 - f2_score_3: 0.0470 - f2_score_4: 0.0147 - f2_score_5: 0.0036 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 190/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1586 - f2_score_1: 0.1104 - f2_score_2: 0.0735 - f2_score_3: 0.0466 - f2_score_4: 0.0146 - f2_score_5: 0.0036 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 191/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1587 - f2_score_1: 0.1101 - f2_score_2: 0.0737 - f2_score_3: 0.0470 - f2_score_4: 0.0149 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 192/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1597 - f2_score_1: 0.1109 - f2_score_2: 0.0738 - f2_score_3: 0.0470 - f2_score_4: 0.0146 - f2_score_5: 0.0035 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 193/200
#  - 6s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1588 - f2_score_1: 0.1102 - f2_score_2: 0.0739 - f2_score_3: 0.0467 - f2_score_4: 0.0146 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 194/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0858 - f2_score: 0.1595 - f2_score_1: 0.1107 - f2_score_2: 0.0740 - f2_score_3: 0.0472 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 195/200
#  - 6s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1589 - f2_score_1: 0.1102 - f2_score_2: 0.0737 - f2_score_3: 0.0469 - f2_score_4: 0.0145 - f2_score_5: 0.0033 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 196/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1591 - f2_score_1: 0.1096 - f2_score_2: 0.0732 - f2_score_3: 0.0471 - f2_score_4: 0.0147 - f2_score_5: 0.0034 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 197/200
#  - 7s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1589 - f2_score_1: 0.1099 - f2_score_2: 0.0738 - f2_score_3: 0.0469 - f2_score_4: 0.0146 - f2_score_5: 0.0032 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0792 - val_f2_score: 0.1483 - val_f2_score_1: 0.1007 - val_f2_score_2: 0.0661 - val_f2_score_3: 0.0407 - val_f2_score_4: 0.0081 - val_f2_score_5: 9.2826e-04
# Epoch 00197: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id    attribute_ids
# 0  10023b2cc4ed5f68              121
# 1  100fbe75ed8fd887              121
# 2  101b627524a04f19              147
# 3  10234480c41284c6     147 813 1092
# 4  1023b0e2636dcea8              813
# 5   1039cd6cf85845c  13 813 896 1092
# 6   103a5b3f83fbe88         813 1092
# 7  10413aaae8d6a9a2     147 813 1092
# 8  10423822b93a65ab              813
# 9  1052bf702cb099f7      147 671 813
