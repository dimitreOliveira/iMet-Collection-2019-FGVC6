# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras import backend as K
from keras import metrics
from sklearn.metrics import fbeta_score

from keras import optimizers
from keras.models import Sequential
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/train.csv')
labels = pd.read_csv('../input/labels.csv')
test = pd.read_csv('../input/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Model

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 50
LEARNING_RATE = 0.01
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
train_datagen=ImageDataGenerator(rescale=1./255, validation_split=0.25)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='training')

valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",    
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='validation')

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 81928 images belonging to 1103 classes.
# Found 27309 images belonging to 1103 classes.
# Found 7443 images.

# %%
print("train size is {}".format(len(os.listdir("../input/train/"))))
print("test size is {}".format(len(os.listdir("../input/test/"))))
# Out:
# train size is 109237
# test size is 7443

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=(HEIGHT, WIDTH, CANAL)))
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

# optimizer = optimizers.adam(lr=LEARNING_RATE)
optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=valid_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=EPOCHS,
                                callbacks=callbacks,
                                verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 777s - loss: 0.0772 - acc: 0.9689 - categorical_accuracy: 0.0141 - f2_score: 0.0431 - f2_score_1: 0.0399 - f2_score_2: 0.0364 - f2_score_3: 0.0333 - f2_score_4: 0.0274 - f2_score_5: 0.0222 - val_loss: 0.0165 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0048 - val_f2_score_1: 8.2545e-04 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/50
#  - 761s - loss: 0.0226 - acc: 0.9965 - categorical_accuracy: 0.0247 - f2_score: 0.0649 - f2_score_1: 0.0545 - f2_score_2: 0.0456 - f2_score_3: 0.0381 - f2_score_4: 0.0260 - f2_score_5: 0.0173 - val_loss: 0.0156 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0190 - val_f2_score_1: 7.4078e-04 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/50
#  - 773s - loss: 0.0204 - acc: 0.9968 - categorical_accuracy: 0.0284 - f2_score: 0.0718 - f2_score_1: 0.0568 - f2_score_2: 0.0445 - f2_score_3: 0.0346 - f2_score_4: 0.0203 - f2_score_5: 0.0113 - val_loss: 0.0153 - val_acc: 0.9971 - val_categorical_accuracy: 0.0101 - val_f2_score: 0.0455 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 4/50
#  - 776s - loss: 0.0194 - acc: 0.9969 - categorical_accuracy: 0.0296 - f2_score: 0.0744 - f2_score_1: 0.0553 - f2_score_2: 0.0405 - f2_score_3: 0.0298 - f2_score_4: 0.0154 - f2_score_5: 0.0074 - val_loss: 0.0152 - val_acc: 0.9971 - val_categorical_accuracy: 0.0101 - val_f2_score: 0.0578 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 5/50
#  - 773s - loss: 0.0188 - acc: 0.9970 - categorical_accuracy: 0.0302 - f2_score: 0.0753 - f2_score_1: 0.0534 - f2_score_2: 0.0373 - f2_score_3: 0.0255 - f2_score_4: 0.0114 - f2_score_5: 0.0046 - val_loss: 0.0151 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0578 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 6/50
#  - 778s - loss: 0.0184 - acc: 0.9970 - categorical_accuracy: 0.0300 - f2_score: 0.0759 - f2_score_1: 0.0512 - f2_score_2: 0.0337 - f2_score_3: 0.0217 - f2_score_4: 0.0085 - f2_score_5: 0.0029 - val_loss: 0.0150 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0585 - val_f2_score_1: 0.0088 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 7/50
#  - 768s - loss: 0.0181 - acc: 0.9971 - categorical_accuracy: 0.0311 - f2_score: 0.0770 - f2_score_1: 0.0500 - f2_score_2: 0.0315 - f2_score_3: 0.0194 - f2_score_4: 0.0065 - f2_score_5: 0.0019 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0101 - val_f2_score: 0.0582 - val_f2_score_1: 0.0069 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 8/50
#  - 771s - loss: 0.0178 - acc: 0.9971 - categorical_accuracy: 0.0321 - f2_score: 0.0765 - f2_score_1: 0.0475 - f2_score_2: 0.0281 - f2_score_3: 0.0161 - f2_score_4: 0.0046 - f2_score_5: 0.0013 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0103 - val_f2_score: 0.0585 - val_f2_score_1: 0.0438 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 9/50
#  - 769s - loss: 0.0176 - acc: 0.9971 - categorical_accuracy: 0.0328 - f2_score: 0.0775 - f2_score_1: 0.0469 - f2_score_2: 0.0262 - f2_score_3: 0.0138 - f2_score_4: 0.0034 - f2_score_5: 7.0540e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0101 - val_f2_score: 0.0584 - val_f2_score_1: 0.0159 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 10/50
#  - 772s - loss: 0.0175 - acc: 0.9971 - categorical_accuracy: 0.0327 - f2_score: 0.0765 - f2_score_1: 0.0443 - f2_score_2: 0.0240 - f2_score_3: 0.0119 - f2_score_4: 0.0026 - f2_score_5: 4.8129e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0100 - val_f2_score: 0.0615 - val_f2_score_1: 0.0254 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 11/50
#  - 776s - loss: 0.0174 - acc: 0.9971 - categorical_accuracy: 0.0322 - f2_score: 0.0769 - f2_score_1: 0.0437 - f2_score_2: 0.0229 - f2_score_3: 0.0111 - f2_score_4: 0.0022 - f2_score_5: 3.8536e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0103 - val_f2_score: 0.0585 - val_f2_score_1: 0.0412 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 12/50
#  - 765s - loss: 0.0173 - acc: 0.9971 - categorical_accuracy: 0.0323 - f2_score: 0.0772 - f2_score_1: 0.0437 - f2_score_2: 0.0224 - f2_score_3: 0.0104 - f2_score_4: 0.0019 - f2_score_5: 2.6829e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0099 - val_f2_score: 0.0583 - val_f2_score_1: 0.0214 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 13/50
#  - 752s - loss: 0.0172 - acc: 0.9971 - categorical_accuracy: 0.0336 - f2_score: 0.0764 - f2_score_1: 0.0419 - f2_score_2: 0.0209 - f2_score_3: 0.0094 - f2_score_4: 0.0015 - f2_score_5: 1.9337e-04 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0100 - val_f2_score: 0.0584 - val_f2_score_1: 0.0523 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 14/50
#  - 746s - loss: 0.0172 - acc: 0.9971 - categorical_accuracy: 0.0320 - f2_score: 0.0766 - f2_score_1: 0.0411 - f2_score_2: 0.0198 - f2_score_3: 0.0086 - f2_score_4: 0.0014 - f2_score_5: 1.4011e-04 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0104 - val_f2_score: 0.0587 - val_f2_score_1: 0.0455 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 15/50
#  - 739s - loss: 0.0171 - acc: 0.9971 - categorical_accuracy: 0.0314 - f2_score: 0.0751 - f2_score_1: 0.0392 - f2_score_2: 0.0184 - f2_score_3: 0.0077 - f2_score_4: 0.0011 - f2_score_5: 7.5563e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0604 - val_f2_score_1: 0.0284 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 16/50
#  - 729s - loss: 0.0171 - acc: 0.9971 - categorical_accuracy: 0.0323 - f2_score: 0.0764 - f2_score_1: 0.0400 - f2_score_2: 0.0182 - f2_score_3: 0.0076 - f2_score_4: 9.3595e-04 - f2_score_5: 1.0889e-04 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0099 - val_f2_score: 0.0586 - val_f2_score_1: 0.0299 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 17/50
#  - 727s - loss: 0.0170 - acc: 0.9971 - categorical_accuracy: 0.0312 - f2_score: 0.0745 - f2_score_1: 0.0378 - f2_score_2: 0.0167 - f2_score_3: 0.0065 - f2_score_4: 8.5375e-04 - f2_score_5: 6.0009e-05 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0103 - val_f2_score: 0.0628 - val_f2_score_1: 0.0582 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 18/50
#  - 722s - loss: 0.0170 - acc: 0.9971 - categorical_accuracy: 0.0328 - f2_score: 0.0760 - f2_score_1: 0.0383 - f2_score_2: 0.0164 - f2_score_3: 0.0063 - f2_score_4: 6.4210e-04 - f2_score_5: 7.4436e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0586 - val_f2_score_1: 0.0497 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 19/50
#  - 718s - loss: 0.0169 - acc: 0.9971 - categorical_accuracy: 0.0329 - f2_score: 0.0765 - f2_score_1: 0.0374 - f2_score_2: 0.0156 - f2_score_3: 0.0057 - f2_score_4: 4.4774e-04 - f2_score_5: 3.4377e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0591 - val_f2_score_1: 0.0525 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 20/50
#  - 713s - loss: 0.0169 - acc: 0.9971 - categorical_accuracy: 0.0331 - f2_score: 0.0748 - f2_score_1: 0.0363 - f2_score_2: 0.0149 - f2_score_3: 0.0052 - f2_score_4: 4.9945e-04 - f2_score_5: 2.1564e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0103 - val_f2_score: 0.0593 - val_f2_score_1: 0.0569 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 21/50
#  - 707s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0318 - f2_score: 0.0748 - f2_score_1: 0.0359 - f2_score_2: 0.0142 - f2_score_3: 0.0048 - f2_score_4: 4.4620e-04 - f2_score_5: 3.6587e-05 - val_loss: 0.0149 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0603 - val_f2_score_1: 0.0584 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 22/50
#  - 708s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0322 - f2_score: 0.0754 - f2_score_1: 0.0363 - f2_score_2: 0.0144 - f2_score_3: 0.0049 - f2_score_4: 3.9690e-04 - f2_score_5: 4.4143e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0100 - val_f2_score: 0.0604 - val_f2_score_1: 0.0559 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 23/50
#  - 712s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0313 - f2_score: 0.0744 - f2_score_1: 0.0352 - f2_score_2: 0.0136 - f2_score_3: 0.0045 - f2_score_4: 3.3166e-04 - f2_score_5: 1.2980e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0097 - val_f2_score: 0.0649 - val_f2_score_1: 0.0559 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 24/50
#  - 712s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0318 - f2_score: 0.0749 - f2_score_1: 0.0351 - f2_score_2: 0.0134 - f2_score_3: 0.0045 - f2_score_4: 3.8507e-04 - f2_score_5: 1.2310e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0102 - val_f2_score: 0.0642 - val_f2_score_1: 0.0574 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 25/50
#  - 719s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0312 - f2_score: 0.0754 - f2_score_1: 0.0352 - f2_score_2: 0.0135 - f2_score_3: 0.0043 - f2_score_4: 3.1850e-04 - f2_score_5: 1.3949e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0107 - val_f2_score: 0.0598 - val_f2_score_1: 0.0542 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 26/50
#  - 727s - loss: 0.0168 - acc: 0.9971 - categorical_accuracy: 0.0309 - f2_score: 0.0735 - f2_score_1: 0.0339 - f2_score_2: 0.0127 - f2_score_3: 0.0038 - f2_score_4: 2.2629e-04 - f2_score_5: 1.6991e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0098 - val_f2_score: 0.0815 - val_f2_score_1: 0.0578 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 27/50
#  - 709s - loss: 0.0167 - acc: 0.9971 - categorical_accuracy: 0.0319 - f2_score: 0.0736 - f2_score_1: 0.0336 - f2_score_2: 0.0127 - f2_score_3: 0.0040 - f2_score_4: 2.9519e-04 - f2_score_5: 2.1649e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0101 - val_f2_score: 0.0597 - val_f2_score_1: 0.0585 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 28/50
#  - 708s - loss: 0.0167 - acc: 0.9971 - categorical_accuracy: 0.0317 - f2_score: 0.0750 - f2_score_1: 0.0337 - f2_score_2: 0.0123 - f2_score_3: 0.0039 - f2_score_4: 2.2481e-04 - f2_score_5: 1.3962e-05 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0104 - val_f2_score: 0.0626 - val_f2_score_1: 0.0584 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 00028: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', figsize=(20,7))

ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
preds = model.predict_generator(test_generator, steps=STEP_SIZE_TEST)

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += labels[idx]
            else:
                valid += (' %s' % labels[idx])
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id attribute_ids
# 0  10023b2cc4ed5f68           813
# 1  100fbe75ed8fd887           813
# 2  101b627524a04f19           813
# 3  10234480c41284c6           813
# 4  1023b0e2636dcea8           813
# 5   1039cd6cf85845c  1092 147 813
# 6   103a5b3f83fbe88           813
# 7  10413aaae8d6a9a2           813
# 8  10423822b93a65ab           813
# 9  1052bf702cb099f7           813
