# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras import applications
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the bottleneck network
model_base = applications.vgg19.VGG19(weights=None, include_top=False)
model_base.load_weights('../input/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_base.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 19s - loss: 0.0251 - acc: 0.9927 - categorical_accuracy: 0.0664 - f2_score: 0.1615 - f2_score_1: 0.1329 - f2_score_2: 0.1076 - f2_score_3: 0.0869 - f2_score_4: 0.0764 - f2_score_5: 0.0704 - f2_score_6: 0.0460 - f2_score_7: 0.0295 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1076 - val_f2_score: 0.2620 - val_f2_score_1: 0.2030 - val_f2_score_2: 0.1560 - val_f2_score_3: 0.1209 - val_f2_score_4: 0.1046 - val_f2_score_5: 0.0956 - val_f2_score_6: 0.0567 - val_f2_score_7: 0.0306
# Epoch 2/200
#  - 17s - loss: 0.0136 - acc: 0.9971 - categorical_accuracy: 0.1139 - f2_score: 0.2611 - f2_score_1: 0.2222 - f2_score_2: 0.1845 - f2_score_3: 0.1515 - f2_score_4: 0.1347 - f2_score_5: 0.1246 - f2_score_6: 0.0839 - f2_score_7: 0.0557 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1339 - val_f2_score: 0.3174 - val_f2_score_1: 0.2710 - val_f2_score_2: 0.2250 - val_f2_score_3: 0.1837 - val_f2_score_4: 0.1626 - val_f2_score_5: 0.1511 - val_f2_score_6: 0.1043 - val_f2_score_7: 0.0733
# Epoch 3/200
#  - 17s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1358 - f2_score: 0.3038 - f2_score_1: 0.2656 - f2_score_2: 0.2259 - f2_score_3: 0.1903 - f2_score_4: 0.1710 - f2_score_5: 0.1589 - f2_score_6: 0.1112 - f2_score_7: 0.0781 - val_loss: 0.0118 - val_acc: 0.9973 - val_categorical_accuracy: 0.1655 - val_f2_score: 0.3613 - val_f2_score_1: 0.3322 - val_f2_score_2: 0.2917 - val_f2_score_3: 0.2483 - val_f2_score_4: 0.2237 - val_f2_score_5: 0.2093 - val_f2_score_6: 0.1462 - val_f2_score_7: 0.1023
# Epoch 4/200
#  - 17s - loss: 0.0122 - acc: 0.9972 - categorical_accuracy: 0.1499 - f2_score: 0.3312 - f2_score_1: 0.2950 - f2_score_2: 0.2547 - f2_score_3: 0.2170 - f2_score_4: 0.1966 - f2_score_5: 0.1837 - f2_score_6: 0.1319 - f2_score_7: 0.0948 - val_loss: 0.0114 - val_acc: 0.9973 - val_categorical_accuracy: 0.1472 - val_f2_score: 0.3756 - val_f2_score_1: 0.3476 - val_f2_score_2: 0.3107 - val_f2_score_3: 0.2717 - val_f2_score_4: 0.2505 - val_f2_score_5: 0.2366 - val_f2_score_6: 0.1775 - val_f2_score_7: 0.1318
# Epoch 5/200
#  - 17s - loss: 0.0118 - acc: 0.9973 - categorical_accuracy: 0.1612 - f2_score: 0.3502 - f2_score_1: 0.3159 - f2_score_2: 0.2768 - f2_score_3: 0.2389 - f2_score_4: 0.2178 - f2_score_5: 0.2045 - f2_score_6: 0.1496 - f2_score_7: 0.1090 - val_loss: 0.0112 - val_acc: 0.9973 - val_categorical_accuracy: 0.1628 - val_f2_score: 0.3882 - val_f2_score_1: 0.3671 - val_f2_score_2: 0.3346 - val_f2_score_3: 0.2980 - val_f2_score_4: 0.2765 - val_f2_score_5: 0.2628 - val_f2_score_6: 0.1967 - val_f2_score_7: 0.1460
# Epoch 6/200
#  - 17s - loss: 0.0115 - acc: 0.9973 - categorical_accuracy: 0.1697 - f2_score: 0.3642 - f2_score_1: 0.3324 - f2_score_2: 0.2941 - f2_score_3: 0.2560 - f2_score_4: 0.2344 - f2_score_5: 0.2210 - f2_score_6: 0.1641 - f2_score_7: 0.1221 - val_loss: 0.0111 - val_acc: 0.9973 - val_categorical_accuracy: 0.1627 - val_f2_score: 0.3999 - val_f2_score_1: 0.3855 - val_f2_score_2: 0.3541 - val_f2_score_3: 0.3187 - val_f2_score_4: 0.2980 - val_f2_score_5: 0.2838 - val_f2_score_6: 0.2167 - val_f2_score_7: 0.1646
# Epoch 7/200
#  - 17s - loss: 0.0113 - acc: 0.9973 - categorical_accuracy: 0.1803 - f2_score: 0.3777 - f2_score_1: 0.3466 - f2_score_2: 0.3081 - f2_score_3: 0.2707 - f2_score_4: 0.2494 - f2_score_5: 0.2358 - f2_score_6: 0.1771 - f2_score_7: 0.1322 - val_loss: 0.0109 - val_acc: 0.9974 - val_categorical_accuracy: 0.1857 - val_f2_score: 0.4060 - val_f2_score_1: 0.3864 - val_f2_score_2: 0.3555 - val_f2_score_3: 0.3213 - val_f2_score_4: 0.2998 - val_f2_score_5: 0.2856 - val_f2_score_6: 0.2198 - val_f2_score_7: 0.1676
# Epoch 8/200
#  - 17s - loss: 0.0110 - acc: 0.9973 - categorical_accuracy: 0.1865 - f2_score: 0.3880 - f2_score_1: 0.3574 - f2_score_2: 0.3199 - f2_score_3: 0.2827 - f2_score_4: 0.2612 - f2_score_5: 0.2478 - f2_score_6: 0.1892 - f2_score_7: 0.1428 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1890 - val_f2_score: 0.4134 - val_f2_score_1: 0.3998 - val_f2_score_2: 0.3712 - val_f2_score_3: 0.3360 - val_f2_score_4: 0.3145 - val_f2_score_5: 0.3009 - val_f2_score_6: 0.2352 - val_f2_score_7: 0.1800
# Epoch 9/200
#  - 17s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.1960 - f2_score: 0.3969 - f2_score_1: 0.3679 - f2_score_2: 0.3316 - f2_score_3: 0.2936 - f2_score_4: 0.2719 - f2_score_5: 0.2586 - f2_score_6: 0.1982 - f2_score_7: 0.1507 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1822 - val_f2_score: 0.4188 - val_f2_score_1: 0.4042 - val_f2_score_2: 0.3762 - val_f2_score_3: 0.3436 - val_f2_score_4: 0.3230 - val_f2_score_5: 0.3101 - val_f2_score_6: 0.2473 - val_f2_score_7: 0.1949
# Epoch 10/200
#  - 17s - loss: 0.0107 - acc: 0.9974 - categorical_accuracy: 0.2032 - f2_score: 0.4058 - f2_score_1: 0.3778 - f2_score_2: 0.3418 - f2_score_3: 0.3050 - f2_score_4: 0.2832 - f2_score_5: 0.2693 - f2_score_6: 0.2080 - f2_score_7: 0.1601 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1882 - val_f2_score: 0.4192 - val_f2_score_1: 0.4123 - val_f2_score_2: 0.3872 - val_f2_score_3: 0.3558 - val_f2_score_4: 0.3352 - val_f2_score_5: 0.3225 - val_f2_score_6: 0.2569 - val_f2_score_7: 0.2008
# Epoch 11/200
#  - 17s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.2096 - f2_score: 0.4123 - f2_score_1: 0.3861 - f2_score_2: 0.3505 - f2_score_3: 0.3133 - f2_score_4: 0.2917 - f2_score_5: 0.2781 - f2_score_6: 0.2169 - f2_score_7: 0.1672 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.2065 - val_f2_score: 0.4267 - val_f2_score_1: 0.4164 - val_f2_score_2: 0.3922 - val_f2_score_3: 0.3607 - val_f2_score_4: 0.3393 - val_f2_score_5: 0.3252 - val_f2_score_6: 0.2596 - val_f2_score_7: 0.2042
# Epoch 12/200
#  - 17s - loss: 0.0104 - acc: 0.9974 - categorical_accuracy: 0.2148 - f2_score: 0.4205 - f2_score_1: 0.3942 - f2_score_2: 0.3587 - f2_score_3: 0.3229 - f2_score_4: 0.3014 - f2_score_5: 0.2876 - f2_score_6: 0.2242 - f2_score_7: 0.1750 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.1972 - val_f2_score: 0.4280 - val_f2_score_1: 0.4176 - val_f2_score_2: 0.3918 - val_f2_score_3: 0.3623 - val_f2_score_4: 0.3420 - val_f2_score_5: 0.3291 - val_f2_score_6: 0.2651 - val_f2_score_7: 0.2115
# Epoch 13/200
#  - 17s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.2222 - f2_score: 0.4267 - f2_score_1: 0.4009 - f2_score_2: 0.3663 - f2_score_3: 0.3301 - f2_score_4: 0.3092 - f2_score_5: 0.2955 - f2_score_6: 0.2336 - f2_score_7: 0.1829 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.2069 - val_f2_score: 0.4336 - val_f2_score_1: 0.4273 - val_f2_score_2: 0.4040 - val_f2_score_3: 0.3747 - val_f2_score_4: 0.3552 - val_f2_score_5: 0.3424 - val_f2_score_6: 0.2761 - val_f2_score_7: 0.2215
# Epoch 14/200
#  - 17s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2285 - f2_score: 0.4329 - f2_score_1: 0.4081 - f2_score_2: 0.3743 - f2_score_3: 0.3383 - f2_score_4: 0.3170 - f2_score_5: 0.3033 - f2_score_6: 0.2412 - f2_score_7: 0.1904 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.2140 - val_f2_score: 0.4337 - val_f2_score_1: 0.4306 - val_f2_score_2: 0.4095 - val_f2_score_3: 0.3837 - val_f2_score_4: 0.3667 - val_f2_score_5: 0.3546 - val_f2_score_6: 0.2899 - val_f2_score_7: 0.2329
# Epoch 15/200
#  - 17s - loss: 0.0100 - acc: 0.9974 - categorical_accuracy: 0.2357 - f2_score: 0.4393 - f2_score_1: 0.4156 - f2_score_2: 0.3815 - f2_score_3: 0.3455 - f2_score_4: 0.3247 - f2_score_5: 0.3108 - f2_score_6: 0.2486 - f2_score_7: 0.1969 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2241 - val_f2_score: 0.4370 - val_f2_score_1: 0.4317 - val_f2_score_2: 0.4104 - val_f2_score_3: 0.3837 - val_f2_score_4: 0.3659 - val_f2_score_5: 0.3529 - val_f2_score_6: 0.2890 - val_f2_score_7: 0.2315
# Epoch 16/200
#  - 17s - loss: 0.0099 - acc: 0.9974 - categorical_accuracy: 0.2402 - f2_score: 0.4439 - f2_score_1: 0.4205 - f2_score_2: 0.3870 - f2_score_3: 0.3523 - f2_score_4: 0.3314 - f2_score_5: 0.3178 - f2_score_6: 0.2548 - f2_score_7: 0.2023 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2138 - val_f2_score: 0.4385 - val_f2_score_1: 0.4347 - val_f2_score_2: 0.4159 - val_f2_score_3: 0.3898 - val_f2_score_4: 0.3718 - val_f2_score_5: 0.3599 - val_f2_score_6: 0.2997 - val_f2_score_7: 0.2434
# Epoch 17/200
#  - 17s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2467 - f2_score: 0.4498 - f2_score_1: 0.4271 - f2_score_2: 0.3946 - f2_score_3: 0.3593 - f2_score_4: 0.3387 - f2_score_5: 0.3252 - f2_score_6: 0.2633 - f2_score_7: 0.2101 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2171 - val_f2_score: 0.4420 - val_f2_score_1: 0.4384 - val_f2_score_2: 0.4195 - val_f2_score_3: 0.3947 - val_f2_score_4: 0.3783 - val_f2_score_5: 0.3666 - val_f2_score_6: 0.3081 - val_f2_score_7: 0.2510
# Epoch 18/200
#  - 17s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2522 - f2_score: 0.4547 - f2_score_1: 0.4327 - f2_score_2: 0.4008 - f2_score_3: 0.3672 - f2_score_4: 0.3466 - f2_score_5: 0.3332 - f2_score_6: 0.2698 - f2_score_7: 0.2166 - val_loss: 0.0103 - val_acc: 0.9975 - val_categorical_accuracy: 0.2266 - val_f2_score: 0.4445 - val_f2_score_1: 0.4410 - val_f2_score_2: 0.4223 - val_f2_score_3: 0.3968 - val_f2_score_4: 0.3801 - val_f2_score_5: 0.3690 - val_f2_score_6: 0.3078 - val_f2_score_7: 0.2532
# Epoch 19/200
#  - 17s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2575 - f2_score: 0.4617 - f2_score_1: 0.4391 - f2_score_2: 0.4068 - f2_score_3: 0.3719 - f2_score_4: 0.3516 - f2_score_5: 0.3380 - f2_score_6: 0.2759 - f2_score_7: 0.2225 - val_loss: 0.0103 - val_acc: 0.9975 - val_categorical_accuracy: 0.2263 - val_f2_score: 0.4448 - val_f2_score_1: 0.4434 - val_f2_score_2: 0.4240 - val_f2_score_3: 0.3976 - val_f2_score_4: 0.3815 - val_f2_score_5: 0.3697 - val_f2_score_6: 0.3079 - val_f2_score_7: 0.2530
# Epoch 20/200
#  - 17s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2635 - f2_score: 0.4662 - f2_score_1: 0.4442 - f2_score_2: 0.4125 - f2_score_3: 0.3786 - f2_score_4: 0.3584 - f2_score_5: 0.3452 - f2_score_6: 0.2831 - f2_score_7: 0.2291 - val_loss: 0.0103 - val_acc: 0.9975 - val_categorical_accuracy: 0.2287 - val_f2_score: 0.4475 - val_f2_score_1: 0.4464 - val_f2_score_2: 0.4288 - val_f2_score_3: 0.4043 - val_f2_score_4: 0.3875 - val_f2_score_5: 0.3760 - val_f2_score_6: 0.3194 - val_f2_score_7: 0.2629
# Epoch 21/200
#  - 17s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2675 - f2_score: 0.4704 - f2_score_1: 0.4495 - f2_score_2: 0.4195 - f2_score_3: 0.3862 - f2_score_4: 0.3662 - f2_score_5: 0.3531 - f2_score_6: 0.2898 - f2_score_7: 0.2351 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2417 - val_f2_score: 0.4478 - val_f2_score_1: 0.4418 - val_f2_score_2: 0.4205 - val_f2_score_3: 0.3949 - val_f2_score_4: 0.3774 - val_f2_score_5: 0.3651 - val_f2_score_6: 0.3080 - val_f2_score_7: 0.2552
# Epoch 22/200
#  - 17s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2730 - f2_score: 0.4756 - f2_score_1: 0.4551 - f2_score_2: 0.4247 - f2_score_3: 0.3918 - f2_score_4: 0.3720 - f2_score_5: 0.3584 - f2_score_6: 0.2958 - f2_score_7: 0.2414 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2184 - val_f2_score: 0.4495 - val_f2_score_1: 0.4470 - val_f2_score_2: 0.4289 - val_f2_score_3: 0.4051 - val_f2_score_4: 0.3894 - val_f2_score_5: 0.3804 - val_f2_score_6: 0.3256 - val_f2_score_7: 0.2704
# Epoch 23/200
#  - 17s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2785 - f2_score: 0.4800 - f2_score_1: 0.4601 - f2_score_2: 0.4302 - f2_score_3: 0.3975 - f2_score_4: 0.3778 - f2_score_5: 0.3648 - f2_score_6: 0.3028 - f2_score_7: 0.2477 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2461 - val_f2_score: 0.4512 - val_f2_score_1: 0.4481 - val_f2_score_2: 0.4296 - val_f2_score_3: 0.4050 - val_f2_score_4: 0.3891 - val_f2_score_5: 0.3785 - val_f2_score_6: 0.3207 - val_f2_score_7: 0.2664
# Epoch 24/200
#  - 17s - loss: 0.0092 - acc: 0.9976 - categorical_accuracy: 0.2827 - f2_score: 0.4847 - f2_score_1: 0.4649 - f2_score_2: 0.4353 - f2_score_3: 0.4025 - f2_score_4: 0.3833 - f2_score_5: 0.3703 - f2_score_6: 0.3088 - f2_score_7: 0.2540 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2357 - val_f2_score: 0.4522 - val_f2_score_1: 0.4491 - val_f2_score_2: 0.4313 - val_f2_score_3: 0.4074 - val_f2_score_4: 0.3904 - val_f2_score_5: 0.3798 - val_f2_score_6: 0.3201 - val_f2_score_7: 0.2658
# Epoch 25/200
#  - 17s - loss: 0.0091 - acc: 0.9976 - categorical_accuracy: 0.2839 - f2_score: 0.4891 - f2_score_1: 0.4698 - f2_score_2: 0.4402 - f2_score_3: 0.4076 - f2_score_4: 0.3883 - f2_score_5: 0.3754 - f2_score_6: 0.3147 - f2_score_7: 0.2594 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2435 - val_f2_score: 0.4529 - val_f2_score_1: 0.4536 - val_f2_score_2: 0.4377 - val_f2_score_3: 0.4147 - val_f2_score_4: 0.3993 - val_f2_score_5: 0.3892 - val_f2_score_6: 0.3342 - val_f2_score_7: 0.2816
# Epoch 26/200
#  - 17s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.2903 - f2_score: 0.4936 - f2_score_1: 0.4743 - f2_score_2: 0.4455 - f2_score_3: 0.4140 - f2_score_4: 0.3949 - f2_score_5: 0.3821 - f2_score_6: 0.3209 - f2_score_7: 0.2652 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2426 - val_f2_score: 0.4550 - val_f2_score_1: 0.4534 - val_f2_score_2: 0.4362 - val_f2_score_3: 0.4127 - val_f2_score_4: 0.3972 - val_f2_score_5: 0.3863 - val_f2_score_6: 0.3291 - val_f2_score_7: 0.2768
# Epoch 27/200
#  - 17s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.2964 - f2_score: 0.4978 - f2_score_1: 0.4804 - f2_score_2: 0.4521 - f2_score_3: 0.4200 - f2_score_4: 0.4009 - f2_score_5: 0.3881 - f2_score_6: 0.3261 - f2_score_7: 0.2707 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2457 - val_f2_score: 0.4551 - val_f2_score_1: 0.4542 - val_f2_score_2: 0.4385 - val_f2_score_3: 0.4164 - val_f2_score_4: 0.4016 - val_f2_score_5: 0.3916 - val_f2_score_6: 0.3373 - val_f2_score_7: 0.2851
# Epoch 28/200
#  - 17s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.3003 - f2_score: 0.5019 - f2_score_1: 0.4847 - f2_score_2: 0.4562 - f2_score_3: 0.4252 - f2_score_4: 0.4059 - f2_score_5: 0.3934 - f2_score_6: 0.3319 - f2_score_7: 0.2768 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2484 - val_f2_score: 0.4558 - val_f2_score_1: 0.4573 - val_f2_score_2: 0.4424 - val_f2_score_3: 0.4201 - val_f2_score_4: 0.4057 - val_f2_score_5: 0.3955 - val_f2_score_6: 0.3437 - val_f2_score_7: 0.2905
# Epoch 00028: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
print('Best f2 score is: %.2f' % best_thr_val)
# Out:
# Best threshold is: 0.15
# Best f2 score is: 0.46

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_base.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                                      attribute_ids
# 0  10023b2cc4ed5f68                                       587 766 1059
# 1  100fbe75ed8fd887                              121 188 231 1039 1085
# 2  101b627524a04f19                         79 121 304 482 498 718 813
# 3  10234480c41284c6         13 51 111 147 480 483 501 738 776 813 1046
# 4  1023b0e2636dcea8  29 147 156 189 227 283 322 383 584 612 671 813...
# 5   1039cd6cf85845c                                13 405 896 903 1092
# 6   103a5b3f83fbe88                                       194 813 1092
# 7  10413aaae8d6a9a2                               51 147 813 1046 1092
# 8  10423822b93a65ab                       147 189 552 671 780 950 1034
# 9  1052bf702cb099f7                                        188 597 671
