# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 5
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 18s - loss: 0.0206 - acc: 0.9945 - categorical_accuracy: 0.0901 - f2_score: 0.2118 - f2_score_1: 0.1810 - f2_score_2: 0.1518 - f2_score_3: 0.1266 - f2_score_4: 0.1136 - f2_score_5: 0.1057 - f2_score_6: 0.0725 - f2_score_7: 0.0485 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1473 - val_f2_score: 0.3079 - val_f2_score_1: 0.2492 - val_f2_score_2: 0.1985 - val_f2_score_3: 0.1571 - val_f2_score_4: 0.1359 - val_f2_score_5: 0.1238 - val_f2_score_6: 0.0783 - val_f2_score_7: 0.0502
# Epoch 2/200
#  - 16s - loss: 0.0125 - acc: 0.9972 - categorical_accuracy: 0.1402 - f2_score: 0.3170 - f2_score_1: 0.2808 - f2_score_2: 0.2421 - f2_score_3: 0.2072 - f2_score_4: 0.1879 - f2_score_5: 0.1760 - f2_score_6: 0.1263 - f2_score_7: 0.0893 - val_loss: 0.0117 - val_acc: 0.9973 - val_categorical_accuracy: 0.1273 - val_f2_score: 0.3432 - val_f2_score_1: 0.2925 - val_f2_score_2: 0.2470 - val_f2_score_3: 0.2067 - val_f2_score_4: 0.1844 - val_f2_score_5: 0.1725 - val_f2_score_6: 0.1215 - val_f2_score_7: 0.0844
# Epoch 3/200
#  - 16s - loss: 0.0117 - acc: 0.9973 - categorical_accuracy: 0.1574 - f2_score: 0.3542 - f2_score_1: 0.3204 - f2_score_2: 0.2813 - f2_score_3: 0.2445 - f2_score_4: 0.2244 - f2_score_5: 0.2112 - f2_score_6: 0.1564 - f2_score_7: 0.1141 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1406 - val_f2_score: 0.3700 - val_f2_score_1: 0.3270 - val_f2_score_2: 0.2837 - val_f2_score_3: 0.2434 - val_f2_score_4: 0.2222 - val_f2_score_5: 0.2083 - val_f2_score_6: 0.1530 - val_f2_score_7: 0.1114
# Epoch 4/200
#  - 16s - loss: 0.0112 - acc: 0.9973 - categorical_accuracy: 0.1696 - f2_score: 0.3777 - f2_score_1: 0.3450 - f2_score_2: 0.3070 - f2_score_3: 0.2700 - f2_score_4: 0.2493 - f2_score_5: 0.2361 - f2_score_6: 0.1779 - f2_score_7: 0.1326 - val_loss: 0.0110 - val_acc: 0.9973 - val_categorical_accuracy: 0.1719 - val_f2_score: 0.3842 - val_f2_score_1: 0.3440 - val_f2_score_2: 0.2995 - val_f2_score_3: 0.2594 - val_f2_score_4: 0.2373 - val_f2_score_5: 0.2233 - val_f2_score_6: 0.1653 - val_f2_score_7: 0.1225
# Epoch 5/200
#  - 16s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.1795 - f2_score: 0.3958 - f2_score_1: 0.3653 - f2_score_2: 0.3275 - f2_score_3: 0.2904 - f2_score_4: 0.2694 - f2_score_5: 0.2562 - f2_score_6: 0.1971 - f2_score_7: 0.1489 - val_loss: 0.0108 - val_acc: 0.9974 - val_categorical_accuracy: 0.1688 - val_f2_score: 0.3986 - val_f2_score_1: 0.3647 - val_f2_score_2: 0.3272 - val_f2_score_3: 0.2904 - val_f2_score_4: 0.2699 - val_f2_score_5: 0.2563 - val_f2_score_6: 0.1952 - val_f2_score_7: 0.1461
# Epoch 6/200
#  - 16s - loss: 0.0106 - acc: 0.9974 - categorical_accuracy: 0.1879 - f2_score: 0.4104 - f2_score_1: 0.3811 - f2_score_2: 0.3440 - f2_score_3: 0.3077 - f2_score_4: 0.2863 - f2_score_5: 0.2730 - f2_score_6: 0.2117 - f2_score_7: 0.1621 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1677 - val_f2_score: 0.4115 - val_f2_score_1: 0.3789 - val_f2_score_2: 0.3423 - val_f2_score_3: 0.3059 - val_f2_score_4: 0.2843 - val_f2_score_5: 0.2700 - val_f2_score_6: 0.2095 - val_f2_score_7: 0.1591
# Epoch 7/200
#  - 16s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.1970 - f2_score: 0.4229 - f2_score_1: 0.3953 - f2_score_2: 0.3590 - f2_score_3: 0.3220 - f2_score_4: 0.3009 - f2_score_5: 0.2869 - f2_score_6: 0.2252 - f2_score_7: 0.1736 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.1919 - val_f2_score: 0.4136 - val_f2_score_1: 0.3818 - val_f2_score_2: 0.3424 - val_f2_score_3: 0.3044 - val_f2_score_4: 0.2831 - val_f2_score_5: 0.2700 - val_f2_score_6: 0.2046 - val_f2_score_7: 0.1542
# Epoch 8/200
#  - 16s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2055 - f2_score: 0.4347 - f2_score_1: 0.4084 - f2_score_2: 0.3723 - f2_score_3: 0.3363 - f2_score_4: 0.3153 - f2_score_5: 0.3014 - f2_score_6: 0.2377 - f2_score_7: 0.1850 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.1873 - val_f2_score: 0.4137 - val_f2_score_1: 0.3782 - val_f2_score_2: 0.3382 - val_f2_score_3: 0.2995 - val_f2_score_4: 0.2786 - val_f2_score_5: 0.2655 - val_f2_score_6: 0.2054 - val_f2_score_7: 0.1604
# Epoch 9/200
#  - 16s - loss: 0.0099 - acc: 0.9974 - categorical_accuracy: 0.2126 - f2_score: 0.4456 - f2_score_1: 0.4198 - f2_score_2: 0.3846 - f2_score_3: 0.3493 - f2_score_4: 0.3276 - f2_score_5: 0.3140 - f2_score_6: 0.2502 - f2_score_7: 0.1968 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.1949 - val_f2_score: 0.4209 - val_f2_score_1: 0.3871 - val_f2_score_2: 0.3490 - val_f2_score_3: 0.3116 - val_f2_score_4: 0.2918 - val_f2_score_5: 0.2792 - val_f2_score_6: 0.2196 - val_f2_score_7: 0.1716
# Epoch 10/200
#  - 16s - loss: 0.0097 - acc: 0.9975 - categorical_accuracy: 0.2195 - f2_score: 0.4560 - f2_score_1: 0.4307 - f2_score_2: 0.3971 - f2_score_3: 0.3602 - f2_score_4: 0.3390 - f2_score_5: 0.3255 - f2_score_6: 0.2618 - f2_score_7: 0.2071 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.1973 - val_f2_score: 0.4264 - val_f2_score_1: 0.3962 - val_f2_score_2: 0.3607 - val_f2_score_3: 0.3238 - val_f2_score_4: 0.3036 - val_f2_score_5: 0.2906 - val_f2_score_6: 0.2320 - val_f2_score_7: 0.1821
# Epoch 11/200
#  - 16s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2289 - f2_score: 0.4639 - f2_score_1: 0.4406 - f2_score_2: 0.4077 - f2_score_3: 0.3726 - f2_score_4: 0.3517 - f2_score_5: 0.3376 - f2_score_6: 0.2722 - f2_score_7: 0.2157 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2054 - val_f2_score: 0.4280 - val_f2_score_1: 0.3986 - val_f2_score_2: 0.3636 - val_f2_score_3: 0.3280 - val_f2_score_4: 0.3072 - val_f2_score_5: 0.2938 - val_f2_score_6: 0.2298 - val_f2_score_7: 0.1795
# Epoch 12/200
#  - 16s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2351 - f2_score: 0.4736 - f2_score_1: 0.4507 - f2_score_2: 0.4174 - f2_score_3: 0.3820 - f2_score_4: 0.3611 - f2_score_5: 0.3471 - f2_score_6: 0.2828 - f2_score_7: 0.2265 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2113 - val_f2_score: 0.4318 - val_f2_score_1: 0.4028 - val_f2_score_2: 0.3660 - val_f2_score_3: 0.3301 - val_f2_score_4: 0.3102 - val_f2_score_5: 0.2973 - val_f2_score_6: 0.2375 - val_f2_score_7: 0.1896
# Epoch 13/200
#  - 16s - loss: 0.0091 - acc: 0.9975 - categorical_accuracy: 0.2410 - f2_score: 0.4816 - f2_score_1: 0.4599 - f2_score_2: 0.4272 - f2_score_3: 0.3924 - f2_score_4: 0.3715 - f2_score_5: 0.3575 - f2_score_6: 0.2935 - f2_score_7: 0.2361 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2009 - val_f2_score: 0.4353 - val_f2_score_1: 0.4081 - val_f2_score_2: 0.3759 - val_f2_score_3: 0.3424 - val_f2_score_4: 0.3221 - val_f2_score_5: 0.3093 - val_f2_score_6: 0.2492 - val_f2_score_7: 0.1986
# Epoch 14/200
#  - 16s - loss: 0.0090 - acc: 0.9976 - categorical_accuracy: 0.2485 - f2_score: 0.4907 - f2_score_1: 0.4701 - f2_score_2: 0.4377 - f2_score_3: 0.4030 - f2_score_4: 0.3823 - f2_score_5: 0.3686 - f2_score_6: 0.3044 - f2_score_7: 0.2468 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2204 - val_f2_score: 0.4375 - val_f2_score_1: 0.4068 - val_f2_score_2: 0.3725 - val_f2_score_3: 0.3365 - val_f2_score_4: 0.3149 - val_f2_score_5: 0.3011 - val_f2_score_6: 0.2440 - val_f2_score_7: 0.1942
# Epoch 15/200
#  - 16s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.2552 - f2_score: 0.4988 - f2_score_1: 0.4785 - f2_score_2: 0.4475 - f2_score_3: 0.4128 - f2_score_4: 0.3918 - f2_score_5: 0.3780 - f2_score_6: 0.3128 - f2_score_7: 0.2555 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2200 - val_f2_score: 0.4414 - val_f2_score_1: 0.4142 - val_f2_score_2: 0.3804 - val_f2_score_3: 0.3458 - val_f2_score_4: 0.3253 - val_f2_score_5: 0.3121 - val_f2_score_6: 0.2524 - val_f2_score_7: 0.2033
# Epoch 16/200
#  - 16s - loss: 0.0087 - acc: 0.9976 - categorical_accuracy: 0.2630 - f2_score: 0.5067 - f2_score_1: 0.4884 - f2_score_2: 0.4575 - f2_score_3: 0.4236 - f2_score_4: 0.4030 - f2_score_5: 0.3890 - f2_score_6: 0.3232 - f2_score_7: 0.2644 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2338 - val_f2_score: 0.4431 - val_f2_score_1: 0.4150 - val_f2_score_2: 0.3802 - val_f2_score_3: 0.3464 - val_f2_score_4: 0.3274 - val_f2_score_5: 0.3144 - val_f2_score_6: 0.2569 - val_f2_score_7: 0.2085
# Epoch 17/200
#  - 16s - loss: 0.0085 - acc: 0.9976 - categorical_accuracy: 0.2689 - f2_score: 0.5143 - f2_score_1: 0.4962 - f2_score_2: 0.4663 - f2_score_3: 0.4322 - f2_score_4: 0.4121 - f2_score_5: 0.3983 - f2_score_6: 0.3333 - f2_score_7: 0.2740 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2226 - val_f2_score: 0.4447 - val_f2_score_1: 0.4188 - val_f2_score_2: 0.3864 - val_f2_score_3: 0.3526 - val_f2_score_4: 0.3330 - val_f2_score_5: 0.3208 - val_f2_score_6: 0.2623 - val_f2_score_7: 0.2114
# Epoch 18/200
#  - 16s - loss: 0.0084 - acc: 0.9976 - categorical_accuracy: 0.2737 - f2_score: 0.5231 - f2_score_1: 0.5048 - f2_score_2: 0.4756 - f2_score_3: 0.4422 - f2_score_4: 0.4220 - f2_score_5: 0.4085 - f2_score_6: 0.3432 - f2_score_7: 0.2834 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2253 - val_f2_score: 0.4464 - val_f2_score_1: 0.4205 - val_f2_score_2: 0.3893 - val_f2_score_3: 0.3562 - val_f2_score_4: 0.3385 - val_f2_score_5: 0.3263 - val_f2_score_6: 0.2677 - val_f2_score_7: 0.2185
# Epoch 19/200
#  - 16s - loss: 0.0083 - acc: 0.9977 - categorical_accuracy: 0.2786 - f2_score: 0.5315 - f2_score_1: 0.5140 - f2_score_2: 0.4835 - f2_score_3: 0.4500 - f2_score_4: 0.4297 - f2_score_5: 0.4166 - f2_score_6: 0.3505 - f2_score_7: 0.2913 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2261 - val_f2_score: 0.4472 - val_f2_score_1: 0.4210 - val_f2_score_2: 0.3910 - val_f2_score_3: 0.3602 - val_f2_score_4: 0.3418 - val_f2_score_5: 0.3304 - val_f2_score_6: 0.2749 - val_f2_score_7: 0.2247
# Epoch 20/200
#  - 16s - loss: 0.0081 - acc: 0.9977 - categorical_accuracy: 0.2842 - f2_score: 0.5377 - f2_score_1: 0.5211 - f2_score_2: 0.4920 - f2_score_3: 0.4594 - f2_score_4: 0.4386 - f2_score_5: 0.4252 - f2_score_6: 0.3603 - f2_score_7: 0.2997 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2302 - val_f2_score: 0.4481 - val_f2_score_1: 0.4207 - val_f2_score_2: 0.3896 - val_f2_score_3: 0.3570 - val_f2_score_4: 0.3383 - val_f2_score_5: 0.3258 - val_f2_score_6: 0.2693 - val_f2_score_7: 0.2217
# Epoch 21/200
#  - 16s - loss: 0.0080 - acc: 0.9977 - categorical_accuracy: 0.2909 - f2_score: 0.5456 - f2_score_1: 0.5294 - f2_score_2: 0.5007 - f2_score_3: 0.4688 - f2_score_4: 0.4492 - f2_score_5: 0.4361 - f2_score_6: 0.3708 - f2_score_7: 0.3100 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2399 - val_f2_score: 0.4502 - val_f2_score_1: 0.4223 - val_f2_score_2: 0.3932 - val_f2_score_3: 0.3613 - val_f2_score_4: 0.3430 - val_f2_score_5: 0.3316 - val_f2_score_6: 0.2762 - val_f2_score_7: 0.2273
# Epoch 22/200
#  - 16s - loss: 0.0079 - acc: 0.9977 - categorical_accuracy: 0.2949 - f2_score: 0.5524 - f2_score_1: 0.5377 - f2_score_2: 0.5097 - f2_score_3: 0.4772 - f2_score_4: 0.4575 - f2_score_5: 0.4442 - f2_score_6: 0.3795 - f2_score_7: 0.3182 - val_loss: 0.0100 - val_acc: 0.9975 - val_categorical_accuracy: 0.2359 - val_f2_score: 0.4520 - val_f2_score_1: 0.4239 - val_f2_score_2: 0.3936 - val_f2_score_3: 0.3615 - val_f2_score_4: 0.3426 - val_f2_score_5: 0.3310 - val_f2_score_6: 0.2758 - val_f2_score_7: 0.2279
# Epoch 23/200
#  - 16s - loss: 0.0077 - acc: 0.9977 - categorical_accuracy: 0.3000 - f2_score: 0.5601 - f2_score_1: 0.5453 - f2_score_2: 0.5180 - f2_score_3: 0.4866 - f2_score_4: 0.4670 - f2_score_5: 0.4538 - f2_score_6: 0.3882 - f2_score_7: 0.3269 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2341 - val_f2_score: 0.4473 - val_f2_score_1: 0.4201 - val_f2_score_2: 0.3901 - val_f2_score_3: 0.3596 - val_f2_score_4: 0.3423 - val_f2_score_5: 0.3310 - val_f2_score_6: 0.2761 - val_f2_score_7: 0.2296
# Epoch 24/200
#  - 16s - loss: 0.0076 - acc: 0.9978 - categorical_accuracy: 0.3045 - f2_score: 0.5681 - f2_score_1: 0.5538 - f2_score_2: 0.5272 - f2_score_3: 0.4960 - f2_score_4: 0.4764 - f2_score_5: 0.4634 - f2_score_6: 0.3990 - f2_score_7: 0.3366 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2370 - val_f2_score: 0.4496 - val_f2_score_1: 0.4249 - val_f2_score_2: 0.3941 - val_f2_score_3: 0.3643 - val_f2_score_4: 0.3474 - val_f2_score_5: 0.3359 - val_f2_score_6: 0.2811 - val_f2_score_7: 0.2329
# Epoch 25/200
#  - 17s - loss: 0.0075 - acc: 0.9978 - categorical_accuracy: 0.3101 - f2_score: 0.5740 - f2_score_1: 0.5612 - f2_score_2: 0.5343 - f2_score_3: 0.5033 - f2_score_4: 0.4843 - f2_score_5: 0.4718 - f2_score_6: 0.4069 - f2_score_7: 0.3447 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2434 - val_f2_score: 0.4481 - val_f2_score_1: 0.4198 - val_f2_score_2: 0.3870 - val_f2_score_3: 0.3558 - val_f2_score_4: 0.3377 - val_f2_score_5: 0.3270 - val_f2_score_6: 0.2735 - val_f2_score_7: 0.2279
# Epoch 26/200
#  - 16s - loss: 0.0074 - acc: 0.9978 - categorical_accuracy: 0.3160 - f2_score: 0.5815 - f2_score_1: 0.5687 - f2_score_2: 0.5430 - f2_score_3: 0.5124 - f2_score_4: 0.4935 - f2_score_5: 0.4806 - f2_score_6: 0.4151 - f2_score_7: 0.3530 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2477 - val_f2_score: 0.4498 - val_f2_score_1: 0.4210 - val_f2_score_2: 0.3891 - val_f2_score_3: 0.3584 - val_f2_score_4: 0.3403 - val_f2_score_5: 0.3292 - val_f2_score_6: 0.2747 - val_f2_score_7: 0.2299
# Epoch 27/200
#  - 16s - loss: 0.0072 - acc: 0.9978 - categorical_accuracy: 0.3212 - f2_score: 0.5881 - f2_score_1: 0.5766 - f2_score_2: 0.5517 - f2_score_3: 0.5209 - f2_score_4: 0.5019 - f2_score_5: 0.4887 - f2_score_6: 0.4244 - f2_score_7: 0.3614 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2407 - val_f2_score: 0.4512 - val_f2_score_1: 0.4262 - val_f2_score_2: 0.3971 - val_f2_score_3: 0.3675 - val_f2_score_4: 0.3491 - val_f2_score_5: 0.3375 - val_f2_score_6: 0.2865 - val_f2_score_7: 0.2396
# Epoch 00027: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.1

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                                 attribute_ids
# 0  10023b2cc4ed5f68                      121 343 369 477 766 1059
# 1  100fbe75ed8fd887                                 121 1039 1059
# 2  101b627524a04f19                            79 482 497 498 961
# 3  10234480c41284c6                13 51 483 725 738 776 830 1046
# 4  1023b0e2636dcea8  147 156 189 283 322 420 584 813 835 954 1092
# 5   1039cd6cf85845c                           13 405 896 903 1092
# 6   103a5b3f83fbe88                      51 194 744 813 1046 1092
# 7  10413aaae8d6a9a2                          51 147 813 1046 1092
# 8  10423822b93a65ab                                   51 147 1046
# 9  1052bf702cb099f7                       147 188 597 671 723 780
