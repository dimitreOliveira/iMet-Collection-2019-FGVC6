# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 10s - loss: 0.0257 - acc: 0.9936 - categorical_accuracy: 0.0339 - f2_score: 0.0834 - f2_score_1: 0.0611 - f2_score_2: 0.0445 - f2_score_3: 0.0326 - f2_score_4: 0.0170 - f2_score_5: 0.0090 - val_loss: 0.0150 - val_acc: 0.9971 - val_categorical_accuracy: 0.0149 - val_f2_score: 0.0698 - val_f2_score_1: 0.0342 - val_f2_score_2: 0.0107 - val_f2_score_3: 4.2481e-04 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 9s - loss: 0.0164 - acc: 0.9971 - categorical_accuracy: 0.0466 - f2_score: 0.1092 - f2_score_1: 0.0716 - f2_score_2: 0.0443 - f2_score_3: 0.0252 - f2_score_4: 0.0069 - f2_score_5: 0.0013 - val_loss: 0.0145 - val_acc: 0.9971 - val_categorical_accuracy: 0.0274 - val_f2_score: 0.1009 - val_f2_score_1: 0.0594 - val_f2_score_2: 0.0385 - val_f2_score_3: 0.0230 - val_f2_score_4: 0.0011 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 9s - loss: 0.0157 - acc: 0.9971 - categorical_accuracy: 0.0553 - f2_score: 0.1235 - f2_score_1: 0.0817 - f2_score_2: 0.0507 - f2_score_3: 0.0294 - f2_score_4: 0.0074 - f2_score_5: 0.0013 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0384 - val_f2_score: 0.1202 - val_f2_score_1: 0.0765 - val_f2_score_2: 0.0503 - val_f2_score_3: 0.0317 - val_f2_score_4: 0.0045 - val_f2_score_5: 4.7248e-05
# Epoch 4/200
#  - 9s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0648 - f2_score: 0.1352 - f2_score_1: 0.0918 - f2_score_2: 0.0595 - f2_score_3: 0.0357 - f2_score_4: 0.0103 - f2_score_5: 0.0019 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0510 - val_f2_score: 0.1306 - val_f2_score_1: 0.0861 - val_f2_score_2: 0.0568 - val_f2_score_3: 0.0360 - val_f2_score_4: 0.0080 - val_f2_score_5: 2.8727e-04
# Epoch 5/200
#  - 9s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0724 - f2_score: 0.1448 - f2_score_1: 0.1001 - f2_score_2: 0.0670 - f2_score_3: 0.0429 - f2_score_4: 0.0142 - f2_score_5: 0.0034 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0565 - val_f2_score: 0.1410 - val_f2_score_1: 0.0964 - val_f2_score_2: 0.0668 - val_f2_score_3: 0.0460 - val_f2_score_4: 0.0143 - val_f2_score_5: 0.0014
# Epoch 6/200
#  - 9s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0790 - f2_score: 0.1535 - f2_score_1: 0.1083 - f2_score_2: 0.0741 - f2_score_3: 0.0490 - f2_score_4: 0.0181 - f2_score_5: 0.0050 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0595 - val_f2_score: 0.1488 - val_f2_score_1: 0.1046 - val_f2_score_2: 0.0754 - val_f2_score_3: 0.0536 - val_f2_score_4: 0.0204 - val_f2_score_5: 0.0029
# Epoch 7/200
#  - 9s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0838 - f2_score: 0.1605 - f2_score_1: 0.1150 - f2_score_2: 0.0801 - f2_score_3: 0.0544 - f2_score_4: 0.0219 - f2_score_5: 0.0071 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0844 - val_f2_score: 0.1525 - val_f2_score_1: 0.1038 - val_f2_score_2: 0.0702 - val_f2_score_3: 0.0468 - val_f2_score_4: 0.0152 - val_f2_score_5: 0.0027
# Epoch 8/200
#  - 9s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0875 - f2_score: 0.1677 - f2_score_1: 0.1214 - f2_score_2: 0.0864 - f2_score_3: 0.0598 - f2_score_4: 0.0257 - f2_score_5: 0.0091 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0844 - val_f2_score: 0.1536 - val_f2_score_1: 0.1046 - val_f2_score_2: 0.0707 - val_f2_score_3: 0.0470 - val_f2_score_4: 0.0160 - val_f2_score_5: 0.0032
# Epoch 9/200
#  - 9s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0904 - f2_score: 0.1747 - f2_score_1: 0.1273 - f2_score_2: 0.0915 - f2_score_3: 0.0643 - f2_score_4: 0.0287 - f2_score_5: 0.0112 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0966 - val_f2_score: 0.1605 - val_f2_score_1: 0.1117 - val_f2_score_2: 0.0771 - val_f2_score_3: 0.0531 - val_f2_score_4: 0.0216 - val_f2_score_5: 0.0064
# Epoch 10/200
#  - 9s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0914 - f2_score: 0.1778 - f2_score_1: 0.1308 - f2_score_2: 0.0947 - f2_score_3: 0.0668 - f2_score_4: 0.0309 - f2_score_5: 0.0127 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0893 - val_f2_score: 0.1698 - val_f2_score_1: 0.1221 - val_f2_score_2: 0.0870 - val_f2_score_3: 0.0623 - val_f2_score_4: 0.0270 - val_f2_score_5: 0.0082
# Epoch 11/200
#  - 9s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0942 - f2_score: 0.1814 - f2_score_1: 0.1345 - f2_score_2: 0.0976 - f2_score_3: 0.0695 - f2_score_4: 0.0327 - f2_score_5: 0.0135 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0868 - val_f2_score: 0.1755 - val_f2_score_1: 0.1252 - val_f2_score_2: 0.0891 - val_f2_score_3: 0.0634 - val_f2_score_4: 0.0279 - val_f2_score_5: 0.0088
# Epoch 12/200
#  - 9s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0961 - f2_score: 0.1840 - f2_score_1: 0.1370 - f2_score_2: 0.0998 - f2_score_3: 0.0715 - f2_score_4: 0.0347 - f2_score_5: 0.0150 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0915 - val_f2_score: 0.1738 - val_f2_score_1: 0.1250 - val_f2_score_2: 0.0889 - val_f2_score_3: 0.0642 - val_f2_score_4: 0.0293 - val_f2_score_5: 0.0099
# Epoch 13/200
#  - 9s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0961 - f2_score: 0.1871 - f2_score_1: 0.1397 - f2_score_2: 0.1024 - f2_score_3: 0.0737 - f2_score_4: 0.0357 - f2_score_5: 0.0154 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0882 - val_f2_score: 0.1813 - val_f2_score_1: 0.1332 - val_f2_score_2: 0.0958 - val_f2_score_3: 0.0699 - val_f2_score_4: 0.0330 - val_f2_score_5: 0.0117
# Epoch 14/200
#  - 9s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0980 - f2_score: 0.1889 - f2_score_1: 0.1416 - f2_score_2: 0.1043 - f2_score_3: 0.0761 - f2_score_4: 0.0374 - f2_score_5: 0.0164 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0972 - val_f2_score: 0.1801 - val_f2_score_1: 0.1294 - val_f2_score_2: 0.0924 - val_f2_score_3: 0.0667 - val_f2_score_4: 0.0305 - val_f2_score_5: 0.0114
# Epoch 15/200
#  - 9s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1004 - f2_score: 0.1918 - f2_score_1: 0.1449 - f2_score_2: 0.1070 - f2_score_3: 0.0782 - f2_score_4: 0.0393 - f2_score_5: 0.0176 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0914 - val_f2_score: 0.1819 - val_f2_score_1: 0.1321 - val_f2_score_2: 0.0963 - val_f2_score_3: 0.0717 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0145
# Epoch 16/200
#  - 9s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.0994 - f2_score: 0.1939 - f2_score_1: 0.1471 - f2_score_2: 0.1092 - f2_score_3: 0.0801 - f2_score_4: 0.0406 - f2_score_5: 0.0183 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1016 - val_f2_score: 0.1849 - val_f2_score_1: 0.1339 - val_f2_score_2: 0.0961 - val_f2_score_3: 0.0702 - val_f2_score_4: 0.0339 - val_f2_score_5: 0.0134
# Epoch 17/200
#  - 9s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1028 - f2_score: 0.1971 - f2_score_1: 0.1492 - f2_score_2: 0.1112 - f2_score_3: 0.0821 - f2_score_4: 0.0420 - f2_score_5: 0.0196 - val_loss: 0.0132 - val_acc: 0.9971 - val_categorical_accuracy: 0.0982 - val_f2_score: 0.1898 - val_f2_score_1: 0.1384 - val_f2_score_2: 0.1000 - val_f2_score_3: 0.0725 - val_f2_score_4: 0.0354 - val_f2_score_5: 0.0137
# Epoch 18/200
#  - 9s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1022 - f2_score: 0.1995 - f2_score_1: 0.1517 - f2_score_2: 0.1133 - f2_score_3: 0.0836 - f2_score_4: 0.0435 - f2_score_5: 0.0203 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.0944 - val_f2_score: 0.1905 - val_f2_score_1: 0.1404 - val_f2_score_2: 0.1025 - val_f2_score_3: 0.0761 - val_f2_score_4: 0.0386 - val_f2_score_5: 0.0160
# Epoch 19/200
#  - 9s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1016 - f2_score: 0.2007 - f2_score_1: 0.1524 - f2_score_2: 0.1139 - f2_score_3: 0.0847 - f2_score_4: 0.0445 - f2_score_5: 0.0213 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1053 - val_f2_score: 0.1941 - val_f2_score_1: 0.1427 - val_f2_score_2: 0.1040 - val_f2_score_3: 0.0755 - val_f2_score_4: 0.0376 - val_f2_score_5: 0.0157
# Epoch 20/200
#  - 9s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1036 - f2_score: 0.2018 - f2_score_1: 0.1548 - f2_score_2: 0.1164 - f2_score_3: 0.0869 - f2_score_4: 0.0455 - f2_score_5: 0.0218 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1063 - val_f2_score: 0.1940 - val_f2_score_1: 0.1425 - val_f2_score_2: 0.1032 - val_f2_score_3: 0.0752 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0157
# Epoch 21/200
#  - 9s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1046 - f2_score: 0.2024 - f2_score_1: 0.1551 - f2_score_2: 0.1172 - f2_score_3: 0.0874 - f2_score_4: 0.0461 - f2_score_5: 0.0223 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1092 - val_f2_score: 0.1951 - val_f2_score_1: 0.1433 - val_f2_score_2: 0.1049 - val_f2_score_3: 0.0771 - val_f2_score_4: 0.0392 - val_f2_score_5: 0.0171
# Epoch 22/200
#  - 9s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1047 - f2_score: 0.2046 - f2_score_1: 0.1569 - f2_score_2: 0.1186 - f2_score_3: 0.0883 - f2_score_4: 0.0472 - f2_score_5: 0.0234 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1020 - val_f2_score: 0.1936 - val_f2_score_1: 0.1420 - val_f2_score_2: 0.1038 - val_f2_score_3: 0.0772 - val_f2_score_4: 0.0392 - val_f2_score_5: 0.0167
# Epoch 23/200
#  - 9s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1056 - f2_score: 0.2053 - f2_score_1: 0.1569 - f2_score_2: 0.1184 - f2_score_3: 0.0888 - f2_score_4: 0.0474 - f2_score_5: 0.0232 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1042 - val_f2_score: 0.1960 - val_f2_score_1: 0.1456 - val_f2_score_2: 0.1076 - val_f2_score_3: 0.0803 - val_f2_score_4: 0.0423 - val_f2_score_5: 0.0191
# Epoch 24/200
#  - 9s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1055 - f2_score: 0.2064 - f2_score_1: 0.1580 - f2_score_2: 0.1191 - f2_score_3: 0.0890 - f2_score_4: 0.0475 - f2_score_5: 0.0236 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1045 - val_f2_score: 0.1985 - val_f2_score_1: 0.1480 - val_f2_score_2: 0.1087 - val_f2_score_3: 0.0805 - val_f2_score_4: 0.0415 - val_f2_score_5: 0.0182
# Epoch 25/200
#  - 9s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1069 - f2_score: 0.2071 - f2_score_1: 0.1597 - f2_score_2: 0.1213 - f2_score_3: 0.0908 - f2_score_4: 0.0492 - f2_score_5: 0.0242 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1031 - val_f2_score: 0.1991 - val_f2_score_1: 0.1482 - val_f2_score_2: 0.1091 - val_f2_score_3: 0.0808 - val_f2_score_4: 0.0428 - val_f2_score_5: 0.0194
# Epoch 26/200
#  - 9s - loss: 0.0137 - acc: 0.9972 - categorical_accuracy: 0.1075 - f2_score: 0.2081 - f2_score_1: 0.1601 - f2_score_2: 0.1213 - f2_score_3: 0.0908 - f2_score_4: 0.0495 - f2_score_5: 0.0251 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1017 - val_f2_score: 0.2006 - val_f2_score_1: 0.1503 - val_f2_score_2: 0.1110 - val_f2_score_3: 0.0830 - val_f2_score_4: 0.0439 - val_f2_score_5: 0.0202
# Epoch 27/200
#  - 9s - loss: 0.0136 - acc: 0.9971 - categorical_accuracy: 0.1058 - f2_score: 0.2083 - f2_score_1: 0.1613 - f2_score_2: 0.1220 - f2_score_3: 0.0922 - f2_score_4: 0.0501 - f2_score_5: 0.0250 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1118 - val_f2_score: 0.1975 - val_f2_score_1: 0.1465 - val_f2_score_2: 0.1080 - val_f2_score_3: 0.0798 - val_f2_score_4: 0.0415 - val_f2_score_5: 0.0191
# Epoch 28/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1078 - f2_score: 0.2100 - f2_score_1: 0.1624 - f2_score_2: 0.1233 - f2_score_3: 0.0929 - f2_score_4: 0.0507 - f2_score_5: 0.0256 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1057 - val_f2_score: 0.2008 - val_f2_score_1: 0.1503 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0841 - val_f2_score_4: 0.0447 - val_f2_score_5: 0.0205
# Epoch 29/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1088 - f2_score: 0.2109 - f2_score_1: 0.1626 - f2_score_2: 0.1235 - f2_score_3: 0.0937 - f2_score_4: 0.0510 - f2_score_5: 0.0258 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1083 - val_f2_score: 0.2016 - val_f2_score_1: 0.1514 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0836 - val_f2_score_4: 0.0449 - val_f2_score_5: 0.0213
# Epoch 30/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1080 - f2_score: 0.2114 - f2_score_1: 0.1634 - f2_score_2: 0.1245 - f2_score_3: 0.0939 - f2_score_4: 0.0516 - f2_score_5: 0.0263 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1103 - val_f2_score: 0.2006 - val_f2_score_1: 0.1494 - val_f2_score_2: 0.1104 - val_f2_score_3: 0.0823 - val_f2_score_4: 0.0437 - val_f2_score_5: 0.0204
# Epoch 31/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1089 - f2_score: 0.2116 - f2_score_1: 0.1637 - f2_score_2: 0.1247 - f2_score_3: 0.0943 - f2_score_4: 0.0517 - f2_score_5: 0.0268 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1041 - val_f2_score: 0.2029 - val_f2_score_1: 0.1526 - val_f2_score_2: 0.1135 - val_f2_score_3: 0.0852 - val_f2_score_4: 0.0461 - val_f2_score_5: 0.0220
# Epoch 32/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1087 - f2_score: 0.2126 - f2_score_1: 0.1647 - f2_score_2: 0.1257 - f2_score_3: 0.0946 - f2_score_4: 0.0522 - f2_score_5: 0.0268 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1047 - val_f2_score: 0.2012 - val_f2_score_1: 0.1515 - val_f2_score_2: 0.1120 - val_f2_score_3: 0.0840 - val_f2_score_4: 0.0446 - val_f2_score_5: 0.0212
# Epoch 33/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1094 - f2_score: 0.2133 - f2_score_1: 0.1648 - f2_score_2: 0.1261 - f2_score_3: 0.0953 - f2_score_4: 0.0532 - f2_score_5: 0.0273 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1096 - val_f2_score: 0.2033 - val_f2_score_1: 0.1529 - val_f2_score_2: 0.1134 - val_f2_score_3: 0.0841 - val_f2_score_4: 0.0444 - val_f2_score_5: 0.0214
# Epoch 34/200
#  - 9s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1106 - f2_score: 0.2130 - f2_score_1: 0.1650 - f2_score_2: 0.1268 - f2_score_3: 0.0954 - f2_score_4: 0.0529 - f2_score_5: 0.0275 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2045 - val_f2_score_1: 0.1530 - val_f2_score_2: 0.1133 - val_f2_score_3: 0.0840 - val_f2_score_4: 0.0445 - val_f2_score_5: 0.0215
# Epoch 35/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1106 - f2_score: 0.2137 - f2_score_1: 0.1654 - f2_score_2: 0.1265 - f2_score_3: 0.0960 - f2_score_4: 0.0535 - f2_score_5: 0.0278 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1064 - val_f2_score: 0.2044 - val_f2_score_1: 0.1545 - val_f2_score_2: 0.1150 - val_f2_score_3: 0.0863 - val_f2_score_4: 0.0468 - val_f2_score_5: 0.0225
# Epoch 36/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1102 - f2_score: 0.2139 - f2_score_1: 0.1661 - f2_score_2: 0.1269 - f2_score_3: 0.0964 - f2_score_4: 0.0534 - f2_score_5: 0.0273 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1094 - val_f2_score: 0.2062 - val_f2_score_1: 0.1549 - val_f2_score_2: 0.1155 - val_f2_score_3: 0.0860 - val_f2_score_4: 0.0458 - val_f2_score_5: 0.0223
# Epoch 37/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1103 - f2_score: 0.2146 - f2_score_1: 0.1672 - f2_score_2: 0.1274 - f2_score_3: 0.0964 - f2_score_4: 0.0537 - f2_score_5: 0.0280 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1101 - val_f2_score: 0.2052 - val_f2_score_1: 0.1544 - val_f2_score_2: 0.1146 - val_f2_score_3: 0.0855 - val_f2_score_4: 0.0457 - val_f2_score_5: 0.0218
# Epoch 38/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1104 - f2_score: 0.2143 - f2_score_1: 0.1662 - f2_score_2: 0.1273 - f2_score_3: 0.0966 - f2_score_4: 0.0542 - f2_score_5: 0.0286 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1067 - val_f2_score: 0.2066 - val_f2_score_1: 0.1561 - val_f2_score_2: 0.1167 - val_f2_score_3: 0.0877 - val_f2_score_4: 0.0476 - val_f2_score_5: 0.0230
# Epoch 39/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1099 - f2_score: 0.2151 - f2_score_1: 0.1677 - f2_score_2: 0.1283 - f2_score_3: 0.0975 - f2_score_4: 0.0544 - f2_score_5: 0.0285 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1100 - val_f2_score: 0.2052 - val_f2_score_1: 0.1528 - val_f2_score_2: 0.1133 - val_f2_score_3: 0.0841 - val_f2_score_4: 0.0446 - val_f2_score_5: 0.0215
# Epoch 40/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1093 - f2_score: 0.2149 - f2_score_1: 0.1677 - f2_score_2: 0.1280 - f2_score_3: 0.0973 - f2_score_4: 0.0540 - f2_score_5: 0.0279 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1129 - val_f2_score: 0.2068 - val_f2_score_1: 0.1557 - val_f2_score_2: 0.1158 - val_f2_score_3: 0.0858 - val_f2_score_4: 0.0454 - val_f2_score_5: 0.0215
# Epoch 41/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2155 - f2_score_1: 0.1677 - f2_score_2: 0.1288 - f2_score_3: 0.0976 - f2_score_4: 0.0546 - f2_score_5: 0.0282 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1080 - val_f2_score: 0.2061 - val_f2_score_1: 0.1556 - val_f2_score_2: 0.1160 - val_f2_score_3: 0.0869 - val_f2_score_4: 0.0473 - val_f2_score_5: 0.0228
# Epoch 42/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1112 - f2_score: 0.2161 - f2_score_1: 0.1682 - f2_score_2: 0.1290 - f2_score_3: 0.0979 - f2_score_4: 0.0549 - f2_score_5: 0.0286 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1085 - val_f2_score: 0.2063 - val_f2_score_1: 0.1549 - val_f2_score_2: 0.1159 - val_f2_score_3: 0.0866 - val_f2_score_4: 0.0466 - val_f2_score_5: 0.0227
# Epoch 43/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2165 - f2_score_1: 0.1684 - f2_score_2: 0.1293 - f2_score_3: 0.0984 - f2_score_4: 0.0546 - f2_score_5: 0.0286 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1098 - val_f2_score: 0.2066 - val_f2_score_1: 0.1555 - val_f2_score_2: 0.1160 - val_f2_score_3: 0.0863 - val_f2_score_4: 0.0464 - val_f2_score_5: 0.0226
# Epoch 44/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2163 - f2_score_1: 0.1686 - f2_score_2: 0.1293 - f2_score_3: 0.0984 - f2_score_4: 0.0546 - f2_score_5: 0.0283 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1090 - val_f2_score: 0.2075 - val_f2_score_1: 0.1558 - val_f2_score_2: 0.1162 - val_f2_score_3: 0.0873 - val_f2_score_4: 0.0472 - val_f2_score_5: 0.0232
# Epoch 45/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2169 - f2_score_1: 0.1691 - f2_score_2: 0.1292 - f2_score_3: 0.0987 - f2_score_4: 0.0546 - f2_score_5: 0.0287 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1088 - val_f2_score: 0.2079 - val_f2_score_1: 0.1567 - val_f2_score_2: 0.1169 - val_f2_score_3: 0.0880 - val_f2_score_4: 0.0482 - val_f2_score_5: 0.0236
# Epoch 46/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2174 - f2_score_1: 0.1693 - f2_score_2: 0.1296 - f2_score_3: 0.0994 - f2_score_4: 0.0555 - f2_score_5: 0.0288 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1098 - val_f2_score: 0.2069 - val_f2_score_1: 0.1558 - val_f2_score_2: 0.1161 - val_f2_score_3: 0.0873 - val_f2_score_4: 0.0474 - val_f2_score_5: 0.0230
# Epoch 47/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1109 - f2_score: 0.2174 - f2_score_1: 0.1689 - f2_score_2: 0.1294 - f2_score_3: 0.0989 - f2_score_4: 0.0551 - f2_score_5: 0.0293 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1097 - val_f2_score: 0.2078 - val_f2_score_1: 0.1571 - val_f2_score_2: 0.1174 - val_f2_score_3: 0.0882 - val_f2_score_4: 0.0484 - val_f2_score_5: 0.0237
# Epoch 48/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2169 - f2_score_1: 0.1691 - f2_score_2: 0.1303 - f2_score_3: 0.0996 - f2_score_4: 0.0556 - f2_score_5: 0.0292 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1105 - val_f2_score: 0.2085 - val_f2_score_1: 0.1576 - val_f2_score_2: 0.1178 - val_f2_score_3: 0.0884 - val_f2_score_4: 0.0481 - val_f2_score_5: 0.0235
# Epoch 49/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2178 - f2_score_1: 0.1695 - f2_score_2: 0.1297 - f2_score_3: 0.0992 - f2_score_4: 0.0558 - f2_score_5: 0.0293 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1125 - val_f2_score: 0.2076 - val_f2_score_1: 0.1561 - val_f2_score_2: 0.1166 - val_f2_score_3: 0.0870 - val_f2_score_4: 0.0473 - val_f2_score_5: 0.0232
# Epoch 50/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1121 - f2_score: 0.2176 - f2_score_1: 0.1697 - f2_score_2: 0.1306 - f2_score_3: 0.0992 - f2_score_4: 0.0556 - f2_score_5: 0.0293 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1108 - val_f2_score: 0.2084 - val_f2_score_1: 0.1576 - val_f2_score_2: 0.1177 - val_f2_score_3: 0.0886 - val_f2_score_4: 0.0483 - val_f2_score_5: 0.0236
# Epoch 51/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2171 - f2_score_1: 0.1695 - f2_score_2: 0.1308 - f2_score_3: 0.0995 - f2_score_4: 0.0561 - f2_score_5: 0.0293 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1096 - val_f2_score: 0.2082 - val_f2_score_1: 0.1574 - val_f2_score_2: 0.1178 - val_f2_score_3: 0.0885 - val_f2_score_4: 0.0485 - val_f2_score_5: 0.0238
# Epoch 52/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1113 - f2_score: 0.2178 - f2_score_1: 0.1698 - f2_score_2: 0.1299 - f2_score_3: 0.0990 - f2_score_4: 0.0558 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1109 - val_f2_score: 0.2077 - val_f2_score_1: 0.1564 - val_f2_score_2: 0.1166 - val_f2_score_3: 0.0876 - val_f2_score_4: 0.0477 - val_f2_score_5: 0.0234
# Epoch 53/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1127 - f2_score: 0.2175 - f2_score_1: 0.1692 - f2_score_2: 0.1300 - f2_score_3: 0.0990 - f2_score_4: 0.0555 - f2_score_5: 0.0294 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2084 - val_f2_score_1: 0.1575 - val_f2_score_2: 0.1179 - val_f2_score_3: 0.0882 - val_f2_score_4: 0.0480 - val_f2_score_5: 0.0235
# Epoch 54/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2177 - f2_score_1: 0.1699 - f2_score_2: 0.1309 - f2_score_3: 0.1001 - f2_score_4: 0.0558 - f2_score_5: 0.0296 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1100 - val_f2_score: 0.2084 - val_f2_score_1: 0.1575 - val_f2_score_2: 0.1181 - val_f2_score_3: 0.0888 - val_f2_score_4: 0.0487 - val_f2_score_5: 0.0240
# Epoch 55/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2181 - f2_score_1: 0.1698 - f2_score_2: 0.1304 - f2_score_3: 0.0991 - f2_score_4: 0.0557 - f2_score_5: 0.0291 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1117 - val_f2_score: 0.2086 - val_f2_score_1: 0.1575 - val_f2_score_2: 0.1178 - val_f2_score_3: 0.0883 - val_f2_score_4: 0.0483 - val_f2_score_5: 0.0237
# Epoch 56/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1130 - f2_score: 0.2181 - f2_score_1: 0.1707 - f2_score_2: 0.1310 - f2_score_3: 0.0994 - f2_score_4: 0.0563 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.2093 - val_f2_score_1: 0.1582 - val_f2_score_2: 0.1185 - val_f2_score_3: 0.0889 - val_f2_score_4: 0.0487 - val_f2_score_5: 0.0239
# Epoch 57/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2189 - f2_score_1: 0.1709 - f2_score_2: 0.1314 - f2_score_3: 0.0998 - f2_score_4: 0.0562 - f2_score_5: 0.0295 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1121 - val_f2_score: 0.2084 - val_f2_score_1: 0.1570 - val_f2_score_2: 0.1175 - val_f2_score_3: 0.0876 - val_f2_score_4: 0.0477 - val_f2_score_5: 0.0235
# Epoch 58/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2188 - f2_score_1: 0.1708 - f2_score_2: 0.1316 - f2_score_3: 0.0997 - f2_score_4: 0.0564 - f2_score_5: 0.0297 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1114 - val_f2_score: 0.2088 - val_f2_score_1: 0.1577 - val_f2_score_2: 0.1181 - val_f2_score_3: 0.0885 - val_f2_score_4: 0.0485 - val_f2_score_5: 0.0239
# Epoch 59/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2172 - f2_score_1: 0.1699 - f2_score_2: 0.1305 - f2_score_3: 0.0993 - f2_score_4: 0.0558 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1094 - val_f2_score: 0.2095 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0896 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0245
# Epoch 60/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1101 - f2_score: 0.2181 - f2_score_1: 0.1709 - f2_score_2: 0.1318 - f2_score_3: 0.1004 - f2_score_4: 0.0567 - f2_score_5: 0.0296 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1106 - val_f2_score: 0.2090 - val_f2_score_1: 0.1580 - val_f2_score_2: 0.1185 - val_f2_score_3: 0.0890 - val_f2_score_4: 0.0487 - val_f2_score_5: 0.0241
# Epoch 61/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2182 - f2_score_1: 0.1702 - f2_score_2: 0.1308 - f2_score_3: 0.0997 - f2_score_4: 0.0566 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.2094 - val_f2_score_1: 0.1582 - val_f2_score_2: 0.1186 - val_f2_score_3: 0.0891 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0242
# Epoch 62/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2184 - f2_score_1: 0.1700 - f2_score_2: 0.1308 - f2_score_3: 0.0997 - f2_score_4: 0.0559 - f2_score_5: 0.0297 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1102 - val_f2_score: 0.2094 - val_f2_score_1: 0.1585 - val_f2_score_2: 0.1189 - val_f2_score_3: 0.0894 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0243
# Epoch 63/200
#  - 10s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2184 - f2_score_1: 0.1704 - f2_score_2: 0.1313 - f2_score_3: 0.1003 - f2_score_4: 0.0565 - f2_score_5: 0.0298 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1099 - val_f2_score: 0.2098 - val_f2_score_1: 0.1586 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0244
# Epoch 64/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2191 - f2_score_1: 0.1713 - f2_score_2: 0.1317 - f2_score_3: 0.1005 - f2_score_4: 0.0571 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.2093 - val_f2_score_1: 0.1581 - val_f2_score_2: 0.1186 - val_f2_score_3: 0.0891 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0242
# Epoch 65/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2184 - f2_score_1: 0.1701 - f2_score_2: 0.1307 - f2_score_3: 0.1001 - f2_score_4: 0.0567 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1102 - val_f2_score: 0.2097 - val_f2_score_1: 0.1586 - val_f2_score_2: 0.1191 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0245
# Epoch 66/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2185 - f2_score_1: 0.1709 - f2_score_2: 0.1316 - f2_score_3: 0.1009 - f2_score_4: 0.0565 - f2_score_5: 0.0296 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1109 - val_f2_score: 0.2096 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1189 - val_f2_score_3: 0.0892 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0243
# Epoch 67/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2186 - f2_score_1: 0.1715 - f2_score_2: 0.1325 - f2_score_3: 0.1009 - f2_score_4: 0.0570 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2096 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1188 - val_f2_score_3: 0.0891 - val_f2_score_4: 0.0489 - val_f2_score_5: 0.0243
# Epoch 68/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2188 - f2_score_1: 0.1708 - f2_score_2: 0.1311 - f2_score_3: 0.1000 - f2_score_4: 0.0566 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1106 - val_f2_score: 0.2098 - val_f2_score_1: 0.1588 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0896 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 69/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1133 - f2_score: 0.2198 - f2_score_1: 0.1721 - f2_score_2: 0.1323 - f2_score_3: 0.1010 - f2_score_4: 0.0568 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1117 - val_f2_score: 0.2094 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1188 - val_f2_score_3: 0.0892 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0244
# Epoch 70/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2190 - f2_score_1: 0.1707 - f2_score_2: 0.1315 - f2_score_3: 0.1005 - f2_score_4: 0.0570 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1114 - val_f2_score: 0.2097 - val_f2_score_1: 0.1585 - val_f2_score_2: 0.1190 - val_f2_score_3: 0.0893 - val_f2_score_4: 0.0491 - val_f2_score_5: 0.0244
# Epoch 71/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1127 - f2_score: 0.2192 - f2_score_1: 0.1709 - f2_score_2: 0.1315 - f2_score_3: 0.1007 - f2_score_4: 0.0565 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2099 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1190 - val_f2_score_3: 0.0894 - val_f2_score_4: 0.0491 - val_f2_score_5: 0.0243
# Epoch 72/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2186 - f2_score_1: 0.1713 - f2_score_2: 0.1319 - f2_score_3: 0.1011 - f2_score_4: 0.0571 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2098 - val_f2_score_1: 0.1584 - val_f2_score_2: 0.1190 - val_f2_score_3: 0.0894 - val_f2_score_4: 0.0490 - val_f2_score_5: 0.0244
# Epoch 73/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2187 - f2_score_1: 0.1703 - f2_score_2: 0.1308 - f2_score_3: 0.0995 - f2_score_4: 0.0564 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1109 - val_f2_score: 0.2100 - val_f2_score_1: 0.1586 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0492 - val_f2_score_5: 0.0245
# Epoch 74/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2193 - f2_score_1: 0.1707 - f2_score_2: 0.1314 - f2_score_3: 0.1000 - f2_score_4: 0.0565 - f2_score_5: 0.0298 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2100 - val_f2_score_1: 0.1587 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0491 - val_f2_score_5: 0.0245
# Epoch 75/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2184 - f2_score_1: 0.1700 - f2_score_2: 0.1314 - f2_score_3: 0.1008 - f2_score_4: 0.0572 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2100 - val_f2_score_1: 0.1587 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0491 - val_f2_score_5: 0.0244
# Epoch 76/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2192 - f2_score_1: 0.1712 - f2_score_2: 0.1321 - f2_score_3: 0.1008 - f2_score_4: 0.0572 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2100 - val_f2_score_1: 0.1588 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0894 - val_f2_score_4: 0.0491 - val_f2_score_5: 0.0245
# Epoch 77/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2191 - f2_score_1: 0.1717 - f2_score_2: 0.1319 - f2_score_3: 0.1009 - f2_score_4: 0.0567 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1114 - val_f2_score: 0.2100 - val_f2_score_1: 0.1588 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0492 - val_f2_score_5: 0.0245
# Epoch 78/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1131 - f2_score: 0.2189 - f2_score_1: 0.1715 - f2_score_2: 0.1317 - f2_score_3: 0.1010 - f2_score_4: 0.0567 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2100 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 79/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1127 - f2_score: 0.2188 - f2_score_1: 0.1707 - f2_score_2: 0.1320 - f2_score_3: 0.1013 - f2_score_4: 0.0570 - f2_score_5: 0.0298 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1110 - val_f2_score: 0.2101 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1195 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 80/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1115 - f2_score: 0.2194 - f2_score_1: 0.1705 - f2_score_2: 0.1317 - f2_score_3: 0.1006 - f2_score_4: 0.0564 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0247
# Epoch 81/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2189 - f2_score_1: 0.1709 - f2_score_2: 0.1322 - f2_score_3: 0.1006 - f2_score_4: 0.0572 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 82/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2193 - f2_score_1: 0.1717 - f2_score_2: 0.1330 - f2_score_3: 0.1017 - f2_score_4: 0.0573 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2100 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 83/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1146 - f2_score: 0.2194 - f2_score_1: 0.1718 - f2_score_2: 0.1322 - f2_score_3: 0.1015 - f2_score_4: 0.0573 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2099 - val_f2_score_1: 0.1587 - val_f2_score_2: 0.1191 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0492 - val_f2_score_5: 0.0245
# Epoch 84/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2195 - f2_score_1: 0.1717 - f2_score_2: 0.1317 - f2_score_3: 0.1006 - f2_score_4: 0.0567 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2100 - val_f2_score_1: 0.1588 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0895 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 85/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1134 - f2_score: 0.2188 - f2_score_1: 0.1710 - f2_score_2: 0.1311 - f2_score_3: 0.1002 - f2_score_4: 0.0563 - f2_score_5: 0.0295 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 86/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1114 - f2_score: 0.2191 - f2_score_1: 0.1711 - f2_score_2: 0.1321 - f2_score_3: 0.1010 - f2_score_4: 0.0563 - f2_score_5: 0.0298 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 87/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2203 - f2_score_1: 0.1716 - f2_score_2: 0.1322 - f2_score_3: 0.1009 - f2_score_4: 0.0571 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0897 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 88/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2188 - f2_score_1: 0.1710 - f2_score_2: 0.1320 - f2_score_3: 0.1010 - f2_score_4: 0.0568 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1110 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1195 - val_f2_score_3: 0.0899 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 89/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2197 - f2_score_1: 0.1714 - f2_score_2: 0.1324 - f2_score_3: 0.1010 - f2_score_4: 0.0572 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2101 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 90/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2191 - f2_score_1: 0.1722 - f2_score_2: 0.1326 - f2_score_3: 0.1010 - f2_score_4: 0.0572 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2102 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 91/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2198 - f2_score_1: 0.1713 - f2_score_2: 0.1317 - f2_score_3: 0.1007 - f2_score_4: 0.0568 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0247
# Epoch 92/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1108 - f2_score: 0.2192 - f2_score_1: 0.1712 - f2_score_2: 0.1315 - f2_score_3: 0.1006 - f2_score_4: 0.0572 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 93/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2196 - f2_score_1: 0.1718 - f2_score_2: 0.1313 - f2_score_3: 0.1003 - f2_score_4: 0.0570 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1195 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 94/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2191 - f2_score_1: 0.1715 - f2_score_2: 0.1320 - f2_score_3: 0.1010 - f2_score_4: 0.0574 - f2_score_5: 0.0307 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1195 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 95/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2196 - f2_score_1: 0.1713 - f2_score_2: 0.1319 - f2_score_3: 0.1005 - f2_score_4: 0.0567 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 96/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2192 - f2_score_1: 0.1718 - f2_score_2: 0.1322 - f2_score_3: 0.1007 - f2_score_4: 0.0569 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 97/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1134 - f2_score: 0.2200 - f2_score_1: 0.1717 - f2_score_2: 0.1329 - f2_score_3: 0.1010 - f2_score_4: 0.0570 - f2_score_5: 0.0308 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 98/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1139 - f2_score: 0.2203 - f2_score_1: 0.1718 - f2_score_2: 0.1321 - f2_score_3: 0.1010 - f2_score_4: 0.0571 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1193 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 99/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2199 - f2_score_1: 0.1720 - f2_score_2: 0.1328 - f2_score_3: 0.1013 - f2_score_4: 0.0571 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 100/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1131 - f2_score: 0.2192 - f2_score_1: 0.1711 - f2_score_2: 0.1325 - f2_score_3: 0.1009 - f2_score_4: 0.0575 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 101/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1109 - f2_score: 0.2197 - f2_score_1: 0.1720 - f2_score_2: 0.1317 - f2_score_3: 0.1006 - f2_score_4: 0.0566 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 102/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2193 - f2_score_1: 0.1705 - f2_score_2: 0.1314 - f2_score_3: 0.1005 - f2_score_4: 0.0567 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 103/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2197 - f2_score_1: 0.1717 - f2_score_2: 0.1317 - f2_score_3: 0.1008 - f2_score_4: 0.0570 - f2_score_5: 0.0307 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1111 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 104/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2192 - f2_score_1: 0.1722 - f2_score_2: 0.1325 - f2_score_3: 0.1014 - f2_score_4: 0.0574 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 105/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2191 - f2_score_1: 0.1713 - f2_score_2: 0.1324 - f2_score_3: 0.1008 - f2_score_4: 0.0575 - f2_score_5: 0.0307 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 106/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2193 - f2_score_1: 0.1712 - f2_score_2: 0.1317 - f2_score_3: 0.1006 - f2_score_4: 0.0571 - f2_score_5: 0.0300 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0246
# Epoch 107/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2194 - f2_score_1: 0.1715 - f2_score_2: 0.1323 - f2_score_3: 0.1008 - f2_score_4: 0.0573 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0246
# Epoch 108/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2187 - f2_score_1: 0.1711 - f2_score_2: 0.1322 - f2_score_3: 0.1008 - f2_score_4: 0.0570 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1112 - val_f2_score: 0.2103 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 109/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2192 - f2_score_1: 0.1718 - f2_score_2: 0.1323 - f2_score_3: 0.1012 - f2_score_4: 0.0571 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 110/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1125 - f2_score: 0.2196 - f2_score_1: 0.1712 - f2_score_2: 0.1313 - f2_score_3: 0.1007 - f2_score_4: 0.0569 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 111/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2191 - f2_score_1: 0.1717 - f2_score_2: 0.1318 - f2_score_3: 0.1010 - f2_score_4: 0.0573 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 112/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1123 - f2_score: 0.2184 - f2_score_1: 0.1709 - f2_score_2: 0.1323 - f2_score_3: 0.1013 - f2_score_4: 0.0570 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2103 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 113/200
# ...
# Epoch 164/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2191 - f2_score_1: 0.1713 - f2_score_2: 0.1321 - f2_score_3: 0.1003 - f2_score_4: 0.0572 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 165/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1127 - f2_score: 0.2193 - f2_score_1: 0.1709 - f2_score_2: 0.1320 - f2_score_3: 0.1012 - f2_score_4: 0.0572 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 166/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1132 - f2_score: 0.2193 - f2_score_1: 0.1713 - f2_score_2: 0.1317 - f2_score_3: 0.1003 - f2_score_4: 0.0570 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 167/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2204 - f2_score_1: 0.1715 - f2_score_2: 0.1318 - f2_score_3: 0.1009 - f2_score_4: 0.0568 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 168/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2195 - f2_score_1: 0.1714 - f2_score_2: 0.1318 - f2_score_3: 0.1008 - f2_score_4: 0.0571 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 169/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1121 - f2_score: 0.2194 - f2_score_1: 0.1718 - f2_score_2: 0.1326 - f2_score_3: 0.1008 - f2_score_4: 0.0574 - f2_score_5: 0.0307 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 170/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1127 - f2_score: 0.2199 - f2_score_1: 0.1712 - f2_score_2: 0.1322 - f2_score_3: 0.1011 - f2_score_4: 0.0572 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 171/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2194 - f2_score_1: 0.1715 - f2_score_2: 0.1318 - f2_score_3: 0.1005 - f2_score_4: 0.0571 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 172/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2194 - f2_score_1: 0.1712 - f2_score_2: 0.1320 - f2_score_3: 0.1010 - f2_score_4: 0.0568 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 173/200
#  - 9s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1135 - f2_score: 0.2192 - f2_score_1: 0.1715 - f2_score_2: 0.1320 - f2_score_3: 0.1009 - f2_score_4: 0.0571 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 174/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2199 - f2_score_1: 0.1714 - f2_score_2: 0.1320 - f2_score_3: 0.1008 - f2_score_4: 0.0569 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 175/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1129 - f2_score: 0.2200 - f2_score_1: 0.1716 - f2_score_2: 0.1322 - f2_score_3: 0.1006 - f2_score_4: 0.0570 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 176/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1133 - f2_score: 0.2194 - f2_score_1: 0.1720 - f2_score_2: 0.1329 - f2_score_3: 0.1014 - f2_score_4: 0.0574 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 177/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2196 - f2_score_1: 0.1712 - f2_score_2: 0.1319 - f2_score_3: 0.1007 - f2_score_4: 0.0568 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 178/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2194 - f2_score_1: 0.1719 - f2_score_2: 0.1317 - f2_score_3: 0.1008 - f2_score_4: 0.0571 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 179/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1134 - f2_score: 0.2196 - f2_score_1: 0.1712 - f2_score_2: 0.1316 - f2_score_3: 0.1008 - f2_score_4: 0.0572 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 180/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1138 - f2_score: 0.2194 - f2_score_1: 0.1712 - f2_score_2: 0.1315 - f2_score_3: 0.1002 - f2_score_4: 0.0565 - f2_score_5: 0.0299 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 181/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1130 - f2_score: 0.2192 - f2_score_1: 0.1716 - f2_score_2: 0.1319 - f2_score_3: 0.1007 - f2_score_4: 0.0572 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 182/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1117 - f2_score: 0.2198 - f2_score_1: 0.1721 - f2_score_2: 0.1317 - f2_score_3: 0.1007 - f2_score_4: 0.0569 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 183/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2201 - f2_score_1: 0.1724 - f2_score_2: 0.1327 - f2_score_3: 0.1011 - f2_score_4: 0.0575 - f2_score_5: 0.0308 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 184/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1119 - f2_score: 0.2183 - f2_score_1: 0.1707 - f2_score_2: 0.1317 - f2_score_3: 0.1002 - f2_score_4: 0.0563 - f2_score_5: 0.0298 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 185/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2191 - f2_score_1: 0.1715 - f2_score_2: 0.1318 - f2_score_3: 0.1008 - f2_score_4: 0.0564 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 186/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1135 - f2_score: 0.2208 - f2_score_1: 0.1721 - f2_score_2: 0.1327 - f2_score_3: 0.1011 - f2_score_4: 0.0573 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 187/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1134 - f2_score: 0.2196 - f2_score_1: 0.1718 - f2_score_2: 0.1323 - f2_score_3: 0.1010 - f2_score_4: 0.0570 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 188/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1133 - f2_score: 0.2197 - f2_score_1: 0.1717 - f2_score_2: 0.1321 - f2_score_3: 0.1016 - f2_score_4: 0.0574 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 189/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2199 - f2_score_1: 0.1713 - f2_score_2: 0.1319 - f2_score_3: 0.1007 - f2_score_4: 0.0568 - f2_score_5: 0.0306 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 190/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2187 - f2_score_1: 0.1711 - f2_score_2: 0.1325 - f2_score_3: 0.1010 - f2_score_4: 0.0568 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 191/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1124 - f2_score: 0.2202 - f2_score_1: 0.1718 - f2_score_2: 0.1324 - f2_score_3: 0.1007 - f2_score_4: 0.0569 - f2_score_5: 0.0305 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 192/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1131 - f2_score: 0.2198 - f2_score_1: 0.1716 - f2_score_2: 0.1322 - f2_score_3: 0.1009 - f2_score_4: 0.0575 - f2_score_5: 0.0303 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 193/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1128 - f2_score: 0.2194 - f2_score_1: 0.1716 - f2_score_2: 0.1329 - f2_score_3: 0.1017 - f2_score_4: 0.0570 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 194/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2196 - f2_score_1: 0.1718 - f2_score_2: 0.1323 - f2_score_3: 0.1018 - f2_score_4: 0.0576 - f2_score_5: 0.0310 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 195/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1122 - f2_score: 0.2196 - f2_score_1: 0.1716 - f2_score_2: 0.1321 - f2_score_3: 0.1009 - f2_score_4: 0.0566 - f2_score_5: 0.0302 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 196/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1126 - f2_score: 0.2194 - f2_score_1: 0.1714 - f2_score_2: 0.1317 - f2_score_3: 0.1004 - f2_score_4: 0.0573 - f2_score_5: 0.0301 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 197/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1117 - f2_score: 0.2190 - f2_score_1: 0.1717 - f2_score_2: 0.1325 - f2_score_3: 0.1010 - f2_score_4: 0.0578 - f2_score_5: 0.0307 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 198/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1118 - f2_score: 0.2206 - f2_score_1: 0.1716 - f2_score_2: 0.1325 - f2_score_3: 0.1014 - f2_score_4: 0.0574 - f2_score_5: 0.0308 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 199/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1141 - f2_score: 0.2199 - f2_score_1: 0.1717 - f2_score_2: 0.1324 - f2_score_3: 0.1012 - f2_score_4: 0.0572 - f2_score_5: 0.0310 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247
# Epoch 200/200
#  - 9s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1121 - f2_score: 0.2200 - f2_score_1: 0.1713 - f2_score_2: 0.1322 - f2_score_3: 0.1014 - f2_score_4: 0.0573 - f2_score_5: 0.0304 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1113 - val_f2_score: 0.2104 - val_f2_score_1: 0.1590 - val_f2_score_2: 0.1194 - val_f2_score_3: 0.0898 - val_f2_score_4: 0.0494 - val_f2_score_5: 0.0247

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id        attribute_ids
# 0  10023b2cc4ed5f68                  121
# 1  100fbe75ed8fd887                  121
# 2  101b627524a04f19                  121
# 3  10234480c41284c6        813 1046 1092
# 4  1023b0e2636dcea8                  671
# 5   1039cd6cf85845c  13 405 813 896 1092
# 6   103a5b3f83fbe88    194 813 1046 1092
# 7  10413aaae8d6a9a2         147 813 1092
# 8  10423822b93a65ab                  147
# 9  1052bf702cb099f7              147 671
