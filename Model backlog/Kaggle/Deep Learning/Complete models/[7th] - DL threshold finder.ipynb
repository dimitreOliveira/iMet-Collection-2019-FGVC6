# %%
import os
import cv2
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras import backend as K
from keras import metrics
from sklearn.metrics import fbeta_score

from keras import optimizers
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/train.csv')
labels = pd.read_csv('../input/labels.csv')
test = pd.read_csv('../input/sample_submission.csv')

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())

train["id"] = train["id"].apply(lambda x:x+".png")
test["id"] = test["id"].apply(lambda x:x+".png")
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                  id        attribute_ids
# 0  1000483014d91860          147 616 813
# 1  1000fe2e667721fe       51 616 734 813
# 2  1001614cb89646ee                  776
# 3  10041eb49b297c08  51 671 698 813 1092
# 4  100501c227f8beea  13 404 492 903 1093
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Model

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 50
LEARNING_RATE = 0.0001
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
train_datagen=ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='training')

valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",    
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='validation')

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 3460 images belonging to 1103 classes.
# Found 864 images belonging to 1103 classes.
# Found 7443 images.

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=(HEIGHT, WIDTH, CANAL)))
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.adam(lr=LEARNING_RATE)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=valid_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=EPOCHS,
                                verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 25s - loss: 0.2210 - acc: 0.9015 - categorical_accuracy: 0.0026 - f2_score: 0.0059 - f2_score_1: 0.0058 - f2_score_2: 0.0057 - f2_score_3: 0.0057 - f2_score_4: 0.0057 - f2_score_5: 0.0054 - val_loss: 0.0095 - val_acc: 0.9991 - val_categorical_accuracy: 0.0577 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/50
#  - 17s - loss: 0.0129 - acc: 0.9982 - categorical_accuracy: 0.0096 - f2_score: 0.0151 - f2_score_1: 0.0146 - f2_score_2: 0.0133 - f2_score_3: 0.0130 - f2_score_4: 0.0121 - f2_score_5: 0.0091 - val_loss: 0.0074 - val_acc: 0.9991 - val_categorical_accuracy: 0.0712 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/50
#  - 17s - loss: 0.0108 - acc: 0.9986 - categorical_accuracy: 0.0142 - f2_score: 0.0216 - f2_score_1: 0.0183 - f2_score_2: 0.0166 - f2_score_3: 0.0152 - f2_score_4: 0.0117 - f2_score_5: 0.0087 - val_loss: 0.0069 - val_acc: 0.9991 - val_categorical_accuracy: 0.0850 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 4/50
#  - 17s - loss: 0.0096 - acc: 0.9988 - categorical_accuracy: 0.0156 - f2_score: 0.0228 - f2_score_1: 0.0207 - f2_score_2: 0.0170 - f2_score_3: 0.0142 - f2_score_4: 0.0114 - f2_score_5: 0.0082 - val_loss: 0.0065 - val_acc: 0.9991 - val_categorical_accuracy: 0.0988 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 5/50
#  - 17s - loss: 0.0087 - acc: 0.9989 - categorical_accuracy: 0.0274 - f2_score: 0.0289 - f2_score_1: 0.0243 - f2_score_2: 0.0222 - f2_score_3: 0.0182 - f2_score_4: 0.0140 - f2_score_5: 0.0113 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.0625 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 6/50
#  - 17s - loss: 0.0082 - acc: 0.9989 - categorical_accuracy: 0.0208 - f2_score: 0.0245 - f2_score_1: 0.0166 - f2_score_2: 0.0119 - f2_score_3: 0.0102 - f2_score_4: 0.0089 - f2_score_5: 0.0056 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.0887 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 7/50
#  - 17s - loss: 0.0078 - acc: 0.9990 - categorical_accuracy: 0.0295 - f2_score: 0.0288 - f2_score_1: 0.0221 - f2_score_2: 0.0178 - f2_score_3: 0.0131 - f2_score_4: 0.0099 - f2_score_5: 0.0073 - val_loss: 0.0064 - val_acc: 0.9991 - val_categorical_accuracy: 0.0800 - val_f2_score: 0.0025 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 8/50
#  - 17s - loss: 0.0074 - acc: 0.9990 - categorical_accuracy: 0.0315 - f2_score: 0.0307 - f2_score_1: 0.0226 - f2_score_2: 0.0179 - f2_score_3: 0.0134 - f2_score_4: 0.0076 - f2_score_5: 0.0031 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.1175 - val_f2_score: 0.0662 - val_f2_score_1: 0.0175 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 9/50
#  - 18s - loss: 0.0072 - acc: 0.9990 - categorical_accuracy: 0.0388 - f2_score: 0.0349 - f2_score_1: 0.0274 - f2_score_2: 0.0200 - f2_score_3: 0.0170 - f2_score_4: 0.0113 - f2_score_5: 0.0074 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.1075 - val_f2_score: 0.0550 - val_f2_score_1: 0.0525 - val_f2_score_2: 0.0437 - val_f2_score_3: 0.0062 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 10/50
#  - 17s - loss: 0.0069 - acc: 0.9990 - categorical_accuracy: 0.0431 - f2_score: 0.0389 - f2_score_1: 0.0314 - f2_score_2: 0.0251 - f2_score_3: 0.0214 - f2_score_4: 0.0138 - f2_score_5: 0.0087 - val_loss: 0.0064 - val_acc: 0.9991 - val_categorical_accuracy: 0.1138 - val_f2_score: 0.0512 - val_f2_score_1: 0.0500 - val_f2_score_2: 0.0400 - val_f2_score_3: 0.0112 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 11/50
#  - 16s - loss: 0.0067 - acc: 0.9991 - categorical_accuracy: 0.0533 - f2_score: 0.0460 - f2_score_1: 0.0379 - f2_score_2: 0.0302 - f2_score_3: 0.0275 - f2_score_4: 0.0180 - f2_score_5: 0.0117 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.1237 - val_f2_score: 0.0650 - val_f2_score_1: 0.0625 - val_f2_score_2: 0.0625 - val_f2_score_3: 0.0587 - val_f2_score_4: 0.0212 - val_f2_score_5: 0.0000e+00
# Epoch 12/50
#  - 16s - loss: 0.0066 - acc: 0.9991 - categorical_accuracy: 0.0616 - f2_score: 0.0550 - f2_score_1: 0.0455 - f2_score_2: 0.0375 - f2_score_3: 0.0317 - f2_score_4: 0.0223 - f2_score_5: 0.0150 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1237 - val_f2_score: 0.0600 - val_f2_score_1: 0.0537 - val_f2_score_2: 0.0537 - val_f2_score_3: 0.0500 - val_f2_score_4: 0.0250 - val_f2_score_5: 0.0000e+00
# Epoch 13/50
#  - 16s - loss: 0.0064 - acc: 0.9991 - categorical_accuracy: 0.0686 - f2_score: 0.0589 - f2_score_1: 0.0489 - f2_score_2: 0.0397 - f2_score_3: 0.0326 - f2_score_4: 0.0221 - f2_score_5: 0.0156 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1400 - val_f2_score: 0.0646 - val_f2_score_1: 0.0537 - val_f2_score_2: 0.0537 - val_f2_score_3: 0.0537 - val_f2_score_4: 0.0375 - val_f2_score_5: 0.0000e+00
# Epoch 14/50
#  - 16s - loss: 0.0064 - acc: 0.9991 - categorical_accuracy: 0.0727 - f2_score: 0.0636 - f2_score_1: 0.0504 - f2_score_2: 0.0398 - f2_score_3: 0.0336 - f2_score_4: 0.0251 - f2_score_5: 0.0165 - val_loss: 0.0069 - val_acc: 0.9991 - val_categorical_accuracy: 0.1400 - val_f2_score: 0.0687 - val_f2_score_1: 0.0612 - val_f2_score_2: 0.0612 - val_f2_score_3: 0.0612 - val_f2_score_4: 0.0425 - val_f2_score_5: 0.0000e+00
# Epoch 15/50
#  - 16s - loss: 0.0062 - acc: 0.9991 - categorical_accuracy: 0.0677 - f2_score: 0.0616 - f2_score_1: 0.0472 - f2_score_2: 0.0396 - f2_score_3: 0.0341 - f2_score_4: 0.0249 - f2_score_5: 0.0176 - val_loss: 0.0068 - val_acc: 0.9991 - val_categorical_accuracy: 0.1490 - val_f2_score: 0.1020 - val_f2_score_1: 0.0733 - val_f2_score_2: 0.0589 - val_f2_score_3: 0.0577 - val_f2_score_4: 0.0493 - val_f2_score_5: 0.0132
# Epoch 16/50
#  - 16s - loss: 0.0062 - acc: 0.9991 - categorical_accuracy: 0.0784 - f2_score: 0.0629 - f2_score_1: 0.0541 - f2_score_2: 0.0462 - f2_score_3: 0.0403 - f2_score_4: 0.0326 - f2_score_5: 0.0242 - val_loss: 0.0073 - val_acc: 0.9991 - val_categorical_accuracy: 0.1388 - val_f2_score: 0.1017 - val_f2_score_1: 0.0750 - val_f2_score_2: 0.0612 - val_f2_score_3: 0.0550 - val_f2_score_4: 0.0525 - val_f2_score_5: 0.0325
# Epoch 17/50
#  - 16s - loss: 0.0060 - acc: 0.9991 - categorical_accuracy: 0.0824 - f2_score: 0.0665 - f2_score_1: 0.0572 - f2_score_2: 0.0510 - f2_score_3: 0.0445 - f2_score_4: 0.0308 - f2_score_5: 0.0222 - val_loss: 0.0061 - val_acc: 0.9991 - val_categorical_accuracy: 0.1512 - val_f2_score: 0.1037 - val_f2_score_1: 0.0850 - val_f2_score_2: 0.0725 - val_f2_score_3: 0.0662 - val_f2_score_4: 0.0587 - val_f2_score_5: 0.0412
# Epoch 18/50
#  - 16s - loss: 0.0060 - acc: 0.9991 - categorical_accuracy: 0.0813 - f2_score: 0.0669 - f2_score_1: 0.0566 - f2_score_2: 0.0480 - f2_score_3: 0.0411 - f2_score_4: 0.0332 - f2_score_5: 0.0253 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1450 - val_f2_score: 0.1199 - val_f2_score_1: 0.0867 - val_f2_score_2: 0.0687 - val_f2_score_3: 0.0537 - val_f2_score_4: 0.0512 - val_f2_score_5: 0.0425
# Epoch 19/50
#  - 16s - loss: 0.0059 - acc: 0.9991 - categorical_accuracy: 0.0917 - f2_score: 0.0755 - f2_score_1: 0.0607 - f2_score_2: 0.0505 - f2_score_3: 0.0437 - f2_score_4: 0.0326 - f2_score_5: 0.0254 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1462 - val_f2_score: 0.1181 - val_f2_score_1: 0.0900 - val_f2_score_2: 0.0800 - val_f2_score_3: 0.0625 - val_f2_score_4: 0.0537 - val_f2_score_5: 0.0487
# Epoch 20/50
#  - 17s - loss: 0.0058 - acc: 0.9991 - categorical_accuracy: 0.1085 - f2_score: 0.0862 - f2_score_1: 0.0716 - f2_score_2: 0.0643 - f2_score_3: 0.0549 - f2_score_4: 0.0425 - f2_score_5: 0.0365 - val_loss: 0.0068 - val_acc: 0.9991 - val_categorical_accuracy: 0.1575 - val_f2_score: 0.1426 - val_f2_score_1: 0.1131 - val_f2_score_2: 0.0921 - val_f2_score_3: 0.0712 - val_f2_score_4: 0.0625 - val_f2_score_5: 0.0537
# Epoch 21/50
#  - 16s - loss: 0.0058 - acc: 0.9991 - categorical_accuracy: 0.0984 - f2_score: 0.0796 - f2_score_1: 0.0693 - f2_score_2: 0.0584 - f2_score_3: 0.0508 - f2_score_4: 0.0444 - f2_score_5: 0.0336 - val_loss: 0.0065 - val_acc: 0.9991 - val_categorical_accuracy: 0.1625 - val_f2_score: 0.1247 - val_f2_score_1: 0.0858 - val_f2_score_2: 0.0685 - val_f2_score_3: 0.0562 - val_f2_score_4: 0.0500 - val_f2_score_5: 0.0500
# Epoch 22/50
#  - 16s - loss: 0.0056 - acc: 0.9991 - categorical_accuracy: 0.1103 - f2_score: 0.0922 - f2_score_1: 0.0774 - f2_score_2: 0.0706 - f2_score_3: 0.0587 - f2_score_4: 0.0476 - f2_score_5: 0.0370 - val_loss: 0.0061 - val_acc: 0.9991 - val_categorical_accuracy: 0.1650 - val_f2_score: 0.1336 - val_f2_score_1: 0.1042 - val_f2_score_2: 0.0812 - val_f2_score_3: 0.0737 - val_f2_score_4: 0.0600 - val_f2_score_5: 0.0575
# Epoch 23/50
#  - 16s - loss: 0.0057 - acc: 0.9991 - categorical_accuracy: 0.1051 - f2_score: 0.0806 - f2_score_1: 0.0704 - f2_score_2: 0.0627 - f2_score_3: 0.0536 - f2_score_4: 0.0432 - f2_score_5: 0.0370 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.1737 - val_f2_score: 0.1417 - val_f2_score_1: 0.1037 - val_f2_score_2: 0.0773 - val_f2_score_3: 0.0662 - val_f2_score_4: 0.0575 - val_f2_score_5: 0.0575
# Epoch 24/50
#  - 16s - loss: 0.0055 - acc: 0.9991 - categorical_accuracy: 0.1274 - f2_score: 0.0958 - f2_score_1: 0.0837 - f2_score_2: 0.0739 - f2_score_3: 0.0677 - f2_score_4: 0.0583 - f2_score_5: 0.0500 - val_loss: 0.0059 - val_acc: 0.9991 - val_categorical_accuracy: 0.1862 - val_f2_score: 0.1347 - val_f2_score_1: 0.0994 - val_f2_score_2: 0.0825 - val_f2_score_3: 0.0762 - val_f2_score_4: 0.0625 - val_f2_score_5: 0.0625
# Epoch 25/50
#  - 16s - loss: 0.0055 - acc: 0.9991 - categorical_accuracy: 0.1193 - f2_score: 0.0951 - f2_score_1: 0.0788 - f2_score_2: 0.0654 - f2_score_3: 0.0565 - f2_score_4: 0.0475 - f2_score_5: 0.0408 - val_loss: 0.0064 - val_acc: 0.9991 - val_categorical_accuracy: 0.1837 - val_f2_score: 0.1540 - val_f2_score_1: 0.1110 - val_f2_score_2: 0.0946 - val_f2_score_3: 0.0775 - val_f2_score_4: 0.0587 - val_f2_score_5: 0.0562
# Epoch 26/50
#  - 17s - loss: 0.0053 - acc: 0.9991 - categorical_accuracy: 0.1417 - f2_score: 0.1171 - f2_score_1: 0.0992 - f2_score_2: 0.0834 - f2_score_3: 0.0733 - f2_score_4: 0.0638 - f2_score_5: 0.0557 - val_loss: 0.0058 - val_acc: 0.9991 - val_categorical_accuracy: 0.1725 - val_f2_score: 0.1272 - val_f2_score_1: 0.0992 - val_f2_score_2: 0.0785 - val_f2_score_3: 0.0662 - val_f2_score_4: 0.0600 - val_f2_score_5: 0.0550
# Epoch 27/50
#  - 16s - loss: 0.0053 - acc: 0.9991 - categorical_accuracy: 0.1325 - f2_score: 0.1024 - f2_score_1: 0.0830 - f2_score_2: 0.0719 - f2_score_3: 0.0627 - f2_score_4: 0.0521 - f2_score_5: 0.0466 - val_loss: 0.0056 - val_acc: 0.9991 - val_categorical_accuracy: 0.1862 - val_f2_score: 0.1638 - val_f2_score_1: 0.1307 - val_f2_score_2: 0.1129 - val_f2_score_3: 0.0979 - val_f2_score_4: 0.0687 - val_f2_score_5: 0.0587
# Epoch 28/50
#  - 18s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1499 - f2_score: 0.1206 - f2_score_1: 0.1011 - f2_score_2: 0.0881 - f2_score_3: 0.0792 - f2_score_4: 0.0666 - f2_score_5: 0.0571 - val_loss: 0.0061 - val_acc: 0.9991 - val_categorical_accuracy: 0.1875 - val_f2_score: 0.1694 - val_f2_score_1: 0.1230 - val_f2_score_2: 0.0981 - val_f2_score_3: 0.0860 - val_f2_score_4: 0.0725 - val_f2_score_5: 0.0625
# Epoch 29/50
#  - 16s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1481 - f2_score: 0.1171 - f2_score_1: 0.1007 - f2_score_2: 0.0838 - f2_score_3: 0.0727 - f2_score_4: 0.0619 - f2_score_5: 0.0538 - val_loss: 0.0054 - val_acc: 0.9991 - val_categorical_accuracy: 0.1911 - val_f2_score: 0.1716 - val_f2_score_1: 0.1368 - val_f2_score_2: 0.1104 - val_f2_score_3: 0.0956 - val_f2_score_4: 0.0707 - val_f2_score_5: 0.0637
# Epoch 30/50
#  - 16s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1415 - f2_score: 0.1149 - f2_score_1: 0.0957 - f2_score_2: 0.0779 - f2_score_3: 0.0684 - f2_score_4: 0.0566 - f2_score_5: 0.0477 - val_loss: 0.0061 - val_acc: 0.9991 - val_categorical_accuracy: 0.1975 - val_f2_score: 0.1911 - val_f2_score_1: 0.1566 - val_f2_score_2: 0.1352 - val_f2_score_3: 0.1069 - val_f2_score_4: 0.0873 - val_f2_score_5: 0.0625
# Epoch 31/50
#  - 16s - loss: 0.0050 - acc: 0.9991 - categorical_accuracy: 0.1623 - f2_score: 0.1426 - f2_score_1: 0.1213 - f2_score_2: 0.0995 - f2_score_3: 0.0896 - f2_score_4: 0.0740 - f2_score_5: 0.0624 - val_loss: 0.0057 - val_acc: 0.9991 - val_categorical_accuracy: 0.1787 - val_f2_score: 0.1668 - val_f2_score_1: 0.1410 - val_f2_score_2: 0.1129 - val_f2_score_3: 0.0948 - val_f2_score_4: 0.0787 - val_f2_score_5: 0.0625
# Epoch 32/50
#  - 16s - loss: 0.0050 - acc: 0.9991 - categorical_accuracy: 0.1661 - f2_score: 0.1408 - f2_score_1: 0.1199 - f2_score_2: 0.1036 - f2_score_3: 0.0888 - f2_score_4: 0.0718 - f2_score_5: 0.0609 - val_loss: 0.0058 - val_acc: 0.9991 - val_categorical_accuracy: 0.2037 - val_f2_score: 0.1833 - val_f2_score_1: 0.1520 - val_f2_score_2: 0.1232 - val_f2_score_3: 0.0967 - val_f2_score_4: 0.0737 - val_f2_score_5: 0.0637
# Epoch 33/50
#  - 16s - loss: 0.0049 - acc: 0.9991 - categorical_accuracy: 0.1702 - f2_score: 0.1406 - f2_score_1: 0.1165 - f2_score_2: 0.0998 - f2_score_3: 0.0915 - f2_score_4: 0.0720 - f2_score_5: 0.0619 - val_loss: 0.0058 - val_acc: 0.9992 - val_categorical_accuracy: 0.2162 - val_f2_score: 0.1939 - val_f2_score_1: 0.1619 - val_f2_score_2: 0.1403 - val_f2_score_3: 0.1286 - val_f2_score_4: 0.1008 - val_f2_score_5: 0.0860
# Epoch 34/50
#  - 17s - loss: 0.0048 - acc: 0.9991 - categorical_accuracy: 0.1852 - f2_score: 0.1598 - f2_score_1: 0.1376 - f2_score_2: 0.1183 - f2_score_3: 0.0995 - f2_score_4: 0.0800 - f2_score_5: 0.0682 - val_loss: 0.0057 - val_acc: 0.9991 - val_categorical_accuracy: 0.1837 - val_f2_score: 0.1870 - val_f2_score_1: 0.1511 - val_f2_score_2: 0.1333 - val_f2_score_3: 0.1058 - val_f2_score_4: 0.0775 - val_f2_score_5: 0.0700
# Epoch 35/50
#  - 16s - loss: 0.0048 - acc: 0.9991 - categorical_accuracy: 0.1773 - f2_score: 0.1489 - f2_score_1: 0.1233 - f2_score_2: 0.1049 - f2_score_3: 0.0929 - f2_score_4: 0.0754 - f2_score_5: 0.0642 - val_loss: 0.0054 - val_acc: 0.9991 - val_categorical_accuracy: 0.1925 - val_f2_score: 0.1796 - val_f2_score_1: 0.1513 - val_f2_score_2: 0.1200 - val_f2_score_3: 0.1004 - val_f2_score_4: 0.0848 - val_f2_score_5: 0.0662
# Epoch 36/50
#  - 16s - loss: 0.0047 - acc: 0.9991 - categorical_accuracy: 0.2025 - f2_score: 0.1683 - f2_score_1: 0.1386 - f2_score_2: 0.1235 - f2_score_3: 0.1092 - f2_score_4: 0.0858 - f2_score_5: 0.0728 - val_loss: 0.0054 - val_acc: 0.9991 - val_categorical_accuracy: 0.2087 - val_f2_score: 0.2004 - val_f2_score_1: 0.1717 - val_f2_score_2: 0.1444 - val_f2_score_3: 0.1229 - val_f2_score_4: 0.0800 - val_f2_score_5: 0.0687
# Epoch 37/50
#  - 16s - loss: 0.0047 - acc: 0.9991 - categorical_accuracy: 0.2022 - f2_score: 0.1822 - f2_score_1: 0.1523 - f2_score_2: 0.1293 - f2_score_3: 0.1138 - f2_score_4: 0.0900 - f2_score_5: 0.0729 - val_loss: 0.0053 - val_acc: 0.9991 - val_categorical_accuracy: 0.2062 - val_f2_score: 0.1892 - val_f2_score_1: 0.1687 - val_f2_score_2: 0.1469 - val_f2_score_3: 0.1144 - val_f2_score_4: 0.0906 - val_f2_score_5: 0.0750
# Epoch 38/50
#  - 16s - loss: 0.0046 - acc: 0.9991 - categorical_accuracy: 0.2149 - f2_score: 0.1825 - f2_score_1: 0.1518 - f2_score_2: 0.1284 - f2_score_3: 0.1142 - f2_score_4: 0.0956 - f2_score_5: 0.0781 - val_loss: 0.0053 - val_acc: 0.9992 - val_categorical_accuracy: 0.2000 - val_f2_score: 0.2068 - val_f2_score_1: 0.1721 - val_f2_score_2: 0.1449 - val_f2_score_3: 0.1248 - val_f2_score_4: 0.1008 - val_f2_score_5: 0.0862
# Epoch 39/50
#  - 16s - loss: 0.0045 - acc: 0.9991 - categorical_accuracy: 0.2184 - f2_score: 0.1932 - f2_score_1: 0.1645 - f2_score_2: 0.1427 - f2_score_3: 0.1285 - f2_score_4: 0.1024 - f2_score_5: 0.0853 - val_loss: 0.0054 - val_acc: 0.9991 - val_categorical_accuracy: 0.2175 - val_f2_score: 0.1990 - val_f2_score_1: 0.1632 - val_f2_score_2: 0.1470 - val_f2_score_3: 0.1262 - val_f2_score_4: 0.0948 - val_f2_score_5: 0.0673
# Epoch 40/50
#  - 16s - loss: 0.0045 - acc: 0.9991 - categorical_accuracy: 0.2203 - f2_score: 0.1850 - f2_score_1: 0.1604 - f2_score_2: 0.1412 - f2_score_3: 0.1251 - f2_score_4: 0.1018 - f2_score_5: 0.0837 - val_loss: 0.0052 - val_acc: 0.9992 - val_categorical_accuracy: 0.2050 - val_f2_score: 0.1880 - val_f2_score_1: 0.1642 - val_f2_score_2: 0.1365 - val_f2_score_3: 0.1169 - val_f2_score_4: 0.0935 - val_f2_score_5: 0.0785
# Epoch 41/50
#  - 16s - loss: 0.0044 - acc: 0.9991 - categorical_accuracy: 0.2309 - f2_score: 0.2048 - f2_score_1: 0.1765 - f2_score_2: 0.1559 - f2_score_3: 0.1341 - f2_score_4: 0.1111 - f2_score_5: 0.0919 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2125 - val_f2_score: 0.1919 - val_f2_score_1: 0.1601 - val_f2_score_2: 0.1323 - val_f2_score_3: 0.1173 - val_f2_score_4: 0.0837 - val_f2_score_5: 0.0775
# Epoch 42/50
#  - 16s - loss: 0.0044 - acc: 0.9991 - categorical_accuracy: 0.2219 - f2_score: 0.1987 - f2_score_1: 0.1698 - f2_score_2: 0.1439 - f2_score_3: 0.1283 - f2_score_4: 0.1015 - f2_score_5: 0.0828 - val_loss: 0.0050 - val_acc: 0.9991 - val_categorical_accuracy: 0.2125 - val_f2_score: 0.2037 - val_f2_score_1: 0.1838 - val_f2_score_2: 0.1626 - val_f2_score_3: 0.1408 - val_f2_score_4: 0.1106 - val_f2_score_5: 0.0823
# Epoch 43/50
#  - 16s - loss: 0.0043 - acc: 0.9991 - categorical_accuracy: 0.2540 - f2_score: 0.2247 - f2_score_1: 0.1919 - f2_score_2: 0.1669 - f2_score_3: 0.1462 - f2_score_4: 0.1190 - f2_score_5: 0.0991 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2260 - val_f2_score: 0.2186 - val_f2_score_1: 0.1836 - val_f2_score_2: 0.1607 - val_f2_score_3: 0.1446 - val_f2_score_4: 0.1090 - val_f2_score_5: 0.0911
# Epoch 44/50
#  - 16s - loss: 0.0042 - acc: 0.9991 - categorical_accuracy: 0.2481 - f2_score: 0.2279 - f2_score_1: 0.1994 - f2_score_2: 0.1725 - f2_score_3: 0.1520 - f2_score_4: 0.1229 - f2_score_5: 0.1042 - val_loss: 0.0051 - val_acc: 0.9991 - val_categorical_accuracy: 0.2250 - val_f2_score: 0.2057 - val_f2_score_1: 0.1713 - val_f2_score_2: 0.1460 - val_f2_score_3: 0.1244 - val_f2_score_4: 0.0987 - val_f2_score_5: 0.0837
# Epoch 45/50
#  - 17s - loss: 0.0041 - acc: 0.9992 - categorical_accuracy: 0.2646 - f2_score: 0.2440 - f2_score_1: 0.2148 - f2_score_2: 0.1978 - f2_score_3: 0.1739 - f2_score_4: 0.1408 - f2_score_5: 0.1130 - val_loss: 0.0052 - val_acc: 0.9991 - val_categorical_accuracy: 0.1900 - val_f2_score: 0.1943 - val_f2_score_1: 0.1733 - val_f2_score_2: 0.1585 - val_f2_score_3: 0.1325 - val_f2_score_4: 0.1015 - val_f2_score_5: 0.0871
# Epoch 46/50
#  - 16s - loss: 0.0040 - acc: 0.9992 - categorical_accuracy: 0.2789 - f2_score: 0.2527 - f2_score_1: 0.2259 - f2_score_2: 0.1966 - f2_score_3: 0.1759 - f2_score_4: 0.1430 - f2_score_5: 0.1174 - val_loss: 0.0049 - val_acc: 0.9991 - val_categorical_accuracy: 0.2350 - val_f2_score: 0.2305 - val_f2_score_1: 0.1967 - val_f2_score_2: 0.1715 - val_f2_score_3: 0.1481 - val_f2_score_4: 0.1231 - val_f2_score_5: 0.0996
# Epoch 47/50
#  - 17s - loss: 0.0039 - acc: 0.9992 - categorical_accuracy: 0.2945 - f2_score: 0.2673 - f2_score_1: 0.2388 - f2_score_2: 0.2099 - f2_score_3: 0.1893 - f2_score_4: 0.1538 - f2_score_5: 0.1291 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2313 - val_f2_score: 0.2224 - val_f2_score_1: 0.1979 - val_f2_score_2: 0.1818 - val_f2_score_3: 0.1583 - val_f2_score_4: 0.1219 - val_f2_score_5: 0.0960
# Epoch 48/50
#  - 16s - loss: 0.0038 - acc: 0.9992 - categorical_accuracy: 0.3062 - f2_score: 0.2828 - f2_score_1: 0.2497 - f2_score_2: 0.2246 - f2_score_3: 0.1986 - f2_score_4: 0.1659 - f2_score_5: 0.1361 - val_loss: 0.0048 - val_acc: 0.9991 - val_categorical_accuracy: 0.2263 - val_f2_score: 0.2281 - val_f2_score_1: 0.1759 - val_f2_score_2: 0.1557 - val_f2_score_3: 0.1404 - val_f2_score_4: 0.1140 - val_f2_score_5: 0.0925
# Epoch 49/50
#  - 16s - loss: 0.0037 - acc: 0.9992 - categorical_accuracy: 0.3104 - f2_score: 0.2866 - f2_score_1: 0.2565 - f2_score_2: 0.2294 - f2_score_3: 0.2101 - f2_score_4: 0.1749 - f2_score_5: 0.1516 - val_loss: 0.0050 - val_acc: 0.9992 - val_categorical_accuracy: 0.2200 - val_f2_score: 0.2018 - val_f2_score_1: 0.1725 - val_f2_score_2: 0.1627 - val_f2_score_3: 0.1486 - val_f2_score_4: 0.1200 - val_f2_score_5: 0.0975
# Epoch 50/50
#  - 16s - loss: 0.0037 - acc: 0.9992 - categorical_accuracy: 0.3253 - f2_score: 0.3011 - f2_score_1: 0.2738 - f2_score_2: 0.2433 - f2_score_3: 0.2219 - f2_score_4: 0.1769 - f2_score_5: 0.1446 - val_loss: 0.0049 - val_acc: 0.9992 - val_categorical_accuracy: 0.2500 - val_f2_score: 0.2506 - val_f2_score_1: 0.2222 - val_f2_score_2: 0.1957 - val_f2_score_3: 0.1642 - val_f2_score_4: 0.1302 - val_f2_score_5: 0.1037

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', figsize=(20,7))

ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = 1

threshold = thresholds[best_thr]

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
preds = model.predict_generator(test_generator, steps=STEP_SIZE_TEST)

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += labels[idx]
            else:
                valid += (' %s' % labels[idx])
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id attribute_ids
# 0  10023b2cc4ed5f68           129
# 1  100fbe75ed8fd887     1039 1059
# 2  101b627524a04f19           897
# 3  10234480c41284c6           599
# 4  1023b0e2636dcea8            46
# 5   1039cd6cf85845c      1092 813
# 6   103a5b3f83fbe88            54
# 7  10413aaae8d6a9a2          1046
# 8  10423822b93a65ab       501 975
# 9  1052bf702cb099f7           897
