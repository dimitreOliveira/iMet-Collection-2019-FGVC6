# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 11s - loss: 0.0234 - acc: 0.9945 - categorical_accuracy: 0.0361 - f2_score: 0.0893 - f2_score_1: 0.0670 - f2_score_2: 0.0499 - f2_score_3: 0.0370 - f2_score_4: 0.0201 - f2_score_5: 0.0107 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0279 - val_f2_score: 0.0798 - val_f2_score_1: 0.0425 - val_f2_score_2: 0.0189 - val_f2_score_3: 0.0038 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 10s - loss: 0.0160 - acc: 0.9971 - categorical_accuracy: 0.0564 - f2_score: 0.1215 - f2_score_1: 0.0848 - f2_score_2: 0.0571 - f2_score_3: 0.0369 - f2_score_4: 0.0138 - f2_score_5: 0.0042 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0402 - val_f2_score: 0.1106 - val_f2_score_1: 0.0710 - val_f2_score_2: 0.0480 - val_f2_score_3: 0.0311 - val_f2_score_4: 0.0056 - val_f2_score_5: 1.4883e-04
# Epoch 3/200
#  - 10s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0685 - f2_score: 0.1384 - f2_score_1: 0.0969 - f2_score_2: 0.0662 - f2_score_3: 0.0438 - f2_score_4: 0.0166 - f2_score_5: 0.0049 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0615 - val_f2_score: 0.1329 - val_f2_score_1: 0.0903 - val_f2_score_2: 0.0619 - val_f2_score_3: 0.0409 - val_f2_score_4: 0.0104 - val_f2_score_5: 7.0611e-04
# Epoch 4/200
#  - 10s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0792 - f2_score: 0.1522 - f2_score_1: 0.1084 - f2_score_2: 0.0760 - f2_score_3: 0.0516 - f2_score_4: 0.0214 - f2_score_5: 0.0073 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0677 - val_f2_score: 0.1472 - val_f2_score_1: 0.1028 - val_f2_score_2: 0.0715 - val_f2_score_3: 0.0504 - val_f2_score_4: 0.0184 - val_f2_score_5: 0.0030
# Epoch 5/200
#  - 10s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1640 - f2_score_1: 0.1186 - f2_score_2: 0.0842 - f2_score_3: 0.0588 - f2_score_4: 0.0254 - f2_score_5: 0.0096 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0744 - val_f2_score: 0.1593 - val_f2_score_1: 0.1133 - val_f2_score_2: 0.0814 - val_f2_score_3: 0.0579 - val_f2_score_4: 0.0247 - val_f2_score_5: 0.0068
# Epoch 6/200
#  - 10s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0925 - f2_score: 0.1725 - f2_score_1: 0.1269 - f2_score_2: 0.0914 - f2_score_3: 0.0651 - f2_score_4: 0.0309 - f2_score_5: 0.0127 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0714 - val_f2_score: 0.1690 - val_f2_score_1: 0.1235 - val_f2_score_2: 0.0912 - val_f2_score_3: 0.0680 - val_f2_score_4: 0.0342 - val_f2_score_5: 0.0120
# Epoch 7/200
#  - 11s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0962 - f2_score: 0.1814 - f2_score_1: 0.1346 - f2_score_2: 0.0985 - f2_score_3: 0.0708 - f2_score_4: 0.0348 - f2_score_5: 0.0150 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.1016 - val_f2_score: 0.1729 - val_f2_score_1: 0.1229 - val_f2_score_2: 0.0860 - val_f2_score_3: 0.0598 - val_f2_score_4: 0.0263 - val_f2_score_5: 0.0100
# Epoch 8/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0999 - f2_score: 0.1875 - f2_score_1: 0.1406 - f2_score_2: 0.1046 - f2_score_3: 0.0763 - f2_score_4: 0.0385 - f2_score_5: 0.0178 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.1031 - val_f2_score: 0.1774 - val_f2_score_1: 0.1257 - val_f2_score_2: 0.0888 - val_f2_score_3: 0.0624 - val_f2_score_4: 0.0281 - val_f2_score_5: 0.0104
# Epoch 9/200
#  - 11s - loss: 0.0139 - acc: 0.9971 - categorical_accuracy: 0.1035 - f2_score: 0.1947 - f2_score_1: 0.1475 - f2_score_2: 0.1102 - f2_score_3: 0.0815 - f2_score_4: 0.0432 - f2_score_5: 0.0210 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.1834 - val_f2_score_1: 0.1326 - val_f2_score_2: 0.0952 - val_f2_score_3: 0.0693 - val_f2_score_4: 0.0337 - val_f2_score_5: 0.0148
# Epoch 10/200
#  - 10s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1047 - f2_score: 0.1987 - f2_score_1: 0.1514 - f2_score_2: 0.1140 - f2_score_3: 0.0849 - f2_score_4: 0.0452 - f2_score_5: 0.0221 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1001 - val_f2_score: 0.1916 - val_f2_score_1: 0.1425 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0787 - val_f2_score_4: 0.0406 - val_f2_score_5: 0.0185
# Epoch 11/200
#  - 10s - loss: 0.0138 - acc: 0.9971 - categorical_accuracy: 0.1062 - f2_score: 0.2020 - f2_score_1: 0.1544 - f2_score_2: 0.1164 - f2_score_3: 0.0869 - f2_score_4: 0.0469 - f2_score_5: 0.0240 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1009 - val_f2_score: 0.1965 - val_f2_score_1: 0.1455 - val_f2_score_2: 0.1079 - val_f2_score_3: 0.0797 - val_f2_score_4: 0.0413 - val_f2_score_5: 0.0189
# Epoch 12/200
#  - 10s - loss: 0.0137 - acc: 0.9971 - categorical_accuracy: 0.1055 - f2_score: 0.2044 - f2_score_1: 0.1571 - f2_score_2: 0.1188 - f2_score_3: 0.0893 - f2_score_4: 0.0484 - f2_score_5: 0.0248 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1035 - val_f2_score: 0.1939 - val_f2_score_1: 0.1439 - val_f2_score_2: 0.1066 - val_f2_score_3: 0.0793 - val_f2_score_4: 0.0418 - val_f2_score_5: 0.0197
# Epoch 13/200
#  - 10s - loss: 0.0137 - acc: 0.9972 - categorical_accuracy: 0.1097 - f2_score: 0.2073 - f2_score_1: 0.1603 - f2_score_2: 0.1215 - f2_score_3: 0.0913 - f2_score_4: 0.0505 - f2_score_5: 0.0259 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.0989 - val_f2_score: 0.2019 - val_f2_score_1: 0.1524 - val_f2_score_2: 0.1149 - val_f2_score_3: 0.0860 - val_f2_score_4: 0.0461 - val_f2_score_5: 0.0222
# Epoch 14/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1091 - f2_score: 0.2098 - f2_score_1: 0.1631 - f2_score_2: 0.1243 - f2_score_3: 0.0941 - f2_score_4: 0.0522 - f2_score_5: 0.0274 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1130 - val_f2_score: 0.2005 - val_f2_score_1: 0.1491 - val_f2_score_2: 0.1101 - val_f2_score_3: 0.0818 - val_f2_score_4: 0.0429 - val_f2_score_5: 0.0206
# Epoch 15/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1116 - f2_score: 0.2130 - f2_score_1: 0.1649 - f2_score_2: 0.1265 - f2_score_3: 0.0963 - f2_score_4: 0.0532 - f2_score_5: 0.0285 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1055 - val_f2_score: 0.2035 - val_f2_score_1: 0.1533 - val_f2_score_2: 0.1151 - val_f2_score_3: 0.0873 - val_f2_score_4: 0.0484 - val_f2_score_5: 0.0253
# Epoch 16/200
#  - 10s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1110 - f2_score: 0.2147 - f2_score_1: 0.1667 - f2_score_2: 0.1286 - f2_score_3: 0.0982 - f2_score_4: 0.0553 - f2_score_5: 0.0297 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1143 - val_f2_score: 0.2071 - val_f2_score_1: 0.1556 - val_f2_score_2: 0.1166 - val_f2_score_3: 0.0871 - val_f2_score_4: 0.0472 - val_f2_score_5: 0.0238
# Epoch 17/200
#  - 11s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1142 - f2_score: 0.2170 - f2_score_1: 0.1701 - f2_score_2: 0.1313 - f2_score_3: 0.1007 - f2_score_4: 0.0569 - f2_score_5: 0.0303 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1120 - val_f2_score: 0.2117 - val_f2_score_1: 0.1589 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0891 - val_f2_score_4: 0.0480 - val_f2_score_5: 0.0249
# Epoch 18/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1153 - f2_score: 0.2197 - f2_score_1: 0.1724 - f2_score_2: 0.1335 - f2_score_3: 0.1026 - f2_score_4: 0.0585 - f2_score_5: 0.0319 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1053 - val_f2_score: 0.2118 - val_f2_score_1: 0.1618 - val_f2_score_2: 0.1229 - val_f2_score_3: 0.0939 - val_f2_score_4: 0.0527 - val_f2_score_5: 0.0286
# Epoch 19/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1154 - f2_score: 0.2209 - f2_score_1: 0.1732 - f2_score_2: 0.1340 - f2_score_3: 0.1034 - f2_score_4: 0.0594 - f2_score_5: 0.0325 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1165 - val_f2_score: 0.2161 - val_f2_score_1: 0.1643 - val_f2_score_2: 0.1243 - val_f2_score_3: 0.0933 - val_f2_score_4: 0.0514 - val_f2_score_5: 0.0267
# Epoch 20/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1164 - f2_score: 0.2234 - f2_score_1: 0.1758 - f2_score_2: 0.1358 - f2_score_3: 0.1047 - f2_score_4: 0.0603 - f2_score_5: 0.0338 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1190 - val_f2_score: 0.2153 - val_f2_score_1: 0.1627 - val_f2_score_2: 0.1226 - val_f2_score_3: 0.0917 - val_f2_score_4: 0.0502 - val_f2_score_5: 0.0267
# Epoch 21/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1153 - f2_score: 0.2239 - f2_score_1: 0.1761 - f2_score_2: 0.1366 - f2_score_3: 0.1054 - f2_score_4: 0.0607 - f2_score_5: 0.0338 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1200 - val_f2_score: 0.2157 - val_f2_score_1: 0.1639 - val_f2_score_2: 0.1243 - val_f2_score_3: 0.0936 - val_f2_score_4: 0.0522 - val_f2_score_5: 0.0282
# Epoch 22/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1179 - f2_score: 0.2260 - f2_score_1: 0.1780 - f2_score_2: 0.1388 - f2_score_3: 0.1068 - f2_score_4: 0.0628 - f2_score_5: 0.0350 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1141 - val_f2_score: 0.2137 - val_f2_score_1: 0.1619 - val_f2_score_2: 0.1224 - val_f2_score_3: 0.0933 - val_f2_score_4: 0.0521 - val_f2_score_5: 0.0277
# Epoch 23/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1180 - f2_score: 0.2260 - f2_score_1: 0.1776 - f2_score_2: 0.1384 - f2_score_3: 0.1066 - f2_score_4: 0.0621 - f2_score_5: 0.0348 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1137 - val_f2_score: 0.2178 - val_f2_score_1: 0.1658 - val_f2_score_2: 0.1268 - val_f2_score_3: 0.0967 - val_f2_score_4: 0.0551 - val_f2_score_5: 0.0304
# Epoch 24/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1179 - f2_score: 0.2271 - f2_score_1: 0.1794 - f2_score_2: 0.1397 - f2_score_3: 0.1079 - f2_score_4: 0.0633 - f2_score_5: 0.0354 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1151 - val_f2_score: 0.2203 - val_f2_score_1: 0.1678 - val_f2_score_2: 0.1282 - val_f2_score_3: 0.0971 - val_f2_score_4: 0.0543 - val_f2_score_5: 0.0292
# Epoch 25/200
#  - 11s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1191 - f2_score: 0.2285 - f2_score_1: 0.1809 - f2_score_2: 0.1411 - f2_score_3: 0.1097 - f2_score_4: 0.0644 - f2_score_5: 0.0364 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1126 - val_f2_score: 0.2215 - val_f2_score_1: 0.1690 - val_f2_score_2: 0.1285 - val_f2_score_3: 0.0983 - val_f2_score_4: 0.0559 - val_f2_score_5: 0.0307
# Epoch 26/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1201 - f2_score: 0.2287 - f2_score_1: 0.1813 - f2_score_2: 0.1416 - f2_score_3: 0.1101 - f2_score_4: 0.0646 - f2_score_5: 0.0361 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1135 - val_f2_score: 0.2233 - val_f2_score_1: 0.1704 - val_f2_score_2: 0.1308 - val_f2_score_3: 0.1003 - val_f2_score_4: 0.0578 - val_f2_score_5: 0.0317
# Epoch 27/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1199 - f2_score: 0.2304 - f2_score_1: 0.1820 - f2_score_2: 0.1423 - f2_score_3: 0.1104 - f2_score_4: 0.0653 - f2_score_5: 0.0372 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1222 - val_f2_score: 0.2203 - val_f2_score_1: 0.1677 - val_f2_score_2: 0.1268 - val_f2_score_3: 0.0966 - val_f2_score_4: 0.0542 - val_f2_score_5: 0.0298
# Epoch 28/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1209 - f2_score: 0.2314 - f2_score_1: 0.1832 - f2_score_2: 0.1434 - f2_score_3: 0.1116 - f2_score_4: 0.0660 - f2_score_5: 0.0374 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1164 - val_f2_score: 0.2243 - val_f2_score_1: 0.1719 - val_f2_score_2: 0.1316 - val_f2_score_3: 0.1020 - val_f2_score_4: 0.0593 - val_f2_score_5: 0.0324
# Epoch 29/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1209 - f2_score: 0.2310 - f2_score_1: 0.1839 - f2_score_2: 0.1443 - f2_score_3: 0.1124 - f2_score_4: 0.0666 - f2_score_5: 0.0381 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1203 - val_f2_score: 0.2249 - val_f2_score_1: 0.1725 - val_f2_score_2: 0.1317 - val_f2_score_3: 0.1009 - val_f2_score_4: 0.0578 - val_f2_score_5: 0.0320
# Epoch 30/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1223 - f2_score: 0.2329 - f2_score_1: 0.1847 - f2_score_2: 0.1447 - f2_score_3: 0.1132 - f2_score_4: 0.0680 - f2_score_5: 0.0389 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1181 - val_f2_score: 0.2244 - val_f2_score_1: 0.1712 - val_f2_score_2: 0.1302 - val_f2_score_3: 0.0994 - val_f2_score_4: 0.0572 - val_f2_score_5: 0.0317
# Epoch 31/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1217 - f2_score: 0.2329 - f2_score_1: 0.1853 - f2_score_2: 0.1450 - f2_score_3: 0.1130 - f2_score_4: 0.0676 - f2_score_5: 0.0386 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1150 - val_f2_score: 0.2256 - val_f2_score_1: 0.1730 - val_f2_score_2: 0.1329 - val_f2_score_3: 0.1022 - val_f2_score_4: 0.0589 - val_f2_score_5: 0.0327
# Epoch 32/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1219 - f2_score: 0.2336 - f2_score_1: 0.1861 - f2_score_2: 0.1458 - f2_score_3: 0.1139 - f2_score_4: 0.0677 - f2_score_5: 0.0393 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1156 - val_f2_score: 0.2254 - val_f2_score_1: 0.1728 - val_f2_score_2: 0.1322 - val_f2_score_3: 0.1016 - val_f2_score_4: 0.0582 - val_f2_score_5: 0.0322
# Epoch 33/200
#  - 11s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1217 - f2_score: 0.2339 - f2_score_1: 0.1864 - f2_score_2: 0.1463 - f2_score_3: 0.1142 - f2_score_4: 0.0683 - f2_score_5: 0.0395 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.2270 - val_f2_score_1: 0.1739 - val_f2_score_2: 0.1327 - val_f2_score_3: 0.1016 - val_f2_score_4: 0.0576 - val_f2_score_5: 0.0321
# Epoch 34/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1215 - f2_score: 0.2339 - f2_score_1: 0.1866 - f2_score_2: 0.1467 - f2_score_3: 0.1147 - f2_score_4: 0.0686 - f2_score_5: 0.0392 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1216 - val_f2_score: 0.2273 - val_f2_score_1: 0.1742 - val_f2_score_2: 0.1325 - val_f2_score_3: 0.1009 - val_f2_score_4: 0.0579 - val_f2_score_5: 0.0322
# Epoch 35/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1222 - f2_score: 0.2346 - f2_score_1: 0.1873 - f2_score_2: 0.1464 - f2_score_3: 0.1140 - f2_score_4: 0.0683 - f2_score_5: 0.0394 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1165 - val_f2_score: 0.2293 - val_f2_score_1: 0.1768 - val_f2_score_2: 0.1359 - val_f2_score_3: 0.1049 - val_f2_score_4: 0.0618 - val_f2_score_5: 0.0346
# Epoch 36/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1216 - f2_score: 0.2357 - f2_score_1: 0.1870 - f2_score_2: 0.1467 - f2_score_3: 0.1142 - f2_score_4: 0.0687 - f2_score_5: 0.0398 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1190 - val_f2_score: 0.2285 - val_f2_score_1: 0.1758 - val_f2_score_2: 0.1345 - val_f2_score_3: 0.1031 - val_f2_score_4: 0.0591 - val_f2_score_5: 0.0328
# Epoch 37/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1219 - f2_score: 0.2362 - f2_score_1: 0.1884 - f2_score_2: 0.1483 - f2_score_3: 0.1156 - f2_score_4: 0.0692 - f2_score_5: 0.0401 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1201 - val_f2_score: 0.2300 - val_f2_score_1: 0.1771 - val_f2_score_2: 0.1355 - val_f2_score_3: 0.1039 - val_f2_score_4: 0.0600 - val_f2_score_5: 0.0335
# Epoch 38/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1232 - f2_score: 0.2358 - f2_score_1: 0.1887 - f2_score_2: 0.1488 - f2_score_3: 0.1163 - f2_score_4: 0.0698 - f2_score_5: 0.0404 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1174 - val_f2_score: 0.2305 - val_f2_score_1: 0.1778 - val_f2_score_2: 0.1370 - val_f2_score_3: 0.1053 - val_f2_score_4: 0.0617 - val_f2_score_5: 0.0346
# Epoch 39/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1229 - f2_score: 0.2373 - f2_score_1: 0.1893 - f2_score_2: 0.1488 - f2_score_3: 0.1166 - f2_score_4: 0.0701 - f2_score_5: 0.0408 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1205 - val_f2_score: 0.2285 - val_f2_score_1: 0.1747 - val_f2_score_2: 0.1329 - val_f2_score_3: 0.1017 - val_f2_score_4: 0.0582 - val_f2_score_5: 0.0322
# Epoch 40/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1223 - f2_score: 0.2362 - f2_score_1: 0.1888 - f2_score_2: 0.1485 - f2_score_3: 0.1161 - f2_score_4: 0.0693 - f2_score_5: 0.0401 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1243 - val_f2_score: 0.2304 - val_f2_score_1: 0.1767 - val_f2_score_2: 0.1352 - val_f2_score_3: 0.1031 - val_f2_score_4: 0.0592 - val_f2_score_5: 0.0328
# Epoch 41/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1233 - f2_score: 0.2375 - f2_score_1: 0.1898 - f2_score_2: 0.1487 - f2_score_3: 0.1169 - f2_score_4: 0.0703 - f2_score_5: 0.0409 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1188 - val_f2_score: 0.2299 - val_f2_score_1: 0.1775 - val_f2_score_2: 0.1360 - val_f2_score_3: 0.1047 - val_f2_score_4: 0.0606 - val_f2_score_5: 0.0341
# Epoch 42/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1234 - f2_score: 0.2373 - f2_score_1: 0.1902 - f2_score_2: 0.1491 - f2_score_3: 0.1167 - f2_score_4: 0.0703 - f2_score_5: 0.0412 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1189 - val_f2_score: 0.2310 - val_f2_score_1: 0.1773 - val_f2_score_2: 0.1363 - val_f2_score_3: 0.1045 - val_f2_score_4: 0.0608 - val_f2_score_5: 0.0340
# Epoch 43/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2368 - f2_score_1: 0.1898 - f2_score_2: 0.1500 - f2_score_3: 0.1177 - f2_score_4: 0.0705 - f2_score_5: 0.0410 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2308 - val_f2_score_1: 0.1777 - val_f2_score_2: 0.1359 - val_f2_score_3: 0.1043 - val_f2_score_4: 0.0604 - val_f2_score_5: 0.0337
# Epoch 44/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1225 - f2_score: 0.2381 - f2_score_1: 0.1905 - f2_score_2: 0.1503 - f2_score_3: 0.1176 - f2_score_4: 0.0706 - f2_score_5: 0.0411 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1204 - val_f2_score: 0.2313 - val_f2_score_1: 0.1778 - val_f2_score_2: 0.1366 - val_f2_score_3: 0.1050 - val_f2_score_4: 0.0610 - val_f2_score_5: 0.0342
# Epoch 45/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1240 - f2_score: 0.2372 - f2_score_1: 0.1894 - f2_score_2: 0.1499 - f2_score_3: 0.1174 - f2_score_4: 0.0712 - f2_score_5: 0.0418 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1177 - val_f2_score: 0.2323 - val_f2_score_1: 0.1790 - val_f2_score_2: 0.1376 - val_f2_score_3: 0.1060 - val_f2_score_4: 0.0622 - val_f2_score_5: 0.0350
# Epoch 46/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1230 - f2_score: 0.2387 - f2_score_1: 0.1906 - f2_score_2: 0.1502 - f2_score_3: 0.1174 - f2_score_4: 0.0710 - f2_score_5: 0.0413 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1194 - val_f2_score: 0.2318 - val_f2_score_1: 0.1786 - val_f2_score_2: 0.1371 - val_f2_score_3: 0.1050 - val_f2_score_4: 0.0612 - val_f2_score_5: 0.0345
# Epoch 47/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1233 - f2_score: 0.2391 - f2_score_1: 0.1913 - f2_score_2: 0.1507 - f2_score_3: 0.1179 - f2_score_4: 0.0717 - f2_score_5: 0.0420 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1209 - val_f2_score: 0.2317 - val_f2_score_1: 0.1785 - val_f2_score_2: 0.1378 - val_f2_score_3: 0.1057 - val_f2_score_4: 0.0616 - val_f2_score_5: 0.0347
# Epoch 48/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1237 - f2_score: 0.2383 - f2_score_1: 0.1912 - f2_score_2: 0.1510 - f2_score_3: 0.1183 - f2_score_4: 0.0712 - f2_score_5: 0.0413 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.2332 - val_f2_score_1: 0.1800 - val_f2_score_2: 0.1386 - val_f2_score_3: 0.1065 - val_f2_score_4: 0.0621 - val_f2_score_5: 0.0349
# Epoch 49/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1231 - f2_score: 0.2389 - f2_score_1: 0.1913 - f2_score_2: 0.1514 - f2_score_3: 0.1193 - f2_score_4: 0.0725 - f2_score_5: 0.0421 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1225 - val_f2_score: 0.2317 - val_f2_score_1: 0.1786 - val_f2_score_2: 0.1367 - val_f2_score_3: 0.1052 - val_f2_score_4: 0.0611 - val_f2_score_5: 0.0343
# Epoch 50/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2383 - f2_score_1: 0.1905 - f2_score_2: 0.1503 - f2_score_3: 0.1185 - f2_score_4: 0.0716 - f2_score_5: 0.0417 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1207 - val_f2_score: 0.2331 - val_f2_score_1: 0.1799 - val_f2_score_2: 0.1385 - val_f2_score_3: 0.1063 - val_f2_score_4: 0.0619 - val_f2_score_5: 0.0350
# Epoch 51/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2385 - f2_score_1: 0.1911 - f2_score_2: 0.1510 - f2_score_3: 0.1187 - f2_score_4: 0.0719 - f2_score_5: 0.0419 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1199 - val_f2_score: 0.2324 - val_f2_score_1: 0.1795 - val_f2_score_2: 0.1382 - val_f2_score_3: 0.1066 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0352
# Epoch 52/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1256 - f2_score: 0.2390 - f2_score_1: 0.1919 - f2_score_2: 0.1514 - f2_score_3: 0.1189 - f2_score_4: 0.0721 - f2_score_5: 0.0418 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1207 - val_f2_score: 0.2326 - val_f2_score_1: 0.1791 - val_f2_score_2: 0.1377 - val_f2_score_3: 0.1058 - val_f2_score_4: 0.0619 - val_f2_score_5: 0.0348
# Epoch 53/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1242 - f2_score: 0.2395 - f2_score_1: 0.1915 - f2_score_2: 0.1511 - f2_score_3: 0.1187 - f2_score_4: 0.0721 - f2_score_5: 0.0421 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1216 - val_f2_score: 0.2336 - val_f2_score_1: 0.1803 - val_f2_score_2: 0.1387 - val_f2_score_3: 0.1066 - val_f2_score_4: 0.0624 - val_f2_score_5: 0.0349
# Epoch 54/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2400 - f2_score_1: 0.1922 - f2_score_2: 0.1518 - f2_score_3: 0.1191 - f2_score_4: 0.0722 - f2_score_5: 0.0423 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1198 - val_f2_score: 0.2336 - val_f2_score_1: 0.1802 - val_f2_score_2: 0.1386 - val_f2_score_3: 0.1069 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0353
# Epoch 55/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1250 - f2_score: 0.2394 - f2_score_1: 0.1925 - f2_score_2: 0.1524 - f2_score_3: 0.1194 - f2_score_4: 0.0724 - f2_score_5: 0.0424 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1221 - val_f2_score: 0.2335 - val_f2_score_1: 0.1799 - val_f2_score_2: 0.1382 - val_f2_score_3: 0.1062 - val_f2_score_4: 0.0619 - val_f2_score_5: 0.0347
# Epoch 56/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1239 - f2_score: 0.2389 - f2_score_1: 0.1916 - f2_score_2: 0.1509 - f2_score_3: 0.1185 - f2_score_4: 0.0715 - f2_score_5: 0.0419 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2340 - val_f2_score_1: 0.1804 - val_f2_score_2: 0.1389 - val_f2_score_3: 0.1069 - val_f2_score_4: 0.0621 - val_f2_score_5: 0.0351
# Epoch 57/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1227 - f2_score: 0.2397 - f2_score_1: 0.1915 - f2_score_2: 0.1520 - f2_score_3: 0.1186 - f2_score_4: 0.0724 - f2_score_5: 0.0422 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1223 - val_f2_score: 0.2337 - val_f2_score_1: 0.1800 - val_f2_score_2: 0.1381 - val_f2_score_3: 0.1064 - val_f2_score_4: 0.0617 - val_f2_score_5: 0.0347
# Epoch 58/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2400 - f2_score_1: 0.1924 - f2_score_2: 0.1521 - f2_score_3: 0.1192 - f2_score_4: 0.0716 - f2_score_5: 0.0417 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.2338 - val_f2_score_1: 0.1802 - val_f2_score_2: 0.1387 - val_f2_score_3: 0.1067 - val_f2_score_4: 0.0619 - val_f2_score_5: 0.0351
# Epoch 59/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2399 - f2_score_1: 0.1915 - f2_score_2: 0.1513 - f2_score_3: 0.1192 - f2_score_4: 0.0717 - f2_score_5: 0.0420 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1194 - val_f2_score: 0.2344 - val_f2_score_1: 0.1809 - val_f2_score_2: 0.1394 - val_f2_score_3: 0.1077 - val_f2_score_4: 0.0632 - val_f2_score_5: 0.0357
# Epoch 60/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1242 - f2_score: 0.2402 - f2_score_1: 0.1921 - f2_score_2: 0.1523 - f2_score_3: 0.1200 - f2_score_4: 0.0730 - f2_score_5: 0.0426 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1203 - val_f2_score: 0.2344 - val_f2_score_1: 0.1805 - val_f2_score_2: 0.1388 - val_f2_score_3: 0.1071 - val_f2_score_4: 0.0624 - val_f2_score_5: 0.0354
# Epoch 61/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1238 - f2_score: 0.2395 - f2_score_1: 0.1927 - f2_score_2: 0.1523 - f2_score_3: 0.1199 - f2_score_4: 0.0718 - f2_score_5: 0.0423 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1208 - val_f2_score: 0.2343 - val_f2_score_1: 0.1807 - val_f2_score_2: 0.1392 - val_f2_score_3: 0.1074 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0356
# Epoch 62/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1252 - f2_score: 0.2401 - f2_score_1: 0.1923 - f2_score_2: 0.1523 - f2_score_3: 0.1196 - f2_score_4: 0.0730 - f2_score_5: 0.0426 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1204 - val_f2_score: 0.2347 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0356
# Epoch 63/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1253 - f2_score: 0.2404 - f2_score_1: 0.1928 - f2_score_2: 0.1528 - f2_score_3: 0.1194 - f2_score_4: 0.0725 - f2_score_5: 0.0423 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1202 - val_f2_score: 0.2349 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1083 - val_f2_score_4: 0.0634 - val_f2_score_5: 0.0358
# Epoch 64/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2417 - f2_score_1: 0.1932 - f2_score_2: 0.1526 - f2_score_3: 0.1196 - f2_score_4: 0.0727 - f2_score_5: 0.0424 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.2345 - val_f2_score_1: 0.1807 - val_f2_score_2: 0.1393 - val_f2_score_3: 0.1076 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0356
# Epoch 65/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1259 - f2_score: 0.2408 - f2_score_1: 0.1931 - f2_score_2: 0.1521 - f2_score_3: 0.1195 - f2_score_4: 0.0724 - f2_score_5: 0.0424 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1196 - val_f2_score: 0.2350 - val_f2_score_1: 0.1816 - val_f2_score_2: 0.1401 - val_f2_score_3: 0.1084 - val_f2_score_4: 0.0637 - val_f2_score_5: 0.0359
# Epoch 66/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1236 - f2_score: 0.2408 - f2_score_1: 0.1930 - f2_score_2: 0.1521 - f2_score_3: 0.1194 - f2_score_4: 0.0728 - f2_score_5: 0.0428 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2347 - val_f2_score_1: 0.1811 - val_f2_score_2: 0.1394 - val_f2_score_3: 0.1077 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0354
# Epoch 67/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1236 - f2_score: 0.2408 - f2_score_1: 0.1928 - f2_score_2: 0.1520 - f2_score_3: 0.1195 - f2_score_4: 0.0730 - f2_score_5: 0.0425 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2345 - val_f2_score_1: 0.1810 - val_f2_score_2: 0.1392 - val_f2_score_3: 0.1076 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0354
# Epoch 68/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1238 - f2_score: 0.2400 - f2_score_1: 0.1921 - f2_score_2: 0.1523 - f2_score_3: 0.1199 - f2_score_4: 0.0729 - f2_score_5: 0.0424 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2349 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1076 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 69/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2408 - f2_score_1: 0.1922 - f2_score_2: 0.1517 - f2_score_3: 0.1192 - f2_score_4: 0.0729 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1217 - val_f2_score: 0.2345 - val_f2_score_1: 0.1808 - val_f2_score_2: 0.1391 - val_f2_score_3: 0.1074 - val_f2_score_4: 0.0625 - val_f2_score_5: 0.0354
# Epoch 70/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1238 - f2_score: 0.2397 - f2_score_1: 0.1924 - f2_score_2: 0.1518 - f2_score_3: 0.1191 - f2_score_4: 0.0730 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2348 - val_f2_score_1: 0.1810 - val_f2_score_2: 0.1394 - val_f2_score_3: 0.1076 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0355
# Epoch 71/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1254 - f2_score: 0.2402 - f2_score_1: 0.1925 - f2_score_2: 0.1526 - f2_score_3: 0.1200 - f2_score_4: 0.0733 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2349 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1396 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 72/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1242 - f2_score: 0.2404 - f2_score_1: 0.1928 - f2_score_2: 0.1535 - f2_score_3: 0.1206 - f2_score_4: 0.0728 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.2349 - val_f2_score_1: 0.1810 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1077 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0355
# Epoch 73/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1251 - f2_score: 0.2409 - f2_score_1: 0.1928 - f2_score_2: 0.1524 - f2_score_3: 0.1195 - f2_score_4: 0.0731 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1209 - val_f2_score: 0.2349 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1397 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 74/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1254 - f2_score: 0.2400 - f2_score_1: 0.1922 - f2_score_2: 0.1521 - f2_score_3: 0.1193 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2350 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 75/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1249 - f2_score: 0.2415 - f2_score_1: 0.1932 - f2_score_2: 0.1522 - f2_score_3: 0.1196 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2352 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1078 - val_f2_score_4: 0.0626 - val_f2_score_5: 0.0356
# Epoch 76/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.2410 - f2_score_1: 0.1930 - f2_score_2: 0.1525 - f2_score_3: 0.1198 - f2_score_4: 0.0723 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2351 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1395 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 77/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2401 - f2_score_1: 0.1924 - f2_score_2: 0.1526 - f2_score_3: 0.1201 - f2_score_4: 0.0725 - f2_score_5: 0.0428 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2350 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1396 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0355
# Epoch 78/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1255 - f2_score: 0.2405 - f2_score_1: 0.1927 - f2_score_2: 0.1526 - f2_score_3: 0.1194 - f2_score_4: 0.0723 - f2_score_5: 0.0425 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1209 - val_f2_score: 0.2350 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1396 - val_f2_score_3: 0.1080 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0356
# Epoch 79/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1257 - f2_score: 0.2409 - f2_score_1: 0.1940 - f2_score_2: 0.1527 - f2_score_3: 0.1197 - f2_score_4: 0.0729 - f2_score_5: 0.0430 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2351 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 80/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2406 - f2_score_1: 0.1936 - f2_score_2: 0.1536 - f2_score_3: 0.1204 - f2_score_4: 0.0727 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2351 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1080 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0356
# Epoch 81/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2414 - f2_score_1: 0.1930 - f2_score_2: 0.1529 - f2_score_3: 0.1205 - f2_score_4: 0.0736 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.2350 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1396 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 82/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1263 - f2_score: 0.2403 - f2_score_1: 0.1927 - f2_score_2: 0.1521 - f2_score_3: 0.1196 - f2_score_4: 0.0724 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2351 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1397 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 83/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1249 - f2_score: 0.2414 - f2_score_1: 0.1936 - f2_score_2: 0.1532 - f2_score_3: 0.1206 - f2_score_4: 0.0728 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2351 - val_f2_score_1: 0.1812 - val_f2_score_2: 0.1397 - val_f2_score_3: 0.1080 - val_f2_score_4: 0.0627 - val_f2_score_5: 0.0356
# Epoch 84/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1254 - f2_score: 0.2406 - f2_score_1: 0.1936 - f2_score_2: 0.1525 - f2_score_3: 0.1203 - f2_score_4: 0.0731 - f2_score_5: 0.0428 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.2353 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0356
# Epoch 85/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1255 - f2_score: 0.2412 - f2_score_1: 0.1935 - f2_score_2: 0.1531 - f2_score_3: 0.1202 - f2_score_4: 0.0729 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1210 - val_f2_score: 0.2353 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 86/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1240 - f2_score: 0.2411 - f2_score_1: 0.1930 - f2_score_2: 0.1523 - f2_score_3: 0.1202 - f2_score_4: 0.0732 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 87/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2409 - f2_score_1: 0.1938 - f2_score_2: 0.1528 - f2_score_3: 0.1203 - f2_score_4: 0.0732 - f2_score_5: 0.0428 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1211 - val_f2_score: 0.2352 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 88/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1250 - f2_score: 0.2405 - f2_score_1: 0.1926 - f2_score_2: 0.1520 - f2_score_3: 0.1199 - f2_score_4: 0.0726 - f2_score_5: 0.0422 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.2352 - val_f2_score_1: 0.1813 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 89/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1250 - f2_score: 0.2404 - f2_score_1: 0.1933 - f2_score_2: 0.1527 - f2_score_3: 0.1201 - f2_score_4: 0.0738 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 90/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2399 - f2_score_1: 0.1925 - f2_score_2: 0.1526 - f2_score_3: 0.1199 - f2_score_4: 0.0726 - f2_score_5: 0.0425 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 91/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1239 - f2_score: 0.2408 - f2_score_1: 0.1934 - f2_score_2: 0.1526 - f2_score_3: 0.1198 - f2_score_4: 0.0728 - f2_score_5: 0.0423 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1215 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 92/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1243 - f2_score: 0.2412 - f2_score_1: 0.1933 - f2_score_2: 0.1532 - f2_score_3: 0.1202 - f2_score_4: 0.0735 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1215 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 93/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1257 - f2_score: 0.2422 - f2_score_1: 0.1938 - f2_score_2: 0.1528 - f2_score_3: 0.1197 - f2_score_4: 0.0720 - f2_score_5: 0.0424 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 94/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1240 - f2_score: 0.2412 - f2_score_1: 0.1936 - f2_score_2: 0.1529 - f2_score_3: 0.1205 - f2_score_4: 0.0733 - f2_score_5: 0.0428 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1080 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 95/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2416 - f2_score_1: 0.1939 - f2_score_2: 0.1525 - f2_score_3: 0.1204 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1215 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 96/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1249 - f2_score: 0.2411 - f2_score_1: 0.1939 - f2_score_2: 0.1532 - f2_score_3: 0.1204 - f2_score_4: 0.0731 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1815 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 97/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1256 - f2_score: 0.2415 - f2_score_1: 0.1935 - f2_score_2: 0.1537 - f2_score_3: 0.1207 - f2_score_4: 0.0735 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1213 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 98/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1240 - f2_score: 0.2398 - f2_score_1: 0.1919 - f2_score_2: 0.1523 - f2_score_3: 0.1197 - f2_score_4: 0.0725 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1398 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 99/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1254 - f2_score: 0.2399 - f2_score_1: 0.1926 - f2_score_2: 0.1522 - f2_score_3: 0.1203 - f2_score_4: 0.0727 - f2_score_5: 0.0426 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 100/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1253 - f2_score: 0.2410 - f2_score_1: 0.1932 - f2_score_2: 0.1524 - f2_score_3: 0.1197 - f2_score_4: 0.0728 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 101/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2407 - f2_score_1: 0.1931 - f2_score_2: 0.1530 - f2_score_3: 0.1204 - f2_score_4: 0.0726 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 102/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1258 - f2_score: 0.2407 - f2_score_1: 0.1929 - f2_score_2: 0.1525 - f2_score_3: 0.1198 - f2_score_4: 0.0725 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 103/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1252 - f2_score: 0.2411 - f2_score_1: 0.1940 - f2_score_2: 0.1532 - f2_score_3: 0.1205 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 104/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2408 - f2_score_1: 0.1932 - f2_score_2: 0.1525 - f2_score_3: 0.1199 - f2_score_4: 0.0733 - f2_score_5: 0.0430 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 105/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.2404 - f2_score_1: 0.1929 - f2_score_2: 0.1531 - f2_score_3: 0.1206 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 106/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1237 - f2_score: 0.2404 - f2_score_1: 0.1927 - f2_score_2: 0.1527 - f2_score_3: 0.1209 - f2_score_4: 0.0736 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 107/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1233 - f2_score: 0.2409 - f2_score_1: 0.1929 - f2_score_2: 0.1528 - f2_score_3: 0.1202 - f2_score_4: 0.0734 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0628 - val_f2_score_5: 0.0357
# Epoch 108/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2406 - f2_score_1: 0.1933 - f2_score_2: 0.1529 - f2_score_3: 0.1204 - f2_score_4: 0.0737 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 109/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2410 - f2_score_1: 0.1930 - f2_score_2: 0.1529 - f2_score_3: 0.1208 - f2_score_4: 0.0732 - f2_score_5: 0.0434 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 110/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2405 - f2_score_1: 0.1934 - f2_score_2: 0.1532 - f2_score_3: 0.1211 - f2_score_4: 0.0738 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 111/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1235 - f2_score: 0.2410 - f2_score_1: 0.1937 - f2_score_2: 0.1533 - f2_score_3: 0.1207 - f2_score_4: 0.0735 - f2_score_5: 0.0430 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 112/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.2412 - f2_score_1: 0.1942 - f2_score_2: 0.1533 - f2_score_3: 0.1204 - f2_score_4: 0.0733 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2353 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1081 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 113/200
# ...
# Epoch 164/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1239 - f2_score: 0.2407 - f2_score_1: 0.1929 - f2_score_2: 0.1532 - f2_score_3: 0.1204 - f2_score_4: 0.0728 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 165/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2404 - f2_score_1: 0.1925 - f2_score_2: 0.1526 - f2_score_3: 0.1200 - f2_score_4: 0.0734 - f2_score_5: 0.0436 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 166/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2415 - f2_score_1: 0.1939 - f2_score_2: 0.1534 - f2_score_3: 0.1201 - f2_score_4: 0.0734 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 167/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1254 - f2_score: 0.2406 - f2_score_1: 0.1933 - f2_score_2: 0.1532 - f2_score_3: 0.1201 - f2_score_4: 0.0731 - f2_score_5: 0.0425 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 168/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2404 - f2_score_1: 0.1930 - f2_score_2: 0.1530 - f2_score_3: 0.1206 - f2_score_4: 0.0734 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 169/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1256 - f2_score: 0.2406 - f2_score_1: 0.1927 - f2_score_2: 0.1526 - f2_score_3: 0.1202 - f2_score_4: 0.0730 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 170/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2411 - f2_score_1: 0.1931 - f2_score_2: 0.1530 - f2_score_3: 0.1205 - f2_score_4: 0.0731 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 171/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.2417 - f2_score_1: 0.1939 - f2_score_2: 0.1536 - f2_score_3: 0.1208 - f2_score_4: 0.0726 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 172/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1252 - f2_score: 0.2414 - f2_score_1: 0.1934 - f2_score_2: 0.1530 - f2_score_3: 0.1204 - f2_score_4: 0.0729 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 173/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1255 - f2_score: 0.2404 - f2_score_1: 0.1925 - f2_score_2: 0.1528 - f2_score_3: 0.1204 - f2_score_4: 0.0737 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 174/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1250 - f2_score: 0.2410 - f2_score_1: 0.1933 - f2_score_2: 0.1533 - f2_score_3: 0.1209 - f2_score_4: 0.0731 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 175/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2415 - f2_score_1: 0.1938 - f2_score_2: 0.1529 - f2_score_3: 0.1205 - f2_score_4: 0.0729 - f2_score_5: 0.0423 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 176/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2407 - f2_score_1: 0.1932 - f2_score_2: 0.1525 - f2_score_3: 0.1203 - f2_score_4: 0.0730 - f2_score_5: 0.0425 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 177/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1260 - f2_score: 0.2400 - f2_score_1: 0.1932 - f2_score_2: 0.1529 - f2_score_3: 0.1201 - f2_score_4: 0.0730 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 178/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1238 - f2_score: 0.2402 - f2_score_1: 0.1928 - f2_score_2: 0.1529 - f2_score_3: 0.1204 - f2_score_4: 0.0732 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 179/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1240 - f2_score: 0.2408 - f2_score_1: 0.1932 - f2_score_2: 0.1530 - f2_score_3: 0.1204 - f2_score_4: 0.0733 - f2_score_5: 0.0430 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 180/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1249 - f2_score: 0.2414 - f2_score_1: 0.1937 - f2_score_2: 0.1533 - f2_score_3: 0.1208 - f2_score_4: 0.0733 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 181/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2403 - f2_score_1: 0.1932 - f2_score_2: 0.1532 - f2_score_3: 0.1207 - f2_score_4: 0.0732 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 182/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2405 - f2_score_1: 0.1929 - f2_score_2: 0.1522 - f2_score_3: 0.1197 - f2_score_4: 0.0727 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 183/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1262 - f2_score: 0.2403 - f2_score_1: 0.1937 - f2_score_2: 0.1535 - f2_score_3: 0.1211 - f2_score_4: 0.0729 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 184/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1252 - f2_score: 0.2403 - f2_score_1: 0.1929 - f2_score_2: 0.1531 - f2_score_3: 0.1202 - f2_score_4: 0.0734 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 185/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2405 - f2_score_1: 0.1933 - f2_score_2: 0.1527 - f2_score_3: 0.1201 - f2_score_4: 0.0729 - f2_score_5: 0.0425 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 186/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1238 - f2_score: 0.2409 - f2_score_1: 0.1933 - f2_score_2: 0.1530 - f2_score_3: 0.1205 - f2_score_4: 0.0731 - f2_score_5: 0.0427 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 187/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2414 - f2_score_1: 0.1937 - f2_score_2: 0.1535 - f2_score_3: 0.1209 - f2_score_4: 0.0731 - f2_score_5: 0.0433 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 188/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1241 - f2_score: 0.2406 - f2_score_1: 0.1935 - f2_score_2: 0.1532 - f2_score_3: 0.1198 - f2_score_4: 0.0727 - f2_score_5: 0.0426 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 189/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1239 - f2_score: 0.2407 - f2_score_1: 0.1937 - f2_score_2: 0.1531 - f2_score_3: 0.1203 - f2_score_4: 0.0732 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 190/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1252 - f2_score: 0.2407 - f2_score_1: 0.1930 - f2_score_2: 0.1521 - f2_score_3: 0.1195 - f2_score_4: 0.0731 - f2_score_5: 0.0434 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 191/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1256 - f2_score: 0.2417 - f2_score_1: 0.1934 - f2_score_2: 0.1531 - f2_score_3: 0.1203 - f2_score_4: 0.0731 - f2_score_5: 0.0429 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 192/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1230 - f2_score: 0.2404 - f2_score_1: 0.1931 - f2_score_2: 0.1525 - f2_score_3: 0.1198 - f2_score_4: 0.0725 - f2_score_5: 0.0431 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 193/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1244 - f2_score: 0.2402 - f2_score_1: 0.1926 - f2_score_2: 0.1530 - f2_score_3: 0.1204 - f2_score_4: 0.0733 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 194/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1239 - f2_score: 0.2401 - f2_score_1: 0.1932 - f2_score_2: 0.1525 - f2_score_3: 0.1202 - f2_score_4: 0.0731 - f2_score_5: 0.0428 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 195/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1232 - f2_score: 0.2405 - f2_score_1: 0.1930 - f2_score_2: 0.1535 - f2_score_3: 0.1211 - f2_score_4: 0.0733 - f2_score_5: 0.0430 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 196/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2417 - f2_score_1: 0.1934 - f2_score_2: 0.1538 - f2_score_3: 0.1206 - f2_score_4: 0.0726 - f2_score_5: 0.0426 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 197/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2411 - f2_score_1: 0.1930 - f2_score_2: 0.1523 - f2_score_3: 0.1205 - f2_score_4: 0.0730 - f2_score_5: 0.0435 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 198/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1246 - f2_score: 0.2412 - f2_score_1: 0.1942 - f2_score_2: 0.1538 - f2_score_3: 0.1205 - f2_score_4: 0.0735 - f2_score_5: 0.0434 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 199/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1245 - f2_score: 0.2403 - f2_score_1: 0.1924 - f2_score_2: 0.1523 - f2_score_3: 0.1202 - f2_score_4: 0.0733 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357
# Epoch 200/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1236 - f2_score: 0.2400 - f2_score_1: 0.1926 - f2_score_2: 0.1524 - f2_score_3: 0.1194 - f2_score_4: 0.0729 - f2_score_5: 0.0432 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1214 - val_f2_score: 0.2354 - val_f2_score_1: 0.1814 - val_f2_score_2: 0.1399 - val_f2_score_3: 0.1082 - val_f2_score_4: 0.0629 - val_f2_score_5: 0.0357

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id        attribute_ids
# 0  10023b2cc4ed5f68                  121
# 1  100fbe75ed8fd887                  121
# 2  101b627524a04f19              813 961
# 3  10234480c41284c6        813 1046 1092
# 4  1023b0e2636dcea8                  671
# 5   1039cd6cf85845c  13 405 813 896 1092
# 6   103a5b3f83fbe88    194 813 1046 1092
# 7  10413aaae8d6a9a2         147 813 1092
# 8  10423822b93a65ab                  147
# 9  1052bf702cb099f7          147 189 671
