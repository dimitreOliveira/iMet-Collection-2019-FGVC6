# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras import applications
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using a pre-trained model

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the bottleneck network
model_base = applications.InceptionV3(weights=None, include_top=False)
model_base.load_weights('../input/inceptionv3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_base.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 13s - loss: 0.0270 - acc: 0.9936 - categorical_accuracy: 0.0418 - f2_score: 0.1093 - f2_score_1: 0.0882 - f2_score_2: 0.0693 - f2_score_3: 0.0536 - f2_score_4: 0.0309 - f2_score_5: 0.0173 - val_loss: 0.0154 - val_acc: 0.9971 - val_categorical_accuracy: 0.0672 - val_f2_score: 0.1311 - val_f2_score_1: 0.0883 - val_f2_score_2: 0.0580 - val_f2_score_3: 0.0363 - val_f2_score_4: 0.0113 - val_f2_score_5: 0.0015
# Epoch 2/200
#  - 10s - loss: 0.0165 - acc: 0.9971 - categorical_accuracy: 0.0699 - f2_score: 0.1607 - f2_score_1: 0.1239 - f2_score_2: 0.0926 - f2_score_3: 0.0675 - f2_score_4: 0.0347 - f2_score_5: 0.0163 - val_loss: 0.0145 - val_acc: 0.9971 - val_categorical_accuracy: 0.0817 - val_f2_score: 0.1619 - val_f2_score_1: 0.1125 - val_f2_score_2: 0.0775 - val_f2_score_3: 0.0525 - val_f2_score_4: 0.0215 - val_f2_score_5: 0.0061
# Epoch 3/200
#  - 10s - loss: 0.0155 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1845 - f2_score_1: 0.1432 - f2_score_2: 0.1102 - f2_score_3: 0.0823 - f2_score_4: 0.0448 - f2_score_5: 0.0231 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0858 - val_f2_score: 0.1869 - val_f2_score_1: 0.1393 - val_f2_score_2: 0.1008 - val_f2_score_3: 0.0731 - val_f2_score_4: 0.0368 - val_f2_score_5: 0.0157
# Epoch 4/200
#  - 10s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0934 - f2_score: 0.2013 - f2_score_1: 0.1600 - f2_score_2: 0.1242 - f2_score_3: 0.0949 - f2_score_4: 0.0540 - f2_score_5: 0.0289 - val_loss: 0.0137 - val_acc: 0.9972 - val_categorical_accuracy: 0.1202 - val_f2_score: 0.2047 - val_f2_score_1: 0.1574 - val_f2_score_2: 0.1154 - val_f2_score_3: 0.0830 - val_f2_score_4: 0.0409 - val_f2_score_5: 0.0182
# Epoch 5/200
#  - 10s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.1000 - f2_score: 0.2144 - f2_score_1: 0.1718 - f2_score_2: 0.1348 - f2_score_3: 0.1051 - f2_score_4: 0.0615 - f2_score_5: 0.0345 - val_loss: 0.0135 - val_acc: 0.9972 - val_categorical_accuracy: 0.1249 - val_f2_score: 0.2097 - val_f2_score_1: 0.1620 - val_f2_score_2: 0.1213 - val_f2_score_3: 0.0892 - val_f2_score_4: 0.0467 - val_f2_score_5: 0.0228
# Epoch 6/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.1055 - f2_score: 0.2242 - f2_score_1: 0.1818 - f2_score_2: 0.1451 - f2_score_3: 0.1137 - f2_score_4: 0.0678 - f2_score_5: 0.0392 - val_loss: 0.0132 - val_acc: 0.9972 - val_categorical_accuracy: 0.1107 - val_f2_score: 0.2264 - val_f2_score_1: 0.1765 - val_f2_score_2: 0.1359 - val_f2_score_3: 0.1028 - val_f2_score_4: 0.0553 - val_f2_score_5: 0.0287
# Epoch 7/200
#  - 10s - loss: 0.0141 - acc: 0.9972 - categorical_accuracy: 0.1086 - f2_score: 0.2335 - f2_score_1: 0.1904 - f2_score_2: 0.1523 - f2_score_3: 0.1210 - f2_score_4: 0.0739 - f2_score_5: 0.0437 - val_loss: 0.0131 - val_acc: 0.9972 - val_categorical_accuracy: 0.1101 - val_f2_score: 0.2310 - val_f2_score_1: 0.1815 - val_f2_score_2: 0.1411 - val_f2_score_3: 0.1091 - val_f2_score_4: 0.0607 - val_f2_score_5: 0.0327
# Epoch 8/200
#  - 10s - loss: 0.0139 - acc: 0.9972 - categorical_accuracy: 0.1120 - f2_score: 0.2409 - f2_score_1: 0.1984 - f2_score_2: 0.1595 - f2_score_3: 0.1269 - f2_score_4: 0.0787 - f2_score_5: 0.0470 - val_loss: 0.0130 - val_acc: 0.9972 - val_categorical_accuracy: 0.1268 - val_f2_score: 0.2348 - val_f2_score_1: 0.1884 - val_f2_score_2: 0.1481 - val_f2_score_3: 0.1147 - val_f2_score_4: 0.0635 - val_f2_score_5: 0.0337
# Epoch 9/200
#  - 10s - loss: 0.0137 - acc: 0.9972 - categorical_accuracy: 0.1137 - f2_score: 0.2465 - f2_score_1: 0.2042 - f2_score_2: 0.1661 - f2_score_3: 0.1333 - f2_score_4: 0.0836 - f2_score_5: 0.0505 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1237 - val_f2_score: 0.2445 - val_f2_score_1: 0.1951 - val_f2_score_2: 0.1528 - val_f2_score_3: 0.1185 - val_f2_score_4: 0.0668 - val_f2_score_5: 0.0362
# Epoch 10/200
#  - 10s - loss: 0.0136 - acc: 0.9972 - categorical_accuracy: 0.1158 - f2_score: 0.2518 - f2_score_1: 0.2088 - f2_score_2: 0.1693 - f2_score_3: 0.1366 - f2_score_4: 0.0866 - f2_score_5: 0.0527 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1225 - val_f2_score: 0.2452 - val_f2_score_1: 0.1972 - val_f2_score_2: 0.1562 - val_f2_score_3: 0.1226 - val_f2_score_4: 0.0722 - val_f2_score_5: 0.0406
# Epoch 11/200
#  - 11s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1175 - f2_score: 0.2560 - f2_score_1: 0.2126 - f2_score_2: 0.1732 - f2_score_3: 0.1402 - f2_score_4: 0.0891 - f2_score_5: 0.0550 - val_loss: 0.0128 - val_acc: 0.9972 - val_categorical_accuracy: 0.1160 - val_f2_score: 0.2517 - val_f2_score_1: 0.2040 - val_f2_score_2: 0.1639 - val_f2_score_3: 0.1307 - val_f2_score_4: 0.0808 - val_f2_score_5: 0.0461
# Epoch 12/200
#  - 10s - loss: 0.0135 - acc: 0.9972 - categorical_accuracy: 0.1176 - f2_score: 0.2576 - f2_score_1: 0.2142 - f2_score_2: 0.1758 - f2_score_3: 0.1416 - f2_score_4: 0.0900 - f2_score_5: 0.0557 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1228 - val_f2_score: 0.2517 - val_f2_score_1: 0.2044 - val_f2_score_2: 0.1633 - val_f2_score_3: 0.1295 - val_f2_score_4: 0.0773 - val_f2_score_5: 0.0437
# Epoch 13/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1193 - f2_score: 0.2601 - f2_score_1: 0.2162 - f2_score_2: 0.1775 - f2_score_3: 0.1440 - f2_score_4: 0.0927 - f2_score_5: 0.0578 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1180 - val_f2_score: 0.2509 - val_f2_score_1: 0.2027 - val_f2_score_2: 0.1631 - val_f2_score_3: 0.1304 - val_f2_score_4: 0.0788 - val_f2_score_5: 0.0447
# Epoch 14/200
#  - 10s - loss: 0.0134 - acc: 0.9972 - categorical_accuracy: 0.1208 - f2_score: 0.2619 - f2_score_1: 0.2196 - f2_score_2: 0.1797 - f2_score_3: 0.1463 - f2_score_4: 0.0946 - f2_score_5: 0.0593 - val_loss: 0.0127 - val_acc: 0.9972 - val_categorical_accuracy: 0.1224 - val_f2_score: 0.2554 - val_f2_score_1: 0.2069 - val_f2_score_2: 0.1671 - val_f2_score_3: 0.1339 - val_f2_score_4: 0.0818 - val_f2_score_5: 0.0474
# Epoch 15/200
#  - 10s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1212 - f2_score: 0.2646 - f2_score_1: 0.2218 - f2_score_2: 0.1822 - f2_score_3: 0.1484 - f2_score_4: 0.0964 - f2_score_5: 0.0605 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1217 - val_f2_score: 0.2542 - val_f2_score_1: 0.2070 - val_f2_score_2: 0.1664 - val_f2_score_3: 0.1321 - val_f2_score_4: 0.0800 - val_f2_score_5: 0.0462
# Epoch 16/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1214 - f2_score: 0.2668 - f2_score_1: 0.2236 - f2_score_2: 0.1841 - f2_score_3: 0.1502 - f2_score_4: 0.0976 - f2_score_5: 0.0619 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1258 - val_f2_score: 0.2594 - val_f2_score_1: 0.2122 - val_f2_score_2: 0.1708 - val_f2_score_3: 0.1358 - val_f2_score_4: 0.0820 - val_f2_score_5: 0.0472
# Epoch 17/200
#  - 10s - loss: 0.0132 - acc: 0.9972 - categorical_accuracy: 0.1230 - f2_score: 0.2685 - f2_score_1: 0.2249 - f2_score_2: 0.1854 - f2_score_3: 0.1517 - f2_score_4: 0.0992 - f2_score_5: 0.0634 - val_loss: 0.0126 - val_acc: 0.9972 - val_categorical_accuracy: 0.1196 - val_f2_score: 0.2611 - val_f2_score_1: 0.2138 - val_f2_score_2: 0.1732 - val_f2_score_3: 0.1379 - val_f2_score_4: 0.0852 - val_f2_score_5: 0.0499
# Epoch 18/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1233 - f2_score: 0.2712 - f2_score_1: 0.2287 - f2_score_2: 0.1888 - f2_score_3: 0.1540 - f2_score_4: 0.1009 - f2_score_5: 0.0645 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1260 - val_f2_score: 0.2646 - val_f2_score_1: 0.2170 - val_f2_score_2: 0.1766 - val_f2_score_3: 0.1409 - val_f2_score_4: 0.0877 - val_f2_score_5: 0.0520
# Epoch 19/200
#  - 10s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1247 - f2_score: 0.2718 - f2_score_1: 0.2295 - f2_score_2: 0.1897 - f2_score_3: 0.1564 - f2_score_4: 0.1024 - f2_score_5: 0.0657 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1241 - val_f2_score: 0.2685 - val_f2_score_1: 0.2200 - val_f2_score_2: 0.1795 - val_f2_score_3: 0.1447 - val_f2_score_4: 0.0896 - val_f2_score_5: 0.0529
# Epoch 20/200
#  - 11s - loss: 0.0131 - acc: 0.9972 - categorical_accuracy: 0.1253 - f2_score: 0.2747 - f2_score_1: 0.2317 - f2_score_2: 0.1919 - f2_score_3: 0.1576 - f2_score_4: 0.1039 - f2_score_5: 0.0670 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1224 - val_f2_score: 0.2705 - val_f2_score_1: 0.2229 - val_f2_score_2: 0.1804 - val_f2_score_3: 0.1455 - val_f2_score_4: 0.0900 - val_f2_score_5: 0.0534
# Epoch 21/200
#  - 10s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1268 - f2_score: 0.2757 - f2_score_1: 0.2338 - f2_score_2: 0.1941 - f2_score_3: 0.1595 - f2_score_4: 0.1059 - f2_score_5: 0.0686 - val_loss: 0.0125 - val_acc: 0.9972 - val_categorical_accuracy: 0.1244 - val_f2_score: 0.2679 - val_f2_score_1: 0.2205 - val_f2_score_2: 0.1791 - val_f2_score_3: 0.1437 - val_f2_score_4: 0.0903 - val_f2_score_5: 0.0537
# Epoch 22/200
#  - 10s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1248 - f2_score: 0.2763 - f2_score_1: 0.2339 - f2_score_2: 0.1936 - f2_score_3: 0.1591 - f2_score_4: 0.1056 - f2_score_5: 0.0682 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1271 - val_f2_score: 0.2695 - val_f2_score_1: 0.2216 - val_f2_score_2: 0.1813 - val_f2_score_3: 0.1464 - val_f2_score_4: 0.0920 - val_f2_score_5: 0.0553
# Epoch 23/200
#  - 10s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1271 - f2_score: 0.2770 - f2_score_1: 0.2345 - f2_score_2: 0.1949 - f2_score_3: 0.1604 - f2_score_4: 0.1067 - f2_score_5: 0.0685 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1299 - val_f2_score: 0.2706 - val_f2_score_1: 0.2239 - val_f2_score_2: 0.1833 - val_f2_score_3: 0.1478 - val_f2_score_4: 0.0933 - val_f2_score_5: 0.0563
# Epoch 24/200
#  - 10s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1264 - f2_score: 0.2780 - f2_score_1: 0.2355 - f2_score_2: 0.1962 - f2_score_3: 0.1611 - f2_score_4: 0.1072 - f2_score_5: 0.0695 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1270 - val_f2_score: 0.2705 - val_f2_score_1: 0.2243 - val_f2_score_2: 0.1827 - val_f2_score_3: 0.1469 - val_f2_score_4: 0.0921 - val_f2_score_5: 0.0560
# Epoch 25/200
#  - 10s - loss: 0.0130 - acc: 0.9972 - categorical_accuracy: 0.1265 - f2_score: 0.2788 - f2_score_1: 0.2360 - f2_score_2: 0.1963 - f2_score_3: 0.1613 - f2_score_4: 0.1073 - f2_score_5: 0.0692 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1296 - val_f2_score: 0.2707 - val_f2_score_1: 0.2234 - val_f2_score_2: 0.1824 - val_f2_score_3: 0.1469 - val_f2_score_4: 0.0919 - val_f2_score_5: 0.0561
# Epoch 26/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1278 - f2_score: 0.2800 - f2_score_1: 0.2372 - f2_score_2: 0.1970 - f2_score_3: 0.1629 - f2_score_4: 0.1083 - f2_score_5: 0.0705 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1284 - val_f2_score: 0.2720 - val_f2_score_1: 0.2243 - val_f2_score_2: 0.1833 - val_f2_score_3: 0.1489 - val_f2_score_4: 0.0945 - val_f2_score_5: 0.0575
# Epoch 27/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1283 - f2_score: 0.2807 - f2_score_1: 0.2384 - f2_score_2: 0.1986 - f2_score_3: 0.1641 - f2_score_4: 0.1094 - f2_score_5: 0.0718 - val_loss: 0.0124 - val_acc: 0.9972 - val_categorical_accuracy: 0.1315 - val_f2_score: 0.2711 - val_f2_score_1: 0.2241 - val_f2_score_2: 0.1828 - val_f2_score_3: 0.1475 - val_f2_score_4: 0.0935 - val_f2_score_5: 0.0572
# Epoch 28/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1292 - f2_score: 0.2820 - f2_score_1: 0.2397 - f2_score_2: 0.2003 - f2_score_3: 0.1654 - f2_score_4: 0.1105 - f2_score_5: 0.0721 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1296 - val_f2_score: 0.2732 - val_f2_score_1: 0.2254 - val_f2_score_2: 0.1835 - val_f2_score_3: 0.1481 - val_f2_score_4: 0.0915 - val_f2_score_5: 0.0559
# Epoch 29/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1278 - f2_score: 0.2819 - f2_score_1: 0.2391 - f2_score_2: 0.1998 - f2_score_3: 0.1648 - f2_score_4: 0.1103 - f2_score_5: 0.0723 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1284 - val_f2_score: 0.2720 - val_f2_score_1: 0.2257 - val_f2_score_2: 0.1853 - val_f2_score_3: 0.1495 - val_f2_score_4: 0.0955 - val_f2_score_5: 0.0582
# Epoch 30/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1292 - f2_score: 0.2829 - f2_score_1: 0.2406 - f2_score_2: 0.2003 - f2_score_3: 0.1655 - f2_score_4: 0.1107 - f2_score_5: 0.0722 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1294 - val_f2_score: 0.2731 - val_f2_score_1: 0.2264 - val_f2_score_2: 0.1850 - val_f2_score_3: 0.1490 - val_f2_score_4: 0.0941 - val_f2_score_5: 0.0575
# Epoch 31/200
#  - 10s - loss: 0.0129 - acc: 0.9972 - categorical_accuracy: 0.1297 - f2_score: 0.2837 - f2_score_1: 0.2414 - f2_score_2: 0.2016 - f2_score_3: 0.1660 - f2_score_4: 0.1116 - f2_score_5: 0.0732 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1281 - val_f2_score: 0.2743 - val_f2_score_1: 0.2272 - val_f2_score_2: 0.1862 - val_f2_score_3: 0.1506 - val_f2_score_4: 0.0955 - val_f2_score_5: 0.0590
# Epoch 32/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1301 - f2_score: 0.2846 - f2_score_1: 0.2426 - f2_score_2: 0.2016 - f2_score_3: 0.1671 - f2_score_4: 0.1116 - f2_score_5: 0.0734 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1273 - val_f2_score: 0.2750 - val_f2_score_1: 0.2280 - val_f2_score_2: 0.1869 - val_f2_score_3: 0.1508 - val_f2_score_4: 0.0960 - val_f2_score_5: 0.0594
# Epoch 33/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1293 - f2_score: 0.2842 - f2_score_1: 0.2414 - f2_score_2: 0.2018 - f2_score_3: 0.1672 - f2_score_4: 0.1124 - f2_score_5: 0.0740 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1302 - val_f2_score: 0.2759 - val_f2_score_1: 0.2285 - val_f2_score_2: 0.1874 - val_f2_score_3: 0.1521 - val_f2_score_4: 0.0968 - val_f2_score_5: 0.0594
# Epoch 34/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1299 - f2_score: 0.2844 - f2_score_1: 0.2422 - f2_score_2: 0.2017 - f2_score_3: 0.1671 - f2_score_4: 0.1127 - f2_score_5: 0.0739 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2755 - val_f2_score_1: 0.2283 - val_f2_score_2: 0.1866 - val_f2_score_3: 0.1507 - val_f2_score_4: 0.0959 - val_f2_score_5: 0.0589
# Epoch 35/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1288 - f2_score: 0.2848 - f2_score_1: 0.2427 - f2_score_2: 0.2024 - f2_score_3: 0.1671 - f2_score_4: 0.1113 - f2_score_5: 0.0738 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1301 - val_f2_score: 0.2769 - val_f2_score_1: 0.2297 - val_f2_score_2: 0.1881 - val_f2_score_3: 0.1527 - val_f2_score_4: 0.0977 - val_f2_score_5: 0.0606
# Epoch 36/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1300 - f2_score: 0.2863 - f2_score_1: 0.2437 - f2_score_2: 0.2037 - f2_score_3: 0.1687 - f2_score_4: 0.1132 - f2_score_5: 0.0743 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1310 - val_f2_score: 0.2741 - val_f2_score_1: 0.2272 - val_f2_score_2: 0.1855 - val_f2_score_3: 0.1503 - val_f2_score_4: 0.0946 - val_f2_score_5: 0.0580
# Epoch 37/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1296 - f2_score: 0.2856 - f2_score_1: 0.2438 - f2_score_2: 0.2039 - f2_score_3: 0.1688 - f2_score_4: 0.1131 - f2_score_5: 0.0745 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1289 - val_f2_score: 0.2754 - val_f2_score_1: 0.2282 - val_f2_score_2: 0.1868 - val_f2_score_3: 0.1519 - val_f2_score_4: 0.0973 - val_f2_score_5: 0.0604
# Epoch 38/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1301 - f2_score: 0.2863 - f2_score_1: 0.2436 - f2_score_2: 0.2043 - f2_score_3: 0.1698 - f2_score_4: 0.1141 - f2_score_5: 0.0752 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1300 - val_f2_score: 0.2753 - val_f2_score_1: 0.2277 - val_f2_score_2: 0.1858 - val_f2_score_3: 0.1503 - val_f2_score_4: 0.0948 - val_f2_score_5: 0.0583
# Epoch 39/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1305 - f2_score: 0.2863 - f2_score_1: 0.2444 - f2_score_2: 0.2048 - f2_score_3: 0.1695 - f2_score_4: 0.1140 - f2_score_5: 0.0752 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1293 - val_f2_score: 0.2771 - val_f2_score_1: 0.2300 - val_f2_score_2: 0.1883 - val_f2_score_3: 0.1524 - val_f2_score_4: 0.0974 - val_f2_score_5: 0.0602
# Epoch 40/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1308 - f2_score: 0.2870 - f2_score_1: 0.2449 - f2_score_2: 0.2051 - f2_score_3: 0.1694 - f2_score_4: 0.1139 - f2_score_5: 0.0751 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1298 - val_f2_score: 0.2779 - val_f2_score_1: 0.2308 - val_f2_score_2: 0.1895 - val_f2_score_3: 0.1534 - val_f2_score_4: 0.0978 - val_f2_score_5: 0.0609
# Epoch 41/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1314 - f2_score: 0.2878 - f2_score_1: 0.2449 - f2_score_2: 0.2049 - f2_score_3: 0.1696 - f2_score_4: 0.1139 - f2_score_5: 0.0750 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1290 - val_f2_score: 0.2775 - val_f2_score_1: 0.2304 - val_f2_score_2: 0.1890 - val_f2_score_3: 0.1534 - val_f2_score_4: 0.0976 - val_f2_score_5: 0.0605
# Epoch 42/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1292 - f2_score: 0.2874 - f2_score_1: 0.2452 - f2_score_2: 0.2049 - f2_score_3: 0.1695 - f2_score_4: 0.1140 - f2_score_5: 0.0753 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1294 - val_f2_score: 0.2774 - val_f2_score_1: 0.2305 - val_f2_score_2: 0.1892 - val_f2_score_3: 0.1533 - val_f2_score_4: 0.0981 - val_f2_score_5: 0.0610
# Epoch 43/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1308 - f2_score: 0.2879 - f2_score_1: 0.2455 - f2_score_2: 0.2053 - f2_score_3: 0.1702 - f2_score_4: 0.1146 - f2_score_5: 0.0760 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1310 - val_f2_score: 0.2771 - val_f2_score_1: 0.2302 - val_f2_score_2: 0.1890 - val_f2_score_3: 0.1529 - val_f2_score_4: 0.0974 - val_f2_score_5: 0.0607
# Epoch 44/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1312 - f2_score: 0.2878 - f2_score_1: 0.2451 - f2_score_2: 0.2047 - f2_score_3: 0.1699 - f2_score_4: 0.1144 - f2_score_5: 0.0752 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1293 - val_f2_score: 0.2777 - val_f2_score_1: 0.2307 - val_f2_score_2: 0.1898 - val_f2_score_3: 0.1533 - val_f2_score_4: 0.0981 - val_f2_score_5: 0.0612
# Epoch 45/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1311 - f2_score: 0.2883 - f2_score_1: 0.2458 - f2_score_2: 0.2062 - f2_score_3: 0.1710 - f2_score_4: 0.1152 - f2_score_5: 0.0760 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1282 - val_f2_score: 0.2780 - val_f2_score_1: 0.2313 - val_f2_score_2: 0.1902 - val_f2_score_3: 0.1544 - val_f2_score_4: 0.0990 - val_f2_score_5: 0.0619
# Epoch 46/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2884 - f2_score_1: 0.2461 - f2_score_2: 0.2062 - f2_score_3: 0.1711 - f2_score_4: 0.1147 - f2_score_5: 0.0756 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1301 - val_f2_score: 0.2765 - val_f2_score_1: 0.2297 - val_f2_score_2: 0.1887 - val_f2_score_3: 0.1528 - val_f2_score_4: 0.0975 - val_f2_score_5: 0.0606
# Epoch 47/200
#  - 10s - loss: 0.0128 - acc: 0.9972 - categorical_accuracy: 0.1313 - f2_score: 0.2875 - f2_score_1: 0.2455 - f2_score_2: 0.2050 - f2_score_3: 0.1702 - f2_score_4: 0.1147 - f2_score_5: 0.0758 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1287 - val_f2_score: 0.2775 - val_f2_score_1: 0.2306 - val_f2_score_2: 0.1898 - val_f2_score_3: 0.1541 - val_f2_score_4: 0.0987 - val_f2_score_5: 0.0614
# Epoch 48/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2882 - f2_score_1: 0.2457 - f2_score_2: 0.2061 - f2_score_3: 0.1710 - f2_score_4: 0.1154 - f2_score_5: 0.0764 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1296 - val_f2_score: 0.2780 - val_f2_score_1: 0.2308 - val_f2_score_2: 0.1899 - val_f2_score_3: 0.1537 - val_f2_score_4: 0.0983 - val_f2_score_5: 0.0612
# Epoch 49/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1314 - f2_score: 0.2874 - f2_score_1: 0.2456 - f2_score_2: 0.2059 - f2_score_3: 0.1710 - f2_score_4: 0.1153 - f2_score_5: 0.0763 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1316 - val_f2_score: 0.2786 - val_f2_score_1: 0.2317 - val_f2_score_2: 0.1908 - val_f2_score_3: 0.1546 - val_f2_score_4: 0.0992 - val_f2_score_5: 0.0621
# Epoch 50/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1314 - f2_score: 0.2889 - f2_score_1: 0.2462 - f2_score_2: 0.2057 - f2_score_3: 0.1708 - f2_score_4: 0.1151 - f2_score_5: 0.0762 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1302 - val_f2_score: 0.2794 - val_f2_score_1: 0.2322 - val_f2_score_2: 0.1912 - val_f2_score_3: 0.1549 - val_f2_score_4: 0.0990 - val_f2_score_5: 0.0618
# Epoch 51/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1314 - f2_score: 0.2898 - f2_score_1: 0.2466 - f2_score_2: 0.2071 - f2_score_3: 0.1713 - f2_score_4: 0.1160 - f2_score_5: 0.0765 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2794 - val_f2_score_1: 0.2321 - val_f2_score_2: 0.1912 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0993 - val_f2_score_5: 0.0621
# Epoch 52/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2897 - f2_score_1: 0.2470 - f2_score_2: 0.2073 - f2_score_3: 0.1712 - f2_score_4: 0.1164 - f2_score_5: 0.0770 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1299 - val_f2_score: 0.2794 - val_f2_score_1: 0.2319 - val_f2_score_2: 0.1911 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0998 - val_f2_score_5: 0.0621
# Epoch 53/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1313 - f2_score: 0.2884 - f2_score_1: 0.2465 - f2_score_2: 0.2068 - f2_score_3: 0.1716 - f2_score_4: 0.1161 - f2_score_5: 0.0776 - val_loss: 0.0123 - val_acc: 0.9972 - val_categorical_accuracy: 0.1298 - val_f2_score: 0.2789 - val_f2_score_1: 0.2319 - val_f2_score_2: 0.1914 - val_f2_score_3: 0.1549 - val_f2_score_4: 0.0994 - val_f2_score_5: 0.0621
# Epoch 54/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1307 - f2_score: 0.2884 - f2_score_1: 0.2467 - f2_score_2: 0.2071 - f2_score_3: 0.1713 - f2_score_4: 0.1159 - f2_score_5: 0.0765 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2800 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1555 - val_f2_score_4: 0.0998 - val_f2_score_5: 0.0622
# Epoch 55/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1340 - f2_score: 0.2895 - f2_score_1: 0.2471 - f2_score_2: 0.2079 - f2_score_3: 0.1725 - f2_score_4: 0.1169 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2796 - val_f2_score_1: 0.2324 - val_f2_score_2: 0.1915 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0999 - val_f2_score_5: 0.0623
# Epoch 56/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2897 - f2_score_1: 0.2482 - f2_score_2: 0.2076 - f2_score_3: 0.1723 - f2_score_4: 0.1168 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2792 - val_f2_score_1: 0.2319 - val_f2_score_2: 0.1912 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0997 - val_f2_score_5: 0.0622
# Epoch 57/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1315 - f2_score: 0.2893 - f2_score_1: 0.2474 - f2_score_2: 0.2076 - f2_score_3: 0.1727 - f2_score_4: 0.1165 - f2_score_5: 0.0766 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2795 - val_f2_score_1: 0.2322 - val_f2_score_2: 0.1911 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0996 - val_f2_score_5: 0.0621
# Epoch 58/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2896 - f2_score_1: 0.2469 - f2_score_2: 0.2071 - f2_score_3: 0.1720 - f2_score_4: 0.1167 - f2_score_5: 0.0768 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1302 - val_f2_score: 0.2799 - val_f2_score_1: 0.2327 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1556 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0626
# Epoch 59/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1330 - f2_score: 0.2901 - f2_score_1: 0.2471 - f2_score_2: 0.2076 - f2_score_3: 0.1729 - f2_score_4: 0.1172 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2795 - val_f2_score_1: 0.2321 - val_f2_score_2: 0.1912 - val_f2_score_3: 0.1551 - val_f2_score_4: 0.0997 - val_f2_score_5: 0.0621
# Epoch 60/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1319 - f2_score: 0.2901 - f2_score_1: 0.2480 - f2_score_2: 0.2072 - f2_score_3: 0.1718 - f2_score_4: 0.1165 - f2_score_5: 0.0770 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2798 - val_f2_score_1: 0.2324 - val_f2_score_2: 0.1915 - val_f2_score_3: 0.1553 - val_f2_score_4: 0.0998 - val_f2_score_5: 0.0625
# Epoch 61/200
#  - 11s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2913 - f2_score_1: 0.2477 - f2_score_2: 0.2072 - f2_score_3: 0.1718 - f2_score_4: 0.1162 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2798 - val_f2_score_1: 0.2325 - val_f2_score_2: 0.1915 - val_f2_score_3: 0.1553 - val_f2_score_4: 0.0998 - val_f2_score_5: 0.0624
# Epoch 62/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1333 - f2_score: 0.2898 - f2_score_1: 0.2476 - f2_score_2: 0.2081 - f2_score_3: 0.1728 - f2_score_4: 0.1166 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1300 - val_f2_score: 0.2798 - val_f2_score_1: 0.2327 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0627
# Epoch 63/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2896 - f2_score_1: 0.2471 - f2_score_2: 0.2077 - f2_score_3: 0.1728 - f2_score_4: 0.1172 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1301 - val_f2_score: 0.2797 - val_f2_score_1: 0.2326 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0628
# Epoch 64/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1331 - f2_score: 0.2902 - f2_score_1: 0.2478 - f2_score_2: 0.2071 - f2_score_3: 0.1723 - f2_score_4: 0.1164 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2798 - val_f2_score_1: 0.2326 - val_f2_score_2: 0.1918 - val_f2_score_3: 0.1557 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0626
# Epoch 65/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1319 - f2_score: 0.2897 - f2_score_1: 0.2479 - f2_score_2: 0.2075 - f2_score_3: 0.1722 - f2_score_4: 0.1173 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1309 - val_f2_score: 0.2796 - val_f2_score_1: 0.2322 - val_f2_score_2: 0.1913 - val_f2_score_3: 0.1553 - val_f2_score_4: 0.0997 - val_f2_score_5: 0.0624
# Epoch 66/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2898 - f2_score_1: 0.2474 - f2_score_2: 0.2079 - f2_score_3: 0.1723 - f2_score_4: 0.1170 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1310 - val_f2_score: 0.2794 - val_f2_score_1: 0.2320 - val_f2_score_2: 0.1913 - val_f2_score_3: 0.1550 - val_f2_score_4: 0.0995 - val_f2_score_5: 0.0623
# Epoch 67/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1312 - f2_score: 0.2903 - f2_score_1: 0.2480 - f2_score_2: 0.2074 - f2_score_3: 0.1723 - f2_score_4: 0.1170 - f2_score_5: 0.0771 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2802 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0627
# Epoch 68/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1327 - f2_score: 0.2908 - f2_score_1: 0.2482 - f2_score_2: 0.2077 - f2_score_3: 0.1725 - f2_score_4: 0.1173 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1303 - val_f2_score: 0.2798 - val_f2_score_1: 0.2327 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1556 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0626
# Epoch 69/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1313 - f2_score: 0.2902 - f2_score_1: 0.2478 - f2_score_2: 0.2085 - f2_score_3: 0.1736 - f2_score_4: 0.1182 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1308 - val_f2_score: 0.2801 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1917 - val_f2_score_3: 0.1555 - val_f2_score_4: 0.1001 - val_f2_score_5: 0.0627
# Epoch 70/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1347 - f2_score: 0.2902 - f2_score_1: 0.2478 - f2_score_2: 0.2081 - f2_score_3: 0.1730 - f2_score_4: 0.1164 - f2_score_5: 0.0771 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2799 - val_f2_score_1: 0.2325 - val_f2_score_2: 0.1916 - val_f2_score_3: 0.1555 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0627
# Epoch 71/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1317 - f2_score: 0.2902 - f2_score_1: 0.2473 - f2_score_2: 0.2073 - f2_score_3: 0.1721 - f2_score_4: 0.1162 - f2_score_5: 0.0773 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2800 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1918 - val_f2_score_3: 0.1557 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0627
# Epoch 72/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1336 - f2_score: 0.2904 - f2_score_1: 0.2479 - f2_score_2: 0.2085 - f2_score_3: 0.1728 - f2_score_4: 0.1170 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2799 - val_f2_score_1: 0.2325 - val_f2_score_2: 0.1916 - val_f2_score_3: 0.1554 - val_f2_score_4: 0.1001 - val_f2_score_5: 0.0627
# Epoch 73/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1328 - f2_score: 0.2912 - f2_score_1: 0.2484 - f2_score_2: 0.2079 - f2_score_3: 0.1726 - f2_score_4: 0.1170 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2800 - val_f2_score_1: 0.2327 - val_f2_score_2: 0.1918 - val_f2_score_3: 0.1556 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0627
# Epoch 74/200
#  - 11s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1335 - f2_score: 0.2906 - f2_score_1: 0.2484 - f2_score_2: 0.2088 - f2_score_3: 0.1736 - f2_score_4: 0.1166 - f2_score_5: 0.0771 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1303 - val_f2_score: 0.2800 - val_f2_score_1: 0.2329 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0629
# Epoch 75/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1322 - f2_score: 0.2905 - f2_score_1: 0.2484 - f2_score_2: 0.2079 - f2_score_3: 0.1726 - f2_score_4: 0.1170 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1305 - val_f2_score: 0.2801 - val_f2_score_1: 0.2329 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0628
# Epoch 76/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1317 - f2_score: 0.2907 - f2_score_1: 0.2484 - f2_score_2: 0.2085 - f2_score_3: 0.1727 - f2_score_4: 0.1175 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2803 - val_f2_score_1: 0.2329 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1557 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0627
# Epoch 77/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2908 - f2_score_1: 0.2486 - f2_score_2: 0.2084 - f2_score_3: 0.1731 - f2_score_4: 0.1172 - f2_score_5: 0.0773 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2802 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1557 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0628
# Epoch 78/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2900 - f2_score_1: 0.2483 - f2_score_2: 0.2082 - f2_score_3: 0.1724 - f2_score_4: 0.1168 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1303 - val_f2_score: 0.2800 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1556 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0628
# Epoch 79/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2913 - f2_score_1: 0.2481 - f2_score_2: 0.2083 - f2_score_3: 0.1728 - f2_score_4: 0.1170 - f2_score_5: 0.0784 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2803 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0628
# Epoch 80/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2899 - f2_score_1: 0.2476 - f2_score_2: 0.2080 - f2_score_3: 0.1734 - f2_score_4: 0.1162 - f2_score_5: 0.0773 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2803 - val_f2_score_1: 0.2329 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 81/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1334 - f2_score: 0.2902 - f2_score_1: 0.2477 - f2_score_2: 0.2083 - f2_score_3: 0.1731 - f2_score_4: 0.1163 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1303 - val_f2_score: 0.2803 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 82/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1319 - f2_score: 0.2908 - f2_score_1: 0.2481 - f2_score_2: 0.2083 - f2_score_3: 0.1728 - f2_score_4: 0.1173 - f2_score_5: 0.0782 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1303 - val_f2_score: 0.2804 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0628
# Epoch 83/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2901 - f2_score_1: 0.2482 - f2_score_2: 0.2083 - f2_score_3: 0.1736 - f2_score_4: 0.1177 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1302 - val_f2_score: 0.2803 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 84/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1323 - f2_score: 0.2904 - f2_score_1: 0.2483 - f2_score_2: 0.2077 - f2_score_3: 0.1729 - f2_score_4: 0.1171 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1304 - val_f2_score: 0.2802 - val_f2_score_1: 0.2328 - val_f2_score_2: 0.1919 - val_f2_score_3: 0.1557 - val_f2_score_4: 0.1002 - val_f2_score_5: 0.0628
# Epoch 85/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1343 - f2_score: 0.2908 - f2_score_1: 0.2482 - f2_score_2: 0.2088 - f2_score_3: 0.1735 - f2_score_4: 0.1170 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2803 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 86/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1330 - f2_score: 0.2908 - f2_score_1: 0.2490 - f2_score_2: 0.2086 - f2_score_3: 0.1731 - f2_score_4: 0.1171 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2801 - val_f2_score_1: 0.2329 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 87/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1322 - f2_score: 0.2907 - f2_score_1: 0.2480 - f2_score_2: 0.2073 - f2_score_3: 0.1721 - f2_score_4: 0.1169 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2802 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1920 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 88/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1331 - f2_score: 0.2902 - f2_score_1: 0.2479 - f2_score_2: 0.2082 - f2_score_3: 0.1727 - f2_score_4: 0.1169 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2802 - val_f2_score_1: 0.2330 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 89/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2908 - f2_score_1: 0.2485 - f2_score_2: 0.2087 - f2_score_3: 0.1735 - f2_score_4: 0.1172 - f2_score_5: 0.0785 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1561 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0629
# Epoch 90/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1328 - f2_score: 0.2902 - f2_score_1: 0.2486 - f2_score_2: 0.2082 - f2_score_3: 0.1733 - f2_score_4: 0.1174 - f2_score_5: 0.0784 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 91/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2904 - f2_score_1: 0.2488 - f2_score_2: 0.2086 - f2_score_3: 0.1739 - f2_score_4: 0.1175 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0629
# Epoch 92/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1315 - f2_score: 0.2906 - f2_score_1: 0.2478 - f2_score_2: 0.2080 - f2_score_3: 0.1731 - f2_score_4: 0.1170 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 93/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1333 - f2_score: 0.2906 - f2_score_1: 0.2486 - f2_score_2: 0.2080 - f2_score_3: 0.1729 - f2_score_4: 0.1174 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 94/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1319 - f2_score: 0.2908 - f2_score_1: 0.2491 - f2_score_2: 0.2090 - f2_score_3: 0.1739 - f2_score_4: 0.1169 - f2_score_5: 0.0771 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 95/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1323 - f2_score: 0.2906 - f2_score_1: 0.2491 - f2_score_2: 0.2092 - f2_score_3: 0.1739 - f2_score_4: 0.1171 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 96/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1330 - f2_score: 0.2912 - f2_score_1: 0.2487 - f2_score_2: 0.2083 - f2_score_3: 0.1732 - f2_score_4: 0.1163 - f2_score_5: 0.0767 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 97/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1340 - f2_score: 0.2899 - f2_score_1: 0.2485 - f2_score_2: 0.2087 - f2_score_3: 0.1727 - f2_score_4: 0.1167 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 98/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1331 - f2_score: 0.2916 - f2_score_1: 0.2488 - f2_score_2: 0.2089 - f2_score_3: 0.1735 - f2_score_4: 0.1175 - f2_score_5: 0.0778 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2803 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 99/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1333 - f2_score: 0.2901 - f2_score_1: 0.2482 - f2_score_2: 0.2080 - f2_score_3: 0.1728 - f2_score_4: 0.1172 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1307 - val_f2_score: 0.2803 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 100/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1337 - f2_score: 0.2900 - f2_score_1: 0.2474 - f2_score_2: 0.2078 - f2_score_3: 0.1723 - f2_score_4: 0.1168 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0630
# Epoch 101/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1338 - f2_score: 0.2905 - f2_score_1: 0.2486 - f2_score_2: 0.2087 - f2_score_3: 0.1731 - f2_score_4: 0.1168 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 102/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2909 - f2_score_1: 0.2483 - f2_score_2: 0.2072 - f2_score_3: 0.1723 - f2_score_4: 0.1166 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 103/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1335 - f2_score: 0.2912 - f2_score_1: 0.2483 - f2_score_2: 0.2086 - f2_score_3: 0.1735 - f2_score_4: 0.1178 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1558 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 104/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1332 - f2_score: 0.2896 - f2_score_1: 0.2480 - f2_score_2: 0.2081 - f2_score_3: 0.1730 - f2_score_4: 0.1174 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 105/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1341 - f2_score: 0.2909 - f2_score_1: 0.2478 - f2_score_2: 0.2077 - f2_score_3: 0.1725 - f2_score_4: 0.1168 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 106/200
#  - 11s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2905 - f2_score_1: 0.2478 - f2_score_2: 0.2077 - f2_score_3: 0.1725 - f2_score_4: 0.1164 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 107/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1307 - f2_score: 0.2903 - f2_score_1: 0.2481 - f2_score_2: 0.2084 - f2_score_3: 0.1728 - f2_score_4: 0.1171 - f2_score_5: 0.0769 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 108/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1340 - f2_score: 0.2914 - f2_score_1: 0.2488 - f2_score_2: 0.2092 - f2_score_3: 0.1734 - f2_score_4: 0.1169 - f2_score_5: 0.0770 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1921 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 109/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2908 - f2_score_1: 0.2489 - f2_score_2: 0.2092 - f2_score_3: 0.1736 - f2_score_4: 0.1175 - f2_score_5: 0.0783 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1003 - val_f2_score_5: 0.0629
# Epoch 110/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1315 - f2_score: 0.2902 - f2_score_1: 0.2480 - f2_score_2: 0.2076 - f2_score_3: 0.1729 - f2_score_4: 0.1170 - f2_score_5: 0.0772 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 111/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1334 - f2_score: 0.2910 - f2_score_1: 0.2494 - f2_score_2: 0.2098 - f2_score_3: 0.1741 - f2_score_4: 0.1179 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 112/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1327 - f2_score: 0.2913 - f2_score_1: 0.2485 - f2_score_2: 0.2090 - f2_score_3: 0.1734 - f2_score_4: 0.1173 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2804 - val_f2_score_1: 0.2331 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1559 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0629
# Epoch 113/200
# ...
# Epoch 140/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1313 - f2_score: 0.2908 - f2_score_1: 0.2480 - f2_score_2: 0.2080 - f2_score_3: 0.1726 - f2_score_4: 0.1168 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 141/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2902 - f2_score_1: 0.2482 - f2_score_2: 0.2082 - f2_score_3: 0.1726 - f2_score_4: 0.1170 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 142/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2906 - f2_score_1: 0.2485 - f2_score_2: 0.2080 - f2_score_3: 0.1725 - f2_score_4: 0.1175 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 143/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1330 - f2_score: 0.2910 - f2_score_1: 0.2488 - f2_score_2: 0.2087 - f2_score_3: 0.1735 - f2_score_4: 0.1167 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 144/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1322 - f2_score: 0.2898 - f2_score_1: 0.2482 - f2_score_2: 0.2084 - f2_score_3: 0.1729 - f2_score_4: 0.1168 - f2_score_5: 0.0773 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 145/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2908 - f2_score_1: 0.2487 - f2_score_2: 0.2084 - f2_score_3: 0.1732 - f2_score_4: 0.1175 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 146/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2913 - f2_score_1: 0.2484 - f2_score_2: 0.2085 - f2_score_3: 0.1736 - f2_score_4: 0.1173 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 147/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1322 - f2_score: 0.2917 - f2_score_1: 0.2490 - f2_score_2: 0.2091 - f2_score_3: 0.1735 - f2_score_4: 0.1175 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 148/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2909 - f2_score_1: 0.2486 - f2_score_2: 0.2086 - f2_score_3: 0.1733 - f2_score_4: 0.1169 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 149/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1332 - f2_score: 0.2905 - f2_score_1: 0.2482 - f2_score_2: 0.2084 - f2_score_3: 0.1739 - f2_score_4: 0.1170 - f2_score_5: 0.0780 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 150/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2907 - f2_score_1: 0.2480 - f2_score_2: 0.2083 - f2_score_3: 0.1726 - f2_score_4: 0.1169 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 151/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1340 - f2_score: 0.2907 - f2_score_1: 0.2488 - f2_score_2: 0.2092 - f2_score_3: 0.1732 - f2_score_4: 0.1177 - f2_score_5: 0.0778 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1004 - val_f2_score_5: 0.0630
# Epoch 152/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1336 - f2_score: 0.2912 - f2_score_1: 0.2486 - f2_score_2: 0.2086 - f2_score_3: 0.1731 - f2_score_4: 0.1177 - f2_score_5: 0.0782 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 153/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2900 - f2_score_1: 0.2485 - f2_score_2: 0.2083 - f2_score_3: 0.1727 - f2_score_4: 0.1170 - f2_score_5: 0.0770 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 154/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1345 - f2_score: 0.2915 - f2_score_1: 0.2491 - f2_score_2: 0.2086 - f2_score_3: 0.1733 - f2_score_4: 0.1171 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 155/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1330 - f2_score: 0.2917 - f2_score_1: 0.2500 - f2_score_2: 0.2096 - f2_score_3: 0.1741 - f2_score_4: 0.1178 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 156/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1333 - f2_score: 0.2899 - f2_score_1: 0.2475 - f2_score_2: 0.2077 - f2_score_3: 0.1732 - f2_score_4: 0.1172 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 157/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1329 - f2_score: 0.2909 - f2_score_1: 0.2484 - f2_score_2: 0.2073 - f2_score_3: 0.1730 - f2_score_4: 0.1171 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2332 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 158/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1313 - f2_score: 0.2905 - f2_score_1: 0.2485 - f2_score_2: 0.2088 - f2_score_3: 0.1730 - f2_score_4: 0.1170 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 159/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1332 - f2_score: 0.2907 - f2_score_1: 0.2482 - f2_score_2: 0.2081 - f2_score_3: 0.1727 - f2_score_4: 0.1166 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 160/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1325 - f2_score: 0.2916 - f2_score_1: 0.2489 - f2_score_2: 0.2087 - f2_score_3: 0.1735 - f2_score_4: 0.1170 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 161/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1336 - f2_score: 0.2905 - f2_score_1: 0.2486 - f2_score_2: 0.2084 - f2_score_3: 0.1736 - f2_score_4: 0.1177 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 162/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1312 - f2_score: 0.2915 - f2_score_1: 0.2490 - f2_score_2: 0.2093 - f2_score_3: 0.1738 - f2_score_4: 0.1176 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 163/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1324 - f2_score: 0.2908 - f2_score_1: 0.2486 - f2_score_2: 0.2083 - f2_score_3: 0.1728 - f2_score_4: 0.1168 - f2_score_5: 0.0779 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 164/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1337 - f2_score: 0.2907 - f2_score_1: 0.2477 - f2_score_2: 0.2080 - f2_score_3: 0.1726 - f2_score_4: 0.1173 - f2_score_5: 0.0782 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 165/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1334 - f2_score: 0.2908 - f2_score_1: 0.2482 - f2_score_2: 0.2080 - f2_score_3: 0.1733 - f2_score_4: 0.1170 - f2_score_5: 0.0781 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 166/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1326 - f2_score: 0.2913 - f2_score_1: 0.2490 - f2_score_2: 0.2084 - f2_score_3: 0.1732 - f2_score_4: 0.1173 - f2_score_5: 0.0778 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 167/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1328 - f2_score: 0.2914 - f2_score_1: 0.2491 - f2_score_2: 0.2082 - f2_score_3: 0.1726 - f2_score_4: 0.1166 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 168/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1327 - f2_score: 0.2919 - f2_score_1: 0.2495 - f2_score_2: 0.2088 - f2_score_3: 0.1730 - f2_score_4: 0.1172 - f2_score_5: 0.0778 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 169/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1329 - f2_score: 0.2910 - f2_score_1: 0.2488 - f2_score_2: 0.2077 - f2_score_3: 0.1727 - f2_score_4: 0.1170 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 170/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1318 - f2_score: 0.2900 - f2_score_1: 0.2476 - f2_score_2: 0.2077 - f2_score_3: 0.1724 - f2_score_4: 0.1165 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 171/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1337 - f2_score: 0.2913 - f2_score_1: 0.2490 - f2_score_2: 0.2088 - f2_score_3: 0.1733 - f2_score_4: 0.1173 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 172/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1316 - f2_score: 0.2900 - f2_score_1: 0.2485 - f2_score_2: 0.2080 - f2_score_3: 0.1727 - f2_score_4: 0.1164 - f2_score_5: 0.0775 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 173/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1333 - f2_score: 0.2899 - f2_score_1: 0.2479 - f2_score_2: 0.2084 - f2_score_3: 0.1735 - f2_score_4: 0.1172 - f2_score_5: 0.0777 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 174/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1321 - f2_score: 0.2902 - f2_score_1: 0.2485 - f2_score_2: 0.2084 - f2_score_3: 0.1736 - f2_score_4: 0.1172 - f2_score_5: 0.0776 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 175/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1329 - f2_score: 0.2906 - f2_score_1: 0.2488 - f2_score_2: 0.2085 - f2_score_3: 0.1731 - f2_score_4: 0.1165 - f2_score_5: 0.0774 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 176/200
#  - 10s - loss: 0.0127 - acc: 0.9972 - categorical_accuracy: 0.1328 - f2_score: 0.2913 - f2_score_1: 0.2484 - f2_score_2: 0.2080 - f2_score_3: 0.1723 - f2_score_4: 0.1164 - f2_score_5: 0.0773 - val_loss: 0.0122 - val_acc: 0.9972 - val_categorical_accuracy: 0.1306 - val_f2_score: 0.2805 - val_f2_score_1: 0.2333 - val_f2_score_2: 0.1922 - val_f2_score_3: 0.1560 - val_f2_score_4: 0.1005 - val_f2_score_5: 0.0630
# Epoch 00176: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_base.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id                  attribute_ids
# 0  10023b2cc4ed5f68                           1059
# 1  100fbe75ed8fd887                            121
# 2  101b627524a04f19                            813
# 3  10234480c41284c6           51 147 813 1046 1092
# 4  1023b0e2636dcea8                            612
# 5   1039cd6cf85845c        13 405 813 896 903 1092
# 6   103a5b3f83fbe88  51 194 671 813 1046 1092 1099
# 7  10413aaae8d6a9a2                51 147 813 1092
# 8  10423822b93a65ab                            121
# 9  1052bf702cb099f7                147 189 671 780
