# %%
import os
import cv2
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras import backend as K
from keras import metrics
from sklearn.metrics import fbeta_score

from keras import optimizers
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/train.csv')
labels = pd.read_csv('../input/labels.csv')
test = pd.read_csv('../input/sample_submission.csv')

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())

train["id"] = train["id"].apply(lambda x:x+".png")
test["id"] = test["id"].apply(lambda x:x+".png")
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                  id        attribute_ids
# 0  1000483014d91860          147 616 813
# 1  1000fe2e667721fe       51 616 734 813
# 2  1001614cb89646ee                  776
# 3  10041eb49b297c08  51 671 698 813 1092
# 4  100501c227f8beea  13 404 492 903 1093
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Model

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 50
LEARNING_RATE = 0.0001
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
train_datagen=ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='training')

valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",    
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='validation')

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 3460 images belonging to 1103 classes.
# Found 864 images belonging to 1103 classes.
# Found 7443 images.

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=(HEIGHT, WIDTH, CANAL)))
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.adam(lr=LEARNING_RATE)
model.compile(optimizer=optimizer, loss="binary_crossentropy", 
              metrics=["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
                       f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)])
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=valid_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=EPOCHS,
                                verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 23s - loss: 0.2209 - acc: 0.9016 - categorical_accuracy: 0.0023 - f2_score: 0.0053 - f2_score_1: 0.0051 - f2_score_2: 0.0052 - f2_score_3: 0.0049 - f2_score_4: 0.0048 - f2_score_5: 0.0050 - val_loss: 0.0094 - val_acc: 0.9991 - val_categorical_accuracy: 0.0565 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/50
#  - 16s - loss: 0.0128 - acc: 0.9983 - categorical_accuracy: 0.0110 - f2_score: 0.0164 - f2_score_1: 0.0153 - f2_score_2: 0.0136 - f2_score_3: 0.0132 - f2_score_4: 0.0100 - f2_score_5: 0.0075 - val_loss: 0.0074 - val_acc: 0.9991 - val_categorical_accuracy: 0.0625 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/50
#  - 17s - loss: 0.0108 - acc: 0.9986 - categorical_accuracy: 0.0136 - f2_score: 0.0184 - f2_score_1: 0.0153 - f2_score_2: 0.0132 - f2_score_3: 0.0122 - f2_score_4: 0.0093 - f2_score_5: 0.0065 - val_loss: 0.0068 - val_acc: 0.9991 - val_categorical_accuracy: 0.0988 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 4/50
#  - 17s - loss: 0.0096 - acc: 0.9988 - categorical_accuracy: 0.0177 - f2_score: 0.0252 - f2_score_1: 0.0221 - f2_score_2: 0.0168 - f2_score_3: 0.0143 - f2_score_4: 0.0099 - f2_score_5: 0.0065 - val_loss: 0.0066 - val_acc: 0.9991 - val_categorical_accuracy: 0.1125 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 5/50
#  - 16s - loss: 0.0089 - acc: 0.9989 - categorical_accuracy: 0.0165 - f2_score: 0.0241 - f2_score_1: 0.0210 - f2_score_2: 0.0167 - f2_score_3: 0.0127 - f2_score_4: 0.0057 - f2_score_5: 0.0049 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.0688 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 6/50
#  - 16s - loss: 0.0083 - acc: 0.9989 - categorical_accuracy: 0.0243 - f2_score: 0.0268 - f2_score_1: 0.0197 - f2_score_2: 0.0171 - f2_score_3: 0.0135 - f2_score_4: 0.0090 - f2_score_5: 0.0062 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.0850 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 7/50
#  - 16s - loss: 0.0078 - acc: 0.9990 - categorical_accuracy: 0.0275 - f2_score: 0.0277 - f2_score_1: 0.0209 - f2_score_2: 0.0158 - f2_score_3: 0.0119 - f2_score_4: 0.0078 - f2_score_5: 0.0046 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.0750 - val_f2_score: 0.0000e+00 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 8/50
#  - 16s - loss: 0.0075 - acc: 0.9990 - categorical_accuracy: 0.0266 - f2_score: 0.0249 - f2_score_1: 0.0170 - f2_score_2: 0.0126 - f2_score_3: 0.0099 - f2_score_4: 0.0064 - f2_score_5: 0.0046 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.1037 - val_f2_score: 0.0262 - val_f2_score_1: 0.0000e+00 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 9/50
#  - 17s - loss: 0.0073 - acc: 0.9990 - categorical_accuracy: 0.0362 - f2_score: 0.0332 - f2_score_1: 0.0236 - f2_score_2: 0.0185 - f2_score_3: 0.0147 - f2_score_4: 0.0090 - f2_score_5: 0.0066 - val_loss: 0.0064 - val_acc: 0.9991 - val_categorical_accuracy: 0.1013 - val_f2_score: 0.0550 - val_f2_score_1: 0.0475 - val_f2_score_2: 0.0162 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 10/50
#  - 16s - loss: 0.0070 - acc: 0.9990 - categorical_accuracy: 0.0368 - f2_score: 0.0351 - f2_score_1: 0.0249 - f2_score_2: 0.0202 - f2_score_3: 0.0159 - f2_score_4: 0.0084 - f2_score_5: 0.0054 - val_loss: 0.0066 - val_acc: 0.9991 - val_categorical_accuracy: 0.0988 - val_f2_score: 0.0487 - val_f2_score_1: 0.0487 - val_f2_score_2: 0.0387 - val_f2_score_3: 0.0100 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 11/50
#  - 16s - loss: 0.0068 - acc: 0.9990 - categorical_accuracy: 0.0621 - f2_score: 0.0524 - f2_score_1: 0.0397 - f2_score_2: 0.0330 - f2_score_3: 0.0268 - f2_score_4: 0.0139 - f2_score_5: 0.0086 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.1263 - val_f2_score: 0.0612 - val_f2_score_1: 0.0612 - val_f2_score_2: 0.0600 - val_f2_score_3: 0.0512 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 12/50
#  - 16s - loss: 0.0066 - acc: 0.9991 - categorical_accuracy: 0.0588 - f2_score: 0.0502 - f2_score_1: 0.0365 - f2_score_2: 0.0311 - f2_score_3: 0.0250 - f2_score_4: 0.0170 - f2_score_5: 0.0130 - val_loss: 0.0065 - val_acc: 0.9991 - val_categorical_accuracy: 0.1100 - val_f2_score: 0.0587 - val_f2_score_1: 0.0575 - val_f2_score_2: 0.0575 - val_f2_score_3: 0.0575 - val_f2_score_4: 0.0325 - val_f2_score_5: 0.0000e+00
# Epoch 13/50
#  - 16s - loss: 0.0065 - acc: 0.9991 - categorical_accuracy: 0.0588 - f2_score: 0.0496 - f2_score_1: 0.0382 - f2_score_2: 0.0316 - f2_score_3: 0.0249 - f2_score_4: 0.0163 - f2_score_5: 0.0110 - val_loss: 0.0068 - val_acc: 0.9991 - val_categorical_accuracy: 0.1187 - val_f2_score: 0.0712 - val_f2_score_1: 0.0587 - val_f2_score_2: 0.0550 - val_f2_score_3: 0.0475 - val_f2_score_4: 0.0100 - val_f2_score_5: 0.0000e+00
# Epoch 14/50
#  - 17s - loss: 0.0064 - acc: 0.9991 - categorical_accuracy: 0.0628 - f2_score: 0.0473 - f2_score_1: 0.0390 - f2_score_2: 0.0344 - f2_score_3: 0.0255 - f2_score_4: 0.0161 - f2_score_5: 0.0110 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1212 - val_f2_score: 0.0650 - val_f2_score_1: 0.0600 - val_f2_score_2: 0.0587 - val_f2_score_3: 0.0587 - val_f2_score_4: 0.0500 - val_f2_score_5: 0.0000e+00
# Epoch 15/50
#  - 17s - loss: 0.0063 - acc: 0.9991 - categorical_accuracy: 0.0729 - f2_score: 0.0614 - f2_score_1: 0.0528 - f2_score_2: 0.0431 - f2_score_3: 0.0364 - f2_score_4: 0.0271 - f2_score_5: 0.0194 - val_loss: 0.0068 - val_acc: 0.9991 - val_categorical_accuracy: 0.1406 - val_f2_score: 0.0839 - val_f2_score_1: 0.0661 - val_f2_score_2: 0.0589 - val_f2_score_3: 0.0589 - val_f2_score_4: 0.0529 - val_f2_score_5: 0.0168
# Epoch 16/50
#  - 16s - loss: 0.0062 - acc: 0.9991 - categorical_accuracy: 0.0718 - f2_score: 0.0587 - f2_score_1: 0.0482 - f2_score_2: 0.0420 - f2_score_3: 0.0350 - f2_score_4: 0.0264 - f2_score_5: 0.0193 - val_loss: 0.0065 - val_acc: 0.9991 - val_categorical_accuracy: 0.1313 - val_f2_score: 0.0750 - val_f2_score_1: 0.0650 - val_f2_score_2: 0.0550 - val_f2_score_3: 0.0537 - val_f2_score_4: 0.0525 - val_f2_score_5: 0.0400
# Epoch 17/50
#  - 16s - loss: 0.0061 - acc: 0.9991 - categorical_accuracy: 0.0790 - f2_score: 0.0601 - f2_score_1: 0.0502 - f2_score_2: 0.0420 - f2_score_3: 0.0355 - f2_score_4: 0.0293 - f2_score_5: 0.0202 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.1550 - val_f2_score: 0.0837 - val_f2_score_1: 0.0612 - val_f2_score_2: 0.0550 - val_f2_score_3: 0.0525 - val_f2_score_4: 0.0512 - val_f2_score_5: 0.0387
# Epoch 18/50
#  - 16s - loss: 0.0060 - acc: 0.9991 - categorical_accuracy: 0.0836 - f2_score: 0.0678 - f2_score_1: 0.0547 - f2_score_2: 0.0485 - f2_score_3: 0.0430 - f2_score_4: 0.0302 - f2_score_5: 0.0214 - val_loss: 0.0067 - val_acc: 0.9991 - val_categorical_accuracy: 0.1487 - val_f2_score: 0.1146 - val_f2_score_1: 0.0860 - val_f2_score_2: 0.0700 - val_f2_score_3: 0.0612 - val_f2_score_4: 0.0587 - val_f2_score_5: 0.0575
# Epoch 19/50
#  - 17s - loss: 0.0059 - acc: 0.9991 - categorical_accuracy: 0.0915 - f2_score: 0.0718 - f2_score_1: 0.0621 - f2_score_2: 0.0503 - f2_score_3: 0.0460 - f2_score_4: 0.0382 - f2_score_5: 0.0268 - val_loss: 0.0066 - val_acc: 0.9991 - val_categorical_accuracy: 0.1388 - val_f2_score: 0.1199 - val_f2_score_1: 0.0835 - val_f2_score_2: 0.0700 - val_f2_score_3: 0.0625 - val_f2_score_4: 0.0550 - val_f2_score_5: 0.0487
# Epoch 20/50
#  - 16s - loss: 0.0058 - acc: 0.9991 - categorical_accuracy: 0.0955 - f2_score: 0.0750 - f2_score_1: 0.0635 - f2_score_2: 0.0547 - f2_score_3: 0.0478 - f2_score_4: 0.0383 - f2_score_5: 0.0297 - val_loss: 0.0064 - val_acc: 0.9992 - val_categorical_accuracy: 0.1550 - val_f2_score: 0.1205 - val_f2_score_1: 0.0923 - val_f2_score_2: 0.0850 - val_f2_score_3: 0.0750 - val_f2_score_4: 0.0650 - val_f2_score_5: 0.0625
# Epoch 21/50
#  - 16s - loss: 0.0059 - acc: 0.9991 - categorical_accuracy: 0.1022 - f2_score: 0.0803 - f2_score_1: 0.0698 - f2_score_2: 0.0591 - f2_score_3: 0.0520 - f2_score_4: 0.0447 - f2_score_5: 0.0352 - val_loss: 0.0060 - val_acc: 0.9991 - val_categorical_accuracy: 0.1713 - val_f2_score: 0.0975 - val_f2_score_1: 0.0696 - val_f2_score_2: 0.0596 - val_f2_score_3: 0.0537 - val_f2_score_4: 0.0512 - val_f2_score_5: 0.0500
# Epoch 22/50
#  - 16s - loss: 0.0056 - acc: 0.9991 - categorical_accuracy: 0.1137 - f2_score: 0.0814 - f2_score_1: 0.0695 - f2_score_2: 0.0625 - f2_score_3: 0.0522 - f2_score_4: 0.0431 - f2_score_5: 0.0353 - val_loss: 0.0061 - val_acc: 0.9991 - val_categorical_accuracy: 0.1537 - val_f2_score: 0.1079 - val_f2_score_1: 0.0862 - val_f2_score_2: 0.0687 - val_f2_score_3: 0.0600 - val_f2_score_4: 0.0575 - val_f2_score_5: 0.0550
# Epoch 23/50
#  - 16s - loss: 0.0056 - acc: 0.9991 - categorical_accuracy: 0.1082 - f2_score: 0.0862 - f2_score_1: 0.0682 - f2_score_2: 0.0599 - f2_score_3: 0.0521 - f2_score_4: 0.0434 - f2_score_5: 0.0339 - val_loss: 0.0062 - val_acc: 0.9991 - val_categorical_accuracy: 0.1762 - val_f2_score: 0.1480 - val_f2_score_1: 0.1096 - val_f2_score_2: 0.0798 - val_f2_score_3: 0.0625 - val_f2_score_4: 0.0587 - val_f2_score_5: 0.0587
# Epoch 24/50
#  - 17s - loss: 0.0056 - acc: 0.9991 - categorical_accuracy: 0.1232 - f2_score: 0.0921 - f2_score_1: 0.0823 - f2_score_2: 0.0731 - f2_score_3: 0.0600 - f2_score_4: 0.0485 - f2_score_5: 0.0422 - val_loss: 0.0060 - val_acc: 0.9991 - val_categorical_accuracy: 0.1613 - val_f2_score: 0.1200 - val_f2_score_1: 0.0885 - val_f2_score_2: 0.0723 - val_f2_score_3: 0.0637 - val_f2_score_4: 0.0587 - val_f2_score_5: 0.0575
# Epoch 25/50
#  - 16s - loss: 0.0055 - acc: 0.9991 - categorical_accuracy: 0.1172 - f2_score: 0.0929 - f2_score_1: 0.0773 - f2_score_2: 0.0680 - f2_score_3: 0.0589 - f2_score_4: 0.0488 - f2_score_5: 0.0408 - val_loss: 0.0062 - val_acc: 0.9992 - val_categorical_accuracy: 0.1850 - val_f2_score: 0.1473 - val_f2_score_1: 0.1004 - val_f2_score_2: 0.0848 - val_f2_score_3: 0.0787 - val_f2_score_4: 0.0675 - val_f2_score_5: 0.0650
# Epoch 26/50
#  - 16s - loss: 0.0054 - acc: 0.9991 - categorical_accuracy: 0.1503 - f2_score: 0.1108 - f2_score_1: 0.0954 - f2_score_2: 0.0862 - f2_score_3: 0.0785 - f2_score_4: 0.0684 - f2_score_5: 0.0575 - val_loss: 0.0060 - val_acc: 0.9991 - val_categorical_accuracy: 0.1688 - val_f2_score: 0.1376 - val_f2_score_1: 0.0954 - val_f2_score_2: 0.0762 - val_f2_score_3: 0.0625 - val_f2_score_4: 0.0575 - val_f2_score_5: 0.0537
# Epoch 27/50
#  - 16s - loss: 0.0053 - acc: 0.9991 - categorical_accuracy: 0.1336 - f2_score: 0.1038 - f2_score_1: 0.0862 - f2_score_2: 0.0723 - f2_score_3: 0.0636 - f2_score_4: 0.0533 - f2_score_5: 0.0442 - val_loss: 0.0063 - val_acc: 0.9991 - val_categorical_accuracy: 0.1825 - val_f2_score: 0.1632 - val_f2_score_1: 0.1196 - val_f2_score_2: 0.0919 - val_f2_score_3: 0.0762 - val_f2_score_4: 0.0625 - val_f2_score_5: 0.0562
# Epoch 28/50
#  - 16s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1378 - f2_score: 0.1055 - f2_score_1: 0.0885 - f2_score_2: 0.0783 - f2_score_3: 0.0683 - f2_score_4: 0.0552 - f2_score_5: 0.0498 - val_loss: 0.0056 - val_acc: 0.9991 - val_categorical_accuracy: 0.1900 - val_f2_score: 0.1554 - val_f2_score_1: 0.1238 - val_f2_score_2: 0.1029 - val_f2_score_3: 0.0900 - val_f2_score_4: 0.0687 - val_f2_score_5: 0.0650
# Epoch 29/50
#  - 17s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1444 - f2_score: 0.1222 - f2_score_1: 0.1000 - f2_score_2: 0.0869 - f2_score_3: 0.0766 - f2_score_4: 0.0606 - f2_score_5: 0.0529 - val_loss: 0.0055 - val_acc: 0.9991 - val_categorical_accuracy: 0.1815 - val_f2_score: 0.1531 - val_f2_score_1: 0.1216 - val_f2_score_2: 0.0923 - val_f2_score_3: 0.0769 - val_f2_score_4: 0.0649 - val_f2_score_5: 0.0625
# Epoch 30/50
#  - 16s - loss: 0.0052 - acc: 0.9991 - categorical_accuracy: 0.1496 - f2_score: 0.1179 - f2_score_1: 0.1023 - f2_score_2: 0.0868 - f2_score_3: 0.0770 - f2_score_4: 0.0642 - f2_score_5: 0.0566 - val_loss: 0.0059 - val_acc: 0.9991 - val_categorical_accuracy: 0.1837 - val_f2_score: 0.1869 - val_f2_score_1: 0.1568 - val_f2_score_2: 0.1237 - val_f2_score_3: 0.1102 - val_f2_score_4: 0.0825 - val_f2_score_5: 0.0712
# Epoch 31/50
#  - 16s - loss: 0.0051 - acc: 0.9991 - categorical_accuracy: 0.1562 - f2_score: 0.1344 - f2_score_1: 0.1122 - f2_score_2: 0.0988 - f2_score_3: 0.0885 - f2_score_4: 0.0725 - f2_score_5: 0.0604 - val_loss: 0.0058 - val_acc: 0.9991 - val_categorical_accuracy: 0.1862 - val_f2_score: 0.1648 - val_f2_score_1: 0.1331 - val_f2_score_2: 0.1067 - val_f2_score_3: 0.0933 - val_f2_score_4: 0.0723 - val_f2_score_5: 0.0637
# Epoch 32/50
#  - 16s - loss: 0.0050 - acc: 0.9991 - categorical_accuracy: 0.1583 - f2_score: 0.1308 - f2_score_1: 0.1129 - f2_score_2: 0.0971 - f2_score_3: 0.0832 - f2_score_4: 0.0672 - f2_score_5: 0.0564 - val_loss: 0.0056 - val_acc: 0.9991 - val_categorical_accuracy: 0.1875 - val_f2_score: 0.1614 - val_f2_score_1: 0.1294 - val_f2_score_2: 0.1035 - val_f2_score_3: 0.0904 - val_f2_score_4: 0.0712 - val_f2_score_5: 0.0612
# Epoch 33/50
#  - 16s - loss: 0.0050 - acc: 0.9991 - categorical_accuracy: 0.1670 - f2_score: 0.1385 - f2_score_1: 0.1187 - f2_score_2: 0.1028 - f2_score_3: 0.0872 - f2_score_4: 0.0725 - f2_score_5: 0.0627 - val_loss: 0.0058 - val_acc: 0.9991 - val_categorical_accuracy: 0.1825 - val_f2_score: 0.1752 - val_f2_score_1: 0.1504 - val_f2_score_2: 0.1163 - val_f2_score_3: 0.0912 - val_f2_score_4: 0.0750 - val_f2_score_5: 0.0712
# Epoch 34/50
#  - 18s - loss: 0.0049 - acc: 0.9991 - categorical_accuracy: 0.1675 - f2_score: 0.1376 - f2_score_1: 0.1161 - f2_score_2: 0.0991 - f2_score_3: 0.0863 - f2_score_4: 0.0684 - f2_score_5: 0.0602 - val_loss: 0.0053 - val_acc: 0.9991 - val_categorical_accuracy: 0.1888 - val_f2_score: 0.1789 - val_f2_score_1: 0.1537 - val_f2_score_2: 0.1221 - val_f2_score_3: 0.1079 - val_f2_score_4: 0.0871 - val_f2_score_5: 0.0687
# Epoch 35/50
#  - 17s - loss: 0.0049 - acc: 0.9991 - categorical_accuracy: 0.1800 - f2_score: 0.1539 - f2_score_1: 0.1357 - f2_score_2: 0.1168 - f2_score_3: 0.1013 - f2_score_4: 0.0810 - f2_score_5: 0.0720 - val_loss: 0.0055 - val_acc: 0.9991 - val_categorical_accuracy: 0.1938 - val_f2_score: 0.1716 - val_f2_score_1: 0.1510 - val_f2_score_2: 0.1238 - val_f2_score_3: 0.1102 - val_f2_score_4: 0.0773 - val_f2_score_5: 0.0685
# Epoch 36/50
#  - 16s - loss: 0.0048 - acc: 0.9991 - categorical_accuracy: 0.1905 - f2_score: 0.1599 - f2_score_1: 0.1392 - f2_score_2: 0.1170 - f2_score_3: 0.1057 - f2_score_4: 0.0847 - f2_score_5: 0.0694 - val_loss: 0.0055 - val_acc: 0.9992 - val_categorical_accuracy: 0.2037 - val_f2_score: 0.1895 - val_f2_score_1: 0.1617 - val_f2_score_2: 0.1350 - val_f2_score_3: 0.1077 - val_f2_score_4: 0.0960 - val_f2_score_5: 0.0785
# Epoch 37/50
#  - 16s - loss: 0.0048 - acc: 0.9991 - categorical_accuracy: 0.1858 - f2_score: 0.1611 - f2_score_1: 0.1343 - f2_score_2: 0.1141 - f2_score_3: 0.1010 - f2_score_4: 0.0801 - f2_score_5: 0.0679 - val_loss: 0.0055 - val_acc: 0.9991 - val_categorical_accuracy: 0.2112 - val_f2_score: 0.1886 - val_f2_score_1: 0.1682 - val_f2_score_2: 0.1487 - val_f2_score_3: 0.1210 - val_f2_score_4: 0.0919 - val_f2_score_5: 0.0762
# Epoch 38/50
#  - 17s - loss: 0.0047 - acc: 0.9991 - categorical_accuracy: 0.2012 - f2_score: 0.1701 - f2_score_1: 0.1452 - f2_score_2: 0.1260 - f2_score_3: 0.1095 - f2_score_4: 0.0871 - f2_score_5: 0.0744 - val_loss: 0.0052 - val_acc: 0.9992 - val_categorical_accuracy: 0.2100 - val_f2_score: 0.1965 - val_f2_score_1: 0.1719 - val_f2_score_2: 0.1486 - val_f2_score_3: 0.1274 - val_f2_score_4: 0.0971 - val_f2_score_5: 0.0775
# Epoch 39/50
#  - 16s - loss: 0.0046 - acc: 0.9991 - categorical_accuracy: 0.2048 - f2_score: 0.1827 - f2_score_1: 0.1582 - f2_score_2: 0.1383 - f2_score_3: 0.1193 - f2_score_4: 0.0998 - f2_score_5: 0.0815 - val_loss: 0.0053 - val_acc: 0.9991 - val_categorical_accuracy: 0.2037 - val_f2_score: 0.1793 - val_f2_score_1: 0.1565 - val_f2_score_2: 0.1362 - val_f2_score_3: 0.1149 - val_f2_score_4: 0.0898 - val_f2_score_5: 0.0710
# Epoch 40/50
#  - 16s - loss: 0.0045 - acc: 0.9991 - categorical_accuracy: 0.2320 - f2_score: 0.2036 - f2_score_1: 0.1775 - f2_score_2: 0.1526 - f2_score_3: 0.1371 - f2_score_4: 0.1086 - f2_score_5: 0.0911 - val_loss: 0.0054 - val_acc: 0.9991 - val_categorical_accuracy: 0.2238 - val_f2_score: 0.1914 - val_f2_score_1: 0.1700 - val_f2_score_2: 0.1455 - val_f2_score_3: 0.1260 - val_f2_score_4: 0.1042 - val_f2_score_5: 0.0908
# Epoch 41/50
#  - 16s - loss: 0.0045 - acc: 0.9991 - categorical_accuracy: 0.2196 - f2_score: 0.1965 - f2_score_1: 0.1628 - f2_score_2: 0.1415 - f2_score_3: 0.1255 - f2_score_4: 0.1010 - f2_score_5: 0.0847 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2087 - val_f2_score: 0.1780 - val_f2_score_1: 0.1587 - val_f2_score_2: 0.1400 - val_f2_score_3: 0.1237 - val_f2_score_4: 0.0981 - val_f2_score_5: 0.0783
# Epoch 42/50
#  - 16s - loss: 0.0044 - acc: 0.9991 - categorical_accuracy: 0.2345 - f2_score: 0.2003 - f2_score_1: 0.1743 - f2_score_2: 0.1534 - f2_score_3: 0.1385 - f2_score_4: 0.1113 - f2_score_5: 0.0894 - val_loss: 0.0053 - val_acc: 0.9991 - val_categorical_accuracy: 0.2125 - val_f2_score: 0.2099 - val_f2_score_1: 0.1829 - val_f2_score_2: 0.1513 - val_f2_score_3: 0.1379 - val_f2_score_4: 0.1037 - val_f2_score_5: 0.0787
# Epoch 43/50
#  - 16s - loss: 0.0044 - acc: 0.9991 - categorical_accuracy: 0.2316 - f2_score: 0.2027 - f2_score_1: 0.1705 - f2_score_2: 0.1492 - f2_score_3: 0.1319 - f2_score_4: 0.1072 - f2_score_5: 0.0905 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2188 - val_f2_score: 0.1982 - val_f2_score_1: 0.1771 - val_f2_score_2: 0.1495 - val_f2_score_3: 0.1302 - val_f2_score_4: 0.0970 - val_f2_score_5: 0.0805
# Epoch 44/50
#  - 16s - loss: 0.0043 - acc: 0.9991 - categorical_accuracy: 0.2420 - f2_score: 0.2080 - f2_score_1: 0.1804 - f2_score_2: 0.1616 - f2_score_3: 0.1451 - f2_score_4: 0.1167 - f2_score_5: 0.0933 - val_loss: 0.0049 - val_acc: 0.9991 - val_categorical_accuracy: 0.2087 - val_f2_score: 0.2000 - val_f2_score_1: 0.1651 - val_f2_score_2: 0.1267 - val_f2_score_3: 0.1179 - val_f2_score_4: 0.0937 - val_f2_score_5: 0.0825
# Epoch 45/50
#  - 16s - loss: 0.0042 - acc: 0.9992 - categorical_accuracy: 0.2599 - f2_score: 0.2273 - f2_score_1: 0.2000 - f2_score_2: 0.1758 - f2_score_3: 0.1557 - f2_score_4: 0.1256 - f2_score_5: 0.1091 - val_loss: 0.0051 - val_acc: 0.9992 - val_categorical_accuracy: 0.2238 - val_f2_score: 0.2163 - val_f2_score_1: 0.1890 - val_f2_score_2: 0.1584 - val_f2_score_3: 0.1273 - val_f2_score_4: 0.1067 - val_f2_score_5: 0.0883
# Epoch 46/50
#  - 16s - loss: 0.0041 - acc: 0.9992 - categorical_accuracy: 0.2716 - f2_score: 0.2521 - f2_score_1: 0.2200 - f2_score_2: 0.1959 - f2_score_3: 0.1753 - f2_score_4: 0.1450 - f2_score_5: 0.1222 - val_loss: 0.0053 - val_acc: 0.9991 - val_categorical_accuracy: 0.2225 - val_f2_score: 0.2275 - val_f2_score_1: 0.1980 - val_f2_score_2: 0.1735 - val_f2_score_3: 0.1508 - val_f2_score_4: 0.1075 - val_f2_score_5: 0.0937
# Epoch 47/50
#  - 16s - loss: 0.0041 - acc: 0.9991 - categorical_accuracy: 0.2688 - f2_score: 0.2442 - f2_score_1: 0.2117 - f2_score_2: 0.1856 - f2_score_3: 0.1623 - f2_score_4: 0.1323 - f2_score_5: 0.1072 - val_loss: 0.0050 - val_acc: 0.9992 - val_categorical_accuracy: 0.2325 - val_f2_score: 0.2143 - val_f2_score_1: 0.1955 - val_f2_score_2: 0.1632 - val_f2_score_3: 0.1579 - val_f2_score_4: 0.1175 - val_f2_score_5: 0.0950
# Epoch 48/50
#  - 16s - loss: 0.0039 - acc: 0.9992 - categorical_accuracy: 0.2842 - f2_score: 0.2664 - f2_score_1: 0.2363 - f2_score_2: 0.2092 - f2_score_3: 0.1900 - f2_score_4: 0.1559 - f2_score_5: 0.1227 - val_loss: 0.0049 - val_acc: 0.9991 - val_categorical_accuracy: 0.2313 - val_f2_score: 0.2140 - val_f2_score_1: 0.1879 - val_f2_score_2: 0.1623 - val_f2_score_3: 0.1448 - val_f2_score_4: 0.1144 - val_f2_score_5: 0.0950
# Epoch 49/50
#  - 17s - loss: 0.0039 - acc: 0.9992 - categorical_accuracy: 0.2939 - f2_score: 0.2711 - f2_score_1: 0.2426 - f2_score_2: 0.2162 - f2_score_3: 0.1947 - f2_score_4: 0.1573 - f2_score_5: 0.1365 - val_loss: 0.0050 - val_acc: 0.9991 - val_categorical_accuracy: 0.2037 - val_f2_score: 0.1973 - val_f2_score_1: 0.1754 - val_f2_score_2: 0.1613 - val_f2_score_3: 0.1464 - val_f2_score_4: 0.1104 - val_f2_score_5: 0.0910
# Epoch 50/50
#  - 16s - loss: 0.0038 - acc: 0.9992 - categorical_accuracy: 0.3096 - f2_score: 0.2848 - f2_score_1: 0.2540 - f2_score_2: 0.2251 - f2_score_3: 0.2067 - f2_score_4: 0.1700 - f2_score_5: 0.1395 - val_loss: 0.0049 - val_acc: 0.9992 - val_categorical_accuracy: 0.2288 - val_f2_score: 0.2205 - val_f2_score_1: 0.1775 - val_f2_score_2: 0.1561 - val_f2_score_3: 0.1438 - val_f2_score_4: 0.1248 - val_f2_score_5: 0.0975

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', figsize=(20,7))

ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
preds = model.predict_generator(test_generator, steps=STEP_SIZE_TEST)

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > 0.28:
            if len(valid) == 0:
                valid += labels[idx]
            else:
                valid += (' %s' % labels[idx])
    if len(valid) == 0:
        valid = np.argmax(pred_ar)
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id attribute_ids
# 0  10023b2cc4ed5f68            68
# 1  100fbe75ed8fd887            46
# 2  101b627524a04f19           897
# 3  10234480c41284c6            41
# 4  1023b0e2636dcea8            68
# 5   1039cd6cf85845c      1092 813
# 6   103a5b3f83fbe88           897
# 7  10413aaae8d6a9a2           897
# 8  10423822b93a65ab           551
# 9  1052bf702cb099f7           897
