# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.1
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.8, decay=0.0, nesterov=False)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [lrate, es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 12s - loss: 0.0293 - acc: 0.9915 - categorical_accuracy: 0.0302 - f2_score: 0.0754 - f2_score_1: 0.0553 - f2_score_2: 0.0405 - f2_score_3: 0.0294 - f2_score_4: 0.0161 - f2_score_5: 0.0089 - val_loss: 0.0152 - val_acc: 0.9971 - val_categorical_accuracy: 0.0112 - val_f2_score: 0.0492 - val_f2_score_1: 0.0021 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 2/200
#  - 10s - loss: 0.0169 - acc: 0.9971 - categorical_accuracy: 0.0370 - f2_score: 0.0898 - f2_score_1: 0.0538 - f2_score_2: 0.0287 - f2_score_3: 0.0145 - f2_score_4: 0.0028 - f2_score_5: 4.3538e-04 - val_loss: 0.0148 - val_acc: 0.9971 - val_categorical_accuracy: 0.0114 - val_f2_score: 0.0724 - val_f2_score_1: 0.0318 - val_f2_score_2: 0.0022 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 3/200
#  - 10s - loss: 0.0162 - acc: 0.9971 - categorical_accuracy: 0.0404 - f2_score: 0.0967 - f2_score_1: 0.0570 - f2_score_2: 0.0310 - f2_score_3: 0.0151 - f2_score_4: 0.0025 - f2_score_5: 2.1016e-04 - val_loss: 0.0146 - val_acc: 0.9971 - val_categorical_accuracy: 0.0368 - val_f2_score: 0.0917 - val_f2_score_1: 0.0521 - val_f2_score_2: 0.0252 - val_f2_score_3: 0.0061 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 4/200
#  - 10s - loss: 0.0158 - acc: 0.9971 - categorical_accuracy: 0.0442 - f2_score: 0.1055 - f2_score_1: 0.0649 - f2_score_2: 0.0378 - f2_score_3: 0.0199 - f2_score_4: 0.0038 - f2_score_5: 4.5824e-04 - val_loss: 0.0144 - val_acc: 0.9971 - val_categorical_accuracy: 0.0463 - val_f2_score: 0.1037 - val_f2_score_1: 0.0597 - val_f2_score_2: 0.0365 - val_f2_score_3: 0.0130 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00
# Epoch 5/200
#  - 10s - loss: 0.0155 - acc: 0.9971 - categorical_accuracy: 0.0491 - f2_score: 0.1121 - f2_score_1: 0.0716 - f2_score_2: 0.0431 - f2_score_3: 0.0237 - f2_score_4: 0.0049 - f2_score_5: 5.6729e-04 - val_loss: 0.0143 - val_acc: 0.9971 - val_categorical_accuracy: 0.0423 - val_f2_score: 0.1197 - val_f2_score_1: 0.0739 - val_f2_score_2: 0.0475 - val_f2_score_3: 0.0283 - val_f2_score_4: 5.1592e-04 - val_f2_score_5: 0.0000e+00
# Epoch 6/200
#  - 10s - loss: 0.0153 - acc: 0.9971 - categorical_accuracy: 0.0532 - f2_score: 0.1193 - f2_score_1: 0.0778 - f2_score_2: 0.0480 - f2_score_3: 0.0272 - f2_score_4: 0.0062 - f2_score_5: 8.7931e-04 - val_loss: 0.0142 - val_acc: 0.9971 - val_categorical_accuracy: 0.0453 - val_f2_score: 0.1230 - val_f2_score_1: 0.0807 - val_f2_score_2: 0.0528 - val_f2_score_3: 0.0340 - val_f2_score_4: 0.0015 - val_f2_score_5: 0.0000e+00
# Epoch 7/200
#  - 10s - loss: 0.0151 - acc: 0.9971 - categorical_accuracy: 0.0577 - f2_score: 0.1261 - f2_score_1: 0.0829 - f2_score_2: 0.0527 - f2_score_3: 0.0306 - f2_score_4: 0.0075 - f2_score_5: 9.5721e-04 - val_loss: 0.0141 - val_acc: 0.9971 - val_categorical_accuracy: 0.0541 - val_f2_score: 0.1278 - val_f2_score_1: 0.0822 - val_f2_score_2: 0.0558 - val_f2_score_3: 0.0333 - val_f2_score_4: 0.0020 - val_f2_score_5: 0.0000e+00
# Epoch 8/200
#  - 10s - loss: 0.0150 - acc: 0.9971 - categorical_accuracy: 0.0623 - f2_score: 0.1307 - f2_score_1: 0.0878 - f2_score_2: 0.0565 - f2_score_3: 0.0339 - f2_score_4: 0.0090 - f2_score_5: 0.0015 - val_loss: 0.0140 - val_acc: 0.9971 - val_categorical_accuracy: 0.0692 - val_f2_score: 0.1315 - val_f2_score_1: 0.0874 - val_f2_score_2: 0.0584 - val_f2_score_3: 0.0346 - val_f2_score_4: 0.0022 - val_f2_score_5: 0.0000e+00
# Epoch 9/200
#  - 11s - loss: 0.0149 - acc: 0.9971 - categorical_accuracy: 0.0668 - f2_score: 0.1358 - f2_score_1: 0.0923 - f2_score_2: 0.0607 - f2_score_3: 0.0377 - f2_score_4: 0.0109 - f2_score_5: 0.0021 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0638 - val_f2_score: 0.1359 - val_f2_score_1: 0.0916 - val_f2_score_2: 0.0628 - val_f2_score_3: 0.0436 - val_f2_score_4: 0.0079 - val_f2_score_5: 2.0121e-04
# Epoch 10/200
#  - 11s - loss: 0.0148 - acc: 0.9971 - categorical_accuracy: 0.0700 - f2_score: 0.1398 - f2_score_1: 0.0959 - f2_score_2: 0.0640 - f2_score_3: 0.0403 - f2_score_4: 0.0128 - f2_score_5: 0.0028 - val_loss: 0.0139 - val_acc: 0.9971 - val_categorical_accuracy: 0.0742 - val_f2_score: 0.1406 - val_f2_score_1: 0.0952 - val_f2_score_2: 0.0631 - val_f2_score_3: 0.0425 - val_f2_score_4: 0.0082 - val_f2_score_5: 2.3595e-04
# Epoch 11/200
#  - 11s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0716 - f2_score: 0.1420 - f2_score_1: 0.0973 - f2_score_2: 0.0653 - f2_score_3: 0.0421 - f2_score_4: 0.0140 - f2_score_5: 0.0033 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0730 - val_f2_score: 0.1485 - val_f2_score_1: 0.1033 - val_f2_score_2: 0.0698 - val_f2_score_3: 0.0493 - val_f2_score_4: 0.0137 - val_f2_score_5: 0.0011
# Epoch 12/200
#  - 10s - loss: 0.0147 - acc: 0.9971 - categorical_accuracy: 0.0739 - f2_score: 0.1448 - f2_score_1: 0.0994 - f2_score_2: 0.0676 - f2_score_3: 0.0440 - f2_score_4: 0.0149 - f2_score_5: 0.0037 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0729 - val_f2_score: 0.1478 - val_f2_score_1: 0.1013 - val_f2_score_2: 0.0702 - val_f2_score_3: 0.0498 - val_f2_score_4: 0.0146 - val_f2_score_5: 0.0014
# Epoch 13/200
#  - 10s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0746 - f2_score: 0.1460 - f2_score_1: 0.1023 - f2_score_2: 0.0693 - f2_score_3: 0.0458 - f2_score_4: 0.0160 - f2_score_5: 0.0045 - val_loss: 0.0138 - val_acc: 0.9971 - val_categorical_accuracy: 0.0759 - val_f2_score: 0.1514 - val_f2_score_1: 0.1021 - val_f2_score_2: 0.0672 - val_f2_score_3: 0.0459 - val_f2_score_4: 0.0127 - val_f2_score_5: 0.0020
# Epoch 14/200
#  - 10s - loss: 0.0146 - acc: 0.9971 - categorical_accuracy: 0.0756 - f2_score: 0.1486 - f2_score_1: 0.1039 - f2_score_2: 0.0707 - f2_score_3: 0.0468 - f2_score_4: 0.0164 - f2_score_5: 0.0046 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0708 - val_f2_score: 0.1568 - val_f2_score_1: 0.1081 - val_f2_score_2: 0.0723 - val_f2_score_3: 0.0508 - val_f2_score_4: 0.0166 - val_f2_score_5: 0.0021
# Epoch 15/200
#  - 10s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0785 - f2_score: 0.1526 - f2_score_1: 0.1065 - f2_score_2: 0.0734 - f2_score_3: 0.0492 - f2_score_4: 0.0183 - f2_score_5: 0.0054 - val_loss: 0.0137 - val_acc: 0.9971 - val_categorical_accuracy: 0.0723 - val_f2_score: 0.1574 - val_f2_score_1: 0.1067 - val_f2_score_2: 0.0749 - val_f2_score_3: 0.0531 - val_f2_score_4: 0.0189 - val_f2_score_5: 0.0040
# Epoch 16/200
#  - 10s - loss: 0.0145 - acc: 0.9971 - categorical_accuracy: 0.0787 - f2_score: 0.1535 - f2_score_1: 0.1076 - f2_score_2: 0.0744 - f2_score_3: 0.0503 - f2_score_4: 0.0191 - f2_score_5: 0.0058 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0757 - val_f2_score: 0.1681 - val_f2_score_1: 0.1178 - val_f2_score_2: 0.0809 - val_f2_score_3: 0.0576 - val_f2_score_4: 0.0208 - val_f2_score_5: 0.0039
# Epoch 17/200
#  - 10s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0785 - f2_score: 0.1557 - f2_score_1: 0.1103 - f2_score_2: 0.0766 - f2_score_3: 0.0516 - f2_score_4: 0.0198 - f2_score_5: 0.0063 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0780 - val_f2_score: 0.1661 - val_f2_score_1: 0.1134 - val_f2_score_2: 0.0782 - val_f2_score_3: 0.0559 - val_f2_score_4: 0.0208 - val_f2_score_5: 0.0045
# Epoch 18/200
#  - 10s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0802 - f2_score: 0.1582 - f2_score_1: 0.1126 - f2_score_2: 0.0786 - f2_score_3: 0.0539 - f2_score_4: 0.0212 - f2_score_5: 0.0069 - val_loss: 0.0136 - val_acc: 0.9971 - val_categorical_accuracy: 0.0722 - val_f2_score: 0.1701 - val_f2_score_1: 0.1226 - val_f2_score_2: 0.0841 - val_f2_score_3: 0.0609 - val_f2_score_4: 0.0264 - val_f2_score_5: 0.0061
# Epoch 19/200
#  - 10s - loss: 0.0144 - acc: 0.9971 - categorical_accuracy: 0.0807 - f2_score: 0.1603 - f2_score_1: 0.1142 - f2_score_2: 0.0797 - f2_score_3: 0.0547 - f2_score_4: 0.0220 - f2_score_5: 0.0074 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0850 - val_f2_score: 0.1756 - val_f2_score_1: 0.1261 - val_f2_score_2: 0.0841 - val_f2_score_3: 0.0587 - val_f2_score_4: 0.0218 - val_f2_score_5: 0.0060
# Epoch 20/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0804 - f2_score: 0.1614 - f2_score_1: 0.1156 - f2_score_2: 0.0811 - f2_score_3: 0.0556 - f2_score_4: 0.0226 - f2_score_5: 0.0074 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0808 - val_f2_score: 0.1721 - val_f2_score_1: 0.1215 - val_f2_score_2: 0.0830 - val_f2_score_3: 0.0588 - val_f2_score_4: 0.0223 - val_f2_score_5: 0.0069
# Epoch 21/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0805 - f2_score: 0.1621 - f2_score_1: 0.1154 - f2_score_2: 0.0814 - f2_score_3: 0.0558 - f2_score_4: 0.0232 - f2_score_5: 0.0080 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0773 - val_f2_score: 0.1759 - val_f2_score_1: 0.1264 - val_f2_score_2: 0.0868 - val_f2_score_3: 0.0628 - val_f2_score_4: 0.0258 - val_f2_score_5: 0.0071
# Epoch 22/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0814 - f2_score: 0.1632 - f2_score_1: 0.1172 - f2_score_2: 0.0826 - f2_score_3: 0.0569 - f2_score_4: 0.0233 - f2_score_5: 0.0080 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1784 - val_f2_score_1: 0.1288 - val_f2_score_2: 0.0890 - val_f2_score_3: 0.0640 - val_f2_score_4: 0.0257 - val_f2_score_5: 0.0072
# Epoch 23/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0812 - f2_score: 0.1654 - f2_score_1: 0.1191 - f2_score_2: 0.0844 - f2_score_3: 0.0584 - f2_score_4: 0.0241 - f2_score_5: 0.0085 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0755 - val_f2_score: 0.1763 - val_f2_score_1: 0.1262 - val_f2_score_2: 0.0867 - val_f2_score_3: 0.0634 - val_f2_score_4: 0.0270 - val_f2_score_5: 0.0084
# Epoch 24/200
#  - 10s - loss: 0.0143 - acc: 0.9971 - categorical_accuracy: 0.0821 - f2_score: 0.1664 - f2_score_1: 0.1194 - f2_score_2: 0.0847 - f2_score_3: 0.0586 - f2_score_4: 0.0247 - f2_score_5: 0.0087 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0769 - val_f2_score: 0.1770 - val_f2_score_1: 0.1280 - val_f2_score_2: 0.0889 - val_f2_score_3: 0.0652 - val_f2_score_4: 0.0279 - val_f2_score_5: 0.0079
# Epoch 25/200
#  - 10s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0826 - f2_score: 0.1666 - f2_score_1: 0.1199 - f2_score_2: 0.0851 - f2_score_3: 0.0591 - f2_score_4: 0.0254 - f2_score_5: 0.0093 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0782 - val_f2_score: 0.1761 - val_f2_score_1: 0.1255 - val_f2_score_2: 0.0877 - val_f2_score_3: 0.0634 - val_f2_score_4: 0.0259 - val_f2_score_5: 0.0074
# Epoch 26/200
#  - 10s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0831 - f2_score: 0.1677 - f2_score_1: 0.1211 - f2_score_2: 0.0862 - f2_score_3: 0.0601 - f2_score_4: 0.0258 - f2_score_5: 0.0092 - val_loss: 0.0135 - val_acc: 0.9971 - val_categorical_accuracy: 0.0763 - val_f2_score: 0.1812 - val_f2_score_1: 0.1310 - val_f2_score_2: 0.0915 - val_f2_score_3: 0.0668 - val_f2_score_4: 0.0282 - val_f2_score_5: 0.0081
# Epoch 27/200
#  - 11s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0838 - f2_score: 0.1693 - f2_score_1: 0.1226 - f2_score_2: 0.0868 - f2_score_3: 0.0607 - f2_score_4: 0.0263 - f2_score_5: 0.0097 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0759 - val_f2_score: 0.1846 - val_f2_score_1: 0.1352 - val_f2_score_2: 0.0948 - val_f2_score_3: 0.0700 - val_f2_score_4: 0.0318 - val_f2_score_5: 0.0099
# Epoch 28/200
#  - 10s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0837 - f2_score: 0.1704 - f2_score_1: 0.1233 - f2_score_2: 0.0876 - f2_score_3: 0.0613 - f2_score_4: 0.0264 - f2_score_5: 0.0098 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0827 - val_f2_score: 0.1814 - val_f2_score_1: 0.1321 - val_f2_score_2: 0.0917 - val_f2_score_3: 0.0661 - val_f2_score_4: 0.0275 - val_f2_score_5: 0.0080
# Epoch 29/200
#  - 10s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0833 - f2_score: 0.1711 - f2_score_1: 0.1236 - f2_score_2: 0.0883 - f2_score_3: 0.0620 - f2_score_4: 0.0267 - f2_score_5: 0.0100 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0820 - val_f2_score: 0.1834 - val_f2_score_1: 0.1328 - val_f2_score_2: 0.0926 - val_f2_score_3: 0.0664 - val_f2_score_4: 0.0280 - val_f2_score_5: 0.0086
# Epoch 30/200
#  - 10s - loss: 0.0142 - acc: 0.9971 - categorical_accuracy: 0.0840 - f2_score: 0.1719 - f2_score_1: 0.1246 - f2_score_2: 0.0891 - f2_score_3: 0.0626 - f2_score_4: 0.0272 - f2_score_5: 0.0101 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0801 - val_f2_score: 0.1863 - val_f2_score_1: 0.1366 - val_f2_score_2: 0.0965 - val_f2_score_3: 0.0697 - val_f2_score_4: 0.0306 - val_f2_score_5: 0.0093
# Epoch 31/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0849 - f2_score: 0.1723 - f2_score_1: 0.1249 - f2_score_2: 0.0893 - f2_score_3: 0.0630 - f2_score_4: 0.0274 - f2_score_5: 0.0104 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0811 - val_f2_score: 0.1877 - val_f2_score_1: 0.1374 - val_f2_score_2: 0.0973 - val_f2_score_3: 0.0705 - val_f2_score_4: 0.0310 - val_f2_score_5: 0.0100
# Epoch 32/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0843 - f2_score: 0.1732 - f2_score_1: 0.1258 - f2_score_2: 0.0899 - f2_score_3: 0.0631 - f2_score_4: 0.0282 - f2_score_5: 0.0108 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0787 - val_f2_score: 0.1855 - val_f2_score_1: 0.1360 - val_f2_score_2: 0.0967 - val_f2_score_3: 0.0704 - val_f2_score_4: 0.0319 - val_f2_score_5: 0.0099
# Epoch 33/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0840 - f2_score: 0.1730 - f2_score_1: 0.1259 - f2_score_2: 0.0899 - f2_score_3: 0.0635 - f2_score_4: 0.0282 - f2_score_5: 0.0108 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0847 - val_f2_score: 0.1864 - val_f2_score_1: 0.1368 - val_f2_score_2: 0.0960 - val_f2_score_3: 0.0689 - val_f2_score_4: 0.0292 - val_f2_score_5: 0.0094
# Epoch 34/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1741 - f2_score_1: 0.1273 - f2_score_2: 0.0903 - f2_score_3: 0.0633 - f2_score_4: 0.0283 - f2_score_5: 0.0107 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0815 - val_f2_score: 0.1878 - val_f2_score_1: 0.1389 - val_f2_score_2: 0.0984 - val_f2_score_3: 0.0710 - val_f2_score_4: 0.0309 - val_f2_score_5: 0.0099
# Epoch 35/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1748 - f2_score_1: 0.1276 - f2_score_2: 0.0909 - f2_score_3: 0.0640 - f2_score_4: 0.0281 - f2_score_5: 0.0110 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0786 - val_f2_score: 0.1879 - val_f2_score_1: 0.1368 - val_f2_score_2: 0.0973 - val_f2_score_3: 0.0712 - val_f2_score_4: 0.0316 - val_f2_score_5: 0.0099
# Epoch 36/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0848 - f2_score: 0.1747 - f2_score_1: 0.1273 - f2_score_2: 0.0913 - f2_score_3: 0.0649 - f2_score_4: 0.0289 - f2_score_5: 0.0111 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0811 - val_f2_score: 0.1897 - val_f2_score_1: 0.1407 - val_f2_score_2: 0.1002 - val_f2_score_3: 0.0731 - val_f2_score_4: 0.0331 - val_f2_score_5: 0.0108
# Epoch 37/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0844 - f2_score: 0.1759 - f2_score_1: 0.1285 - f2_score_2: 0.0927 - f2_score_3: 0.0650 - f2_score_4: 0.0292 - f2_score_5: 0.0111 - val_loss: 0.0134 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1887 - val_f2_score_1: 0.1397 - val_f2_score_2: 0.0996 - val_f2_score_3: 0.0724 - val_f2_score_4: 0.0321 - val_f2_score_5: 0.0107
# Epoch 38/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0851 - f2_score: 0.1763 - f2_score_1: 0.1285 - f2_score_2: 0.0928 - f2_score_3: 0.0656 - f2_score_4: 0.0296 - f2_score_5: 0.0115 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0789 - val_f2_score: 0.1920 - val_f2_score_1: 0.1427 - val_f2_score_2: 0.1018 - val_f2_score_3: 0.0753 - val_f2_score_4: 0.0351 - val_f2_score_5: 0.0112
# Epoch 39/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0856 - f2_score: 0.1764 - f2_score_1: 0.1286 - f2_score_2: 0.0923 - f2_score_3: 0.0654 - f2_score_4: 0.0296 - f2_score_5: 0.0119 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0818 - val_f2_score: 0.1904 - val_f2_score_1: 0.1404 - val_f2_score_2: 0.1000 - val_f2_score_3: 0.0732 - val_f2_score_4: 0.0330 - val_f2_score_5: 0.0109
# Epoch 40/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0853 - f2_score: 0.1766 - f2_score_1: 0.1292 - f2_score_2: 0.0927 - f2_score_3: 0.0656 - f2_score_4: 0.0295 - f2_score_5: 0.0117 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0797 - val_f2_score: 0.1912 - val_f2_score_1: 0.1415 - val_f2_score_2: 0.1009 - val_f2_score_3: 0.0744 - val_f2_score_4: 0.0344 - val_f2_score_5: 0.0113
# Epoch 41/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0847 - f2_score: 0.1767 - f2_score_1: 0.1287 - f2_score_2: 0.0930 - f2_score_3: 0.0657 - f2_score_4: 0.0297 - f2_score_5: 0.0121 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0813 - val_f2_score: 0.1920 - val_f2_score_1: 0.1423 - val_f2_score_2: 0.1014 - val_f2_score_3: 0.0741 - val_f2_score_4: 0.0340 - val_f2_score_5: 0.0111
# Epoch 42/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1764 - f2_score_1: 0.1304 - f2_score_2: 0.0936 - f2_score_3: 0.0661 - f2_score_4: 0.0302 - f2_score_5: 0.0122 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0821 - val_f2_score: 0.1909 - val_f2_score_1: 0.1405 - val_f2_score_2: 0.1002 - val_f2_score_3: 0.0733 - val_f2_score_4: 0.0330 - val_f2_score_5: 0.0109
# Epoch 43/200
#  - 11s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1773 - f2_score_1: 0.1299 - f2_score_2: 0.0932 - f2_score_3: 0.0665 - f2_score_4: 0.0304 - f2_score_5: 0.0122 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0826 - val_f2_score: 0.1916 - val_f2_score_1: 0.1417 - val_f2_score_2: 0.1010 - val_f2_score_3: 0.0736 - val_f2_score_4: 0.0337 - val_f2_score_5: 0.0111
# Epoch 44/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1778 - f2_score_1: 0.1306 - f2_score_2: 0.0939 - f2_score_3: 0.0667 - f2_score_4: 0.0304 - f2_score_5: 0.0119 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0816 - val_f2_score: 0.1930 - val_f2_score_1: 0.1433 - val_f2_score_2: 0.1023 - val_f2_score_3: 0.0751 - val_f2_score_4: 0.0350 - val_f2_score_5: 0.0117
# Epoch 45/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1773 - f2_score_1: 0.1293 - f2_score_2: 0.0933 - f2_score_3: 0.0661 - f2_score_4: 0.0303 - f2_score_5: 0.0121 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0821 - val_f2_score: 0.1935 - val_f2_score_1: 0.1445 - val_f2_score_2: 0.1031 - val_f2_score_3: 0.0755 - val_f2_score_4: 0.0354 - val_f2_score_5: 0.0119
# Epoch 46/200
#  - 10s - loss: 0.0141 - acc: 0.9971 - categorical_accuracy: 0.0874 - f2_score: 0.1782 - f2_score_1: 0.1304 - f2_score_2: 0.0941 - f2_score_3: 0.0676 - f2_score_4: 0.0309 - f2_score_5: 0.0125 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0795 - val_f2_score: 0.1924 - val_f2_score_1: 0.1431 - val_f2_score_2: 0.1025 - val_f2_score_3: 0.0763 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0121
# Epoch 47/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0854 - f2_score: 0.1782 - f2_score_1: 0.1308 - f2_score_2: 0.0942 - f2_score_3: 0.0677 - f2_score_4: 0.0312 - f2_score_5: 0.0125 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0801 - val_f2_score: 0.1928 - val_f2_score_1: 0.1431 - val_f2_score_2: 0.1024 - val_f2_score_3: 0.0757 - val_f2_score_4: 0.0355 - val_f2_score_5: 0.0120
# Epoch 48/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1784 - f2_score_1: 0.1306 - f2_score_2: 0.0941 - f2_score_3: 0.0672 - f2_score_4: 0.0303 - f2_score_5: 0.0118 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0800 - val_f2_score: 0.1939 - val_f2_score_1: 0.1442 - val_f2_score_2: 0.1031 - val_f2_score_3: 0.0762 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0121
# Epoch 49/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1787 - f2_score_1: 0.1313 - f2_score_2: 0.0953 - f2_score_3: 0.0680 - f2_score_4: 0.0309 - f2_score_5: 0.0122 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0794 - val_f2_score: 0.1935 - val_f2_score_1: 0.1446 - val_f2_score_2: 0.1038 - val_f2_score_3: 0.0768 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0123
# Epoch 50/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0853 - f2_score: 0.1783 - f2_score_1: 0.1308 - f2_score_2: 0.0951 - f2_score_3: 0.0681 - f2_score_4: 0.0315 - f2_score_5: 0.0126 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0816 - val_f2_score: 0.1942 - val_f2_score_1: 0.1450 - val_f2_score_2: 0.1035 - val_f2_score_3: 0.0765 - val_f2_score_4: 0.0363 - val_f2_score_5: 0.0123
# Epoch 51/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0856 - f2_score: 0.1788 - f2_score_1: 0.1321 - f2_score_2: 0.0951 - f2_score_3: 0.0673 - f2_score_4: 0.0308 - f2_score_5: 0.0126 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0813 - val_f2_score: 0.1943 - val_f2_score_1: 0.1444 - val_f2_score_2: 0.1033 - val_f2_score_3: 0.0761 - val_f2_score_4: 0.0356 - val_f2_score_5: 0.0121
# Epoch 52/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1794 - f2_score_1: 0.1314 - f2_score_2: 0.0946 - f2_score_3: 0.0669 - f2_score_4: 0.0309 - f2_score_5: 0.0125 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0803 - val_f2_score: 0.1943 - val_f2_score_1: 0.1451 - val_f2_score_2: 0.1040 - val_f2_score_3: 0.0771 - val_f2_score_4: 0.0369 - val_f2_score_5: 0.0126
# Epoch 53/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1790 - f2_score_1: 0.1314 - f2_score_2: 0.0960 - f2_score_3: 0.0686 - f2_score_4: 0.0317 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1940 - val_f2_score_1: 0.1440 - val_f2_score_2: 0.1029 - val_f2_score_3: 0.0756 - val_f2_score_4: 0.0351 - val_f2_score_5: 0.0122
# Epoch 54/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1791 - f2_score_1: 0.1316 - f2_score_2: 0.0951 - f2_score_3: 0.0683 - f2_score_4: 0.0317 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0819 - val_f2_score: 0.1949 - val_f2_score_1: 0.1451 - val_f2_score_2: 0.1039 - val_f2_score_3: 0.0762 - val_f2_score_4: 0.0356 - val_f2_score_5: 0.0122
# Epoch 55/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1789 - f2_score_1: 0.1328 - f2_score_2: 0.0956 - f2_score_3: 0.0682 - f2_score_4: 0.0316 - f2_score_5: 0.0127 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1948 - val_f2_score_1: 0.1445 - val_f2_score_2: 0.1033 - val_f2_score_3: 0.0760 - val_f2_score_4: 0.0353 - val_f2_score_5: 0.0122
# Epoch 56/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0856 - f2_score: 0.1795 - f2_score_1: 0.1321 - f2_score_2: 0.0957 - f2_score_3: 0.0679 - f2_score_4: 0.0310 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1947 - val_f2_score_1: 0.1449 - val_f2_score_2: 0.1037 - val_f2_score_3: 0.0762 - val_f2_score_4: 0.0355 - val_f2_score_5: 0.0122
# Epoch 57/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1790 - f2_score_1: 0.1312 - f2_score_2: 0.0949 - f2_score_3: 0.0676 - f2_score_4: 0.0309 - f2_score_5: 0.0125 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0821 - val_f2_score: 0.1948 - val_f2_score_1: 0.1449 - val_f2_score_2: 0.1037 - val_f2_score_3: 0.0763 - val_f2_score_4: 0.0359 - val_f2_score_5: 0.0124
# Epoch 58/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1803 - f2_score_1: 0.1325 - f2_score_2: 0.0956 - f2_score_3: 0.0684 - f2_score_4: 0.0317 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1946 - val_f2_score_1: 0.1447 - val_f2_score_2: 0.1034 - val_f2_score_3: 0.0761 - val_f2_score_4: 0.0356 - val_f2_score_5: 0.0123
# Epoch 59/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0850 - f2_score: 0.1805 - f2_score_1: 0.1319 - f2_score_2: 0.0950 - f2_score_3: 0.0682 - f2_score_4: 0.0317 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0819 - val_f2_score: 0.1948 - val_f2_score_1: 0.1452 - val_f2_score_2: 0.1040 - val_f2_score_3: 0.0768 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0125
# Epoch 60/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1795 - f2_score_1: 0.1325 - f2_score_2: 0.0962 - f2_score_3: 0.0686 - f2_score_4: 0.0313 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1954 - val_f2_score_1: 0.1460 - val_f2_score_2: 0.1044 - val_f2_score_3: 0.0768 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0125
# Epoch 61/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1803 - f2_score_1: 0.1329 - f2_score_2: 0.0958 - f2_score_3: 0.0683 - f2_score_4: 0.0313 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1957 - val_f2_score_1: 0.1463 - val_f2_score_2: 0.1047 - val_f2_score_3: 0.0772 - val_f2_score_4: 0.0366 - val_f2_score_5: 0.0128
# Epoch 62/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1806 - f2_score_1: 0.1322 - f2_score_2: 0.0962 - f2_score_3: 0.0689 - f2_score_4: 0.0321 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1952 - val_f2_score_1: 0.1455 - val_f2_score_2: 0.1042 - val_f2_score_3: 0.0767 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0125
# Epoch 63/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1806 - f2_score_1: 0.1330 - f2_score_2: 0.0960 - f2_score_3: 0.0682 - f2_score_4: 0.0319 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1949 - val_f2_score_1: 0.1454 - val_f2_score_2: 0.1043 - val_f2_score_3: 0.0767 - val_f2_score_4: 0.0361 - val_f2_score_5: 0.0125
# Epoch 64/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1802 - f2_score_1: 0.1332 - f2_score_2: 0.0964 - f2_score_3: 0.0688 - f2_score_4: 0.0317 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1960 - val_f2_score_1: 0.1466 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0774 - val_f2_score_4: 0.0367 - val_f2_score_5: 0.0127
# Epoch 65/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1801 - f2_score_1: 0.1326 - f2_score_2: 0.0968 - f2_score_3: 0.0687 - f2_score_4: 0.0318 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1961 - val_f2_score_1: 0.1461 - val_f2_score_2: 0.1048 - val_f2_score_3: 0.0771 - val_f2_score_4: 0.0364 - val_f2_score_5: 0.0127
# Epoch 66/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1806 - f2_score_1: 0.1335 - f2_score_2: 0.0966 - f2_score_3: 0.0692 - f2_score_4: 0.0319 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1959 - val_f2_score_1: 0.1460 - val_f2_score_2: 0.1046 - val_f2_score_3: 0.0771 - val_f2_score_4: 0.0365 - val_f2_score_5: 0.0127
# Epoch 67/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0860 - f2_score: 0.1808 - f2_score_1: 0.1333 - f2_score_2: 0.0967 - f2_score_3: 0.0690 - f2_score_4: 0.0321 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1956 - val_f2_score_1: 0.1459 - val_f2_score_2: 0.1045 - val_f2_score_3: 0.0769 - val_f2_score_4: 0.0364 - val_f2_score_5: 0.0127
# Epoch 68/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1804 - f2_score_1: 0.1321 - f2_score_2: 0.0961 - f2_score_3: 0.0690 - f2_score_4: 0.0319 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1962 - val_f2_score_1: 0.1465 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0775 - val_f2_score_4: 0.0369 - val_f2_score_5: 0.0128
# Epoch 69/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0879 - f2_score: 0.1802 - f2_score_1: 0.1328 - f2_score_2: 0.0961 - f2_score_3: 0.0689 - f2_score_4: 0.0317 - f2_score_5: 0.0128 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1962 - val_f2_score_1: 0.1465 - val_f2_score_2: 0.1050 - val_f2_score_3: 0.0774 - val_f2_score_4: 0.0366 - val_f2_score_5: 0.0128
# Epoch 70/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1805 - f2_score_1: 0.1332 - f2_score_2: 0.0966 - f2_score_3: 0.0689 - f2_score_4: 0.0321 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0827 - val_f2_score: 0.1960 - val_f2_score_1: 0.1462 - val_f2_score_2: 0.1048 - val_f2_score_3: 0.0773 - val_f2_score_4: 0.0366 - val_f2_score_5: 0.0127
# Epoch 71/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0888 - f2_score: 0.1808 - f2_score_1: 0.1331 - f2_score_2: 0.0965 - f2_score_3: 0.0691 - f2_score_4: 0.0319 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1958 - val_f2_score_1: 0.1461 - val_f2_score_2: 0.1048 - val_f2_score_3: 0.0773 - val_f2_score_4: 0.0367 - val_f2_score_5: 0.0128
# Epoch 72/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1811 - f2_score_1: 0.1335 - f2_score_2: 0.0967 - f2_score_3: 0.0692 - f2_score_4: 0.0318 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1958 - val_f2_score_1: 0.1460 - val_f2_score_2: 0.1046 - val_f2_score_3: 0.0772 - val_f2_score_4: 0.0366 - val_f2_score_5: 0.0127
# Epoch 73/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1810 - f2_score_1: 0.1327 - f2_score_2: 0.0959 - f2_score_3: 0.0688 - f2_score_4: 0.0314 - f2_score_5: 0.0128 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1959 - val_f2_score_1: 0.1462 - val_f2_score_2: 0.1049 - val_f2_score_3: 0.0774 - val_f2_score_4: 0.0368 - val_f2_score_5: 0.0128
# Epoch 74/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1808 - f2_score_1: 0.1332 - f2_score_2: 0.0968 - f2_score_3: 0.0692 - f2_score_4: 0.0322 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1960 - val_f2_score_1: 0.1464 - val_f2_score_2: 0.1049 - val_f2_score_3: 0.0776 - val_f2_score_4: 0.0369 - val_f2_score_5: 0.0129
# Epoch 75/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1814 - f2_score_1: 0.1330 - f2_score_2: 0.0962 - f2_score_3: 0.0687 - f2_score_4: 0.0320 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0129
# Epoch 76/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1810 - f2_score_1: 0.1329 - f2_score_2: 0.0968 - f2_score_3: 0.0689 - f2_score_4: 0.0319 - f2_score_5: 0.0128 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1963 - val_f2_score_1: 0.1466 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0777 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0129
# Epoch 77/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1806 - f2_score_1: 0.1330 - f2_score_2: 0.0967 - f2_score_3: 0.0690 - f2_score_4: 0.0320 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1963 - val_f2_score_1: 0.1466 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0775 - val_f2_score_4: 0.0369 - val_f2_score_5: 0.0129
# Epoch 78/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1806 - f2_score_1: 0.1337 - f2_score_2: 0.0966 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1960 - val_f2_score_1: 0.1463 - val_f2_score_2: 0.1048 - val_f2_score_3: 0.0774 - val_f2_score_4: 0.0367 - val_f2_score_5: 0.0129
# Epoch 79/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1807 - f2_score_1: 0.1331 - f2_score_2: 0.0961 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1966 - val_f2_score_1: 0.1467 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0777 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0130
# Epoch 80/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0880 - f2_score: 0.1813 - f2_score_1: 0.1339 - f2_score_2: 0.0965 - f2_score_3: 0.0686 - f2_score_4: 0.0320 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1966 - val_f2_score_1: 0.1468 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0130
# Epoch 81/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1810 - f2_score_1: 0.1337 - f2_score_2: 0.0965 - f2_score_3: 0.0688 - f2_score_4: 0.0316 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1961 - val_f2_score_1: 0.1464 - val_f2_score_2: 0.1049 - val_f2_score_3: 0.0776 - val_f2_score_4: 0.0369 - val_f2_score_5: 0.0129
# Epoch 82/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1805 - f2_score_1: 0.1332 - f2_score_2: 0.0971 - f2_score_3: 0.0694 - f2_score_4: 0.0319 - f2_score_5: 0.0128 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0823 - val_f2_score: 0.1964 - val_f2_score_1: 0.1467 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 83/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0874 - f2_score: 0.1814 - f2_score_1: 0.1337 - f2_score_2: 0.0968 - f2_score_3: 0.0691 - f2_score_4: 0.0316 - f2_score_5: 0.0126 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0822 - val_f2_score: 0.1964 - val_f2_score_1: 0.1467 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 84/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1817 - f2_score_1: 0.1338 - f2_score_2: 0.0963 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1966 - val_f2_score_1: 0.1468 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 85/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0853 - f2_score: 0.1806 - f2_score_1: 0.1331 - f2_score_2: 0.0966 - f2_score_3: 0.0695 - f2_score_4: 0.0318 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1965 - val_f2_score_1: 0.1468 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0130
# Epoch 86/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0871 - f2_score: 0.1813 - f2_score_1: 0.1336 - f2_score_2: 0.0967 - f2_score_3: 0.0689 - f2_score_4: 0.0319 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1965 - val_f2_score_1: 0.1467 - val_f2_score_2: 0.1051 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 87/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1810 - f2_score_1: 0.1334 - f2_score_2: 0.0969 - f2_score_3: 0.0688 - f2_score_4: 0.0321 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1964 - val_f2_score_1: 0.1468 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 88/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1808 - f2_score_1: 0.1333 - f2_score_2: 0.0971 - f2_score_3: 0.0693 - f2_score_4: 0.0325 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1966 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 89/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0858 - f2_score: 0.1811 - f2_score_1: 0.1330 - f2_score_2: 0.0965 - f2_score_3: 0.0691 - f2_score_4: 0.0326 - f2_score_5: 0.0138 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1965 - val_f2_score_1: 0.1468 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 90/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1815 - f2_score_1: 0.1328 - f2_score_2: 0.0966 - f2_score_3: 0.0688 - f2_score_4: 0.0320 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 91/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1811 - f2_score_1: 0.1334 - f2_score_2: 0.0966 - f2_score_3: 0.0693 - f2_score_4: 0.0321 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 92/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1807 - f2_score_1: 0.1333 - f2_score_2: 0.0962 - f2_score_3: 0.0689 - f2_score_4: 0.0319 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 93/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1816 - f2_score_1: 0.1333 - f2_score_2: 0.0971 - f2_score_3: 0.0698 - f2_score_4: 0.0325 - f2_score_5: 0.0136 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1965 - val_f2_score_1: 0.1469 - val_f2_score_2: 0.1052 - val_f2_score_3: 0.0778 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 94/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1808 - f2_score_1: 0.1335 - f2_score_2: 0.0964 - f2_score_3: 0.0691 - f2_score_4: 0.0320 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 95/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1815 - f2_score_1: 0.1334 - f2_score_2: 0.0969 - f2_score_3: 0.0698 - f2_score_4: 0.0322 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1967 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 96/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1814 - f2_score_1: 0.1334 - f2_score_2: 0.0965 - f2_score_3: 0.0690 - f2_score_4: 0.0319 - f2_score_5: 0.0128 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1967 - val_f2_score_1: 0.1469 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0130
# Epoch 97/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1811 - f2_score_1: 0.1332 - f2_score_2: 0.0962 - f2_score_3: 0.0691 - f2_score_4: 0.0327 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1967 - val_f2_score_1: 0.1469 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0779 - val_f2_score_4: 0.0370 - val_f2_score_5: 0.0130
# Epoch 98/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1813 - f2_score_1: 0.1330 - f2_score_2: 0.0966 - f2_score_3: 0.0688 - f2_score_4: 0.0320 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0130
# Epoch 99/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1814 - f2_score_1: 0.1332 - f2_score_2: 0.0966 - f2_score_3: 0.0689 - f2_score_4: 0.0323 - f2_score_5: 0.0138 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 100/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1808 - f2_score_1: 0.1328 - f2_score_2: 0.0960 - f2_score_3: 0.0685 - f2_score_4: 0.0319 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 101/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1807 - f2_score_1: 0.1330 - f2_score_2: 0.0968 - f2_score_3: 0.0693 - f2_score_4: 0.0327 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 102/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1812 - f2_score_1: 0.1331 - f2_score_2: 0.0965 - f2_score_3: 0.0693 - f2_score_4: 0.0326 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 103/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1815 - f2_score_1: 0.1331 - f2_score_2: 0.0968 - f2_score_3: 0.0697 - f2_score_4: 0.0322 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 104/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0857 - f2_score: 0.1811 - f2_score_1: 0.1335 - f2_score_2: 0.0963 - f2_score_3: 0.0685 - f2_score_4: 0.0320 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 105/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0870 - f2_score: 0.1817 - f2_score_1: 0.1331 - f2_score_2: 0.0971 - f2_score_3: 0.0693 - f2_score_4: 0.0317 - f2_score_5: 0.0129 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 106/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1811 - f2_score_1: 0.1333 - f2_score_2: 0.0964 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 107/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1811 - f2_score_1: 0.1336 - f2_score_2: 0.0972 - f2_score_3: 0.0697 - f2_score_4: 0.0323 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 108/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1808 - f2_score_1: 0.1335 - f2_score_2: 0.0970 - f2_score_3: 0.0693 - f2_score_4: 0.0325 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0132
# Epoch 109/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1812 - f2_score_1: 0.1333 - f2_score_2: 0.0966 - f2_score_3: 0.0693 - f2_score_4: 0.0323 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0132
# Epoch 110/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0873 - f2_score: 0.1806 - f2_score_1: 0.1341 - f2_score_2: 0.0970 - f2_score_3: 0.0699 - f2_score_4: 0.0323 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 111/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1810 - f2_score_1: 0.1332 - f2_score_2: 0.0968 - f2_score_3: 0.0692 - f2_score_4: 0.0319 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 112/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1801 - f2_score_1: 0.1332 - f2_score_2: 0.0970 - f2_score_3: 0.0692 - f2_score_4: 0.0320 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 113/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0874 - f2_score: 0.1814 - f2_score_1: 0.1335 - f2_score_2: 0.0969 - f2_score_3: 0.0699 - f2_score_4: 0.0327 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 114/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0850 - f2_score: 0.1811 - f2_score_1: 0.1327 - f2_score_2: 0.0960 - f2_score_3: 0.0687 - f2_score_4: 0.0317 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1053 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 115/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1815 - f2_score_1: 0.1340 - f2_score_2: 0.0961 - f2_score_3: 0.0693 - f2_score_4: 0.0324 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 116/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1805 - f2_score_1: 0.1328 - f2_score_2: 0.0963 - f2_score_3: 0.0689 - f2_score_4: 0.0322 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 117/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0879 - f2_score: 0.1815 - f2_score_1: 0.1335 - f2_score_2: 0.0969 - f2_score_3: 0.0693 - f2_score_4: 0.0327 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0825 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 118/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0864 - f2_score: 0.1814 - f2_score_1: 0.1335 - f2_score_2: 0.0967 - f2_score_3: 0.0697 - f2_score_4: 0.0324 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 119/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0868 - f2_score: 0.1815 - f2_score_1: 0.1331 - f2_score_2: 0.0958 - f2_score_3: 0.0686 - f2_score_4: 0.0317 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0132
# Epoch 120/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0866 - f2_score: 0.1808 - f2_score_1: 0.1332 - f2_score_2: 0.0973 - f2_score_3: 0.0696 - f2_score_4: 0.0331 - f2_score_5: 0.0137 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 121/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0862 - f2_score: 0.1815 - f2_score_1: 0.1332 - f2_score_2: 0.0964 - f2_score_3: 0.0687 - f2_score_4: 0.0317 - f2_score_5: 0.0131 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 122/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1813 - f2_score_1: 0.1332 - f2_score_2: 0.0966 - f2_score_3: 0.0690 - f2_score_4: 0.0320 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 123/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0867 - f2_score: 0.1809 - f2_score_1: 0.1335 - f2_score_2: 0.0973 - f2_score_3: 0.0694 - f2_score_4: 0.0328 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 124/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0868 - f2_score: 0.1801 - f2_score_1: 0.1325 - f2_score_2: 0.0966 - f2_score_3: 0.0688 - f2_score_4: 0.0324 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0373 - val_f2_score_5: 0.0131
# Epoch 125/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0887 - f2_score: 0.1818 - f2_score_1: 0.1338 - f2_score_2: 0.0972 - f2_score_3: 0.0699 - f2_score_4: 0.0330 - f2_score_5: 0.0137 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 126/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0880 - f2_score: 0.1817 - f2_score_1: 0.1335 - f2_score_2: 0.0968 - f2_score_3: 0.0695 - f2_score_4: 0.0324 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1055 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 127/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1809 - f2_score_1: 0.1336 - f2_score_2: 0.0965 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0130 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 128/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0869 - f2_score: 0.1807 - f2_score_1: 0.1333 - f2_score_2: 0.0964 - f2_score_3: 0.0695 - f2_score_4: 0.0325 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 129/200
#  - 11s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0859 - f2_score: 0.1813 - f2_score_1: 0.1336 - f2_score_2: 0.0965 - f2_score_3: 0.0690 - f2_score_4: 0.0321 - f2_score_5: 0.0134 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1471 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0781 - val_f2_score_4: 0.0372 - val_f2_score_5: 0.0131
# Epoch 130/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1804 - f2_score_1: 0.1332 - f2_score_2: 0.0967 - f2_score_3: 0.0692 - f2_score_4: 0.0325 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 131/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0863 - f2_score: 0.1811 - f2_score_1: 0.1336 - f2_score_2: 0.0964 - f2_score_3: 0.0691 - f2_score_4: 0.0321 - f2_score_5: 0.0135 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 132/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0855 - f2_score: 0.1806 - f2_score_1: 0.1330 - f2_score_2: 0.0963 - f2_score_3: 0.0690 - f2_score_4: 0.0324 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 133/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0861 - f2_score: 0.1809 - f2_score_1: 0.1332 - f2_score_2: 0.0967 - f2_score_3: 0.0699 - f2_score_4: 0.0323 - f2_score_5: 0.0133 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1969 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 134/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0872 - f2_score: 0.1812 - f2_score_1: 0.1331 - f2_score_2: 0.0973 - f2_score_3: 0.0696 - f2_score_4: 0.0322 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 135/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0868 - f2_score: 0.1809 - f2_score_1: 0.1326 - f2_score_2: 0.0964 - f2_score_3: 0.0691 - f2_score_4: 0.0322 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 136/200
#  - 10s - loss: 0.0140 - acc: 0.9971 - categorical_accuracy: 0.0865 - f2_score: 0.1820 - f2_score_1: 0.1344 - f2_score_2: 0.0967 - f2_score_3: 0.0692 - f2_score_4: 0.0320 - f2_score_5: 0.0132 - val_loss: 0.0133 - val_acc: 0.9971 - val_categorical_accuracy: 0.0824 - val_f2_score: 0.1968 - val_f2_score_1: 0.1470 - val_f2_score_2: 0.1054 - val_f2_score_3: 0.0780 - val_f2_score_4: 0.0371 - val_f2_score_5: 0.0131
# Epoch 00136: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id          attribute_ids
# 0  10023b2cc4ed5f68                    121
# 1  100fbe75ed8fd887                    121
# 2  101b627524a04f19                    121
# 3  10234480c41284c6      147 813 1046 1092
# 4  1023b0e2636dcea8                    121
# 5   1039cd6cf85845c    13 405 813 896 1092
# 6   103a5b3f83fbe88  147 194 813 1046 1092
# 7  10413aaae8d6a9a2           147 813 1092
# 8  10423822b93a65ab                147 813
# 9  1052bf702cb099f7                147 671
