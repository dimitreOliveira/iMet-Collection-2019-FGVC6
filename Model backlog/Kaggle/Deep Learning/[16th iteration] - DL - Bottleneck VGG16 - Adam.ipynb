# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Bottleneck features using VGG16

# %%
# Model parameters
BATCH_SIZE = 64
EPOCHS = 200
LEARNING_RATE = 0.0001
HEIGHT = 128
WIDTH = 128
CANAL = 3
N_CLASSES = labels.shape[0]
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = 0.5
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode=None,
    target_size=(HEIGHT, WIDTH))

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 109237 images.
# Found 7443 images.

# %%
# Build the VGG16 network
model_vgg = VGG16(weights=None, include_top=False)
model_vgg.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size

train_data = model_vgg.predict_generator(train_generator, STEP_SIZE_TRAIN)

train_labels = []
for label in train['attribute_ids'][:train_data.shape[0]].values:
    zeros = np.zeros(N_CLASSES)
    for label_i in label:
        zeros[int(label_i)] = 1
    train_labels.append(zeros)
    
train_labels = np.asarray(train_labels)

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size=0.2, random_state=0)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="sigmoid"))

optimizer = optimizers.Adam(lr=LEARNING_RATE)
thresholds = [0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x=X_train, y=Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks,
                    verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 87347 samples, validate on 21837 samples
# Epoch 1/200
#  - 13s - loss: 0.0252 - acc: 0.9927 - categorical_accuracy: 0.0725 - f2_score: 0.1464 - f2_score_1: 0.1211 - f2_score_2: 0.0993 - f2_score_3: 0.0813 - f2_score_4: 0.0540 - f2_score_5: 0.0349 - val_loss: 0.0129 - val_acc: 0.9972 - val_categorical_accuracy: 0.1234 - val_f2_score: 0.2077 - val_f2_score_1: 0.1577 - val_f2_score_2: 0.1192 - val_f2_score_3: 0.0907 - val_f2_score_4: 0.0524 - val_f2_score_5: 0.0294
# Epoch 2/200
#  - 11s - loss: 0.0133 - acc: 0.9972 - categorical_accuracy: 0.1228 - f2_score: 0.2443 - f2_score_1: 0.2052 - f2_score_2: 0.1703 - f2_score_3: 0.1401 - f2_score_4: 0.0950 - f2_score_5: 0.0623 - val_loss: 0.0121 - val_acc: 0.9972 - val_categorical_accuracy: 0.1283 - val_f2_score: 0.2732 - val_f2_score_1: 0.2226 - val_f2_score_2: 0.1805 - val_f2_score_3: 0.1461 - val_f2_score_4: 0.0983 - val_f2_score_5: 0.0645
# Epoch 3/200
#  - 11s - loss: 0.0124 - acc: 0.9972 - categorical_accuracy: 0.1428 - f2_score: 0.2894 - f2_score_1: 0.2483 - f2_score_2: 0.2103 - f2_score_3: 0.1775 - f2_score_4: 0.1244 - f2_score_5: 0.0864 - val_loss: 0.0116 - val_acc: 0.9973 - val_categorical_accuracy: 0.1339 - val_f2_score: 0.3019 - val_f2_score_1: 0.2550 - val_f2_score_2: 0.2143 - val_f2_score_3: 0.1790 - val_f2_score_4: 0.1252 - val_f2_score_5: 0.0866
# Epoch 4/200
#  - 11s - loss: 0.0118 - acc: 0.9973 - categorical_accuracy: 0.1546 - f2_score: 0.3161 - f2_score_1: 0.2756 - f2_score_2: 0.2373 - f2_score_3: 0.2034 - f2_score_4: 0.1468 - f2_score_5: 0.1048 - val_loss: 0.0113 - val_acc: 0.9973 - val_categorical_accuracy: 0.1462 - val_f2_score: 0.3150 - val_f2_score_1: 0.2672 - val_f2_score_2: 0.2266 - val_f2_score_3: 0.1906 - val_f2_score_4: 0.1377 - val_f2_score_5: 0.0988
# Epoch 5/200
#  - 11s - loss: 0.0114 - acc: 0.9973 - categorical_accuracy: 0.1632 - f2_score: 0.3353 - f2_score_1: 0.2956 - f2_score_2: 0.2575 - f2_score_3: 0.2222 - f2_score_4: 0.1642 - f2_score_5: 0.1186 - val_loss: 0.0111 - val_acc: 0.9973 - val_categorical_accuracy: 0.1585 - val_f2_score: 0.3463 - val_f2_score_1: 0.3059 - val_f2_score_2: 0.2651 - val_f2_score_3: 0.2276 - val_f2_score_4: 0.1649 - val_f2_score_5: 0.1200
# Epoch 6/200
#  - 11s - loss: 0.0111 - acc: 0.9973 - categorical_accuracy: 0.1692 - f2_score: 0.3506 - f2_score_1: 0.3116 - f2_score_2: 0.2731 - f2_score_3: 0.2379 - f2_score_4: 0.1785 - f2_score_5: 0.1324 - val_loss: 0.0109 - val_acc: 0.9973 - val_categorical_accuracy: 0.1492 - val_f2_score: 0.3540 - val_f2_score_1: 0.3126 - val_f2_score_2: 0.2736 - val_f2_score_3: 0.2369 - val_f2_score_4: 0.1767 - val_f2_score_5: 0.1291
# Epoch 7/200
#  - 11s - loss: 0.0109 - acc: 0.9973 - categorical_accuracy: 0.1776 - f2_score: 0.3643 - f2_score_1: 0.3261 - f2_score_2: 0.2882 - f2_score_3: 0.2530 - f2_score_4: 0.1907 - f2_score_5: 0.1423 - val_loss: 0.0108 - val_acc: 0.9973 - val_categorical_accuracy: 0.1757 - val_f2_score: 0.3613 - val_f2_score_1: 0.3181 - val_f2_score_2: 0.2768 - val_f2_score_3: 0.2393 - val_f2_score_4: 0.1750 - val_f2_score_5: 0.1258
# Epoch 8/200
#  - 11s - loss: 0.0107 - acc: 0.9974 - categorical_accuracy: 0.1849 - f2_score: 0.3753 - f2_score_1: 0.3375 - f2_score_2: 0.2999 - f2_score_3: 0.2642 - f2_score_4: 0.2016 - f2_score_5: 0.1517 - val_loss: 0.0107 - val_acc: 0.9974 - val_categorical_accuracy: 0.1726 - val_f2_score: 0.3623 - val_f2_score_1: 0.3197 - val_f2_score_2: 0.2784 - val_f2_score_3: 0.2423 - val_f2_score_4: 0.1795 - val_f2_score_5: 0.1342
# Epoch 9/200
#  - 11s - loss: 0.0105 - acc: 0.9974 - categorical_accuracy: 0.1909 - f2_score: 0.3861 - f2_score_1: 0.3488 - f2_score_2: 0.3113 - f2_score_3: 0.2749 - f2_score_4: 0.2122 - f2_score_5: 0.1613 - val_loss: 0.0106 - val_acc: 0.9974 - val_categorical_accuracy: 0.1875 - val_f2_score: 0.3644 - val_f2_score_1: 0.3222 - val_f2_score_2: 0.2818 - val_f2_score_3: 0.2469 - val_f2_score_4: 0.1861 - val_f2_score_5: 0.1416
# Epoch 10/200
#  - 11s - loss: 0.0103 - acc: 0.9974 - categorical_accuracy: 0.1980 - f2_score: 0.3949 - f2_score_1: 0.3580 - f2_score_2: 0.3202 - f2_score_3: 0.2847 - f2_score_4: 0.2218 - f2_score_5: 0.1689 - val_loss: 0.0105 - val_acc: 0.9974 - val_categorical_accuracy: 0.1850 - val_f2_score: 0.3736 - val_f2_score_1: 0.3344 - val_f2_score_2: 0.2957 - val_f2_score_3: 0.2617 - val_f2_score_4: 0.1997 - val_f2_score_5: 0.1505
# Epoch 11/200
#  - 11s - loss: 0.0101 - acc: 0.9974 - categorical_accuracy: 0.2036 - f2_score: 0.4035 - f2_score_1: 0.3672 - f2_score_2: 0.3299 - f2_score_3: 0.2937 - f2_score_4: 0.2293 - f2_score_5: 0.1770 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.1895 - val_f2_score: 0.3865 - val_f2_score_1: 0.3496 - val_f2_score_2: 0.3112 - val_f2_score_3: 0.2752 - val_f2_score_4: 0.2103 - val_f2_score_5: 0.1575
# Epoch 12/200
#  - 11s - loss: 0.0100 - acc: 0.9974 - categorical_accuracy: 0.2096 - f2_score: 0.4118 - f2_score_1: 0.3764 - f2_score_2: 0.3385 - f2_score_3: 0.3031 - f2_score_4: 0.2391 - f2_score_5: 0.1859 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.2005 - val_f2_score: 0.3821 - val_f2_score_1: 0.3435 - val_f2_score_2: 0.3046 - val_f2_score_3: 0.2679 - val_f2_score_4: 0.2063 - val_f2_score_5: 0.1586
# Epoch 13/200
#  - 11s - loss: 0.0099 - acc: 0.9974 - categorical_accuracy: 0.2135 - f2_score: 0.4192 - f2_score_1: 0.3837 - f2_score_2: 0.3469 - f2_score_3: 0.3111 - f2_score_4: 0.2461 - f2_score_5: 0.1914 - val_loss: 0.0104 - val_acc: 0.9974 - val_categorical_accuracy: 0.1895 - val_f2_score: 0.3902 - val_f2_score_1: 0.3535 - val_f2_score_2: 0.3169 - val_f2_score_3: 0.2837 - val_f2_score_4: 0.2196 - val_f2_score_5: 0.1659
# Epoch 14/200
#  - 11s - loss: 0.0098 - acc: 0.9975 - categorical_accuracy: 0.2189 - f2_score: 0.4249 - f2_score_1: 0.3909 - f2_score_2: 0.3541 - f2_score_3: 0.3180 - f2_score_4: 0.2534 - f2_score_5: 0.1985 - val_loss: 0.0103 - val_acc: 0.9974 - val_categorical_accuracy: 0.2000 - val_f2_score: 0.3952 - val_f2_score_1: 0.3582 - val_f2_score_2: 0.3211 - val_f2_score_3: 0.2872 - val_f2_score_4: 0.2242 - val_f2_score_5: 0.1727
# Epoch 15/200
#  - 11s - loss: 0.0096 - acc: 0.9975 - categorical_accuracy: 0.2243 - f2_score: 0.4327 - f2_score_1: 0.3982 - f2_score_2: 0.3624 - f2_score_3: 0.3267 - f2_score_4: 0.2612 - f2_score_5: 0.2056 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.1981 - val_f2_score: 0.3980 - val_f2_score_1: 0.3600 - val_f2_score_2: 0.3220 - val_f2_score_3: 0.2880 - val_f2_score_4: 0.2275 - val_f2_score_5: 0.1776
# Epoch 16/200
#  - 11s - loss: 0.0095 - acc: 0.9975 - categorical_accuracy: 0.2280 - f2_score: 0.4385 - f2_score_1: 0.4049 - f2_score_2: 0.3684 - f2_score_3: 0.3331 - f2_score_4: 0.2681 - f2_score_5: 0.2116 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2112 - val_f2_score: 0.3948 - val_f2_score_1: 0.3556 - val_f2_score_2: 0.3187 - val_f2_score_3: 0.2849 - val_f2_score_4: 0.2242 - val_f2_score_5: 0.1748
# Epoch 17/200
#  - 11s - loss: 0.0094 - acc: 0.9975 - categorical_accuracy: 0.2346 - f2_score: 0.4454 - f2_score_1: 0.4126 - f2_score_2: 0.3762 - f2_score_3: 0.3408 - f2_score_4: 0.2763 - f2_score_5: 0.2197 - val_loss: 0.0102 - val_acc: 0.9974 - val_categorical_accuracy: 0.2012 - val_f2_score: 0.4031 - val_f2_score_1: 0.3652 - val_f2_score_2: 0.3270 - val_f2_score_3: 0.2925 - val_f2_score_4: 0.2290 - val_f2_score_5: 0.1772
# Epoch 18/200
#  - 11s - loss: 0.0093 - acc: 0.9975 - categorical_accuracy: 0.2400 - f2_score: 0.4520 - f2_score_1: 0.4185 - f2_score_2: 0.3834 - f2_score_3: 0.3475 - f2_score_4: 0.2827 - f2_score_5: 0.2245 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2121 - val_f2_score: 0.4086 - val_f2_score_1: 0.3742 - val_f2_score_2: 0.3387 - val_f2_score_3: 0.3049 - val_f2_score_4: 0.2433 - val_f2_score_5: 0.1893
# Epoch 19/200
#  - 12s - loss: 0.0092 - acc: 0.9975 - categorical_accuracy: 0.2434 - f2_score: 0.4581 - f2_score_1: 0.4262 - f2_score_2: 0.3901 - f2_score_3: 0.3542 - f2_score_4: 0.2886 - f2_score_5: 0.2309 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2081 - val_f2_score: 0.4092 - val_f2_score_1: 0.3759 - val_f2_score_2: 0.3414 - val_f2_score_3: 0.3079 - val_f2_score_4: 0.2486 - val_f2_score_5: 0.1974
# Epoch 20/200
#  - 11s - loss: 0.0091 - acc: 0.9975 - categorical_accuracy: 0.2475 - f2_score: 0.4632 - f2_score_1: 0.4312 - f2_score_2: 0.3962 - f2_score_3: 0.3611 - f2_score_4: 0.2958 - f2_score_5: 0.2378 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2248 - val_f2_score: 0.4018 - val_f2_score_1: 0.3641 - val_f2_score_2: 0.3271 - val_f2_score_3: 0.2919 - val_f2_score_4: 0.2323 - val_f2_score_5: 0.1841
# Epoch 21/200
#  - 11s - loss: 0.0090 - acc: 0.9975 - categorical_accuracy: 0.2519 - f2_score: 0.4696 - f2_score_1: 0.4379 - f2_score_2: 0.4023 - f2_score_3: 0.3670 - f2_score_4: 0.3011 - f2_score_5: 0.2436 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2262 - val_f2_score: 0.4098 - val_f2_score_1: 0.3754 - val_f2_score_2: 0.3386 - val_f2_score_3: 0.3051 - val_f2_score_4: 0.2447 - val_f2_score_5: 0.1947
# Epoch 22/200
#  - 11s - loss: 0.0089 - acc: 0.9976 - categorical_accuracy: 0.2553 - f2_score: 0.4746 - f2_score_1: 0.4435 - f2_score_2: 0.4092 - f2_score_3: 0.3739 - f2_score_4: 0.3089 - f2_score_5: 0.2501 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2161 - val_f2_score: 0.4105 - val_f2_score_1: 0.3731 - val_f2_score_2: 0.3363 - val_f2_score_3: 0.3043 - val_f2_score_4: 0.2450 - val_f2_score_5: 0.1956
# Epoch 23/200
#  - 11s - loss: 0.0088 - acc: 0.9976 - categorical_accuracy: 0.2580 - f2_score: 0.4799 - f2_score_1: 0.4485 - f2_score_2: 0.4144 - f2_score_3: 0.3797 - f2_score_4: 0.3138 - f2_score_5: 0.2545 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2185 - val_f2_score: 0.4072 - val_f2_score_1: 0.3709 - val_f2_score_2: 0.3378 - val_f2_score_3: 0.3055 - val_f2_score_4: 0.2480 - val_f2_score_5: 0.1997
# Epoch 24/200
#  - 11s - loss: 0.0087 - acc: 0.9976 - categorical_accuracy: 0.2630 - f2_score: 0.4850 - f2_score_1: 0.4542 - f2_score_2: 0.4199 - f2_score_3: 0.3858 - f2_score_4: 0.3201 - f2_score_5: 0.2604 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2185 - val_f2_score: 0.4116 - val_f2_score_1: 0.3764 - val_f2_score_2: 0.3421 - val_f2_score_3: 0.3102 - val_f2_score_4: 0.2538 - val_f2_score_5: 0.2048
# Epoch 25/200
#  - 11s - loss: 0.0086 - acc: 0.9976 - categorical_accuracy: 0.2674 - f2_score: 0.4900 - f2_score_1: 0.4601 - f2_score_2: 0.4266 - f2_score_3: 0.3923 - f2_score_4: 0.3275 - f2_score_5: 0.2664 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2270 - val_f2_score: 0.4042 - val_f2_score_1: 0.3680 - val_f2_score_2: 0.3331 - val_f2_score_3: 0.3015 - val_f2_score_4: 0.2447 - val_f2_score_5: 0.1971
# Epoch 26/200
#  - 11s - loss: 0.0085 - acc: 0.9976 - categorical_accuracy: 0.2713 - f2_score: 0.4963 - f2_score_1: 0.4664 - f2_score_2: 0.4328 - f2_score_3: 0.3981 - f2_score_4: 0.3323 - f2_score_5: 0.2722 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2257 - val_f2_score: 0.4068 - val_f2_score_1: 0.3707 - val_f2_score_2: 0.3354 - val_f2_score_3: 0.3051 - val_f2_score_4: 0.2473 - val_f2_score_5: 0.2012
# Epoch 27/200
#  - 12s - loss: 0.0085 - acc: 0.9976 - categorical_accuracy: 0.2765 - f2_score: 0.5012 - f2_score_1: 0.4714 - f2_score_2: 0.4383 - f2_score_3: 0.4039 - f2_score_4: 0.3378 - f2_score_5: 0.2777 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2254 - val_f2_score: 0.4145 - val_f2_score_1: 0.3807 - val_f2_score_2: 0.3469 - val_f2_score_3: 0.3160 - val_f2_score_4: 0.2590 - val_f2_score_5: 0.2093
# Epoch 28/200
#  - 11s - loss: 0.0084 - acc: 0.9976 - categorical_accuracy: 0.2781 - f2_score: 0.5065 - f2_score_1: 0.4773 - f2_score_2: 0.4440 - f2_score_3: 0.4097 - f2_score_4: 0.3442 - f2_score_5: 0.2832 - val_loss: 0.0102 - val_acc: 0.9975 - val_categorical_accuracy: 0.2310 - val_f2_score: 0.4051 - val_f2_score_1: 0.3690 - val_f2_score_2: 0.3354 - val_f2_score_3: 0.3048 - val_f2_score_4: 0.2494 - val_f2_score_5: 0.2036
# Epoch 29/200
#  - 11s - loss: 0.0083 - acc: 0.9976 - categorical_accuracy: 0.2818 - f2_score: 0.5111 - f2_score_1: 0.4821 - f2_score_2: 0.4489 - f2_score_3: 0.4160 - f2_score_4: 0.3496 - f2_score_5: 0.2885 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2362 - val_f2_score: 0.4142 - val_f2_score_1: 0.3788 - val_f2_score_2: 0.3439 - val_f2_score_3: 0.3123 - val_f2_score_4: 0.2557 - val_f2_score_5: 0.2095
# Epoch 30/200
#  - 11s - loss: 0.0082 - acc: 0.9977 - categorical_accuracy: 0.2851 - f2_score: 0.5166 - f2_score_1: 0.4870 - f2_score_2: 0.4544 - f2_score_3: 0.4211 - f2_score_4: 0.3548 - f2_score_5: 0.2935 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2297 - val_f2_score: 0.4118 - val_f2_score_1: 0.3769 - val_f2_score_2: 0.3440 - val_f2_score_3: 0.3138 - val_f2_score_4: 0.2584 - val_f2_score_5: 0.2115
# Epoch 31/200
#  - 11s - loss: 0.0081 - acc: 0.9977 - categorical_accuracy: 0.2871 - f2_score: 0.5211 - f2_score_1: 0.4924 - f2_score_2: 0.4600 - f2_score_3: 0.4267 - f2_score_4: 0.3612 - f2_score_5: 0.2986 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2267 - val_f2_score: 0.4167 - val_f2_score_1: 0.3833 - val_f2_score_2: 0.3512 - val_f2_score_3: 0.3212 - val_f2_score_4: 0.2673 - val_f2_score_5: 0.2182
# Epoch 32/200
#  - 11s - loss: 0.0081 - acc: 0.9977 - categorical_accuracy: 0.2925 - f2_score: 0.5264 - f2_score_1: 0.4985 - f2_score_2: 0.4662 - f2_score_3: 0.4331 - f2_score_4: 0.3660 - f2_score_5: 0.3048 - val_loss: 0.0101 - val_acc: 0.9975 - val_categorical_accuracy: 0.2278 - val_f2_score: 0.4141 - val_f2_score_1: 0.3805 - val_f2_score_2: 0.3485 - val_f2_score_3: 0.3196 - val_f2_score_4: 0.2672 - val_f2_score_5: 0.2200
# Epoch 00032: early stopping

# %% [markdown]
# ### Model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.15')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.2')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.25')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.3')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.4')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
# Out:
# Best threshold is: 0.15

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
bottleneck_preds = model_vgg.predict_generator(test_generator, steps=STEP_SIZE_TEST)
preds = model.predict(bottleneck_preds)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id               attribute_ids
# 0  10023b2cc4ed5f68        121 343 369 766 1059
# 1  100fbe75ed8fd887                        1039
# 2  101b627524a04f19                  79 482 498
# 3  10234480c41284c6  13 51 483 725 776 830 1046
# 4  1023b0e2636dcea8    156 189 584 813 954 1092
# 5   1039cd6cf85845c         13 405 896 903 1092
# 6   103a5b3f83fbe88                194 813 1092
# 7  10413aaae8d6a9a2             51 147 813 1092
# 8  10423822b93a65ab                      51 147
# 9  1052bf702cb099f7                     188 671
