# %%
import os
import cv2
import math
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, fbeta_score
from keras import optimizers
from keras import backend as K
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation, BatchNormalization, GlobalAveragePooling2D

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/imet-2019-fgvc6/train.csv')
labels = pd.read_csv('../input/imet-2019-fgvc6/labels.csv')
test = pd.read_csv('../input/imet-2019-fgvc6/sample_submission.csv')

train["attribute_ids"] = train["attribute_ids"].apply(lambda x:x.split(" "))
train["id"] = train["id"].apply(lambda x: x + ".png")
test["id"] = test["id"].apply(lambda x: x + ".png")

print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
print('Number of labels: ', labels.shape[0])
display(train.head())
display(labels.head())
# Out:
# Number of train samples:  109237
# Number of test samples:  7443
# Number of labels:  1103
#                      id              attribute_ids
# 0  1000483014d91860.png            [147, 616, 813]
# 1  1000fe2e667721fe.png        [51, 616, 734, 813]
# 2  1001614cb89646ee.png                      [776]
# 3  10041eb49b297c08.png  [51, 671, 698, 813, 1092]
# 4  100501c227f8beea.png  [13, 404, 492, 903, 1093]
#    attribute_id          attribute_name
# 0             0        culture::abruzzi
# 1             1     culture::achaemenid
# 2             2         culture::aegean
# 3             3         culture::afghan
# 4             4  culture::after british

# %% [markdown]
# ### Model parameters

# %%
# Model parameters
BATCH_SIZE = 128
EPOCHS = 20
LEARNING_RATE = 0.0001
HEIGHT = 64
WIDTH = 64
CANAL = 3
N_CLASSES = labels.shape[0]
ES_PATIENCE = 3
DECAY_DROP = 0.5
DECAY_EPOCHS = 10
classes = list(map(str, range(N_CLASSES)))

# %%
def f2_score_thr(threshold=0.5):
    def f2_score(y_true, y_pred):
        beta = 2
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold), K.floatx())

        true_positives = K.sum(K.clip(y_true * y_pred, 0, 1), axis=1)
        predicted_positives = K.sum(K.clip(y_pred, 0, 1), axis=1)
        possible_positives = K.sum(K.clip(y_true, 0, 1), axis=1)

        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())

        return K.mean(((1+beta**2)*precision*recall) / ((beta**2)*precision+recall+K.epsilon()))
    return f2_score

def step_decay(epoch):
    initial_lrate = LEARNING_RATE
    drop = DECAY_DROP
    epochs_drop = DECAY_EPOCHS
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    return lrate

# %%
train_datagen=ImageDataGenerator(rescale=1./255, validation_split=0.25)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='training')

valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="../input/imet-2019-fgvc6/train",
    x_col="id",
    y_col="attribute_ids",
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="categorical",    
    classes=classes,
    target_size=(HEIGHT, WIDTH),
    subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/imet-2019-fgvc6/test",    
        x_col="id",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)
# Out:
# Found 81928 images belonging to 1103 classes.
# Found 27309 images belonging to 1103 classes.
# Found 7443 images.

# %% [markdown]
# ### Base model

# %%
base_model = VGG16(weights=None, include_top=False)
base_model.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Top model

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(2048, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(N_CLASSES, activation="sigmoid")(x)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Complete model

# %%
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
for layer in base_model.layers:
    layer.trainable = False

optimizer = optimizers.Adam(lr=LEARNING_RATE)
metrics = ["accuracy", "categorical_accuracy"]
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=ES_PATIENCE)
callbacks = [es]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              1050624
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1103)              1130575
# =================================================================
# Total params: 18,994,063
# Trainable params: 4,279,375
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# #### Train top layers

# %%
# STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
# history = model.fit_generator(generator=train_generator,
#                               steps_per_epoch=STEP_SIZE_TRAIN,
#                               validation_data=valid_generator,
#                               validation_steps=STEP_SIZE_VALID,
#                               epochs=EPOCHS,
#                               callbacks=callbacks,
#                               verbose=2)

# %% [markdown]
# ### Top model graph loss

# %%
# sns.set_style("whitegrid")
# fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


# ax1.plot(history.history['loss'], label='Train loss')
# ax1.plot(history.history['val_loss'], label='Validation loss')
# ax1.legend(loc='best')
# ax1.set_title('Loss')

# ax2.plot(history.history['acc'], label='Train Accuracy')
# ax2.plot(history.history['val_acc'], label='Validation accuracy')
# ax2.legend(loc='best')
# ax2.set_title('Accuracy')

# ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
# ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
# ax3.legend(loc='best')
# ax3.set_title('Cat Accuracy')

# plt.xlabel('Epochs')
# sns.despine()
# plt.show()

# %% [markdown]
# #### Fine-tune the complete model

# %%
# set the first 15 layers (up to the last conv block)
for layer in model.layers[:15]:
    layer.trainable = False
    
for layer in model.layers[15:]:
    layer.trainable = True

thresholds = [0.1, 0.15, 0.2, 0.25, 0.28, 0.3, 0.4, 0.5]
metrics = ["accuracy", "categorical_accuracy", f2_score_thr(0.1), f2_score_thr(0.15), f2_score_thr(0.2), 
           f2_score_thr(0.25), f2_score_thr(0.28), f2_score_thr(0.3), f2_score_thr(0.4), f2_score_thr(0.5)]
optimizer = optimizers.SGD(lr=1e-4, momentum=0.9)
lrate = LearningRateScheduler(step_decay)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=(ES_PATIENCE+10))
callbacks = [es, lrate]
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              1050624
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1103)              1130575
# =================================================================
# Total params: 18,994,063
# Trainable params: 11,358,799
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
train_generator.reset()
valid_generator.reset()

STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              epochs=EPOCHS,
                              callbacks=callbacks,
                              verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
#  - 753s - loss: 0.7003 - acc: 0.5230 - categorical_accuracy: 4.5166e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0142 - f2_score_5: 0.0141 - f2_score_6: 0.0138 - f2_score_7: 0.0134 - val_loss: 0.6808 - val_acc: 0.5748 - val_categorical_accuracy: 6.6021e-04 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0141 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0141 - val_f2_score_6: 0.0141 - val_f2_score_7: 0.0133
# Epoch 2/20
#  - 756s - loss: 0.6862 - acc: 0.5513 - categorical_accuracy: 8.4229e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0142 - f2_score_5: 0.0142 - f2_score_6: 0.0138 - f2_score_7: 0.0134 - val_loss: 0.6697 - val_acc: 0.6305 - val_categorical_accuracy: 0.0017 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0141 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0141 - val_f2_score_6: 0.0141 - val_f2_score_7: 0.0133
# Epoch 3/20
#  - 706s - loss: 0.6748 - acc: 0.5777 - categorical_accuracy: 6.8360e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0142 - f2_score_5: 0.0142 - f2_score_6: 0.0138 - f2_score_7: 0.0134 - val_loss: 0.6583 - val_acc: 0.6791 - val_categorical_accuracy: 0.0026 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0141 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0141 - val_f2_score_6: 0.0141 - val_f2_score_7: 0.0133
# Epoch 4/20
#  - 697s - loss: 0.6630 - acc: 0.6034 - categorical_accuracy: 8.0567e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0142 - f2_score_5: 0.0141 - f2_score_6: 0.0138 - f2_score_7: 0.0133 - val_loss: 0.6445 - val_acc: 0.7207 - val_categorical_accuracy: 0.0028 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0141 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0141 - val_f2_score_6: 0.0137 - val_f2_score_7: 0.0134
# Epoch 5/20
#  - 693s - loss: 0.6491 - acc: 0.6290 - categorical_accuracy: 8.0567e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0141 - f2_score_5: 0.0141 - f2_score_6: 0.0137 - f2_score_7: 0.0133 - val_loss: 0.6261 - val_acc: 0.7569 - val_categorical_accuracy: 0.0027 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0141 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0142 - val_f2_score_6: 0.0138 - val_f2_score_7: 0.0134
# Epoch 6/20
#  - 693s - loss: 0.6308 - acc: 0.6555 - categorical_accuracy: 8.7891e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0142 - f2_score_3: 0.0141 - f2_score_4: 0.0140 - f2_score_5: 0.0140 - f2_score_6: 0.0136 - f2_score_7: 0.0133 - val_loss: 0.5995 - val_acc: 0.7896 - val_categorical_accuracy: 0.0021 - val_f2_score: 0.0142 - val_f2_score_1: 0.0142 - val_f2_score_2: 0.0142 - val_f2_score_3: 0.0142 - val_f2_score_4: 0.0142 - val_f2_score_5: 0.0142 - val_f2_score_6: 0.0134 - val_f2_score_7: 0.0137
# Epoch 7/20
#  - 684s - loss: 0.6050 - acc: 0.6837 - categorical_accuracy: 8.3008e-04 - f2_score: 0.0142 - f2_score_1: 0.0142 - f2_score_2: 0.0141 - f2_score_3: 0.0140 - f2_score_4: 0.0139 - f2_score_5: 0.0138 - f2_score_6: 0.0135 - f2_score_7: 0.0133 - val_loss: 0.5570 - val_acc: 0.8209 - val_categorical_accuracy: 0.0011 - val_f2_score: 0.0141 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0142 - val_f2_score_3: 0.0141 - val_f2_score_4: 0.0138 - val_f2_score_5: 0.0137 - val_f2_score_6: 0.0128 - val_f2_score_7: 0.0143
# Epoch 8/20
#  - 683s - loss: 0.5642 - acc: 0.7161 - categorical_accuracy: 7.3242e-04 - f2_score: 0.0142 - f2_score_1: 0.0141 - f2_score_2: 0.0139 - f2_score_3: 0.0138 - f2_score_4: 0.0137 - f2_score_5: 0.0137 - f2_score_6: 0.0134 - f2_score_7: 0.0132 - val_loss: 0.4748 - val_acc: 0.8589 - val_categorical_accuracy: 2.2074e-04 - val_f2_score: 0.0142 - val_f2_score_1: 0.0142 - val_f2_score_2: 0.0138 - val_f2_score_3: 0.0139 - val_f2_score_4: 0.0135 - val_f2_score_5: 0.0131 - val_f2_score_6: 0.0126 - val_f2_score_7: 0.0138
# Epoch 9/20
#  - 677s - loss: 0.5007 - acc: 0.7575 - categorical_accuracy: 6.5918e-04 - f2_score: 0.0140 - f2_score_1: 0.0139 - f2_score_2: 0.0137 - f2_score_3: 0.0136 - f2_score_4: 0.0136 - f2_score_5: 0.0136 - f2_score_6: 0.0134 - f2_score_7: 0.0132 - val_loss: 0.3584 - val_acc: 0.9102 - val_categorical_accuracy: 1.8395e-04 - val_f2_score: 0.0139 - val_f2_score_1: 0.0137 - val_f2_score_2: 0.0133 - val_f2_score_3: 0.0127 - val_f2_score_4: 0.0123 - val_f2_score_5: 0.0123 - val_f2_score_6: 0.0140 - val_f2_score_7: 0.0155
# Epoch 10/20
#  - 677s - loss: 0.4431 - acc: 0.7935 - categorical_accuracy: 9.0332e-04 - f2_score: 0.0139 - f2_score_1: 0.0138 - f2_score_2: 0.0137 - f2_score_3: 0.0136 - f2_score_4: 0.0136 - f2_score_5: 0.0136 - f2_score_6: 0.0134 - f2_score_7: 0.0132 - val_loss: 0.2974 - val_acc: 0.9419 - val_categorical_accuracy: 1.4716e-04 - val_f2_score: 0.0139 - val_f2_score_1: 0.0136 - val_f2_score_2: 0.0127 - val_f2_score_3: 0.0123 - val_f2_score_4: 0.0129 - val_f2_score_5: 0.0136 - val_f2_score_6: 0.0149 - val_f2_score_7: 0.0159
# Epoch 11/20
#  - 674s - loss: 0.4019 - acc: 0.8176 - categorical_accuracy: 8.6670e-04 - f2_score: 0.0139 - f2_score_1: 0.0137 - f2_score_2: 0.0137 - f2_score_3: 0.0136 - f2_score_4: 0.0136 - f2_score_5: 0.0136 - f2_score_6: 0.0134 - f2_score_7: 0.0133 - val_loss: 0.2383 - val_acc: 0.9687 - val_categorical_accuracy: 1.4716e-04 - val_f2_score: 0.0136 - val_f2_score_1: 0.0130 - val_f2_score_2: 0.0123 - val_f2_score_3: 0.0138 - val_f2_score_4: 0.0141 - val_f2_score_5: 0.0144 - val_f2_score_6: 0.0170 - val_f2_score_7: 0.0149
# Epoch 12/20
#  - 671s - loss: 0.3595 - acc: 0.8411 - categorical_accuracy: 8.1787e-04 - f2_score: 0.0139 - f2_score_1: 0.0138 - f2_score_2: 0.0138 - f2_score_3: 0.0137 - f2_score_4: 0.0137 - f2_score_5: 0.0137 - f2_score_6: 0.0136 - f2_score_7: 0.0133 - val_loss: 0.1833 - val_acc: 0.9808 - val_categorical_accuracy: 1.4716e-04 - val_f2_score: 0.0135 - val_f2_score_1: 0.0125 - val_f2_score_2: 0.0139 - val_f2_score_3: 0.0149 - val_f2_score_4: 0.0158 - val_f2_score_5: 0.0163 - val_f2_score_6: 0.0162 - val_f2_score_7: 0.0151
# Epoch 13/20
#  - 670s - loss: 0.3179 - acc: 0.8631 - categorical_accuracy: 8.9112e-04 - f2_score: 0.0140 - f2_score_1: 0.0139 - f2_score_2: 0.0138 - f2_score_3: 0.0138 - f2_score_4: 0.0138 - f2_score_5: 0.0138 - f2_score_6: 0.0136 - f2_score_7: 0.0134 - val_loss: 0.1354 - val_acc: 0.9919 - val_categorical_accuracy: 1.4716e-04 - val_f2_score: 0.0127 - val_f2_score_1: 0.0141 - val_f2_score_2: 0.0156 - val_f2_score_3: 0.0177 - val_f2_score_4: 0.0195 - val_f2_score_5: 0.0198 - val_f2_score_6: 0.0158 - val_f2_score_7: 0.0019
# Epoch 14/20
#  - 676s - loss: 0.2790 - acc: 0.8829 - categorical_accuracy: 0.0010 - f2_score: 0.0142 - f2_score_1: 0.0141 - f2_score_2: 0.0141 - f2_score_3: 0.0140 - f2_score_4: 0.0140 - f2_score_5: 0.0139 - f2_score_6: 0.0139 - f2_score_7: 0.0136 - val_loss: 0.0973 - val_acc: 0.9970 - val_categorical_accuracy: 1.1037e-04 - val_f2_score: 0.0140 - val_f2_score_1: 0.0162 - val_f2_score_2: 0.0198 - val_f2_score_3: 0.0205 - val_f2_score_4: 0.0174 - val_f2_score_5: 0.0163 - val_f2_score_6: 0.0023 - val_f2_score_7: 5.3043e-05
# Epoch 15/20
#  - 674s - loss: 0.2435 - acc: 0.9002 - categorical_accuracy: 9.7656e-04 - f2_score: 0.0144 - f2_score_1: 0.0143 - f2_score_2: 0.0142 - f2_score_3: 0.0142 - f2_score_4: 0.0142 - f2_score_5: 0.0141 - f2_score_6: 0.0140 - f2_score_7: 0.0137 - val_loss: 0.0692 - val_acc: 0.9971 - val_categorical_accuracy: 1.4716e-04 - val_f2_score: 0.0162 - val_f2_score_1: 0.0224 - val_f2_score_2: 0.0203 - val_f2_score_3: 0.0119 - val_f2_score_4: 0.0051 - val_f2_score_5: 0.0030 - val_f2_score_6: 1.4150e-05 - val_f2_score_7: 0.0000e+00
# Epoch 16/20
#  - 673s - loss: 0.2128 - acc: 0.9148 - categorical_accuracy: 0.0012 - f2_score: 0.0146 - f2_score_1: 0.0145 - f2_score_2: 0.0145 - f2_score_3: 0.0145 - f2_score_4: 0.0144 - f2_score_5: 0.0143 - f2_score_6: 0.0141 - f2_score_7: 0.0137 - val_loss: 0.0501 - val_acc: 0.9971 - val_categorical_accuracy: 1.1037e-04 - val_f2_score: 0.0234 - val_f2_score_1: 0.0210 - val_f2_score_2: 0.0065 - val_f2_score_3: 9.8809e-04 - val_f2_score_4: 1.1639e-04 - val_f2_score_5: 3.4009e-05 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 17/20
#  - 672s - loss: 0.1870 - acc: 0.9268 - categorical_accuracy: 0.0011 - f2_score: 0.0150 - f2_score_1: 0.0149 - f2_score_2: 0.0148 - f2_score_3: 0.0147 - f2_score_4: 0.0147 - f2_score_5: 0.0146 - f2_score_6: 0.0143 - f2_score_7: 0.0139 - val_loss: 0.0378 - val_acc: 0.9971 - val_categorical_accuracy: 3.6790e-05 - val_f2_score: 0.0269 - val_f2_score_1: 0.0054 - val_f2_score_2: 3.9815e-04 - val_f2_score_3: 2.2337e-05 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 18/20
#  - 669s - loss: 0.1655 - acc: 0.9367 - categorical_accuracy: 0.0014 - f2_score: 0.0152 - f2_score_1: 0.0152 - f2_score_2: 0.0151 - f2_score_3: 0.0150 - f2_score_4: 0.0150 - f2_score_5: 0.0149 - f2_score_6: 0.0145 - f2_score_7: 0.0140 - val_loss: 0.0300 - val_acc: 0.9971 - val_categorical_accuracy: 2.9432e-04 - val_f2_score: 0.0101 - val_f2_score_1: 5.6878e-04 - val_f2_score_2: 2.1501e-05 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 19/20
#  - 671s - loss: 0.1471 - acc: 0.9449 - categorical_accuracy: 0.0014 - f2_score: 0.0155 - f2_score_1: 0.0155 - f2_score_2: 0.0154 - f2_score_3: 0.0153 - f2_score_4: 0.0152 - f2_score_5: 0.0151 - f2_score_6: 0.0147 - f2_score_7: 0.0141 - val_loss: 0.0253 - val_acc: 0.9971 - val_categorical_accuracy: 0.0059 - val_f2_score: 0.0015 - val_f2_score_1: 3.2398e-05 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00
# Epoch 20/20
#  - 676s - loss: 0.1356 - acc: 0.9501 - categorical_accuracy: 0.0017 - f2_score: 0.0157 - f2_score_1: 0.0157 - f2_score_2: 0.0156 - f2_score_3: 0.0155 - f2_score_4: 0.0155 - f2_score_5: 0.0154 - f2_score_6: 0.0150 - f2_score_7: 0.0144 - val_loss: 0.0237 - val_acc: 0.9971 - val_categorical_accuracy: 0.0139 - val_f2_score: 6.8699e-04 - val_f2_score_1: 7.0751e-06 - val_f2_score_2: 0.0000e+00 - val_f2_score_3: 0.0000e+00 - val_f2_score_4: 0.0000e+00 - val_f2_score_5: 0.0000e+00 - val_f2_score_6: 0.0000e+00 - val_f2_score_7: 0.0000e+00

# %% [markdown]
# ### Build complete model

# %% [markdown]
# ### Complete model graph loss

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='col', figsize=(20,7))


ax1.plot(history.history['loss'], label='Train loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history.history['acc'], label='Train Accuracy')
ax2.plot(history.history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

ax3.plot(history.history['categorical_accuracy'], label='Train Cat Accuracy')
ax3.plot(history.history['val_categorical_accuracy'], label='Validation Cat Accuracy')
ax3.legend(loc='best')
ax3.set_title('Cat Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, sharex='col', figsize=(20,7))

axes[0][0].plot(history.history['f2_score'], label='Train F2 Score')
axes[0][0].plot(history.history['val_f2_score'], label='Validation F2 Score')
axes[0][0].legend(loc='best')
axes[0][0].set_title('F2 Score threshold 0.1')

axes[0][1].plot(history.history['f2_score_1'], label='Train F2 Score')
axes[0][1].plot(history.history['val_f2_score_1'], label='Validation F2 Score')
axes[0][1].legend(loc='best')
axes[0][1].set_title('F2 Score threshold 0.15')

axes[1][0].plot(history.history['f2_score_2'], label='Train F2 Score')
axes[1][0].plot(history.history['val_f2_score_2'], label='Validation F2 Score')
axes[1][0].legend(loc='best')
axes[1][0].set_title('F2 Score threshold 0.2')

axes[1][1].plot(history.history['f2_score_3'], label='Train F2 Score')
axes[1][1].plot(history.history['val_f2_score_3'], label='Validation F2 Score')
axes[1][1].legend(loc='best')
axes[1][1].set_title('F2 Score threshold 0.25')

axes[2][0].plot(history.history['f2_score_4'], label='Train F2 Score')
axes[2][0].plot(history.history['val_f2_score_4'], label='Validation F2 Score')
axes[2][0].legend(loc='best')
axes[2][0].set_title('F2 Score threshold 0.28')

axes[2][1].plot(history.history['f2_score_5'], label='Train F2 Score')
axes[2][1].plot(history.history['val_f2_score_5'], label='Validation F2 Score')
axes[2][1].legend(loc='best')
axes[2][1].set_title('F2 Score threshold 0.3')

axes[3][0].plot(history.history['f2_score_6'], label='Train F2 Score')
axes[3][0].plot(history.history['val_f2_score_6'], label='Validation F2 Score')
axes[3][0].legend(loc='best')
axes[3][0].set_title('F2 Score threshold 0.4')

axes[3][1].plot(history.history['f2_score_7'], label='Train F2 Score')
axes[3][1].plot(history.history['val_f2_score_7'], label='Validation F2 Score')
axes[3][1].legend(loc='best')
axes[3][1].set_title('F2 Score threshold 0.5')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# ### Find best threshold value

# %%
best_thr = 0
best_thr_val = history.history['val_f2_score'][-1]
for i in range(1, len(metrics)-2):
    if best_thr_val < history.history['val_f2_score_%s' % i][-1]:
        best_thr_val = history.history['val_f2_score_%s' % i][-1]
        best_thr = i

threshold = thresholds[best_thr]
print('Best threshold is: %s' % threshold)
print('Best f2 score is: %.2f' % best_thr_val)
# Out:
# Best threshold is: 0.1
# Best f2 score is: 0.00

# %% [markdown]
# ### Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
preds = model.predict_generator(test_generator, steps=STEP_SIZE_TEST)

# %%
predictions = []
for pred_ar in preds:
    valid = ''
    for idx, pred in enumerate(pred_ar):
        if pred > threshold:
            if len(valid) == 0:
                valid += str(idx)
            else:
                valid += (' %s' % idx)
    if len(valid) == 0:
        valid = str(np.argmax(pred_ar))
    predictions.append(valid)

# %%
filenames = test_generator.filenames
results = pd.DataFrame({'id':filenames, 'attribute_ids':predictions})
results['id'] = results['id'].map(lambda x: str(x)[:-4])
results.to_csv('submission.csv',index=False)
results.head(10)
# Out:
#                  id attribute_ids
# 0  10023b2cc4ed5f68           327
# 1  100fbe75ed8fd887           739
# 2  101b627524a04f19           739
# 3  10234480c41284c6           129
# 4  1023b0e2636dcea8           327
# 5   1039cd6cf85845c           327
# 6   103a5b3f83fbe88           739
# 7  10413aaae8d6a9a2           203
# 8  10423822b93a65ab           739
# 9  1052bf702cb099f7           327
